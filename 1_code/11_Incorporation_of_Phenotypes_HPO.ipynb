# %%
# %matplotlib inline

import pandas as pd
from pathlib import Path
from biothings_client import get_client

from metapaths.tools import obo_tools as ot
from metapaths.tools.processing import expand_col_on_char, expand_split_col
from hetnet_ml.src import graph_tools as gt


data_dir = Path('../2_pipeline/00_download_data/out/').resolve()
this_name = '11_Incorporation_of_Phenotypes_HPO'
out_dir = Path('../2_pipeline/').joinpath(this_name).joinpath('out').resolve()

# %%
if not out_dir.exists():
    out_dir.mkdir(parents=True)

# %%
hp_nodes = ot.get_ontology_nodes(data_dir.joinpath('hpo.obo'))
hp_struct = ot.get_ontology_edges(data_dir.joinpath('hpo.obo'))

# %%
tab_cols = ['db', 'db_object_id', 'db_name', 'qualifier', 'hp_id', 'db_reference', 'evidence_code', 'onset_modifier', 
            'frequency', 'sex', 'modifier', 'aspect', 'date_created', 'assigned_by']

hp_anno = pd.read_csv(data_dir.joinpath('phenotype_annotation.tab'), header=None, 
                       sep='\t', dtype=str, names=tab_cols)
hp_gene = pd.read_csv(data_dir.joinpath('ALL_SOURCES_ALL_FREQUENCIES_genes_to_phenotype.txt'), 
                       sep='\t', header=None, comment='#', dtype=str,
                       names=['gene_id', 'gene_symbol', 'hp_name', 'hp_id'])

# %%
hp_name_map = hp_nodes.set_index('id')['name'].to_dict()
hp_anno['hp_name'] = hp_anno['hp_id'].map(hp_name_map)

# %%
len(hp_anno), len(hp_gene)
# Out:
# (166084, 142947)

# %%
hp_anno.head(2)
# Out:
#          db db_object_id                   db_name qualifier       hp_id  \
# 0  DECIPHER            1  Wolf-Hirschhorn Syndrome       NaN  HP:0000252
# 1  DECIPHER            1  Wolf-Hirschhorn Syndrome       NaN  HP:0001249
#
#   db_reference evidence_code onset_modifier frequency  sex modifier  \
# 0   DECIPHER:1           IEA            NaN       NaN  NaN        P
# 1   DECIPHER:1           IEA            NaN       NaN  NaN        P
#
#                      aspect  date_created assigned_by                  hp_name
# 0  WOLF-HIRSCHHORN SYNDROME  HPO:skoehler         NaN             Microcephaly
# 1  WOLF-HIRSCHHORN SYNDROME  HPO:skoehler         NaN  Intellectual disability

# %%
hp_gene.head(2)
# Out:
#   gene_id gene_symbol        hp_name       hp_id
# 0    8192        CLPP       Seizures  HP:0001250
# 1    8192        CLPP  Short stature  HP:0004322

# %% [markdown]
# ## Examine Genes
#
# Genes are using entrez gene_id, so looking for overlap to the current network should be stratightforward

# %%
hp_genes = hp_gene['gene_id'].unique()

# %%
nodes = gt.remove_colons(pd.read_csv('../2_pipeline/07_Filter_non_human_annotations/out/nodes_filt.csv', dtype=str))
nodes.query('id in @hp_genes')
# Out:
#            id                                               name label  \
# 22691       2                              alpha-2-macroglobulin  Gene
# 22693  144568                       alpha-2-macroglobulin like 1  Gene
# 22696   53947    alpha 1,4-galactosyltransferase (P blood group)  Gene
# 22699    8086                       aladin WD repeat nucleoporin  Gene
# 22708   79719            alpha and gamma adaptin binding protein  Gene
# 22715      16                             alanyl-tRNA synthetase  Gene
# 22716   57505            alanyl-tRNA synthetase 2, mitochondrial  Gene
# 22720   10157                 aminoadipate-semialdehyde synthase  Gene
# 22724      18                   4-aminobutyrate aminotransferase  Gene
# 22725      19          ATP binding cassette subfamily A member 1  Gene
# 22728   26154         ATP binding cassette subfamily A member 12  Gene
# 22731      21          ATP binding cassette subfamily A member 3  Gene
# 22732      24          ATP binding cassette subfamily A member 4  Gene
# 22733   23461          ATP binding cassette subfamily A member 5  Gene
# 22735   10347          ATP binding cassette subfamily A member 7  Gene
# 22741    8647         ATP binding cassette subfamily B member 11  Gene
# 22744    5244          ATP binding cassette subfamily B member 4  Gene
# 22746   10058  ATP binding cassette subfamily B member 6 (Lan...  Gene
# 22747      22          ATP binding cassette subfamily B member 7  Gene
# 22755    1244          ATP binding cassette subfamily C member 2  Gene
# 22759     368          ATP binding cassette subfamily C member 6  Gene
# 22763    6833          ATP binding cassette subfamily C member 8  Gene
# 22764   10060          ATP binding cassette subfamily C member 9  Gene
# 22765     215          ATP binding cassette subfamily D member 1  Gene
# 22767    5825          ATP binding cassette subfamily D member 3  Gene
# 22768    5826          ATP binding cassette subfamily D member 4  Gene
# 22776   64240          ATP binding cassette subfamily G member 5  Gene
# 22777   64241          ATP binding cassette subfamily G member 8  Gene
# 22782   26090                   abhydrolase domain containing 12  Gene
# 22800   51099                    abhydrolase domain containing 5  Gene
# ...       ...                                                ...   ...
# 47078   51663                    zinc finger RNA binding protein  Gene
# 47086   23503                zinc finger FYVE-type containing 26  Gene
# 47087  118813                zinc finger FYVE-type containing 27  Gene
# 47099    7545                                Zic family member 1  Gene
# 47100    7546                                Zic family member 2  Gene
# 47101    7547                                Zic family member 3  Gene
# 47123   10269                        zinc metallopeptidase STE24  Gene
# 47130   51364                zinc finger MYND-type containing 10  Gene
# 47131   10771                zinc finger MYND-type containing 11  Gene
# 47133   84225                zinc finger MYND-type containing 15  Gene
# 47157    7700                            zinc finger protein 141  Gene
# 47161    7707                            zinc finger protein 148  Gene
# 47290   63925                            zinc finger protein 335  Gene
# 47296   84905                            zinc finger protein 341  Gene
# 47309   22891                            zinc finger protein 365  Gene
# 47330   79797                            zinc finger protein 408  Gene
# 47331    7592                             zinc finger protein 41  Gene
# 47340   23090                            zinc finger protein 423  Gene
# 47371   84627                            zinc finger protein 469  Gene
# 47404  130557                            zinc finger protein 513  Gene
# 47478    9640                            zinc finger protein 592  Gene
# 47518   84146                            zinc finger protein 644  Gene
# 47554   57592                            zinc finger protein 687  Gene
# 47583    7552                            zinc finger protein 711  Gene
# 47611   79755                            zinc finger protein 750  Gene
# 47659  347344                             zinc finger protein 81  Gene
# 47714    9326                  zinc finger HIT-type containing 3  Gene
# 47726   22917                      zona pellucida glycoprotein 1  Gene
# 47728    7784                      zona pellucida glycoprotein 3  Gene
# 47770   57688                 zinc finger SWIM-type containing 6  Gene
#
#       tree_numbers drug_bank_ids alt_disease_ids gene_symbol  \
# 22691          NaN           NaN             NaN         A2M
# 22693          NaN           NaN             NaN       A2ML1
# 22696          NaN           NaN             NaN      A4GALT
# 22699          NaN           NaN             NaN        AAAS
# 22708          NaN           NaN             NaN       AAGAB
# 22715          NaN           NaN             NaN        AARS
# 22716          NaN           NaN             NaN       AARS2
# 22720          NaN           NaN             NaN        AASS
# 22765                106717|198062                  PA24396
# 22767         111783|202521|247310                  PA24402
# 22768                       111784                  PA24403
# 22776                       122124                  PA24411
# 22777                       122125                  PA24412
# 22782                117541|218015                  PA25738
# 22800                119288|212211              PA134891622
# ...                            ...                      ...
# 47078                119667|204689                  PA38219
# 47086                       117050              PA134904455
# 47087                       125623              PA134863310
# 47099                113377|204694                  PA37461
# 47100                113378|204695                  PA37462
# 47101                113379|204696                  PA37463
# 47123                115560|260472                  PA37466
# 47130                 119499|64827              PA134981649
# 47131                115989|211523              PA128394578
# 47133                          NaN              PA134873463
# 47157                          NaN                  PA37513
# 47161                       113501                  PA37520
# 47290                       121994                  PA38041
# 47296                       124344                  PA38076
# 47309                       116557              PA134873576
# 47330                       122894              PA134936136
# 47331                       113418                  PA37682
# 47340                       116718              PA134903681
# 47371                       124156              PA134861470
# 47404                       126240              PA134872812
# 47478                       114999  PA134918837|PA147357419
# 47518                       123913              PA134984168
# 47554                       121643              PA142670486
# 47583                       113384                  PA37702
# 47611                       122866              PA145149939
# 47659                       131424                  PA37730
# 47714                       114736                  PA36987
# 47726                          NaN                  PA37755
# 47728                       113565                  PA37757
# 47770                       121714              PA134910181
#
#                                             uni_prot_ids uniprot_id mesh_ids  \
# 22691  A0A1U7TC46|A0A2K5E7U5|A0A2K5KBI2|A0A2K6N6A9|A0...     P01023      NaN
# 22693  A0A0D9RAZ7|A0A1S3AMH8|A0A1U7S0T5|A0A1U7SWH3|A0...     A8K2U0      NaN
# 22696  A0A096N8Q2|A0A0D9SD56|A0A0S2Z5J1|A0A1S2ZRQ3|A0...     Q9NPC4      NaN
# 22699  A0A087XX44|A0A091CTK4|A0A096NFX9|A0A0P7XRK7|A0...     Q9NRG9      NaN
# 22708  A0A087XSX4|A0A091HBL0|A0A091RR32|A0A091SVE7|A0...     Q6PD74      NaN
# 22715  A0A087QNA5|A0A087YD10|A0A091HLZ9|A0A091JF69|A0...     P49588      NaN
# 22716  A0A091DVT7|A0A091FJP6|A0A091LAT9|A0A093BS06|A0...     Q5JTZ9      NaN
# 22720  A0A087VFH2|A0A091DEE2|A0A091GVL3|A0A091HV79|A0...     Q9UDR5      NaN
# 22724  A0A096NLK8|A0A0D9R8N1|A0A1S3EUJ4|A0A1S3WN71|A0...     P80404      NaN
# 22725  A0A096P0Z3|A0A0A0R2Y4|A0A0D9RFW1|A0A0N8ETW3|A0...     O95477      NaN
# 22728  A0A1S3A1T0|A0A1S3F8Z6|A0A1S3PNE6|A0A1U7T2P3|A0...     Q86UK0      NaN
# 22731  A0A087XXW3|A0A091D033|A0A096NL49|A0A0G2K1Q8|A0...     Q99758      NaN
# 22732  A0A1S3FCC2|A0A1S3WRN0|A0A1U7RPS9|A0A1U7V3J2|A0...     P78363      NaN
# 22733  A0A087RA58|A0A087VIV6|A0A091I201|A0A091KDZ7|A0...     Q8WWZ7      NaN
# 22735  A0A151P1R5|A0A1S3FP60|A0A1S3WDM6|A0A1U7RAZ5|A0...     Q8IZY2      NaN
# 22741  A0A0D9RRV8|A0A1A8AFY8|A0A1S3AR49|A0A1S3ARM6|A0...     O95342      NaN
# 47296  A0A096NUU2|A0A0R4IQE7|A0A151P6C0|A0A151P6L8|A0...     Q9BYN7      NaN
# 47309  A0A091D6G0|A0A0P6JXJ6|A0A1S2ZCV7|A0A1S2ZCW5|A0...     Q70YC5      NaN
# 47330  A0A1S2ZGR6|A0A1S3GB37|A0A1S3KT89|A0A1S3KTE7|A0...     Q9H9D4      NaN
# 47331  A0A024R1C4|A0A096N6N7|A0A1S3GRS9|A0A2I2Y594|A0...     P51814      NaN
# 47340  A0A087XBL5|A0A0D9QZC5|A0A0P6IZ70|A0A1A8AYX8|A0...     Q2M1K9      NaN
# 47371  A0A0F8D0L3|A0A1S3AAM1|A0A1S3EUT8|A0A1W5B4U3|A0...     Q96JG9      NaN
# 47404  A0A096M6I7|A0A096MFQ7|A0A096NQ32|A0A0D9RBU1|A0...     Q8N8E2      NaN
# 47478  A0A087XDF5|A0A093R066|A0A094MJN2|A0A096NN17|A0...     Q92610      NaN
# 47518  A0A096N0M9|A0A0D9S6S7|A0A1A7ZGD0|A0A1D5PEY0|A0...     Q9H582      NaN
# 47554  A0A0P6JJ90|A0A1D5PTU9|A0A1S3A7U9|A0A1S3F382|A0...     Q8N1G0      NaN
# 47583  A0A087Y3G6|A0A096MME0|A0A098KXC1|A0A098KXF5|A0...     Q9Y462      NaN
# 47611  A0A061I2Q4|A0A087R2J2|A0A087VQS6|A0A087XF48|A0...     Q32MQ0      NaN
# 47659  A0A096N7G0|A0A1S3GQ34|A0A1U7SXN2|A0A2I2Z1I9|A0...     P51508      NaN
# 47714  A0A024R0X8|A0A096P508|A0A0D9R135|A0A0F8BRC4|A0...     Q15649      NaN
# 47726  A0A1S2ZI42|A0A1S3G862|A0A1U7SEE5|A0A2R9B9H1|A0...     P60852      NaN
# 47728  A0A096N0R5|A0A1S3GER7|A0A1S3W4X9|A0A1U7Q274|A0...     P21754      NaN
# 47770  A0A1D5PX77|A0A1S3FW11|A0A1S3PFQ4|A0A1S3PFZ9|A0...     Q9HCJ5      NaN
#
#       chebi_ids
# 22691       NaN
# 22693       NaN
# 22696       NaN
# 22699       NaN
# 22708       NaN
# 22715       NaN
# 22716       NaN
# 22720       NaN
# 22724       NaN
# 22725       NaN
# 22728       NaN
# 22731       NaN
# 22732       NaN
# 22733       NaN
# 22735       NaN
# 22741       NaN
# 22744       NaN
# 22746       NaN
# 22747       NaN
# 22755       NaN
# 22759       NaN
# 22763       NaN
# 22764       NaN
# 22765       NaN
# 22767       NaN
# 22768       NaN
# 22776       NaN
# 22777       NaN
# 22782       NaN
# 22800       NaN
# ...         ...
# 47078       NaN
# 47086       NaN
# 47087       NaN
# 47099       NaN
# 47100       NaN
# 47101       NaN
# 47123       NaN
# 47130       NaN
# 47131       NaN
# 47133       NaN
# 47157       NaN
# 47161       NaN
# 47290       NaN
# 47296       NaN
# 47309       NaN
# 47330       NaN
# 47331       NaN
# 47340       NaN
# 47371       NaN
# 47404       NaN
# 47478       NaN
# 47518       NaN
# 47554       NaN
# 47583       NaN
# 47611       NaN
# 47659       NaN
# 47714       NaN
# 47726       NaN
# 47728       NaN
# 47770       NaN
#
# [4015 rows x 14 columns]

# %%
hp_gene['gene_id'].nunique()
# Out:
# 4016

# %%
node_ids = set(nodes['id'])
set(hp_gene['gene_id']) - node_ids
# Out:
# {'101928376'}

# %% [markdown]
# Only 1 gene is missing... Don't think we'll add it, but let's at least look at what it is

# %%
mg = get_client('gene')
mg.getgene(101928376, fields=['name', 'symbol', 'uniprot'])
# Out:
# {'_id': '101928376',
#  '_score': 13.905111,
#  'name': 'IL12A antisense RNA 1',
#  'symbol': 'IL12A-AS1'}

# %% [markdown]
# ## Now HP to Disease Links
#
# HP has OMIM ids for diseases... luckily our CTD network already has xrefs to OMIM for many diseases, so we will use these to merge concepts.

# %%
hp_anno.query('db == "OMIM"')['db_object_id'].nunique()
# Out:
# 7605

# %%
hp_anno['disease_id'] = hp_anno['db'] + ':' + hp_anno['db_object_id']

# %%
nodes.query('label == "Disease"')['id'].nunique()
# Out:
# 7201

# %%
mesh_to_omim = (expand_col_on_char(nodes.query('label == "Disease"'), 'alt_disease_ids', '|')
                    .dropna(subset=['alt_disease_ids'])
                    .set_index('id')['alt_disease_ids'].to_dict())

len(set(hp_anno.query('db == "OMIM"')['disease_id']) - set(mesh_to_omim.values()))
# Out:
# 4930

# %%
missing_diseases = set(hp_anno.query('db == "OMIM"')['disease_id']) - set(mesh_to_omim.values())
hp_anno.query('disease_id in @missing_diseases')['disease_id'].nunique()
# Out:
# 4930

# %%
found_diseases = set(hp_anno.query('db == "OMIM"')['disease_id']) & set(mesh_to_omim.values())
hp_to_dis = hp_anno.query('disease_id in @found_diseases').copy()

print(hp_to_dis['disease_id'].nunique())
print(len(hp_to_dis))
# Out:
# 2675
# 41319

# %%
hp_to_dis['evidence_code'].value_counts()
# Out:
# IEA    21763
# TAS    15392
# PCS     4164
# Name: evidence_code, dtype: int64

# %%
# Tons of edges, so remove the electronic annotations
hp_to_dis = hp_to_dis.query('evidence_code != "IEA"').copy()
hp_to_dis = hp_to_dis.drop_duplicates(subset=['disease_id', 'hp_id'])
hp_to_dis.head(4)
# Out:
#        db db_object_id                                            db_name  \
# 341  OMIM       100100  #100100 PRUNE BELLY SYNDROME; PBS;;ABDOMINAL M...
# 434  OMIM       101000                         NEUROFIBROMATOSIS, TYPE II
# 435  OMIM       101000                         NEUROFIBROMATOSIS, TYPE II
# 436  OMIM       101000                         NEUROFIBROMATOSIS, TYPE II
#
#       qualifier       hp_id  db_reference evidence_code onset_modifier  \
# 341         NaN  HP:0001627   OMIM:100100           TAS            NaN
# 434         NaN  HP:0000360  PMID:1484939           PCS            NaN
# 435  HP:0012833  HP:0000365  PMID:1484939           PCS            NaN
# 436         NaN  HP:0000957  PMID:1484939           PCS            NaN
#
#       frequency  sex modifier aspect   date_created assigned_by  \
# 341         NaN  NaN        P    NaN   HPO:skoehler         NaN
# 434  HP:0040284  NaN        P    NaN  HPO:probinson      12/120
# 435  HP:0040284  NaN        P    NaN  HPO:probinson      42/120
# 436  HP:0040284  NaN        P    NaN        HPO:iea         43%
#
#                        hp_name   disease_id
# 341  Abnormal heart morphology  OMIM:100100
# 434                   Tinnitus  OMIM:101000
# 435         Hearing impairment  OMIM:101000
# 436          Cafe-au-lait spot  OMIM:101000

# %% [markdown]
# So a lot of HPO Items have xrefs to either mesh or omim... thos that are already classified as dieases in our network are not of interest... So we will compare the Xrefs of HPO ids to our network and select those which do not have an xref.

# %%
hp_xrefs = expand_split_col(hp_nodes['xref'].dropna().str.split('|'))['xref'].str.replace('MSH:', 'MESH:').unique()

# %%
hp_to_xref = expand_split_col(hp_nodes.set_index('id')['xref'].dropna().str.split('|')).rename(columns={'old_idx': 'hp_id'})
(hp_to_xref[hp_to_xref['xref'].str.contains('MSH:')]['hp_id'].value_counts() > 1).sum()
# Out:
# 78

# %%
hp_to_xref['hp_id'].nunique()
# Out:
# 11686

# %%
disease_ids = nodes.query('label == "Disease"')['id'].unique()

# %%
hp_to_xref['xref'] = hp_to_xref['xref'].str.replace('MSH:', 'MESH:')
hp_disease_ids = hp_to_xref.query('xref in @disease_ids')['hp_id'].unique()
non_disease_hp = hp_to_xref.query('xref not in @disease_ids').copy()
non_disease_hp['name'] = non_disease_hp['hp_id'].map(hp_name_map)
len(non_disease_hp[non_disease_hp['xref'].str.contains('MESH:')])
# Out:
# 453

# %%
hp_to_dis = hp_to_dis.query('hp_id not in @hp_disease_ids').copy()
print(len(hp_to_dis))
print(hp_to_dis['hp_id'].nunique())
print(hp_to_dis['disease_id'].nunique())
# Out:
# 12483
# 2824
# 2245

# %%
hp_to_dis.sample(10)
# Out:
#          db db_object_id                                            db_name  \
# 54030  OMIM       602579  CONGENITAL DISORDER OF GLYCOSYLATION, TYPE Ib;...
# 50994  OMIM       601152  #601152 HEREDITARY MOTOR AND SENSORY NEUROPATH...
# 15494  OMIM       186570  #186570 TARSAL-CARPAL COALITION SYNDROME; TCC;...
# 65625  OMIM       610717        NEUTRAL LIPID STORAGE DISEASE WITH MYOPATHY
# 59048  OMIM       607595  BRAIN SMALL VESSEL DISEASE WITH OR WITHOUT OCU...
# 69285  OMIM       612718            Cerebral creatine deficiency syndrome 3
# 15499  OMIM       186570  #186570 TARSAL-CARPAL COALITION SYNDROME; TCC;...
# 39137  OMIM       273750  #273750 THREE M SYNDROME 1; 3M1;;3@M SYNDROME;...
# 59587  OMIM       607812                   CRANIOLENTICULOSUTURAL DYSPLASIA
# 53552  OMIM       602398                            #602398 DESMOSTEROLOSIS
#
#       qualifier       hp_id               db_reference evidence_code  \
# 54030       NaN  HP:0011473                OMIM:602579           TAS
# 50994       NaN  HP:0008587                OMIM:601152           TAS
# 15494       NaN  HP:0002967                OMIM:186570           PCS
# 65625       NaN  HP:0009046                OMIM:610717           TAS
# 59048       NaN  HP:0000519                OMIM:607595           TAS
# 69285       NaN  HP:0025051              PMID:20682460           PCS
# 15499       NaN  HP:0008368  OMIM:186579;PMID:11545688           PCS
# 39137       NaN  HP:0001382                OMIM:273750           TAS
# 59587       NaN  HP:0000343                OMIM:607812           TAS
# 53552       NaN  HP:0000463                OMIM:602398           TAS
#
#       onset_modifier   frequency  sex modifier  \
# 54030            NaN         NaN  NaN        P
# 50994            NaN  HP:0040283  NaN        P
# 15494            NaN  HP:0040283  NaN        P
# 65625            NaN         NaN  NaN        P
# 59048            NaN  HP:0040283  NaN        P
# 69285            NaN         NaN  NaN        P
# 15499            NaN  HP:0040282  NaN        P
# 39137            NaN         NaN  NaN        P
# 59587            NaN         NaN  NaN        P
# 53552            NaN         NaN  NaN        P
#
#                                                   aspect   date_created  \
# 54030  CONGENITAL DISORDER OF GLYCOSYLATION, TYPE IB;...   HPO:skoehler
# 50994                                                NaN  HPO:probinson
# 15494                                                NaN        HPO:iea
# 65625                                                NaN   HPO:skoehler
# 59048                                                NaN   HPO:skoehler
# 69285            CEREBRAL CREATINE DEFICIENCY SYNDROME 3   HP:probinson
# 15499                                                NaN        HPO:iea
# 39137                                                NaN  HPO:probinson
# 59587                                                NaN  HPO:probinson
# 53552                                                NaN   HPO:skoehler
#
#       assigned_by                               hp_name   disease_id
# 54030         NaN                       Villous atrophy  OMIM:602579
# 50994  HP:0040283  Mild neurosensory hearing impairment  OMIM:601152
# 15494  HP:0040283                        Cubitus valgus  OMIM:186570
# 65625         NaN                    Difficulty running  OMIM:610717
# 59048  HP:0040283                Developmental cataract  OMIM:607595
# 69285         NaN   Reduced brain creatine level by MRS  OMIM:612718
# 15499  HP:0040282                     Tarsal synostosis  OMIM:186570
# 39137         NaN                   Joint hypermobility  OMIM:273750
# 59587         NaN                         Long philtrum  OMIM:607812
# 53552         NaN                      Anteverted nares  OMIM:602398

# %%
hp_to_keep = hp_to_dis['hp_id'].unique()

# %% [markdown]
# So these are the HPO ids that we'll keep for our network...
# Not all the Gene to HP ids will be contained in this set so we need to filter a bit

# %%
hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids')['gene_id'].nunique()
# Out:
# 3951

# %%
hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids')['hp_id'].nunique()
# Out:
# 2803

# %%
len(hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids'))
# Out:
# 67367

# %% [markdown]
# ## Aggregate the new edges and save to disk

# %%
hp_to_dis_edges = hp_to_dis.rename(columns={'disease_id': 'start_id', 'hp_id': 'end_id'})
hp_to_dis_edges['start_id'] = hp_to_dis_edges['start_id'].map({v:k for k, v in mesh_to_omim.items()})
hp_to_dis_edges['type'] = 'presents_DpPH'

hp_to_dis_edges[['start_id', 'end_id', 'type']].head(2)
# Out:
#          start_id      end_id           type
# 443  MESH:D016518  HP:0007935  presents_DpPH
# 445  MESH:D016518  HP:0009590  presents_DpPH

# %%
hp_to_gene_edges = hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids').copy()
hp_to_gene_edges = hp_to_gene_edges.rename(columns={'hp_id': 'start_id', 'gene_id': 'end_id'})
hp_to_gene_edges['type'] = 'associated_with_PHawG'

hp_to_gene_edges[['start_id', 'end_id', 'type']].head(2)
# Out:
#      start_id end_id                   type
# 1  HP:0004322   8192  associated_with_PHawG
# 2  HP:0000786   8192  associated_with_PHawG

# %%
all_edges = pd.concat([hp_to_dis_edges[['start_id', 'end_id', 'type']], 
                       hp_to_gene_edges[['start_id', 'end_id', 'type']]], ignore_index=True)
all_edges.head(2)
# Out:
#        start_id      end_id           type
# 0  MESH:D016518  HP:0007935  presents_DpPH
# 1  MESH:D016518  HP:0009590  presents_DpPH

# %%
edge_ids = set(all_edges['start_id']).union(set(all_edges['end_id']))
hp_nodes_filt = hp_nodes.query('id in @edge_ids')[['id', 'name']]
hp_nodes_filt['label'] = 'Phenotype'

# %%
all_edges.to_csv(out_dir.joinpath('edges.csv'), index=False)
hp_nodes_filt.to_csv(out_dir.joinpath('nodes.csv'), index=False)
