# %% [markdown]
# # Query WikiData to get Biomedical Entities
#
# We will get the nodes (and later some edges) for our biomedical graph from WikiData

# %%
import pandas as pd
from pathlib import Path
from data_tools.df_processing import char_combine_iter
from data_tools.wiki import node_query_pipeline

# %%
nodes = []

# %% [markdown]
# # Diseases

# %%
q = """ SELECT DISTINCT ?disease ?diseaseLabel ?umlscui ?snomed_ct ?doid ?mesh ?mondo ?omim ?orpha
        WHERE {

          # Initial typing for Disease 
          # Either instance of Disease of has a Disease Ontology ID
          {?disease wdt:P31 wd:Q12136}UNION{?disease wdt:P699 ?doid}.

          OPTIONAL {?disease wdt:P2892 ?umlscui .}
          OPTIONAL {?disease wdt:P5806 ?snomed_ct. }
          OPTIONAL {?disease wdt:P699 ?doid. }
          OPTIONAL {?disease wdt:P486 ?mesh. }
          OPTIONAL {?disease wdt:P5270 ?mondo. }
          OPTIONAL {?disease wdt:P492 ?omim. }
          OPTIONAL {?disease wdt:P1550 ?orpha. }

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
dis_curi_map = {'umlscui': 'UMLS', 'snomed_ct': 'SNOMED', 'mesh': 'MESH', 
                'doid': 'DOID', 'mondo': 'MONDO', 'omim': 'OMIM', 'orpha': 'ORPHA'}

res = node_query_pipeline(q, dis_curi_map, 'disease')
nodes.append(res)
nodes[0].head()
# Out:
#          id                                               name    label  \
# 0  Q1002195  autosomal recessive limb-girdle muscular dystr...  Disease
# 1  Q1003534                                    bulbar syndrome  Disease
# 2  Q1004647                                 bullous pemphigoid  Disease
# 3  Q1016288                             buried bumper syndrome  Disease
# 4  Q1016605                                   Burkitt lymphoma  Disease
#
#                                                xrefs
# 0  DOID:0110297|MONDO:0012248|OMIM:609308|UMLS:C1...
# 1
# 2  DOID:8506|MESH:D010391|MONDO:0019082|UMLS:C003...
# 3
# 4   DOID:8584|MESH:D002051|OMIM:113970|UMLS:C0006413

# %% [markdown]
# # Compounds

# %%
q = """SELECT DISTINCT ?compound ?compoundLabel ?kegg_drug ?chebi ?drugbank_id ?umlscui ?chembl_id ?unii ?ikey ?pubchem_cid ?rxnorm ?mesh_supplemental_record_ui ?mesh_descriptor_ui
        WHERE {

          # Initial typing for Compound
          # ?compound wdt:P31 wd:Q11173 .

          OPTIONAL { ?compound wdt:P665 ?kegg_drug .}
          OPTIONAL { ?compound wdt:P683 ?chebi .}
          OPTIONAL { ?compound wdt:P715 ?drugbank_id .}
          OPTIONAL { ?compound wdt:P2892 ?umlscui .}
          OPTIONAL { ?compound wdt:P592 ?chembl_id .}
          OPTIONAL { ?compound wdt:P652 ?unii .}
          OPTIONAL { ?compound wdt:P3350 ?ikey .}
          OPTIONAL { ?compound wdt:P662 ?pubchem_cid .}
          OPTIONAL { ?compound wdt:P3345 ?rxnorm .}
          OPTIONAL { ?compound wdt:P6680 ?mesh_supplemental_record_ui .}
          OPTIONAL { ?compound wdt:P486 ?mesh_descriptor_ui .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
chem_curi_map = {'unii': 'UNII', 
    'rxnorm': 'RxCUI', 
    'drugbank_id': 'DB', 
    'umlscui': 'UMLS', 
    'chebi': 'CHEBI', 
    'chembl_id': 'CHEMBL',
    'kegg_drug': 'KEGG', 
    'ikey': 'IKEY', 
    'pubchem_cid': 'PCID', 
    'mesh_supplemental_record_ui': 'MESH', 
    'mesh_descriptor_ui': 'MESH'}

res = node_query_pipeline(q, chem_curi_map, 'compound')
nodes.append(res)
nodes[1].head()
# Out:
#          id                  name     label  \
# 0  Q1002152     fluoroiodomethane  Compound
# 1  Q1002165           fluticasone  Compound
# 2  Q1003185            fosfestrol  Compound
# 3  Q1003526  (S)-(+)-bulbocapnine  Compound
# 4  Q1007138            gabaculine  Compound
#
#                                                xrefs
# 0                                      PCID:13981373
# 1  CHEBI:5134|CHEMBL:CHEMBL1201396|KEGG:C07815|KE...
# 2  CHEBI:4532|CHEMBL:CHEMBL1200598|KEGG:C08145|KE...
# 3  CHEBI:3211|CHEMBL:CHEMBL157912|KEGG:C09367|PCI...
# 4         CHEBI:29585|CHEMBL:CHEMBL1394922|PCID:3445

# %% [markdown]
# # Phenotype

# %%
q = """SELECT DISTINCT ?phenotype ?phenotypeLabel ?hpo ?mesh ?omim ?snomed
        WHERE {

          # Initial typing for phenotype
          {?phenotype wdt:P31 wd:Q169872.}UNION{?phenotype wdt:P3841 ?hpo}

          # Xrefs associated with phenotypes
          OPTIONAL {?phenotype wdt:P3841 ?hpo .}
          OPTIONAL {?phenotype wdt:P486 ?mesh . }
          OPTIONAL {?phenotype wdt:P492 ?omim . }
          OPTIONAL {?phenotype wdt:P5806 ?snomed . }

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'mesh': 'MESH', 'omim': 'OMIM', 'hpo':'HP', 'snomed': 'SNOMED'}, 'phenotype')
nodes.append(res)
nodes[2].head()
# Out:
#           id                 name      label  \
# 0   Q1016605     Burkitt lymphoma  Phenotype
# 1    Q101971                 wart  Phenotype
# 2    Q101991         inflammation  Phenotype
# 3  Q10265550  acid–base imbalance  Phenotype
# 4   Q1027995     pyloric stenosis  Phenotype
#
#                                  xrefs
# 0  HP:0030080|MESH:D002051|OMIM:113970
# 1              HP:0200043|MESH:D014860
# 2                         MESH:D007249
# 3              HP:0004360|MESH:D000137
# 4              HP:0002021|MESH:D011707

# %% [markdown]
# # Gene
#
# Genes are too numerous and will require filtering to a single taxon in order for the query to finish successfully.
#
# For now we will only extract human genes, but in the future we will do the same for infectious taxa.

# %%
q = """SELECT DISTINCT ?gene ?geneLabel ?entrez ?symbol ?hgnc ?omim ?ensembl
        WHERE {{

          # Initial typing for Gene
          # ?gene wdt:P31 wd:Q7187.
          # ?gene wdt:P703 wd:{tax}.

          OPTIONAL{{?gene wdt:P351 ?entrez .}}
          OPTIONAL{{?gene wdt:P353 ?symbol .}}
          OPTIONAL{{?gene wdt:P354 ?hgnc .}}
          OPTIONAL{{?gene wdt:P492 ?omim .}}
          OPTIONAL{{?gene wdt:P594 ?ensembl .}}

          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }}
        }}"""

human_tax_wd_id = 'Q15978631' 
q = q.format(tax=human_tax_wd_id)

# %%
gene_curi_map = {'entrez': 'NCBIGene', 'symbol': 'SYM', 'hgnc':'HGNC', 'omim':'OMIM', 'ensembl':'ENSG'}
res = node_query_pipeline(q, gene_curi_map, 'gene')
nodes.append(res)
nodes[3].head()
# Out:
#           id      name label  \
# 0   Q1022703  ZMPSTE24  Gene
# 1   Q1145906     HADHA  Gene
# 2   Q1161264     ETFDH  Gene
# 3   Q1181014      DNM1  Gene
# 4  Q11868650     SPEF2  Gene
#
#                                                xrefs
# 0  ENSG:ENSG00000084073|HGNC:12877|NCBIGene:10269...
# 1  ENSG:ENSG00000084754|HGNC:4801|NCBIGene:3030|O...
# 2  ENSG:ENSG00000171503|HGNC:3483|NCBIGene:2110|O...
# 3  ENSG:ENSG00000106976|HGNC:2972|NCBIGene:1759|O...
# 4  ENSG:ENSG00000152582|HGNC:26293|NCBIGene:79925...

# %% [markdown]
# # Protein

# %%
q = """SELECT DISTINCT ?protein ?proteinLabel ?uniprot
        WHERE {{

          # Initial typing for Protein
          # ?protein wdt:P31 wd:Q8054.
          # ?protein wdt:P703 wd:{tax}.

          OPTIONAL{{?protein wdt:P352 ?uniprot .}}
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }}
        }}"""
q = q.format(tax=human_tax_wd_id)

# %%
res = node_query_pipeline(q, {'uniprot':'UniProt'}, 'protein')
nodes.append(res)
nodes[4].head()
# Out:
#          id                                name    label           xrefs
# 0  Q1024612    C-X-C motif chemokine receptor 5  Protein  UniProt:P32302
# 1  Q1032902   Mucin 16, cell surface associated  Protein  UniProt:Q8WXI7
# 2  Q1056532  CD44 molecule (Indian blood group)  Protein  UniProt:P16070
# 3  Q1058190                        CD9 molecule  Protein  UniProt:P21926
# 4  Q1069599       C-C motif chemokine ligand 17  Protein  UniProt:Q92583

# %% [markdown]
# # Pathway

# %%
q = """SELECT DISTINCT ?pathway ?pathwayLabel ?react ?wpid
        WHERE {

          # Initial typing for Pathway
          # ?pathway wdt:P31 wd:Q4915012 .

          OPTIONAL{?pathway wdt:P3937 ?react .}
          OPTIONAL{?pathway wdt:P2410 ?wpid .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'react':'REACT', 'wpid':'WP'}, 'pathway')
nodes.append(res)
nodes[5].head()
# Out:
#           id                                   name    label xrefs
# 0  Q14859896  cellular amino acid metabolic process  Pathway
# 1  Q14864262              protein metabolic process  Pathway
# 2  Q14866112            apoptotic signaling pathway  Pathway
# 3   Q1502576                gene regulatory network  Pathway
# 4    Q210973                         cell signaling  Pathway

# %% [markdown]
# # Molecular Function

# %%
q = """SELECT DISTINCT ?molecular_function ?molecular_functionLabel ?goid
        WHERE {

          # Initial typing for molecular Function
          # ?molecular_function wdt:P31 wd:Q14860489 .
          # ?molecular_function wdt:P686 ?goid

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'molecular_function')
nodes.append(res)
nodes[6].head()
# Out:
#           id                                      name               label  \
# 0   Q1012651                   ribonuclease P activity  Molecular Function
# 1  Q13667380                         metal ion binding  Molecular Function
# 2  Q13667398     lipoprotein particle receptor binding  Molecular Function
# 3  Q14326094  protein serine/threonine kinase activity  Molecular Function
# 4  Q14326101            serine-type peptidase activity  Molecular Function
#
#         xrefs
# 0  GO:0004526
# 1  GO:0046872
# 2  GO:0070325
# 3  GO:0004674
# 4  GO:0008236

# %% [markdown]
# # Biological Process

# %%
q = """SELECT DISTINCT ?biological_process ?biological_processLabel ?goid
        WHERE {

          # Initial typing for molecular Function
          # ?biological_process wdt:P31 wd:Q2996394 .
          # ?biological_process wdt:P686 ?goid

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'biological_process')
nodes.append(res)
nodes[7].head()
# Out:
#           id                          name               label       xrefs
# 0      Q1057                    metabolism  Biological Process  GO:0008152
# 1    Q105726                     urination  Biological Process  GO:0060073
# 2   Q1067506              vasoconstriction  Biological Process  GO:0042310
# 3   Q1068809         cell cycle checkpoint  Biological Process  GO:0000075
# 4  Q10746904  intramembranous ossification  Biological Process  GO:0001957

# %% [markdown]
# # Cellular Component

# %%
q = """SELECT DISTINCT ?cellular_component ?cellular_componentLabel ?goid
    WHERE {

      # Initial typing for Cellular Component
      # ?cellular_component wdt:P31 wd:Q5058355 .
      # ?cellular_component wdt:P686 ?goid

      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
    }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'cellular_component')
nodes.append(res)
nodes[8].head()
# Out:
#          id                  name               label       xrefs
# 0  Q1051872               caveola  Cellular Component  GO:0005901
# 1  Q1065756            melanosome  Cellular Component  GO:0042470
# 2  Q1134046           plasmodesma  Cellular Component  GO:0009506
# 3  Q1136436             costamere  Cellular Component  GO:0043034
# 4  Q1140236  mitochondrial crista  Cellular Component  GO:0030061

# %% [markdown]
# # Anatomy

# %%
q = """SELECT DISTINCT ?anatomy ?anatomyLabel ?uberon ?mesh
        WHERE {

          # Anatomical Strucutres
          # ?anatomy wdt:P1554 ?uberon
          
          OPTIONAL{?anatomy wdt:P486 ?mesh .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'uberon':'UBERON', 'mesh': 'MESH'}, 'anatomy')
nodes.append(res)
nodes[9].head()
# Out:
#          id                                       name    label  \
# 0  Q1001337  Mesencephalic nucleus of trigeminal nerve  Anatomy
# 1  Q1002789                posterior ethmoidal foramen  Anatomy
# 2  Q1003805                           Nucleus ambiguus  Anatomy
# 3   Q101004                                      aorta  Anatomy
# 4  Q1029907                                    stomach  Anatomy
#
#                          xrefs
# 0               UBERON:0001718
# 1               UBERON:0018654
# 2               UBERON:0001719
# 3  MESH:D001011|UBERON:0000947
# 4  MESH:D013270|UBERON:0000945

# %% [markdown]
# # Put them all together

# %%
nodes = pd.concat(nodes, sort=False, ignore_index=True)
len(nodes)
# Out:
# 419648

# %%
nodes['id'].nunique()
# Out:
# 418518

# %%
nodes[nodes['id'].duplicated(keep=False)].sort_values('id').head(50)
# Out:
#                id                        name      label  \
# 4        Q1016605            Burkitt lymphoma    Disease
# 281782   Q1016605            Burkitt lymphoma  Phenotype
# 281783    Q101971                        wart  Phenotype
# 9         Q101971                        wart    Disease
# 20       Q1027995            pyloric stenosis    Disease
# 281786   Q1027995            pyloric stenosis  Phenotype
# 32       Q1036696                 hypothermia    Disease
# 281791   Q1036696                 hypothermia  Phenotype
# 281792  Q10434599                  bradyopsia  Phenotype
# 36      Q10434599                  bradyopsia    Disease
# 281793   Q1047559          agammaglobulinemia  Phenotype
# 40       Q1047559          agammaglobulinemia    Disease
# 45       Q1049655                  paraplegia    Disease
# 281795   Q1049655                  paraplegia  Phenotype
# 46       Q1049881               retinoschisis    Disease
# 281796   Q1049881               retinoschisis  Phenotype
# 281799   Q1053824             Raynaud disease  Phenotype
# 55       Q1053824             Raynaud disease    Disease
# 59       Q1054718              kidney disease    Disease
# 281800   Q1054718              kidney disease  Phenotype
# 281801    Q105688                     hypoxia  Phenotype
# 64        Q105688                     hypoxia    Disease
# 281804   Q1061988                 Flail chest  Phenotype
# 71       Q1061988                 Flail chest    Disease
# 281805   Q1063085      neurogenic arthropathy  Phenotype
# 72       Q1063085      neurogenic arthropathy    Disease
# 78       Q1068997                   cheilitis    Disease
# 281807   Q1068997                   cheilitis  Phenotype
# 82       Q1071707  Arnold-Chiari malformation    Disease
# 281809   Q1071707  Arnold-Chiari malformation  Phenotype
# 84       Q1072420   primary biliary cirrhosis    Disease
# 281810   Q1072420   primary biliary cirrhosis  Phenotype
# 281811   Q1072716              Mongolian spot  Phenotype
# 85       Q1072716              Mongolian spot    Disease
# 86      Q10748814              megalencephaly    Disease
# 281812  Q10748814              megalencephaly  Phenotype
# 281813   Q1075923                 cholestasis  Phenotype
# 89       Q1075923                 cholestasis    Disease
# 90       Q1076053             chondroblastoma    Disease
# 281814   Q1076053             chondroblastoma  Phenotype
# 281815   Q1076078                   chondroma  Phenotype
# 93       Q1076078                   chondroma    Disease
# 281816   Q1076087              chondrosarcoma  Phenotype
# 95       Q1076087              chondrosarcoma    Disease
# 96       Q1076389                    chordoma    Disease
# 281817   Q1076389                    chordoma  Phenotype
# 281818   Q1076421           choreatic disease  Phenotype
# 97       Q1076421           choreatic disease    Disease
# 98       Q1076481             choriocarcinoma    Disease
# 281819   Q1076481             choriocarcinoma  Phenotype
#
#                                                     xrefs
# 4        DOID:8584|MESH:D002051|OMIM:113970|UMLS:C0006413
# 281782                HP:0030080|MESH:D002051|OMIM:113970
# 281783                            HP:0200043|MESH:D014860
# 9                              MESH:D014860|UMLS:C3665596
# 20                  DOID:12639|MESH:D011707|UMLS:C0034194
# 281786                            HP:0002021|MESH:D011707
# 32                             MESH:D007035|UMLS:C0020672
# 281791                            HP:0002045|MESH:D007035
# 281792                HP:0030511|MESH:C564243|OMIM:608415
# 36      DOID:0050335|MESH:C564243|MONDO:0012033|OMIM:6...
# 281793  HP:0004313|HP:0004432|MESH:D000361|OMIM:601495...
# 40      DOID:2583|MESH:D000361|MONDO:0015977|OMIM:6014...
# 45      DOID:607|MESH:D010264|MONDO:0003757|UMLS:C0030...
# 281795                            HP:0001258|MESH:D010264
# 46      DOID:8465|MESH:D041441|MONDO:0004579|UMLS:C015...
# 281796                            HP:0030502|MESH:D041441
# 281799                HP:0030880|MESH:D011928|OMIM:179600
# 55      DOID:10300|MESH:D011928|OMIM:179600|UMLS:C0034...
# 59      DOID:557|MESH:D007674|MONDO:0005240|UMLS:C0022...
# 281800                 HP:0000077|HP:0000112|MESH:D007674
# 281801                            HP:0012418|MESH:D000860
# 64                             MESH:D000860|UMLS:C0700292
# 281804                            HP:0030207|MESH:D005409
# 71               MESH:D005409|UMLS:C0016196|UMLS:C0231852
# 281805                            HP:0002821|MESH:D001177
# 72      DOID:14286|MESH:D001177|MONDO:0001935|UMLS:C00...
# 78      DOID:1762|MESH:D002613|MONDO:0002102|UMLS:C000...
# 281807                            HP:0100825|MESH:D002613
# 82      MESH:D001139|MONDO:0000115|MONDO:0008816|OMIM:...
# 281809                HP:0002308|MESH:D001139|OMIM:207950
# 84      DOID:12236|MESH:D008105|MONDO:0005388|OMIM:109...
# 281810  HP:0002613|MESH:D008105|OMIM:109720|OMIM:61300...
# 281811                            HP:0011369|MESH:D049328
# 85      DOID:4702|MESH:D049328|MONDO:0006582|UMLS:C026...
# 86      MESH:D058627|MONDO:0007961|OMIM:155350|UMLS:C0...
# 281812                HP:0001355|MESH:D058627|OMIM:155350
# 281813                            HP:0001396|MESH:D002779
# 89      DOID:13580|MESH:D002779|MONDO:0001751|UMLS:C00...
# 90      DOID:2649|MESH:D002804|MONDO:0004997|UMLS:C000...
# 281814                            HP:0030432|MESH:D002804
# 281815                            HP:0030038|MESH:D002812
# 93      DOID:2602|MESH:D002812|MONDO:0002360|UMLS:C093...
# 281816                HP:0006765|MESH:D002813|OMIM:215300
# 95      DOID:3371|MESH:D002813|MONDO:0008977|OMIM:2153...
# 96      DOID:3302|MESH:D002817|MONDO:0008978|OMIM:2154...
# 281817                HP:0010762|MESH:D002817|OMIM:215400
# 281818    HP:0002072|MESH:D002819|OMIM:118700|OMIM:215450
# 97      DOID:12859|MESH:D002819|MONDO:0007324|OMIM:118...
# 98      DOID:3594|MESH:D002822|MONDO:0005207|UMLS:C000...
# 281819                            HP:0100768|MESH:D002822

# %%
nodes[nodes['id'].duplicated(keep=False)].sort_values('id').tail(50)
# Out:
#              id                           name      label  \
# 283694  Q943897                  gastroparesis  Phenotype
# 15370   Q943897                  gastroparesis    Disease
# 283697  Q945238          peripheral neuropathy  Phenotype
# 15374   Q945238          peripheral neuropathy    Disease
# 283698  Q947813               encephalomalacia  Phenotype
# 15378   Q947813               encephalomalacia    Disease
# 15383   Q950591                        scotoma    Disease
# 283700  Q950591                        scotoma  Phenotype
# 15384   Q950838                      germinoma    Disease
# 283701  Q950838                      germinoma  Phenotype
# 15388   Q954625       myelodysplastic syndrome    Disease
# 283702  Q954625       myelodysplastic syndrome  Phenotype
# 283703  Q954674         iron deficiency anemia  Phenotype
# 15389   Q954674         iron deficiency anemia    Disease
# 15390   Q954831                   prolactinoma    Disease
# 283704  Q954831                   prolactinoma  Phenotype
# 283705  Q955454                     Coxa valga  Phenotype
# 15391   Q955454                     Coxa valga    Disease
# 15393   Q957751          XY gonadal dysgenesis    Disease
# 283706  Q957751          XY gonadal dysgenesis  Phenotype
# 283707  Q958797                    scleroderma  Phenotype
# 15394   Q958797                    scleroderma    Disease
# 283709  Q961331                 pilonidal cyst  Phenotype
# 15398   Q961331                 pilonidal cyst    Disease
# 283712  Q964920  Gingival recession, localised  Phenotype
# 15400   Q964920  Gingival recession, localised    Disease
# 283713  Q966052                 cryptorchidism  Phenotype
# 15401   Q966052                 cryptorchidism    Disease
# 15406   Q970208                  liver failure    Disease
# 283715  Q970208                  liver failure  Phenotype
# 283716  Q972514                 optic neuritis  Phenotype
# 15408   Q972514                 optic neuritis    Disease
# 15409   Q973524              spondylolisthesis    Disease
# 283717  Q973524              spondylolisthesis  Phenotype
# 15412   Q975182            Pelger-Huet anomaly    Disease
# 283720  Q975182            Pelger-Huet anomaly  Phenotype
# 15413   Q975705    gastric mucosal hypertrophy    Disease
# 283721  Q975705    gastric mucosal hypertrophy  Phenotype
# 283722  Q976163                 polyhydramnios  Phenotype
# 15414   Q976163                 polyhydramnios    Disease
# 15415   Q976388                 acute leukemia    Disease
# 283723  Q976388                 acute leukemia  Phenotype
# 283724  Q977787             gallbladder cancer  Phenotype
# 15417   Q977787             gallbladder cancer    Disease
# 15420   Q979168                 cerebral edema    Disease
# 283725  Q979168                 cerebral edema  Phenotype
# 283728  Q994859                 homocystinuria  Phenotype
# 15431   Q994859                 homocystinuria    Disease
# 15432   Q994942                        bruxism    Disease
# 283729  Q994942                        bruxism  Phenotype
#
#                                                     xrefs
# 283694            HP:0002578|MESH:D018589|OMIM:MTHU005170
# 15370   DOID:11914|MESH:D018589|MONDO:0006769|OMIM:MTH...
# 283697                            HP:0009830|MESH:D010523
# 15374   DOID:574|MESH:D010523|MONDO:0020126|UMLS:C0031...
# 283698                            HP:0040197|MESH:D004678
# 15378   DOID:2034|MESH:D004678|MONDO:0006741|UMLS:C001...
# 15383   DOID:9335|MESH:D012607|MONDO:0004758|UMLS:C002...
# 283700                            HP:0000575|MESH:D012607
# 15384   DOID:3304|MESH:D018237|MONDO:0002598|UMLS:C020...
# 283701                            HP:0100620|MESH:D018237
# 15388   DOID:0050908|MESH:D009190|MONDO:0018881|OMIM:6...
# 283702                HP:0002863|MESH:D009190|OMIM:614286
# 283703                            HP:0001891|MESH:D018798
# 15389   DOID:11758|MESH:D018798|MONDO:0001356|UMLS:C00...
# 15390   DOID:5394|MESH:D015175|MONDO:0010911|OMIM:6006...
# 283704                HP:0006767|MESH:D015175|OMIM:600634
# 283705                            HP:0002673|MESH:D060906
# 15391            MESH:D060906|UMLS:C0239137|UMLS:C3549698
# 15393   DOID:14448|MESH:D006061|OMIM:154230|OMIM:23342...
# 283706  HP:0000037|MESH:D006061|OMIM:154230|OMIM:23342...
# 283707                                         HP:0100324
# 15394                              DOID:419|UMLS:C0011644
# 283709                HP:0010769|MESH:D010864|OMIM:173000
# 15398   MESH:D010864|MONDO:0008249|OMIM:173000|UMLS:C0...
# 283712                            HP:0030816|MESH:D005889
# 15400   DOID:1134|MESH:D005889|UMLS:C0017572|UMLS:C026...
# 283713                HP:0000028|MESH:D003456|OMIM:219050
# 15401   DOID:11383|MESH:D003456|MONDO:0009047|OMIM:219...
# 15406                          MESH:D017093|UMLS:C0085605
# 283715                            HP:0001399|MESH:D017093
# 283716                 HP:0100653|HP:0100654|MESH:D009902
# 15408   DOID:1210|MESH:D009902|MONDO:0005885|UMLS:C002...
# 15409   DOID:6682|MESH:D013168|MONDO:0008475|OMIM:1842...
# 283717                HP:0003302|MESH:D013168|OMIM:184200
# 15412   DOID:9631|MESH:D010381|MONDO:0008214|OMIM:1694...
# 283720                HP:0011447|MESH:D010381|OMIM:169400
# 15413   DOID:8757|MESH:D005758|MONDO:0007652|OMIM:1372...
# 283721                HP:0005246|MESH:D005758|OMIM:137280
# 283722                            HP:0001561|MESH:D006831
# 15414   DOID:8488|MESH:D006831|MONDO:0004585|UMLS:C002...
# 15415   DOID:12603|MESH:C564112|MONDO:0010643|OMIM:308...
# 283723                HP:0002488|MESH:C564112|OMIM:308960
# 283724                                         HP:0100575
# 15417   DOID:3121|MONDO:0005411|UMLS:C0016978|UMLS:C01...
# 15420   DOID:4724|MESH:D001929|MONDO:0006684|UMLS:C000...
# 283725                            HP:0002181|MESH:D001929
# 283728    HP:0002156|MESH:D006712|OMIM:236200|OMIM:236250
# 15431   DOID:9263|MESH:D006712|MONDO:0004737|OMIM:2362...
# 15432   DOID:2846|MESH:D002012|MONDO:0002443|UMLS:C000...
# 283729                            HP:0003763|MESH:D002012

# %%
nodes['label'].value_counts()
# Out:
# Compound              266348
# Gene                   58919
# Biological Process     30290
# Protein                25578
# Disease                15434
# Molecular Function     11316
# Cellular Component      4281
# Pathway                 3026
# Anatomy                 2508
# Phenotype               1948
# Name: label, dtype: int64

# %% [markdown]
# ## Save

# %%
this_name = '01a_WikiData_Nodes'
out_dir = Path('../2_pipeline/').joinpath(this_name, 'out')

# Make the output directory if doesn't already exist
out_dir.mkdir(parents=True, exist_ok=True)

nodes.to_csv(out_dir.joinpath('nodes.csv'), index=False)
