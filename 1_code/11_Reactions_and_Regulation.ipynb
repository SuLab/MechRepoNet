# %% [markdown]
# # Reactions and Regulation
#
# We started with reactions as their own nodes... so if a Compound regulates another compound through a action on a reaction the path was represend like this (Compound 1) -[negatively regulates]- (Reaction) -[has_part]- (Compound 2).  As reactions are human abstractoins of chemical-chemical interactions, we feel it is better to represent these interactions as direct relationships between (Compound 1) and (Compound 2).  Therefore we will be merging different concepts across the reaction node to better represent these direct relationships

# %%
import pandas as pd
from pathlib import Path

from data_tools import df_processing as dfp
from data_tools import graphs as gt

from wikidataintegrator.wdi_core import WDItemEngine
# Out:
# /opt/mmayers/software/anaconda3/envs/ml/lib/python3.6/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
rhea_react = pd.read_csv('ftp://ftp.expasy.org/databases/rhea/tsv/rhea2reactome.tsv', sep='\t')
rhea_react.head(2)
# Out:
#    RHEA_ID DIRECTION  MASTER_ID               ID
# 0    10041        LR      10040   R-HSA-176606.2
# 1    10041        LR      10040  R-HSA-8953499.2

# %%
rhea_react.columns = [c.lower() for c in rhea_react.columns]
rhea_react['rhea_id'] = 'RHEA:' + rhea_react['rhea_id'].astype(str)
rhea_react['id'] = 'REACT:' + rhea_react['id']
rhea_react.head(2)
# Out:
#       rhea_id direction  master_id                     id
# 0  RHEA:10041        LR      10040   REACT:R-HSA-176606.2
# 1  RHEA:10041        LR      10040  REACT:R-HSA-8953499.2

# %%
rhea_react['spl_id'] = rhea_react['id'].apply(lambda s: s.split('.')[0])

# %%
rhea_uniprot = pd.read_csv('ftp://ftp.expasy.org/databases/rhea/tsv/rhea2uniprot.tsv', sep='\t')
rhea_uniprot.head(2)
# Out:
#    RHEA_ID DIRECTION  MASTER_ID      ID
# 0    10008        UN      10008  O17433
# 1    10008        UN      10008  O34564

# %%
rhea_uniprot.columns = [c.lower() for c in rhea_uniprot.columns]
rhea_uniprot['rhea_id'] = 'RHEA:' + rhea_uniprot['rhea_id'].astype(str)
rhea_uniprot['id'] = 'UniProt:' + rhea_uniprot['id']
rhea_uniprot.head(2)
# Out:
#       rhea_id direction  master_id              id
# 0  RHEA:10008        UN      10008  UniProt:O17433
# 1  RHEA:10008        UN      10008  UniProt:O34564

# %%
cheb_names = pd.read_csv('ftp://ftp.expasy.org/databases/rhea/tsv/chebiId_name.tsv', sep='\t', header=None, names=['id', 'name'])
cheb_names.head(2)
# Out:
#          id               name
# 0   CHEBI:7      (+)-car-3-ene
# 1  CHEBI:20   (1R,4S)-camphene

# %%
# Get chemicals involved in reactions

query = """PREFIX rh:<http://rdf.rhea-db.org/>
            SELECT DISTINCT ?rhea_id ?chebi_id WHERE {
          # ?reaction rdfs:subClassOf rh:Reaction .
          # ?reaction rh:status rh:Approved .
          # ?reaction rh:side ?reactionSide .
          # ?reactionSide rh:contains ?sideContents .
          # ?sideContents rh:compound ?sideCompound .
          # ?sideCompound rh:accession ?chebi_id .
          # ?reaction rh:accession ?rhea_id . 
        }"""

# %%
# Get names and citations related to different reactions

query2 = """PREFIX rh:<http://rdf.rhea-db.org/>
            SELECT DISTINCT ?rhea_id ?cit ?eqn ?trans WHERE {
          # ?reaction rdfs:subClassOf rh:Reaction .
          # ?reaction rh:status rh:Approved .
          # ?reaction rh:equation ?eqn .
          # ?reaction rh:citation ?cit .
          # ?reaction rh:accession ?rhea_id . 
          # ?reaction rh:isTransport ?trans .
        }"""

# %%
rhea_db = WDItemEngine.execute_sparql_query(query, endpoint='https://sparql.rhea-db.org/sparql', as_dataframe=True)
rhea_db
# Out:
#           rhea_id       chebi_id
# 0      RHEA:51132    CHEBI:26386
# 1      RHEA:26006   CHEBI:142217
# 2      RHEA:26006   CHEBI:142345
# 3      RHEA:40719  GENERIC:14730
# 4      RHEA:40719  GENERIC:14731
# ...           ...            ...
# 62308  RHEA:52216  POLYMER:15071
# 62309  RHEA:56932   CHEBI:141179
# 62310  RHEA:56936   CHEBI:141179
# 62311  RHEA:57904  GENERIC:15030
# 62312  RHEA:57904  GENERIC:15031
#
# [62313 rows x 2 columns]

# %%
rhea_nodes = WDItemEngine.execute_sparql_query(query2, endpoint='https://sparql.rhea-db.org/sparql', as_dataframe=True)
rhea_nodes
# Out:
#           rhea_id                                          cit  \
# 0      RHEA:13973  http://rdf.ncbi.nlm.nih.gov/pubmed/16664761
# 1      RHEA:13973  http://rdf.ncbi.nlm.nih.gov/pubmed/16667022
# 2      RHEA:13973   http://rdf.ncbi.nlm.nih.gov/pubmed/2479537
# 3      RHEA:13973  http://rdf.ncbi.nlm.nih.gov/pubmed/29691313
# 4      RHEA:19121   http://rdf.ncbi.nlm.nih.gov/pubmed/8626454
# ...           ...                                          ...
# 27046  RHEA:57884  http://rdf.ncbi.nlm.nih.gov/pubmed/15697234
# 27047  RHEA:57884  http://rdf.ncbi.nlm.nih.gov/pubmed/17605473
# 27048  RHEA:57896  http://rdf.ncbi.nlm.nih.gov/pubmed/28002401
# 27049  RHEA:57900  http://rdf.ncbi.nlm.nih.gov/pubmed/30197295
# 27050  RHEA:57904  http://rdf.ncbi.nlm.nih.gov/pubmed/30197295
#
#                                                      eqn trans
# 0      diphosphate + H(+)(in) + H2O = 2 H(+)(out) + 2...     1
# 1      diphosphate + H(+)(in) + H2O = 2 H(+)(out) + 2...     1
# 2      diphosphate + H(+)(in) + H2O = 2 H(+)(out) + 2...     1
# 3      diphosphate + H(+)(in) + H2O = 2 H(+)(out) + 2...     1
# 4      an S-substituted glutathione(in) + ATP + H2O =...     1
# ...                                                  ...   ...
# 27046  diphosphate + H2O + Na(+)(in) = H(+) + Na(+)(o...     1
# 27047  diphosphate + H2O + Na(+)(in) = H(+) + Na(+)(o...     1
# 27048  2-oxoglutarate + a 5'-end (N(7)-methyl 5'-trip...     0
# 27049  2-oxoglutarate + N(6)-methyladenosine in U6 sn...     0
# 27050  2-oxoglutarate + a 5'-end (N(7)-methyl 5'-trip...     0
#
# [27051 rows x 4 columns]

# %%
rhea_nodes['cit'] = rhea_nodes['cit'].apply(lambda c: c.split('/')[-1])
rhea_nodes = dfp.combine_group_cols_on_char(rhea_nodes, ['rhea_id'], sort=True, prog=False)
rhea_nodes
# Out:
#           rhea_id                                  cit  \
# 0      RHEA:27746                             17420004
# 1      RHEA:45912                             11514237
# 2      RHEA:46564                             12815048
# 3      RHEA:46736                              9305923
# 4      RHEA:50868                             11192938
# ...           ...                                  ...
# 11645  RHEA:63844                    11087748|20356456
# 11646  RHEA:64016                      1520296|7721776
# 11647  RHEA:64024  17346033|20466767|22408253|27425635
# 11648  RHEA:64028  17346033|20466767|22408253|27425635
# 11649  RHEA:64112                    27374330|32271712
#
#                                                      eqn trans
# 0                   H(+) + L-cysteine = CO2 + cysteamine     0
# 1      a (2E,4E)-dienoyl-CoA + H(+) + NADPH = a 4,5-s...     0
# 2      acetyl-CoA + apo-[ACP] = acetyl-[ACP] + adenos...     0
# 3      H2O + monoacyl-sn-glycero-3-phosphate = a mono...     0
# 4      (18R)-hydroxy-(5Z,8Z,11Z,14Z,16E)-eicosapentae...     0
# ...                                                  ...   ...
# 11645  [thioredoxin]-dithiol + cumene hydroperoxide =...     0
# 11646  alpha-L-Fuc-(1->2)-beta-D-Gal-(1->4)-D-Glc + G...     0
# 11647  3,4-dihydroxybenzoyl-[aryl-carrier protein] + ...     0
# 11648  3,4-dihydroxybenzoyl-[aryl-carrier protein] + ...     0
# 11649  an N-acyl-L-phenylalanine + H2O = a fatty acid...     0
#
# [11650 rows x 4 columns]

# %% [markdown]
# ### Just a quick look see what chemicals are present in most approved reactions...

# %%
top_cheb = rhea_db[rhea_db['chebi_id'].str.startswith('CHEBI:')]['chebi_id'].value_counts().head(40).rename('count').to_frame().reset_index()
top_cheb.merge(cheb_names, how='left', left_on=['index'], right_on=['id']).drop('index', axis=1)
# Out:
#     count            id                           name
# 0    7566   CHEBI:15378                           H(+)
# 1    4971   CHEBI:15377                            H2O
# 2    2147   CHEBI:15379                             O2
# 3    1165   CHEBI:57287                            CoA
# 4    1108   CHEBI:58349                        NADP(+)
# 5    1107   CHEBI:57783                          NADPH
# 6    1019   CHEBI:30616                            ATP
# 7     975   CHEBI:57540                         NAD(+)
# 8     948   CHEBI:57945                           NADH
# 9     839   CHEBI:33019                    diphosphate
# 10    829   CHEBI:16526                            CO2
# 11    792   CHEBI:43474                      phosphate
# 12    702  CHEBI:456216                            ADP
# 13    666   CHEBI:59789        S-adenosyl-L-methionine
# 14    604   CHEBI:57856      S-adenosyl-L-homocysteine
# 15    472   CHEBI:58223                            UDP
# 16    392   CHEBI:28938                         NH4(+)
# 17    357  CHEBI:456215                            AMP
# 18    339   CHEBI:17499                            AH2
# 19    339   CHEBI:13193                              A
# 20    311   CHEBI:16240                           H2O2
# 21    311   CHEBI:16810                 2-oxoglutarate
# 22    252   CHEBI:57288                     acetyl-CoA
# 23    227   CHEBI:30031                      succinate
# 24    202   CHEBI:58885            UDP-alpha-D-glucose
# 25    194   CHEBI:29985                    L-glutamate
# 26    180   CHEBI:15361                       pyruvate
# 27    163   CHEBI:57384                    malonyl-CoA
# 28    150   CHEBI:30089                        acetate
# 29    138  CHEBI:175763   (2E,6E)-farnesyl diphosphate
# 30    136   CHEBI:58189                            GDP
# 31    118   CHEBI:60377                            CMP
# 32    107   CHEBI:16842                   formaldehyde
# 33    106   CHEBI:30823             (9Z)-octadecenoate
# 34    104   CHEBI:28868                   a fatty acid
# 35     99   CHEBI:57305                        glycine
# 36     97   CHEBI:57379               hexadecanoyl-CoA
# 37     89    CHEBI:7896                  hexadecanoate
# 38     88   CHEBI:57387          (9Z)-octadecenoyl-CoA
# 39     87   CHEBI:57844                   L-methionine

# %%
load_dir = Path('../2_pipeline').resolve()

# %%
prev_dir = load_dir.joinpath('10e_Diseae_Phenotype_Cleanup_adding_edges', 'out')
nodes = pd.read_csv(prev_dir.joinpath('nodes.csv'), dtype=str)
edges = pd.read_csv(prev_dir.joinpath('edges.csv'), dtype=str)

node_ids = set(nodes['id'].unique())
edge_ids = set(edges[['start_id', 'end_id']].stack().unique())

# %%
combo = gt.combine_nodes_and_edges(nodes, edges)

# %%
len(combo.query('start_label == "Reaction" or end_label == "Reaction"'))
# Out:
# 543936

# %%
new_edges = []

# %% [markdown]
# ## Format relationships from Rhea

# %%
len(rhea_db.query('chebi_id in @edge_ids'))
# Out:
# 32102

# %%
len(rhea_db.query('chebi_id in @node_ids'))
# Out:
# 45234

# %%
len(rhea_react.query('spl_id in @node_ids'))
# Out:
# 895

# %%
len(rhea_react)
# Out:
# 900

# %%
from data_tools.wiki import get_curi_xrefs

# %%
uniprot_xrefs = get_curi_xrefs(nodes, 'UniProt')

# %%
uniprot_ids = set(uniprot_xrefs['xrefs'].unique())| set([u for u in node_ids if u.startswith('UniProt:')])

# %%
rhea_uniprot.query('id in @uniprot_ids')
# Out:
#            rhea_id direction  master_id              id
# 8       RHEA:10008        UN      10008  UniProt:P58004
# 15      RHEA:10008        UN      10008  UniProt:Q9Y6P5
# 24      RHEA:10024        UN      10024  UniProt:O44498
# 25      RHEA:10024        UN      10024  UniProt:O44757
# 28      RHEA:10024        UN      10024  UniProt:P34544
# ...            ...       ...        ...             ...
# 297117  RHEA:64224        UN      64224  UniProt:Q5ZRP2
# 297152  RHEA:64224        UN      64224  UniProt:Q837T2
# 297161  RHEA:64224        UN      64224  UniProt:Q8CXS1
# 297196  RHEA:64228        UN      64228  UniProt:Q6P1A2
# 297200  RHEA:64229        LR      64228  UniProt:Q6P1A2
#
# [13454 rows x 4 columns]

# %%
rhea_uniprot.query('id in @uniprot_ids')
# Out:
#            rhea_id direction  master_id              id
# 8       RHEA:10008        UN      10008  UniProt:P58004
# 15      RHEA:10008        UN      10008  UniProt:Q9Y6P5
# 24      RHEA:10024        UN      10024  UniProt:O44498
# 25      RHEA:10024        UN      10024  UniProt:O44757
# 28      RHEA:10024        UN      10024  UniProt:P34544
# ...            ...       ...        ...             ...
# 297117  RHEA:64224        UN      64224  UniProt:Q5ZRP2
# 297152  RHEA:64224        UN      64224  UniProt:Q837T2
# 297161  RHEA:64224        UN      64224  UniProt:Q8CXS1
# 297196  RHEA:64228        UN      64228  UniProt:Q6P1A2
# 297200  RHEA:64229        LR      64228  UniProt:Q6P1A2
#
# [13454 rows x 4 columns]

# %%
rhea_mappable = rhea_react.query('spl_id in @node_ids')['rhea_id'].unique()

# %%
rhea_uniprot.query('id in @uniprot_ids and rhea_id in @rhea_mappable')
# Out:
#            rhea_id direction  master_id              id
# 271     RHEA:10133        LR      10132  UniProt:Q08AH1
# 272     RHEA:10133        LR      10132  UniProt:Q08AH3
# 273     RHEA:10133        LR      10132  UniProt:Q68CK6
# 2410    RHEA:10225        LR      10224  UniProt:O00764
# 4774    RHEA:10389        LR      10388  UniProt:P35558
# ...            ...       ...        ...             ...
# 270313  RHEA:52357        LR      52356  UniProt:O00204
# 270317  RHEA:52369        LR      52368  UniProt:O00204
# 270325  RHEA:52373        LR      52372  UniProt:P49888
# 272715  RHEA:53509        LR      53508  UniProt:Q16873
# 291362  RHEA:60369        LR      60368  UniProt:Q9UNQ0
#
# [228 rows x 4 columns]

# %%
rhea_chems = rhea_db.query('chebi_id in @node_ids')['rhea_id'].unique()
rhea_prot_mapped = rhea_uniprot.query('id in @uniprot_ids and (rhea_id in @rhea_mappable or rhea_id in @rhea_chems)')['rhea_id'].unique()

# %%
rhea_db.query('chebi_id in @node_ids and rhea_id in @rhea_prot_mapped')
# Out:
#           rhea_id      chebi_id
# 0      RHEA:51132   CHEBI:26386
# 13     RHEA:53972  CHEBI:138002
# 16     RHEA:53992  CHEBI:138003
# 17     RHEA:53980  CHEBI:138004
# 18     RHEA:54000  CHEBI:138004
# ...           ...           ...
# 62226  RHEA:57840   CHEBI:43474
# 62227  RHEA:57884   CHEBI:43474
# 62242  RHEA:56916   CHEBI:15994
# 62309  RHEA:56932  CHEBI:141179
# 62310  RHEA:56936  CHEBI:141179
#
# [12485 rows x 2 columns]

# %%
rhea_edges = rhea_db.merge(rhea_uniprot, on='rhea_id', how='inner').query('chebi_id in @node_ids and id in @uniprot_ids')

rhea_edges = rhea_edges.merge(uniprot_xrefs, left_on='id', right_on='xrefs', how='left', suffixes=('_xref', '_nw'))
rhea_edges.head(2)
# Out:
#       rhea_id     chebi_id direction  master_id         id_xref  \
# 0  RHEA:51132  CHEBI:26386        UN      51132  UniProt:O43598
# 1  RHEA:51132  CHEBI:15377        UN      51132  UniProt:O43598
#
#             id_nw           xrefs
# 0  NCBIGene:10591  UniProt:O43598
# 1  NCBIGene:10591  UniProt:O43598

# %%
rhea_edges = rhea_edges.drop_duplicates(['chebi_id', 'id_xref'])
len(rhea_edges)
# Out:
# 21745

# %%
rhea_edges.count()
# Out:
# rhea_id      21745
# chebi_id     21745
# direction    21745
# master_id    21745
# id_xref      21745
# id_nw        21481
# xrefs        21481
# dtype: int64

# %%
rhea_edges['id_nw'] = rhea_edges['id_nw'].fillna(rhea_edges['id_xref'])

# %%
rhea_edges = rhea_edges.merge(rhea_nodes[['rhea_id', 'cit', 'trans']], on='rhea_id', how='left')
rhea_edges = rhea_edges.rename(columns={'cit': 'pmids'})

# %%
rhea_edges
# Out:
#           rhea_id     chebi_id direction  master_id         id_xref  \
# 0      RHEA:51132  CHEBI:26386        UN      51132  UniProt:O43598
# 1      RHEA:51132  CHEBI:15377        UN      51132  UniProt:O43598
# 2      RHEA:51132  CHEBI:62877        UN      51132  UniProt:O43598
# 3      RHEA:40719  CHEBI:15378        UN      40719  UniProt:Q9Y4U1
# 4      RHEA:40719  CHEBI:57925        UN      40719  UniProt:Q9Y4U1
# ...           ...          ...       ...        ...             ...
# 21740  RHEA:57884  CHEBI:29101        UN      57884  UniProt:Q8F641
# 21741  RHEA:57884  CHEBI:15378        UN      57884  UniProt:Q8F641
# 21742  RHEA:57884  CHEBI:43474        UN      57884  UniProt:Q8F641
# 21743  RHEA:57892  CHEBI:57783        UN      57892  UniProt:P37061
# 21744  RHEA:57892  CHEBI:58349        UN      57892  UniProt:P37061
#
#                   id_nw           xrefs                                pmids  \
# 0        NCBIGene:10591  UniProt:O43598  17234634|19720067|19822152|20962348
# 1        NCBIGene:10591  UniProt:O43598  17234634|19720067|19822152|20962348
# 2        NCBIGene:10591  UniProt:O43598  17234634|19720067|19822152|20962348
# 3        NCBIGene:25974  UniProt:Q9Y4U1           19447654|19801555|21697092
# 4        NCBIGene:25974  UniProt:Q9Y4U1           19447654|19801555|21697092
# ...                 ...             ...                                  ...
# 21740  NCBIGene:1150814  UniProt:Q8F641                    15697234|17605473
# 21741  NCBIGene:1150814  UniProt:Q8F641                    15697234|17605473
# 21742  NCBIGene:1150814  UniProt:Q8F641                    15697234|17605473
# 21743  NCBIGene:1200486  UniProt:P37061                                  NaN
# 21744  NCBIGene:1200486  UniProt:P37061                                  NaN
#
#       trans
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 21740     1
# 21741     1
# 21742     1
# 21743   NaN
# 21744   NaN
#
# [21745 rows x 9 columns]

# %%
#rhea_edges['type'] = rhea_edges['trans'].map({'1': 'in_transport_reaction_with'}).fillna('in_reaction_with')
rhea_edges['type'] = 'in_reaction_with'

rhea_edges = rhea_edges.drop(['direction', 'master_id', 'id_xref', 'xrefs', 'trans'], axis=1)
rhea_edges = gt.order_cols(rhea_edges.rename(columns={'chebi_id': 'end_id', 'id_nw': 'start_id', 'rhea_id': 'merge_id'}))

rhea_edges['dsrc_type'] = 'curated'
rhea_edges['source'] = 'RheaDB'
rhea_edges['license'] = 'CC-BY 4.0'

rhea_edges.sample(10)
# Out:
#                start_id        end_id              type    merge_id  \
# 18137   NCBIGene:122481   CHEBI:57930  in_reaction_with  RHEA:18113
# 2829   NCBIGene:1149468   CHEBI:15378  in_reaction_with  RHEA:24793
# 9922      NCBIGene:9107   CHEBI:43474  in_reaction_with  RHEA:39019
# 4399      NCBIGene:2182   CHEBI:57287  in_reaction_with  RHEA:30751
# 9349    NCBIGene:117283   CHEBI:30616  in_reaction_with  RHEA:37467
# 19737     NCBIGene:5917   CHEBI:30616  in_reaction_with  RHEA:20301
# 10332     NCBIGene:5321   CHEBI:15377  in_reaction_with  RHEA:40427
# 719       NCBIGene:3931   CHEBI:58168  in_reaction_with  RHEA:21204
# 21219     NCBIGene:1588  CHEBI:137031  in_reaction_with  RHEA:53200
# 16710  NCBIGene:1150196   CHEBI:58274  in_reaction_with  RHEA:14877
#
#                                                    pmids dsrc_type  source  \
# 18137                                                NaN   curated  RheaDB
# 2829                 11264293|11839304|12795595|16142895   curated  RheaDB
# 9922                          11676921|12045210|19901554   curated  RheaDB
# 4399   10198260|10749848|11772874|11980911|12366803|1...   curated  RheaDB
# 9349   10567691|10574768|17412958|17690096|17702752|1...   curated  RheaDB
# 19737                                                NaN   curated  RheaDB
# 10332  10085124|10358058|12522102|12672805|14636062|1...   curated  RheaDB
# 719    10222237|10329423|14636062|15654758|19065001|2...   curated  RheaDB
# 21219                                           22773874   curated  RheaDB
# 16710                                   29777624|6319365   curated  RheaDB
#
#          license
# 18137  CC-BY 4.0
# 2829   CC-BY 4.0
# 9922   CC-BY 4.0
# 4399   CC-BY 4.0
# 9349   CC-BY 4.0
# 19737  CC-BY 4.0
# 10332  CC-BY 4.0
# 719    CC-BY 4.0
# 21219  CC-BY 4.0
# 16710  CC-BY 4.0

# %%
new_edges.append(rhea_edges)

# %% [markdown]
# # Update reactions in network
#
# Having to have things go through a reaction node is expensive.... Direct connections between genes and chemicals and whatever they go through is better for the algorithm's small path length limitaitons.  Long path lengths may result in important information not being utilized by the algorithm

# %%
combo.query('start_label == "Reaction" or end_label == "Reaction"').groupby(['start_label', 'end_label', 'type']).apply(len).rename('count').to_frame().reset_index().sort_values('type')
# Out:
#    start_label           end_label                  type   count
# 29    Reaction             Disease       associated_with     670
# 30    Reaction             Disease          disrupted_in     377
# 42    Reaction            Reaction              disrupts     351
# 35    Reaction  Molecular Function               enables    1688
# 43    Reaction            Reaction   follows_in_sequence   10363
# 8         Gene            Reaction   fucntion_altered_in    2361
# 15     Protein            Reaction   fucntion_altered_in       1
# 27    Reaction            Compound             has_input   10412
# 25    Reaction             Complex             has_input    5500
# 31    Reaction                Drug             has_input     900
# 33    Reaction                Gene             has_input  101837
# 40    Reaction             Protein             has_input   15404
# 34    Reaction                Gene            has_output   99902
# 28    Reaction            Compound            has_output   10034
# 41    Reaction             Protein            has_output   15421
# 32    Reaction                Drug            has_output     867
# 26    Reaction             Complex            has_output    6283
# 44    Reaction               Taxon              in_taxon    5239
# 20    Reaction  Biological Process           involved_in     660
# 36    Reaction  Molecular Function  negatively_regulates       3
# 21    Reaction  Biological Process  negatively_regulates      56
# 0      Complex            Reaction  negatively_regulates     355
# 16     Protein            Reaction  negatively_regulates      11
# 2     Compound            Reaction  negatively_regulates      86
# 9         Gene            Reaction  negatively_regulates     132
# 5         Drug            Reaction  negatively_regulates      23
# 24    Reaction  Cellular Component               part_of   26205
# 17     Protein            Reaction               part_of   23816
# 13   Micro RNA            Reaction               part_of     164
# 3     Compound            Reaction               part_of   29212
# 39    Reaction             Pathway               part_of   15232
# 10        Gene            Reaction               part_of  145584
# 6         Drug            Reaction               part_of    3856
# 18     Protein            Reaction  positively_regulates      66
# 1      Complex            Reaction  positively_regulates     718
# 37    Reaction  Molecular Function  positively_regulates       8
# 7         Drug            Reaction  positively_regulates      22
# 11        Gene            Reaction  positively_regulates     354
# 14   Micro RNA            Reaction  positively_regulates       1
# 4     Compound            Reaction  positively_regulates     213
# 22    Reaction  Biological Process  positively_regulates      28
# 19     Protein            Reaction             regulates     440
# 38    Reaction  Molecular Function             regulates       1
# 12        Gene            Reaction             regulates    9054
# 23    Reaction  Biological Process             regulates      26

# %%
chem_types = ['Compound', 'Drug']
gene_types = ['Gene', 'Protein', 'Complex', 'Micro RNA']


chem_react = combo.query('start_label in @chem_types and end_label == "Reaction"')
gene_react = combo.query('start_label in @gene_types and end_label == "Reaction"')

react_chem = combo.query('end_label in @chem_types and start_label == "Reaction"')
react_gene = combo.query('end_label in @gene_types and start_label == "Reaction"')

# %%
chem_react['type'].value_counts()
# Out:
# part_of                 33068
# positively_regulates      235
# negatively_regulates      109
# Name: type, dtype: int64

# %%
gene_react['type'].value_counts()
# Out:
# part_of                 169564
# regulates                 9494
# fucntion_altered_in       2362
# positively_regulates      1139
# negatively_regulates       498
# Name: type, dtype: int64

# %%
react_chem['type'].value_counts()
# Out:
# has_input     11312
# has_output    10901
# Name: type, dtype: int64

# %%
react_gene['type'].value_counts()
# Out:
# has_input     122741
# has_output    121606
# Name: type, dtype: int64

# %%
cg_edges = chem_react.query('type == "part_of"').merge(gene_react.query('type == "part_of"'), on='end_id')[['start_id_x', 'start_id_y', 'end_id', 'source_x', 'dsrc_type_x', 'comp_type_x', 'license_x']].drop_duplicates()
cg_edges = cg_edges.rename(columns={'start_id_x': 'end_id', 'start_id_y': 'start_id', 'end_id': 'merge_id'})
cg_edges.columns = [c.replace('_x', '') for c in cg_edges.columns]
cg_edges['type'] = 'in_reaction_with'
cg_edges = gt.order_cols(cg_edges)
cg_edges.head(2)
# Out:
#          start_id       end_id              type            merge_id  \
# 0  NCBIGene:79001  CHEBI:10033  in_reaction_with  REACT:R-HSA-159790
# 1  NCBIGene:79001  CHEBI:15378  in_reaction_with  REACT:R-HSA-159790
#
#      source dsrc_type comp_type  license
# 0  Reactome   curated       NaN  CC0 1.0
# 1  Reactome   curated       NaN  CC0 1.0

# %%
new_edges.append(cg_edges)

# %%
len(cg_edges.drop_duplicates(subset=['start_id', 'end_id']))
# Out:
# 128777

# %%
cg_edges2 = react_chem.merge(react_gene, on='start_id')[['end_id_x', 'end_id_y', 'source_x', 'dsrc_type_x', 'comp_type_x', 'license_x', 'start_id']].drop_duplicates()
cg_edges2 = cg_edges2.rename(columns={'end_id_y': 'start_id', 'end_id_x': 'end_id', 'start_id': 'merge_id'})
cg_edges2.columns = [c.replace('_x', '') for c in cg_edges2.columns]
cg_edges2['type'] = 'in_reaction_with'
cg_edges2 = gt.order_cols(cg_edges2)
cg_edges2.head(4)
# Out:
#              start_id       end_id              type    source dsrc_type  \
# 0  REACT:R-CEL-162401  CHEBI:16618  in_reaction_with  Reactome   curated
# 1  REACT:R-CEL-109696  CHEBI:16618  in_reaction_with  Reactome   curated
# 2     NCBIGene:179424  CHEBI:16618  in_reaction_with  Reactome   curated
# 4     NCBIGene:181524  CHEBI:16618  in_reaction_with  Reactome   curated
#
#   comp_type  license            merge_id
# 0       NaN  CC0 1.0  REACT:R-CEL-109700
# 1       NaN  CC0 1.0  REACT:R-CEL-109700
# 2       NaN  CC0 1.0  REACT:R-CEL-109700
# 4       NaN  CC0 1.0  REACT:R-CEL-109700

# %%
new_edges.append(cg_edges2)

# %% [markdown]
# ### We will not do Chemical-Chemical or Gene-Gene
#
# Some reactions are of the form GeneA - reacts with - (SET OF GENES) - to produce - GeneB...
# These will cause issues in that the set of genes involved are not specifically in a reaction with each other, but merging over the reaction would have them all the genes in the set linked, rather than only linked to Genes A and B.
#
# What we really want is the product of (GeneA + GeneB) X  (SET OF GENES) are the involved speices. Unfortunately we do not have this data avaliable currently to do this expansion properly

# %% [markdown]
# ## Reaction to Taxa -> Gene to Taxa

# %%
react_tax = combo.query('start_label == "Reaction" and type == "in_taxon"').copy()
gene_tax = gene_react.merge(react_tax, left_on='end_id', right_on='start_id')

gene_tax_tup = gene_tax[['start_id_x', 'end_id_y']].apply(tuple, axis=1)

# %%
old_gene_tax_tup = combo.query('start_label in @gene_types and type == "in_taxon"')[['start_id', 'end_id']].apply(tuple, axis=1)

# %%
len(old_gene_tax_tup)
# Out:
# 207486

# %%
len(set(gene_tax_tup) - set(old_gene_tax_tup))
# Out:
# 1284

# %%
gene_tax['tup'] = gene_tax_tup
gt_edges = gene_tax.query('tup not in @old_gene_tax_tup')

# %%
gt_edges.head(2)
# Out:
#       start_id_x             end_id_x               type_x dsrc_type_x  \
# 3  NCBIGene:4615  REACT:R-HSA-5602316  fucntion_altered_in     curated
# 4  NCBIGene:4615  REACT:R-HSA-5602316              part_of     curated
#
#   comp_type_x p_val_x adj_p_x  source_x license_x experiments_x  ... phase_y  \
# 3         NaN     NaN     NaN  Reactome   CC0 1.0           NaN  ...     NaN
# 4         NaN     NaN     NaN  Reactome   CC0 1.0           NaN  ...     NaN
#
#   date_y name_y name_x_y name_y_y  \
# 3    NaN    NaN      NaN      NaN
# 4    NaN    NaN      NaN      NaN
#
#                                         start_name_y        end_name_y  \
# 3  Defective MyD88 does not oligomerize within th...  Escherichia coli
# 4  Defective MyD88 does not oligomerize within th...  Escherichia coli
#
#   start_label_y end_label_y                             tup
# 3      Reaction       Taxon  (NCBIGene:4615, NCBITaxon:562)
# 4      Reaction       Taxon  (NCBIGene:4615, NCBITaxon:562)
#
# [2 rows x 43 columns]

# %%
gt_edges = gt_edges.rename(columns={'start_id_x': 'start_id', 'end_id_y': 'end_id', 'end_id_x': 'merge_id'})[['start_id', 'end_id', 'source_x', 'dsrc_type_x', 'comp_type_x', 'license_x', 'merge_id']].drop_duplicates()
gt_edges.columns = [c.replace('_x', '') for c in gt_edges.columns]
gt_edges['type'] = 'in_taxon'
gt_edges = gt.order_cols(gt_edges)
gt_edges.head(4)
# Out:
#           start_id            end_id      type    source dsrc_type comp_type  \
# 3    NCBIGene:4615     NCBITaxon:562  in_taxon  Reactome   curated       NaN
# 5    NCBIGene:7100     NCBITaxon:562  in_taxon  Reactome   curated       NaN
# 410  NCBIGene:4928   NCBITaxon:11320  in_taxon  Reactome   curated       NaN
# 411  NCBIGene:4928  NCBITaxon:407754  in_taxon  Reactome   curated       NaN
#
#      license             merge_id
# 3    CC0 1.0  REACT:R-HSA-5602316
# 5    CC0 1.0  REACT:R-HSA-5602316
# 410  CC0 1.0  REACT:R-HSA-1176059
# 411  CC0 1.0  REACT:R-HSA-1176059

# %%
new_edges.append(gt_edges)

# %% [markdown]
# ## Gene -> GO, Chem -> GO

# %% [markdown]
# #### Gene - GO

# %%
go_types = ['Molecular Function', 'Biological Process', 'Cellular Component']

# %%
rx_go = combo.query('start_label == "Reaction" and end_label in @go_types')

# %%
gene_go = gene_react.query('type == "part_of"').merge(rx_go, left_on='end_id', right_on='start_id', how='inner').copy()
gene_go_tup = gene_go[['start_id_x', 'end_id_y']].apply(tuple, axis=1)
gene_go['tup'] = gene_go_tup

# %%
len(gene_go)
# Out:
# 299430

# %%
nw_gene_go_tup = combo.query('start_label in @gene_types and end_label in @go_types')[['start_id', 'end_id']].apply(tuple, axis=1)

# %%
len(set(gene_go_tup) - set(nw_gene_go_tup))
# Out:
# 27726

# %%
gene_go.head(2)
# Out:
#              start_id_x             end_id_x   type_x dsrc_type_x comp_type_x  \
# 0  ENSG:ENSG00000076242  REACT:R-HSA-5358510  part_of     curated         NaN
# 1    NCBIGene:107984056  REACT:R-HSA-5358510  part_of     curated         NaN
#
#   p_val_x adj_p_x  source_x license_x experiments_x  ... phase_y date_y  \
# 0     NaN     NaN  Reactome   CC0 1.0           NaN  ...     NaN    NaN
# 1     NaN     NaN  Reactome   CC0 1.0           NaN  ...     NaN    NaN
#
#   name_y name_x_y name_y_y                                       start_name_y  \
# 0    NaN      NaN      NaN  MSH2:MSH6 recruits MLH1:PMS2 to mismatch and i...
# 1    NaN      NaN      NaN  MSH2:MSH6 recruits MLH1:PMS2 to mismatch and i...
#
#     end_name_y start_label_y         end_label_y  \
# 0  nucleoplasm      Reaction  Cellular Component
# 1  nucleoplasm      Reaction  Cellular Component
#
#                                   tup
# 0  (ENSG:ENSG00000076242, GO:0005654)
# 1    (NCBIGene:107984056, GO:0005654)
#
# [2 rows x 43 columns]

# %%
gg_edges = gene_go.query('tup not in @nw_gene_go_tup')

gg_edges = gg_edges.rename(columns={'start_id_x': 'start_id', 'end_id_y': 'end_id', 'end_id_x': 'merge_id'})[['start_id', 'end_id', 'type_y', 'source_y', 'dsrc_type_y', 'comp_type_y', 'license_y', 'merge_id']].drop_duplicates()
gg_edges.columns = [c.replace('_y', '') for c in gg_edges.columns]
gg_edges = gt.order_cols(gg_edges)
gg_edges.head(4)
# Out:
#                 start_id      end_id     type    source dsrc_type comp_type  \
# 14  ENSG:ENSG00000076242  GO:0004519  enables  Reactome   curated       NaN
# 18         NCBIGene:2956  GO:0004519  enables  Reactome   curated       NaN
# 20         NCBIGene:4292  GO:0004519  enables  Reactome   curated       NaN
# 22         NCBIGene:4436  GO:0004519  enables  Reactome   curated       NaN
#
#     license             merge_id
# 14  CC0 1.0  REACT:R-HSA-5358518
# 18  CC0 1.0  REACT:R-HSA-5358518
# 20  CC0 1.0  REACT:R-HSA-5358518
# 22  CC0 1.0  REACT:R-HSA-5358518

# %%
gene_go2 = react_gene.merge(rx_go, on='start_id', how='inner').copy()
gene_go2_tup = gene_go2[['end_id_x', 'end_id_y']].apply(tuple, axis=1)
gene_go2['tup'] = gene_go2_tup

# %%
gg_edges2 = gene_go2.query('tup not in @nw_gene_go_tup')

gg_edges2 = gg_edges2.rename(columns={'end_id_x': 'start_id', 'end_id_y': 'end_id', 'start_id': 'merge_id'})[['start_id', 'end_id', 'type_y', 'source_y', 'dsrc_type_y', 'comp_type_y', 'license_y', 'merge_id']].drop_duplicates()
gg_edges2.columns = [c.replace('_y', '') for c in gg_edges2.columns]
gg_edges2 = gt.order_cols(gg_edges2)
gg_edges2.head(4)
# Out:
#               start_id      end_id     type    source dsrc_type comp_type  \
# 47  UniProt:A0A1C3NSK2  GO:0005576  part_of  Reactome   curated       NaN
# 49  UniProt:A0A1C3NSN6  GO:0005576  part_of  Reactome   curated       NaN
# 55     NCBIGene:174803  GO:0005576  part_of  Reactome   curated       NaN
# 59     NCBIGene:180944  GO:0005576  part_of  Reactome   curated       NaN
#
#     license             merge_id
# 47  CC0 1.0  REACT:R-CEL-1013012
# 49  CC0 1.0  REACT:R-CEL-1013012
# 55  CC0 1.0  REACT:R-CEL-1013012
# 59  CC0 1.0  REACT:R-CEL-1013012

# %%
len(gg_edges2)
# Out:
# 64358

# %%
combo.query('start_label in @gene_types and end_label in @go_types')['type'].value_counts()
# Out:
# involved_in             294419
# part_of                 249607
# enables                 226591
# regulates                23166
# positively_regulates     22080
# negatively_regulates     16044
# marker_or_mechanism         10
# decreases_phenotype          5
# increases_phenotype          4
# decreases_reaction           3
# therapeutic                  3
# increases_reaction           1
# affects_reaction             1
# Name: type, dtype: int64

# %%
gg_edges['type'].value_counts()
# Out:
# part_of                 78159
# enables                  9962
# involved_in              3800
# negatively_regulates      342
# positively_regulates      155
# regulates                 106
# Name: type, dtype: int64

# %%
gg_edges2['type'].value_counts()
# Out:
# part_of                 52736
# enables                  8727
# involved_in              2488
# negatively_regulates      249
# regulates                  86
# positively_regulates       72
# Name: type, dtype: int64

# %%
new_edges.append(gg_edges)
new_edges.append(gg_edges2)

# %% [markdown]
# #### Chem - GO

# %%
combo.query('start_label in @chem_types and end_label in @go_types')['type'].value_counts()
# Out:
# increases_phenotype    37158
# decreases_reaction     28285
# decreases_phenotype    18767
# affects_phenotype      11388
# increases_reaction      6906
# part_of                 3576
# affects_reaction        2593
# inhibitor                746
# activator                412
# modulator                330
# interacts                 81
# blocker                   50
# substrate                 34
# marker_or_mechanism       24
# chelating_agent            9
# antagonist                 6
# therapeutic                6
# partial_agonist            3
# binding_agent              3
# opener                     3
# releasing_agent            2
# oxidative_enzyme           2
# chaperone                  2
# agonist                    1
# Name: type, dtype: int64

# %%
chem_go = chem_react.query('type == "part_of"').merge(rx_go, left_on='end_id', right_on='start_id', how='inner').copy()
chem_go_tup = chem_go[['start_id_x', 'end_id_y']].apply(tuple, axis=1)
chem_go['tup'] = chem_go_tup

# %%
len(chem_go)
# Out:
# 58656

# %%
nw_chem_go_tup = combo.query('start_label in @chem_types and end_label in @go_types')[['start_id', 'end_id']].apply(tuple, axis=1)

# %%
len(set(chem_go_tup) - set(nw_chem_go_tup))
# Out:
# 5707

# %%
cgo_edges = chem_go.query('tup not in @nw_gene_go_tup')

cgo_edges = cgo_edges.rename(columns={'start_id_x': 'start_id', 'end_id_y': 'end_id', 'end_id_x': 'merge_id'})[['start_id', 'end_id', 'type_y', 'source_y', 'dsrc_type_y', 'comp_type_y', 'license_y', 'merge_id']].drop_duplicates()
cgo_edges.columns = [c.replace('_y', '') for c in cgo_edges.columns]
cgo_edges = gt.order_cols(cgo_edges)
cgo_edges.head(4)
# Out:
#       start_id      end_id     type    source dsrc_type comp_type  license  \
# 0  CHEBI:10033  GO:0005788  part_of  Reactome   curated       NaN  CC0 1.0
# 1  CHEBI:10033  GO:0005789  part_of  Reactome   curated       NaN  CC0 1.0
# 2  CHEBI:10033  GO:0005829  part_of  Reactome   curated       NaN  CC0 1.0
# 3  CHEBI:15378  GO:0005788  part_of  Reactome   curated       NaN  CC0 1.0
#
#              merge_id
# 0  REACT:R-HSA-159790
# 1  REACT:R-HSA-159790
# 2  REACT:R-HSA-159790
# 3  REACT:R-HSA-159790

# %%
chem_go2 = react_chem.merge(rx_go, on='start_id', how='inner').copy()
chem_go2_tup = chem_go2[['end_id_x', 'end_id_y']].apply(tuple, axis=1)
chem_go2['tup'] = chem_go2_tup

# %%
cgo_edges2 = chem_go2.query('tup not in @nw_gene_go_tup')

cgo_edges2 = cgo_edges2.rename(columns={'end_id_x': 'start_id', 'end_id_y': 'end_id', 'start_id': 'merge_id'})[['start_id', 'end_id', 'type_y', 'source_y', 'dsrc_type_y', 'comp_type_y', 'license_y', 'merge_id']].drop_duplicates()
cgo_edges2.columns = [c.replace('_y', '') for c in cgo_edges2.columns]
cgo_edges2 = gt.order_cols(cgo_edges2)
cgo_edges2.head(4)
# Out:
#        start_id      end_id     type    source dsrc_type comp_type  license  \
# 0   CHEBI:15996  GO:0005759  part_of  Reactome   curated       NaN  CC0 1.0
# 1   CHEBI:16027  GO:0005759  part_of  Reactome   curated       NaN  CC0 1.0
# 2   CHEBI:17552  GO:0005759  part_of  Reactome   curated       NaN  CC0 1.0
# 3  CHEBI:456216  GO:0005759  part_of  Reactome   curated       NaN  CC0 1.0
#
#               merge_id
# 0  REACT:R-CEL-1008248
# 1  REACT:R-CEL-1008248
# 2  REACT:R-CEL-1008248
# 3  REACT:R-CEL-1008248

# %%
cgo_edges['type'].value_counts()
# Out:
# part_of                 52621
# enables                  4738
# involved_in              1140
# regulates                  53
# negatively_regulates       52
# positively_regulates       52
# Name: type, dtype: int64

# %%
cgo_edges2['type'].value_counts()
# Out:
# part_of                 31501
# enables                  3799
# involved_in               754
# negatively_regulates       42
# positively_regulates       37
# regulates                  31
# Name: type, dtype: int64

# %%
new_edges.append(cgo_edges)
new_edges.append(cgo_edges2)

# %% [markdown]
# ## Regulation of reaction components

# %%
reg_types = ['negatively_regulates', 'positively_regulates', 'regulates']

# %%
gene_reg_rx = combo.query('start_label in @gene_types and end_label == "Reaction" and type in @reg_types')

# %%
chem_reg_rx = combo.query('start_label in @chem_types and end_label == "Reaction" and type in @reg_types')

# %% [markdown]
# #### Get all the genes and reactions on the same side...

# %%
chem_react1 = pd.concat([chem_react, react_chem.rename(columns={'start_id': 'end_id', 'end_id': 'start_id'})], sort=False)
gene_react1 = pd.concat([gene_react, react_gene.rename(columns={'start_id': 'end_id', 'end_id': 'start_id'})], sort=False)

# %%
gene_react1['type'].value_counts()
# Out:
# part_of                 169564
# has_input               122741
# has_output              121606
# regulates                 9494
# fucntion_altered_in       2362
# positively_regulates      1139
# negatively_regulates       498
# Name: type, dtype: int64

# %%
membership = ['part_of', 'has_input', 'has_output']

# %%
gene_gene_reg = gene_reg_rx.merge(gene_react1.query('type in {}'.format(['part_of', 'has_output'])), on='end_id', how='inner').drop_duplicates(subset=['start_id_x', 'start_id_y', 'type_x'])

# %%
# Any instance where a gene regulates a reaction that the gene is also a part of is going to 
# result in bi-directional regulation of All genes within that reaction
prob_tups = gene_gene_reg.query('start_id_x == start_id_y')[['start_id_x', 'end_id']].apply(tuple, axis=1)

# %%
gene_gene_reg['gene_rx_tup'] = gene_gene_reg[['start_id_x', 'end_id']].apply(tuple, axis=1)
gene_gene_reg.query('gene_rx_tup in @prob_tups')
# Out:
#              start_id_x               end_id                type_x  \
# 0       NCBIGene:172243   REACT:R-CEL-549241  negatively_regulates
# 1       NCBIGene:172243   REACT:R-CEL-549241  negatively_regulates
# 2       NCBIGene:172243   REACT:R-CEL-549241  negatively_regulates
# 3       NCBIGene:172243   REACT:R-CEL-549241  negatively_regulates
# 4       NCBIGene:172243   REACT:R-CEL-549241  negatively_regulates
# ...                 ...                  ...                   ...
# 482427    NCBIGene:9636  REACT:R-HSA-1169307             regulates
# 482428    NCBIGene:9636  REACT:R-HSA-1169307             regulates
# 482429    NCBIGene:9636  REACT:R-HSA-1169307             regulates
# 482430    NCBIGene:9636  REACT:R-HSA-1169307             regulates
# 482431    NCBIGene:9636  REACT:R-HSA-1169307             regulates
#
#        dsrc_type_x comp_type_x p_val_x adj_p_x  source_x license_x  \
# 0          curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 1          curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 2          curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 3          curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 4          curated         NaN     NaN     NaN  Reactome   CC0 1.0
# ...            ...         ...     ...     ...       ...       ...
# 482427     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 482428     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 482429     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 482430     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 482431     curated         NaN     NaN     NaN  Reactome   CC0 1.0
#
#        experiments_x  ... phase_y date_y name_y name_x_y name_y_y  \
# 0                NaN  ...     NaN    NaN    NaN      NaN      NaN
# 1                NaN  ...     NaN    NaN    NaN      NaN      NaN
# 2                NaN  ...     NaN    NaN    NaN      NaN      NaN
# 3                NaN  ...     NaN    NaN    NaN      NaN      NaN
# 4                NaN  ...     NaN    NaN    NaN      NaN      NaN
# ...              ...  ...     ...    ...    ...      ...      ...
# 482427           NaN  ...     NaN    NaN    NaN      NaN      NaN
# 482428           NaN  ...     NaN    NaN    NaN      NaN      NaN
# 482429           NaN  ...     NaN    NaN    NaN      NaN      NaN
# 482430           NaN  ...     NaN    NaN    NaN      NaN      NaN
# 482431           NaN  ...     NaN    NaN    NaN      NaN      NaN
#
#                             start_name_y  \
# 0                                str-176
# 1                                  rnt-1
# 2                                K05F1.6
# 3                             Y82E9BR.16
# 4                                  oat-1
# ...                                  ...
# 482427  N-myristoyl GAG (P12493) protein
# 482428                            RPS27A
# 482429                             UBA52
# 482430                               UBB
# 482431                               UBC
#
#                                                end_name_y start_label_y  \
# 0       SLC22A4 cotransports ERGT, Na+ from extracellu...          Gene
# 1       SLC22A4 cotransports ERGT, Na+ from extracellu...          Gene
# 2       SLC22A4 cotransports ERGT, Na+ from extracellu...          Gene
# 3       SLC22A4 cotransports ERGT, Na+ from extracellu...          Gene
# 4       SLC22A4 cotransports ERGT, Na+ from extracellu...          Gene
# ...                                                   ...           ...
# 482427  Monoubiquitination of N-myristoyl GAG (P12493)...       Protein
# 482428  Monoubiquitination of N-myristoyl GAG (P12493)...          Gene
# 482429  Monoubiquitination of N-myristoyl GAG (P12493)...          Gene
# 482430  Monoubiquitination of N-myristoyl GAG (P12493)...          Gene
# 482431  Monoubiquitination of N-myristoyl GAG (P12493)...          Gene
#
#        end_label_y                            gene_rx_tup
# 0         Reaction  (NCBIGene:172243, REACT:R-CEL-549241)
# 1         Reaction  (NCBIGene:172243, REACT:R-CEL-549241)
# 2         Reaction  (NCBIGene:172243, REACT:R-CEL-549241)
# 3         Reaction  (NCBIGene:172243, REACT:R-CEL-549241)
# 4         Reaction  (NCBIGene:172243, REACT:R-CEL-549241)
# ...            ...                                    ...
# 482427    Reaction   (NCBIGene:9636, REACT:R-HSA-1169307)
# 482428    Reaction   (NCBIGene:9636, REACT:R-HSA-1169307)
# 482429    Reaction   (NCBIGene:9636, REACT:R-HSA-1169307)
# 482430    Reaction   (NCBIGene:9636, REACT:R-HSA-1169307)
# 482431    Reaction   (NCBIGene:9636, REACT:R-HSA-1169307)
#
# [107047 rows x 42 columns]

# %%
gene_gene_reg = gene_gene_reg.query('gene_rx_tup not in @prob_tups').copy()

# %%
gene_gene_reg['short_tup'] = gene_gene_reg[['start_id_x', 'start_id_y']].apply(tuple, axis=1)
gene_gene_reg['long_tup'] = gene_gene_reg[['start_id_x', 'type_x', 'start_id_y']].apply(tuple, axis=1)

# %%
gene_gene_reg['rev_short_tup'] = gene_gene_reg[['start_id_y', 'start_id_x']].apply(tuple, axis=1)
gene_gene_reg['rev_long_tup'] = gene_gene_reg[['start_id_y', 'type_x', 'start_id_x']].apply(tuple, axis=1)

# %%
conflict = set(gene_gene_reg['short_tup']) & set(gene_gene_reg['rev_short_tup'])
len(conflict)
# Out:
# 8898

# %%
conflict1 = set(gene_gene_reg['long_tup']) & set(gene_gene_reg['rev_long_tup'])
len(conflict1)
# Out:
# 8696

# %%
gene_gene_reg.query('short_tup in @conflict')
# Out:
#              start_id_x               end_id                type_x  \
# 1345    NCBIGene:173085  REACT:R-CEL-5672972             regulates
# 1349    NCBIGene:173085  REACT:R-CEL-5672972             regulates
# 1795    NCBIGene:181082  REACT:R-CEL-5672972             regulates
# 1799    NCBIGene:181082  REACT:R-CEL-5672972             regulates
# 2969      NCBIGene:3569  REACT:R-HSA-1112602             regulates
# ...                 ...                  ...                   ...
# 479523     NCBIGene:801  REACT:R-HSA-8986939             regulates
# 479544     NCBIGene:805  REACT:R-HSA-8986939             regulates
# 479565     NCBIGene:808  REACT:R-HSA-8986939             regulates
# 481344    NCBIGene:6928   REACT:R-HSA-210784  positively_regulates
# 481346    NCBIGene:6928   REACT:R-HSA-210784             regulates
#
#        dsrc_type_x comp_type_x p_val_x adj_p_x  source_x license_x  \
# 1345       curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 1349       curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 1795       curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 1799       curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 2969       curated         NaN     NaN     NaN  Reactome   CC0 1.0
# ...            ...         ...     ...     ...       ...       ...
# 479523     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 479544     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 479565     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 481344     curated         NaN     NaN     NaN  Reactome   CC0 1.0
# 481346     curated         NaN     NaN     NaN  Reactome   CC0 1.0
#
#        experiments_x  ... name_y_y start_name_y  \
# 1345             NaN  ...      NaN        src-1
# 1349             NaN  ...      NaN        mpk-1
# 1795             NaN  ...      NaN        src-1
# 1799             NaN  ...      NaN        mpk-1
# 2969             NaN  ...      NaN        STAT3
# ...              ...  ...      ...          ...
# 479523           NaN  ...      NaN       PRKACA
# 479544           NaN  ...      NaN       PRKACA
# 479565           NaN  ...      NaN       PRKACA
# 481344           NaN  ...      NaN      ONECUT1
# 481346           NaN  ...      NaN      ONECUT1
#
#                                                end_name_y start_label_y  \
# 1345    MAP2Ks and MAPKs bind to the activated RAF com...          Gene
# 1349    MAP2Ks and MAPKs bind to the activated RAF com...          Gene
# 1795    MAP2Ks and MAPKs bind to the activated RAF com...          Gene
# 1799    MAP2Ks and MAPKs bind to the activated RAF com...          Gene
# 2969    Tyrosine phosphorylation of STAT1, STAT3 by IL...          Gene
# ...                                                   ...           ...
# 479523                  MECP2 binds the NCoR/SMRT complex          Gene
# 479544                  MECP2 binds the NCoR/SMRT complex          Gene
# 479565                  MECP2 binds the NCoR/SMRT complex          Gene
# 481344          HNF1B-dependent synthesis of HNF6 protein          Gene
# 481346          HNF1B-dependent synthesis of HNF6 protein          Gene
#
#        end_label_y                             gene_rx_tup  \
# 1345      Reaction  (NCBIGene:173085, REACT:R-CEL-5672972)
# 1349      Reaction  (NCBIGene:173085, REACT:R-CEL-5672972)
# 1795      Reaction  (NCBIGene:181082, REACT:R-CEL-5672972)
# 1799      Reaction  (NCBIGene:181082, REACT:R-CEL-5672972)
# 2969      Reaction    (NCBIGene:3569, REACT:R-HSA-1112602)
# ...            ...                                     ...
# 479523    Reaction     (NCBIGene:801, REACT:R-HSA-8986939)
# 479544    Reaction     (NCBIGene:805, REACT:R-HSA-8986939)
# 479565    Reaction     (NCBIGene:808, REACT:R-HSA-8986939)
# 481344    Reaction     (NCBIGene:6928, REACT:R-HSA-210784)
# 481346    Reaction     (NCBIGene:6928, REACT:R-HSA-210784)
#
#                                  short_tup  \
# 1345    (NCBIGene:173085, NCBIGene:171722)
# 1349    (NCBIGene:173085, NCBIGene:175545)
# 1795    (NCBIGene:181082, NCBIGene:171722)
# 1799    (NCBIGene:181082, NCBIGene:175545)
# 2969        (NCBIGene:3569, NCBIGene:6774)
# ...                                    ...
# 479523       (NCBIGene:801, NCBIGene:5566)
# 479544       (NCBIGene:805, NCBIGene:5566)
# 479565       (NCBIGene:808, NCBIGene:5566)
# 481344      (NCBIGene:6928, NCBIGene:3175)
# 481346      (NCBIGene:6928, NCBIGene:3175)
#
#                                                  long_tup  \
# 1345        (NCBIGene:173085, regulates, NCBIGene:171722)
# 1349        (NCBIGene:173085, regulates, NCBIGene:175545)
# 1795        (NCBIGene:181082, regulates, NCBIGene:171722)
# 1799        (NCBIGene:181082, regulates, NCBIGene:175545)
# 2969            (NCBIGene:3569, regulates, NCBIGene:6774)
# ...                                                   ...
# 479523           (NCBIGene:801, regulates, NCBIGene:5566)
# 479544           (NCBIGene:805, regulates, NCBIGene:5566)
# 479565           (NCBIGene:808, regulates, NCBIGene:5566)
# 481344  (NCBIGene:6928, positively_regulates, NCBIGene...
# 481346          (NCBIGene:6928, regulates, NCBIGene:3175)
#
#                              rev_short_tup  \
# 1345    (NCBIGene:171722, NCBIGene:173085)
# 1349    (NCBIGene:175545, NCBIGene:173085)
# 1795    (NCBIGene:171722, NCBIGene:181082)
# 1799    (NCBIGene:175545, NCBIGene:181082)
# 2969        (NCBIGene:6774, NCBIGene:3569)
# ...                                    ...
# 479523       (NCBIGene:5566, NCBIGene:801)
# 479544       (NCBIGene:5566, NCBIGene:805)
# 479565       (NCBIGene:5566, NCBIGene:808)
# 481344      (NCBIGene:3175, NCBIGene:6928)
# 481346      (NCBIGene:3175, NCBIGene:6928)
#
#                                              rev_long_tup
# 1345        (NCBIGene:171722, regulates, NCBIGene:173085)
# 1349        (NCBIGene:175545, regulates, NCBIGene:173085)
# 1795        (NCBIGene:171722, regulates, NCBIGene:181082)
# 1799        (NCBIGene:175545, regulates, NCBIGene:181082)
# 2969            (NCBIGene:6774, regulates, NCBIGene:3569)
# ...                                                   ...
# 479523           (NCBIGene:5566, regulates, NCBIGene:801)
# 479544           (NCBIGene:5566, regulates, NCBIGene:805)
# 479565           (NCBIGene:5566, regulates, NCBIGene:808)
# 481344  (NCBIGene:3175, positively_regulates, NCBIGene...
# 481346          (NCBIGene:3175, regulates, NCBIGene:6928)
#
# [9061 rows x 46 columns]

# %%
len(gene_gene_reg.query('short_tup in @conflict')), len(gene_gene_reg.query('short_tup not in @conflict'))
# Out:
# (9061, 43467)

# %% [markdown]
# lot less conflicts than non, conflicts... but genes can regulate each other...

# %%
gene_gene_reg = gene_gene_reg.drop(['short_tup', 'long_tup', 'rev_short_tup', 'rev_long_tup'], axis=1)

# %% [markdown]
# #### Gene regulates chemical

# %%
gene_chem_reg = gene_reg_rx.merge(chem_react1.query('type in @membership'), on='end_id', how='inner').drop_duplicates(subset=['start_id_x', 'start_id_y', 'type_x'])

# %%
gene_chem_reg[['start_name_x', 'start_name_y', 'type_x']]
# Out:
#                                       start_name_x  \
# 0                                            rnt-1
# 1                                            rnt-1
# 6      Runt domain-containing protein CELE_B0414.2
# 7      Runt domain-containing protein CELE_B0414.2
# 12                                           rnt-1
# ...                                            ...
# 23463                                        MPDU1
# 23470                                        MPDU1
# 23471                                        MPDU1
# 23494                                        MPDU1
# 23502                                        MPDU1
#
#                                            start_name_y                type_x
# 0      SSU72 homolog, RNA polymerase II CTD phosphatase  negatively_regulates
# 1                             ergothioneine thione form  negatively_regulates
# 6      SSU72 homolog, RNA polymerase II CTD phosphatase  negatively_regulates
# 7                             ergothioneine thione form  negatively_regulates
# 12     SSU72 homolog, RNA polymerase II CTD phosphatase             regulates
# ...                                                 ...                   ...
# 23463                        (GlcNAc)2 (Man)8 (PP-Dol)1  positively_regulates
# 23470                        (GlcNAc)2 (Man)7 (PP-Dol)1             regulates
# 23471                        (GlcNAc)2 (Man)8 (PP-Dol)1             regulates
# 23494                        (GlcNAc)2 (Man)9 (PP-Dol)1  positively_regulates
# 23502                        (GlcNAc)2 (Man)9 (PP-Dol)1             regulates
#
# [10757 rows x 3 columns]

# %% [markdown]
# #### Chemical regulates gene

# %%
chem_gene_reg = chem_reg_rx.merge(gene_react1.query('type in @membership'), on='end_id', how='inner').drop_duplicates(subset=['start_id_x', 'start_id_y', 'type_x'])

# %%
chem_gene_reg[['start_name_x', 'start_name_y', 'type_x']].sample(20)
# Out:
#                                            start_name_x  \
# 4678                                            ATP(4-)
# 3433                                                 HS
# 4906                                          c-GMP-AMP
# 67                          sapropterin dihydrochloride
# 2121    1-phosphatidyl-1D-myo-inositol 3,4-bisphosphate
# 1967                                                GTP
# 2403    1-phosphatidyl-1D-myo-inositol 3,4-bisphosphate
# 3983                     PYD and CARD domain containing
# 457                                         glutathione
# 590                                           amiloride
# 2102    1-phosphatidyl-1D-myo-inositol 3,4-bisphosphate
# 2789           1-O-acyl-sn-glycero-3-phosphocholine(1+)
# 2374    1-phosphatidyl-1D-myo-inositol 3,4-bisphosphate
# 3917                     PYD and CARD domain containing
# 2040                         adenosine 5'-monophosphate
# 4462                                            ATP(4-)
# 167                                                 FMN
# 547   N(omega),N'(omega)-dimethyl-L-arginine zwitterion
# 3453                                                 HS
# 698                          adenosine 5'-monophosphate
#
#                                            start_name_y                type_x
# 4678  eukaryotic translation initiation factor 3 sub...  positively_regulates
# 3433                                               FGF3  positively_regulates
# 4906                                              XRCC5  positively_regulates
# 67                                 GTP cyclohydrolase I  negatively_regulates
# 2121  Eps15 (endocytosis protein) Homologous Sequenc...  positively_regulates
# 1967                                         eif-2alpha  positively_regulates
# 2403                                               FZD4  positively_regulates
# 3983                                             pygl-1  positively_regulates
# 457                              glutathione synthetase  negatively_regulates
# 590                                              egas-3  negatively_regulates
# 2102                                      SyNapTotagmin  positively_regulates
# 2789                                             tbcb-1  positively_regulates
# 2374                                              ITSN2  positively_regulates
# 3917                                              che-6  positively_regulates
# 2040                                              CAB39  positively_regulates
# 4462                                             EIF1AX  positively_regulates
# 167                                             SLC52A3  negatively_regulates
# 547                                               CALM1  negatively_regulates
# 3453                                              FGF17  positively_regulates
# 698                                             pfk-1.1  positively_regulates

# %%
reg_edges = pd.concat([gene_gene_reg, gene_chem_reg, chem_gene_reg], sort=False)

reg_edges = reg_edges.rename(columns={'start_id_x': 'start_id', 'start_id_y': 'end_id', 'end_id': 'merge_id'})

reg_edges = reg_edges[['start_id', 'end_id', 'type_x', 'source_x', 'dsrc_type_x', 'comp_type_x', 'license_x', 'merge_id']].drop_duplicates()
reg_edges.columns = [c.replace('_x', '') for c in reg_edges.columns]

reg_edges['dsrc_type'] = 'computed'
reg_edges['comp_type'] = 'punning'

reg_edges = gt.order_cols(reg_edges)

# %%
reg_edges
# Out:
#               start_id           end_id                  type    source  \
# 307      NCBIGene:8837    NCBIGene:7186  negatively_regulates  Reactome
# 309      NCBIGene:8837    NCBIGene:8717  negatively_regulates  Reactome
# 310      NCBIGene:8837    NCBIGene:8737  negatively_regulates  Reactome
# 319   UniProt:O15519-2    NCBIGene:7186  negatively_regulates  Reactome
# 321   UniProt:O15519-2    NCBIGene:8717  negatively_regulates  Reactome
# ...                ...              ...                   ...       ...
# 4949       CHEBI:58095  NCBIGene:181633  negatively_regulates  Reactome
# 4950       CHEBI:58095  NCBIGene:185086  negatively_regulates  Reactome
# 4951       CHEBI:58095   UniProt:Q8MP09  negatively_regulates  Reactome
# 4952       CHEBI:58095   UniProt:Q9XX97  negatively_regulates  Reactome
# 4953       CHEBI:58095     NCBIGene:883  negatively_regulates  Reactome
#
#      dsrc_type comp_type  license            merge_id
# 307   computed   punning  CC0 1.0  REACT:R-HSA-141159
# 309   computed   punning  CC0 1.0  REACT:R-HSA-141159
# 310   computed   punning  CC0 1.0  REACT:R-HSA-141159
# 319   computed   punning  CC0 1.0  REACT:R-HSA-141159
# 321   computed   punning  CC0 1.0  REACT:R-HSA-141159
# ...        ...       ...      ...                 ...
# 4949  computed   punning  CC0 1.0  REACT:R-CEL-893596
# 4950  computed   punning  CC0 1.0  REACT:R-CEL-893596
# 4951  computed   punning  CC0 1.0  REACT:R-CEL-893596
# 4952  computed   punning  CC0 1.0  REACT:R-CEL-893596
# 4953  computed   punning  CC0 1.0  REACT:R-HSA-893596
#
# [65209 rows x 8 columns]

# %%
new_edges.append(reg_edges)

# %% [markdown]
# ## Gene - Disease assocations

# %%
react_dis = combo.query('start_label == "Reaction" and end_label == "Disease"')
alt_gene = gene_react.query('type == "fucntion_altered_in"')

gd_edges = react_dis.merge(alt_gene, left_on='start_id', right_on='end_id', how='inner')

alt_gets = gd_edges['start_id_y'].unique()

# %%
combo.query('start_id in @alt_gets and end_label == "Disease"')['type'].value_counts()
# Out:
# marker_or_mechanism    1087
# associated_with         601
# therapeutic              44
# Name: type, dtype: int64

# %%
react_gene_dis = set(gd_edges[['start_id_y', 'end_id_x']].apply(tuple, axis=1))

# %%
nw_gene_dis_tups = set(combo.query('start_id in @alt_gets and end_label == "Disease"')[['start_id', 'end_id']].apply(tuple, axis=1))

# %%
len(react_gene_dis)
# Out:
# 380

# %%
len(nw_gene_dis_tups)
# Out:
# 1611

# %%
len(react_gene_dis - nw_gene_dis_tups)
# Out:
# 355

# %%
id_to_name = nodes.set_index('id')['name'].to_dict()

# %%
gd_edges['end_id_x'].map(id_to_name).value_counts()
# Out:
# cancer                                         1693
# bone development disease                        503
# T-cell lymphoblastic leukemia/lymphoma          142
# Noonan syndrome                                  34
# cardiofaciocutaneous syndrome                    31
# ovarian cancer                                   30
# cystic fibrosis                                  29
# chronic myeloid leukemia                         28
# female reproductive endometrioid cancer          25
# holoprosencephaly                                18
# subacute leukemia                                15
# myelodysplastic/myeloproliferative neoplasm      15
# acute lymphoblastic leukemia                     15
# acrocephalosyndactylia                           14
# craniosynostosis                                 13
# breast cancer                                     9
# large intestine cancer                            5
# rhabdomyosarcoma                                  3
# multiple myeloma                                  2
# glioblastoma multiforme                           2
# stomach cancer                                    2
# neonatal diabetes mellitus                        1
# severe combined immunodeficiency                  1
# primary immunodeficiency disease                  1
# Name: end_id_x, dtype: int64

# %%
gd_edges['start_id_y'].map(id_to_name).value_counts()
# Out:
# FGF2      71
# FGF1      71
# FGF9      71
# FGF20     68
# FGF5      68
#           ..
# NFKBIA     2
# ERLIN1     2
# DERL3      2
# JAK2       1
# ABCC8      1
# Name: start_id_y, Length: 141, dtype: int64

# %% [markdown]
# These are all pretty generic... but we will keep them

# %%
gd_edges = gd_edges.rename(columns={'start_id_x': 'reactome_id', 'end_id_x': 'end_id', 'start_id_y': 'start_id'})[['start_id', 'end_id', 'type_y', 'source_y', 'dsrc_type_y', 'comp_type_y', 'license_y', 'reactome_id']]


gd_edges.columns = [c.replace('_y', '') for c in gd_edges.columns]
gd_edges['type'] = 'marker_or_mechanism'
gd_edges = gt.order_cols(gd_edges).drop_duplicates()

gd_edges.head(4)
# Out:
#          start_id    end_id                 type    source dsrc_type  \
# 0  NCBIGene:11140  DOID:162  marker_or_mechanism  Reactome   curated
# 1   NCBIGene:1950  DOID:162  marker_or_mechanism  Reactome   curated
# 2   NCBIGene:1956  DOID:162  marker_or_mechanism  Reactome   curated
# 3   NCBIGene:3320  DOID:162  marker_or_mechanism  Reactome   curated
#
#   comp_type  license          reactome_id
# 0       NaN  CC0 1.0  REACT:R-HSA-1169421
# 1       NaN  CC0 1.0  REACT:R-HSA-1169421
# 2       NaN  CC0 1.0  REACT:R-HSA-1169421
# 3       NaN  CC0 1.0  REACT:R-HSA-1169421

# %%
gd_edges = dfp.combine_group_cols_on_char(gd_edges, ['start_id', 'end_id', 'type'], sort=True, prog=False)

# %%
len(gd_edges)
# Out:
# 380

# %%
new_edges.append(gd_edges)

# %% [markdown]
# ## Put it all together

# %%
edges_to_add = pd.concat(new_edges, ignore_index=True, sort=False)

# %%
# In reaction with is a direct curated relationship...
# These edges we made by merging across nodes is equivalent to punning, so lets account for that
pun_idx = edges_to_add.query('type != "in_reaction_with"').index
edges_to_add.loc[pun_idx, 'comp_type'] = 'punning'
edges_to_add.loc[pun_idx, 'dsrc_type'] = 'computed'

# %%
edges_to_add = dfp.combine_group_cols_on_char(edges_to_add, ['start_id', 'end_id', 'type'], sort=True, prog=False)

# %%
len(edges_to_add)
# Out:
# 259373

# %%
edges_to_add['type'].value_counts()
# Out:
# in_reaction_with        151733
# regulates                48796
# part_of                  27468
# positively_regulates     11490
# enables                   9382
# negatively_regulates      5462
# involved_in               3378
# in_taxon                  1284
# marker_or_mechanism        380
# Name: type, dtype: int64

# %%
new_combo = gt.combine_nodes_and_edges(nodes, edges_to_add)

# %%
me_counts = new_combo.groupby(['start_label', 'end_label', 'type']).apply(len).rename('count').to_frame().reset_index().sort_values('type')

# %%
len(me_counts)
# Out:
# 105

# %%
me_counts.sort_values('count', ascending=False).head(50)
# Out:
#     start_label           end_label                  type   count
# 55         Gene            Compound      in_reaction_with  102702
# 66         Gene                Gene             regulates   35602
# 60         Gene                Drug      in_reaction_with   21920
# 88      Protein            Compound      in_reaction_with   18069
# 51         Gene  Cellular Component               part_of   15660
# 14      Complex                Gene  positively_regulates    7666
# 58         Gene            Compound             regulates    5649
# 68         Gene  Molecular Function               enables    5625
# 7       Complex            Compound      in_reaction_with    4927
# 27     Compound  Cellular Component               part_of    4701
# 92      Protein                Drug      in_reaction_with    3872
# 13      Complex                Gene  negatively_regulates    3532
# 85      Protein  Cellular Component               part_of    3327
# 63         Gene                Drug             regulates    2738
# 4       Complex  Cellular Component               part_of    2559
# 32     Compound  Molecular Function               enables    2370
# 47         Gene  Biological Process           involved_in    1853
# 72         Gene             Protein             regulates    1778
# 73         Gene               Taxon              in_taxon    1192
# 39         Drug  Cellular Component               part_of    1182
# 54         Gene             Complex             regulates    1045
# 31     Compound                Gene  positively_regulates    1026
# 17      Complex  Molecular Function               enables     833
# 91      Protein            Compound             regulates     572
# 81      Protein  Biological Process           involved_in     559
# 9       Complex            Compound  positively_regulates     530
# 65         Gene                Gene  positively_regulates     465
# 23     Compound  Biological Process           involved_in     455
# 0       Complex  Biological Process           involved_in     445
# 98      Protein                Gene             regulates     397
# 21      Complex             Protein  positively_regulates     396
# 59         Gene             Disease   marker_or_mechanism     380
# 67         Gene           Micro RNA             regulates     376
# 15      Complex           Micro RNA  negatively_regulates     361
# 99      Protein  Molecular Function               enables     288
# 8       Complex            Compound  negatively_regulates     266
# 44         Drug  Molecular Function               enables     265
# 57         Gene            Compound  positively_regulates     259
# 37     Compound             Protein  positively_regulates     242
# 30     Compound                Gene  negatively_regulates     241
# 10      Complex                Drug      in_reaction_with     238
# 103     Protein             Protein             regulates     233
# 12      Complex                Drug  positively_regulates     214
# 95      Protein                Drug             regulates     212
# 20      Complex             Protein  negatively_regulates     203
# 48         Gene  Biological Process  negatively_regulates     144
# 87      Protein             Complex             regulates     133
# 43         Drug                Gene  positively_regulates     123
# 56         Gene            Compound  negatively_regulates     119
# 29     Compound             Complex  positively_regulates     104

# %%
remove_nodes = nodes.query('label == "Reaction"')['id'].unique()

edges_out = edges.query('start_id not in @remove_nodes and end_id not in @remove_nodes')
print(len(edges), len(edges_out))
# Out:
# 9267553 8723617

# %%
edges_out = pd.concat([edges_out, edges_to_add], sort=False)
edges_out = dfp.combine_group_cols_on_char(edges_out, ['start_id', 'end_id', 'type'], sort=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='total_progress', max=3.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='dsrc_type', max=3391.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='source', max=3391.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='license', max=3391.0, style=ProgressStyle(description_wid…

# %%
len(edges_out)
# Out:
# 8979599

# %%
edge_ids = set(edges_out[['start_id', 'end_id']].stack().unique())
node_ids = set(nodes['id'])

edge_ids - node_ids
# Out:
# set()

# %% [markdown]
# # Save

# %%
this_name = '11_Reactions_and_Regulation'

out_dir = load_dir.joinpath(this_name, 'out')
out_dir.mkdir(exist_ok=True, parents=True)

# %%
# Nodes were unchanged
nodes.to_csv(out_dir.joinpath('nodes.csv'), index=False)
edges_out.to_csv(out_dir.joinpath('edges.csv'), index=False)
