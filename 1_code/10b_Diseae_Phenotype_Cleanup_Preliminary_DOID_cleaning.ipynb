# %% [markdown]
# # Cleaning up some DOID info
#
# It was noticed that some disease ontology IDs have a cross-reference to another disease ontology ID... they should all have their own separate entity at this point, so we need to figure out which is the correct identifier and merge all instances of the false one into the correct one.  We will do this by taking the true name for the identifier from DO directly, then see wheather the node's ID or it's cross-reference maps to the same name as the node's name.

# %%
import pandas as pd
from pathlib import Path
from data_tools.wiki import get_curi_xrefs
from data_tools.df_processing import expand_col_on_char, combine_group_cols_on_char

import obonet
import networkx
# Out:
# /opt/mmayers/software/anaconda3/envs/ml/lib/python3.6/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
this_name = '10b_Diseae_Phenotype_Cleanup_preliminary_DOID_cleaning'
out_dir = Path('../2_pipeline').resolve().joinpath(this_name, 'out')

out_dir.mkdir(parents=True, exist_ok=True)

# %%
nw_name = '09_GAUSS_Geneset_to_Phenotype'
nw_dir = Path('../2_pipeline').resolve().joinpath(nw_name, 'out')

# %%
nodes = pd.read_csv(nw_dir.joinpath('nodes.csv'), dtype=str)
edges = pd.read_csv(nw_dir.joinpath('edges.csv'), dtype=str)

# %%
doid = 'https://github.com/DiseaseOntology/HumanDiseaseOntology/raw/master/src/ontology/doid.obo'
graph = obonet.read_obo(doid)
len(graph)
# Out:
# 10334

# %%
id_to_name = {id_: data.get('name') for id_, data in graph.nodes(data=True)}

# %%
nwid_to_name = nodes.set_index('id')['name'].to_dict()

# %%
diseases = nodes.query('label == "Disease"')

# %%
doid_xref = get_curi_xrefs(diseases, 'DOID')
doid_xref['id_name'] = doid_xref['id'].map(id_to_name)
doid_xref['xref_name'] = doid_xref['xrefs'].map(id_to_name)
doid_xref['nw_name'] = doid_xref['id'].map(nwid_to_name)

mismatch_doid_xref = doid_xref[doid_xref['id'] != doid_xref['xrefs']].copy()

# %%
disease_ids = diseases['id'].unique()

# %%
len(mismatch_doid_xref)
# Out:
# 122

# %%
mismatch_doid_xref.query('xrefs in @disease_ids')
# Out:
#                  id         xrefs                        id_name  \
# 160    DOID:0040098    DOID:14482          pemphigus gestationis
# 210    DOID:0050047  DOID:0050053  Flinders Island spotted fever
# 220    DOID:0050053  DOID:0050047                            NaN
# 295    DOID:0050119     DOID:2365                            NaN
# 538    DOID:0050287     DOID:4271                            NaN
# ...             ...           ...                            ...
# 44010     DOID:9498     DOID:5870         pulmonary eosinophilia
# 44182     DOID:9678     DOID:9681                            NaN
# 44186     DOID:9681     DOID:9678          cervical incompetence
# 44275     DOID:9829  DOID:0060001                            NaN
# 44360     DOID:9929  DOID:0080176                            NaN
#
#                            xref_name                        nw_name
# 160           pemphigoid gestationis             herpes gestationis
# 210                              NaN  Flinders Island spotted fever
# 220    Flinders Island spotted fever  Flinders Island spotted fever
# 295           West Nile encephalitis         West Nile encephalitis
# 538                 microsporidiosis               microsporidiosis
# ...                              ...                            ...
# 44010         eosinophilic pneumonia         eosinophilic pneumonia
# 44182          cervical incompetence          cervical incompetence
# 44186                            NaN          cervical incompetence
# 44275            withdrawal disorder            withdrawal syndrome
# 44360       meningococcal meningitis       meningococcal meningitis
#
# [122 rows x 5 columns]

# %% [markdown]
# These are all duplicated ids that should be merged...

# %%
keep_id = mismatch_doid_xref[mismatch_doid_xref['id_name'] == mismatch_doid_xref['nw_name']]['id'].unique()
mismatch_doid_xref.query('id in @keep_id and xrefs in @keep_id')
# Out:
#                  id         xrefs                                   id_name  \
# 10779    DOID:11132     DOID:2883                     prostatic hypertrophy
# 14121     DOID:1595     DOID:1470                     endogenous depression
# 14123     DOID:1595     DOID:2848                     endogenous depression
# 15545     DOID:2848     DOID:1470                               melancholia
# 15546     DOID:2848     DOID:1595                               melancholia
# 30122  DOID:0050783  DOID:0050784  secondary progressive multiple sclerosis
# 30123  DOID:0050783  DOID:0050785  secondary progressive multiple sclerosis
# 30129  DOID:0050784  DOID:0050783    primary progressive multiple sclerosis
# 30131  DOID:0050784  DOID:0050785    primary progressive multiple sclerosis
# 30137  DOID:0050785  DOID:0050783  progressive relapsing multiple sclerosis
# 30138  DOID:0050785  DOID:0050784  progressive relapsing multiple sclerosis
# 38009     DOID:1470     DOID:1595                 major depressive disorder
# 38010     DOID:1470     DOID:2848                 major depressive disorder
# 39571     DOID:2883    DOID:11132                         prostatic adenoma
#
#                                       xref_name  \
# 10779                         prostatic adenoma
# 14121                 major depressive disorder
# 14123                               melancholia
# 15545                 major depressive disorder
# 15546                     endogenous depression
# 30122    primary progressive multiple sclerosis
# 30123  progressive relapsing multiple sclerosis
# 30129  secondary progressive multiple sclerosis
# 30131  progressive relapsing multiple sclerosis
# 30137  secondary progressive multiple sclerosis
# 30138    primary progressive multiple sclerosis
# 38009                     endogenous depression
# 38010                               melancholia
# 39571                     prostatic hypertrophy
#
#                                         nw_name
# 10779                     prostatic hypertrophy
# 14121                     endogenous depression
# 14123                     endogenous depression
# 15545                               melancholia
# 15546                               melancholia
# 30122  secondary progressive multiple sclerosis
# 30123  secondary progressive multiple sclerosis
# 30129    primary progressive multiple sclerosis
# 30131    primary progressive multiple sclerosis
# 30137  progressive relapsing multiple sclerosis
# 30138  progressive relapsing multiple sclerosis
# 38009                 major depressive disorder
# 38010                 major depressive disorder
# 39571                         prostatic adenoma

# %%
fix_disease = diseases.query('id in @keep_id')
fix_idx = fix_disease.index

fix_disease = expand_col_on_char(fix_disease, 'xrefs', '|')

fix_disease.query('xrefs in @keep_id and id != xrefs')
# Out:
#                id                                      name    label  \
# 24     DOID:11132                     prostatic hypertrophy  Disease
# 34      DOID:1595                     endogenous depression  Disease
# 36      DOID:1595                     endogenous depression  Disease
# 45      DOID:2848                               melancholia  Disease
# 46      DOID:2848                               melancholia  Disease
# 68   DOID:0050783  secondary progressive multiple sclerosis  Disease
# 69   DOID:0050783  secondary progressive multiple sclerosis  Disease
# 75   DOID:0050784    primary progressive multiple sclerosis  Disease
# 77   DOID:0050784    primary progressive multiple sclerosis  Disease
# 83   DOID:0050785  progressive relapsing multiple sclerosis  Disease
# 84   DOID:0050785  progressive relapsing multiple sclerosis  Disease
# 136     DOID:1470                 major depressive disorder  Disease
# 137     DOID:1470                 major depressive disorder  Disease
# 156     DOID:2883                         prostatic adenoma  Disease
#
#             xrefs  source
# 24      DOID:2883     NaN
# 34      DOID:1470     NaN
# 36      DOID:2848     NaN
# 45      DOID:1470     NaN
# 46      DOID:1595     NaN
# 68   DOID:0050784     NaN
# 69   DOID:0050785     NaN
# 75   DOID:0050783     NaN
# 77   DOID:0050785     NaN
# 83   DOID:0050783     NaN
# 84   DOID:0050784     NaN
# 136     DOID:1595     NaN
# 137     DOID:2848     NaN
# 156    DOID:11132     NaN

# %%
drop_idx = fix_disease.query('xrefs in @keep_id and id != xrefs').index
fix_disease = fix_disease.drop(drop_idx)

fix_disease = combine_group_cols_on_char(fix_disease, ['id'], ['xrefs'], sort=True, prog=False)

# %%
diseases = diseases.drop(fix_idx)
diseases = pd.concat([diseases, fix_disease], sort=False, ignore_index=True)

# %%
doid_xref = get_curi_xrefs(diseases, 'DOID')
doid_xref['id_name'] = doid_xref['id'].map(id_to_name)
doid_xref['xref_name'] = doid_xref['xrefs'].map(id_to_name)
doid_xref['nw_name'] = doid_xref['id'].map(nwid_to_name)

mismatch_doid_xref = doid_xref[doid_xref['id'] != doid_xref['xrefs']].copy()

either = mismatch_doid_xref[mismatch_doid_xref['id_name'].isnull() & mismatch_doid_xref['xref_name'].isnull()]['id'].unique()

mismatch_doid_xref.query('id in @either')
# Out:
#                  id         xrefs id_name      xref_name  \
# 9701     DOID:10059    DOID:10111     NaN            NaN
# 9725     DOID:10111    DOID:10059     NaN            NaN
# 10710    DOID:11099     DOID:1709     NaN            NaN
# 11799      DOID:122      DOID:284     NaN            NaN
# 12140    DOID:12647     DOID:9940     NaN            NaN
# 12853    DOID:13469     DOID:5000     NaN            NaN
# 14216     DOID:1709    DOID:11099     NaN            NaN
# 15423     DOID:2778     DOID:2779     NaN            NaN
# 15424     DOID:2779     DOID:2778     NaN            NaN
# 15498      DOID:284      DOID:122     NaN            NaN
# 18503     DOID:5000    DOID:13469     NaN            NaN
# 24597     DOID:9940    DOID:12647     NaN            NaN
# 29191  DOID:0050341     DOID:2313     NaN            NaN
# 35504    DOID:11092  DOID:0060859     NaN  salmonellosis
# 35506    DOID:11092     DOID:1466     NaN            NaN
# 37811     DOID:1466  DOID:0060859     NaN  salmonellosis
# 37812     DOID:1466    DOID:11092     NaN            NaN
# 38813     DOID:2313  DOID:0050341     NaN            NaN
#
#                                                  nw_name
# 9701   Congenital or acquired abnormality of vagina c...
# 9725   Congenital or acquired abnormality of vagina c...
# 10710          primary Rickettsiaceae infectious disease
# 11799                                   abdominal cancer
# 12140  congenital or acquired abnormality of vulva co...
# 12853                       secondary cutaneous syphilis
# 14216                                      rickettsiosis
# 15423            tumors of body of uterus, with delivery
# 15424            tumors of body of uterus, with delivery
# 15498                                   abdominal cancer
# 18503                       secondary cutaneous syphilis
# 24597  congenital or acquired abnormality of vulva co...
# 29191                 Actinomycetales infectious disease
# 35504                                      salmonellosis
# 35506                                      salmonellosis
# 37811                                      salmonellosis
# 37812                                      salmonellosis
# 38813                 Actinomycetales infectious disease

# %%
set(either)
# Out:
# {'DOID:0050341',
#  'DOID:10059',
#  'DOID:10111',
#  'DOID:11092',
#  'DOID:11099',
#  'DOID:122',
#  'DOID:12647',
#  'DOID:13469',
#  'DOID:1466',
#  'DOID:1709',
#  'DOID:2313',
#  'DOID:2778',
#  'DOID:2779',
#  'DOID:284',
#  'DOID:5000',
#  'DOID:9940'}

# %%
keep_id = mismatch_doid_xref[~mismatch_doid_xref['id_name'].isnull() & mismatch_doid_xref['xref_name'].isnull()]['id'].unique()
keep_xref = mismatch_doid_xref[mismatch_doid_xref['id_name'].isnull() & ~mismatch_doid_xref['xref_name'].isnull()]['xrefs'].unique()

set(keep_id) == set(keep_xref)
# Out:
# True

# %%
mismatch_doid_xref.query('xrefs in @keep_id')
# Out:
#                  id         xrefs                        id_name  \
# 217    DOID:0050053  DOID:0050047                            NaN
# 292    DOID:0050119     DOID:2365                            NaN
# 535    DOID:0050287     DOID:4271                            NaN
# 1881   DOID:0060006  DOID:0090012                            NaN
# 2092   DOID:0060120  DOID:0060094                            NaN
# 2220   DOID:0060171  DOID:0080422                            NaN
# 4117   DOID:0070076  DOID:0050880                            NaN
# 15602     DOID:2947     DOID:9682                            NaN
# 15884     DOID:3166  DOID:0060888                            NaN
# 16547     DOID:3680    DOID:11934                            NaN
# 24559     DOID:9915     DOID:5090                            NaN
# 29160  DOID:0050309     DOID:8622                            NaN
# 29170  DOID:0050329      DOID:150                            NaN
# 29198  DOID:0050399     DOID:1116                            NaN
# 30429  DOID:0060052      DOID:863                            NaN
# 31864  DOID:0070075  DOID:0060352                            NaN
# 31973  DOID:0080013      DOID:700                            NaN
# 31997  DOID:0080022    DOID:14773                            NaN
# 35504    DOID:11092  DOID:0060859                            NaN
# 35782    DOID:11503    DOID:12785  diabetic autonomic neuropathy
# 36146    DOID:12052  DOID:0080159                            NaN
# 36324    DOID:12255  DOID:0050811                            NaN
# 36338    DOID:12269    DOID:13593                            NaN
# 36686    DOID:12785    DOID:11503        diabetic polyneuropathy
# 37811     DOID:1466  DOID:0060859                            NaN
# 38062     DOID:1550    DOID:11714                            NaN
# 38095      DOID:157      DOID:305                            NaN
# 38883     DOID:2370    DOID:11503                            NaN
# 38884     DOID:2370    DOID:12785                            NaN
# 38897     DOID:2376  DOID:0050783                            NaN
# 38898     DOID:2376  DOID:0050784                            NaN
# 38899     DOID:2376  DOID:0050785                            NaN
# 40808     DOID:4121     DOID:2366                            NaN
# 42114     DOID:5928  DOID:0110861                            NaN
# 42240      DOID:611     DOID:6612                            NaN
# 42944     DOID:8524  DOID:0050873                            NaN
# 43457     DOID:9195  DOID:0080158                            NaN
# 43999     DOID:9678     DOID:9681                            NaN
# 44087     DOID:9829  DOID:0060001                            NaN
# 44172     DOID:9929  DOID:0080176                            NaN
#
#                                                xref_name  \
# 217                        Flinders Island spotted fever
# 292                               West Nile encephalitis
# 535                                     microsporidiosis
# 1881   severe combined immunodeficiency with sensitiv...
# 2092                                bone benign neoplasm
# 2220                                     Dravet syndrome
# 4117                            Koolen de Vries syndrome
# 15602                                       yellow fever
# 15884              transient myeloproliferative syndrome
# 16547                               head and neck cancer
# 24559                                     sternum cancer
# 29160                                            measles
# 29170                           disease of mental health
# 29198                                          pertussis
# 30429                             nervous system disease
# 31864                               Kleefstra syndrome 1
# 31973                   mitochondrial metabolism disease
# 31997                          cartilage-hair hypoplasia
# 35504                                      salmonellosis
# 35782                            diabetic polyneuropathy
# 36146                            Cryptococcal meningitis
# 36324                     congenital adrenal hyperplasia
# 36338                                          eclampsia
# 36686                      diabetic autonomic neuropathy
# 37811                                      salmonellosis
# 38062                               gestational diabetes
# 38095                                          carcinoma
# 38883                      diabetic autonomic neuropathy
# 38884                            diabetic polyneuropathy
# 38897           secondary progressive multiple sclerosis
# 38898             primary progressive multiple sclerosis
# 38899           progressive relapsing multiple sclerosis
# 40808                                    West Nile fever
# 42114      autosomal recessive polycystic kidney disease
# 42240                      leukocyte adhesion deficiency
# 42944                                follicular lymphoma
# 43457                     herpes simplex virus keratitis
# 43999                              cervical incompetence
# 44087                                withdrawal disorder
# 44172                           meningococcal meningitis
#
#                                       nw_name
# 217             Flinders Island spotted fever
# 292                    West Nile encephalitis
# 535                          microsporidiosis
# 1881                       artemis deficiency
# 2092                     bone benign neoplasm
# 2220                          Dravet syndrome
# 4117                 Koolen de Vries syndrome
# 15602                            yellow fever
# 15884   transient myeloproliferative syndrome
# 16547                    head and neck cancer
# 24559                          sternum cancer
# 29160                                 measles
# 29170                         mental disorder
# 29198                               pertussis
# 30429                   neurological disorder
# 31864                      Kleefstra syndrome
# 31973                   mitochondrial disease
# 31997     McKusick type metaphyseal dysplasia
# 35504                           salmonellosis
# 35782                    diabetic nephropathy
# 36146                 cryptococcal meningitis
# 36324          congenital adrenal hyperplasia
# 36338                               eclampsia
# 36686                    diabetic nephropathy
# 37811                           salmonellosis
# 38062                    gestational diabetes
# 38095                               carcinoma
# 38883                    diabetic nephropathy
# 38884                    diabetic nephropathy
# 38897  chronic progressive multiple sclerosis
# 38898  chronic progressive multiple sclerosis
# 38899  chronic progressive multiple sclerosis
# 40808                         West Nile fever
# 42114   Autosomal recessive polycystic kidney
# 42240  leukocyte-adhesion deficiency syndrome
# 42944                     follicular lymphoma
# 43457          herpes simplex virus keratitis
# 43999                   cervical incompetence
# 44087                     withdrawal syndrome
# 44172                meningococcal meningitis

# %%
old_to_new = mismatch_doid_xref.query('id in @keep_id').set_index('xrefs')['id'].to_dict()

old_to_new = {**mismatch_doid_xref.query('xrefs in @keep_id').set_index('id')['xrefs'].to_dict(), **old_to_new}
old_to_new = {**{_id:_id for _id in keep_id}, **old_to_new}

mismatch_doid_xref['new_id'] = mismatch_doid_xref['id'].map(old_to_new)
mismatch_doid_xref['new_id'] = mismatch_doid_xref['new_id'].fillna(mismatch_doid_xref['xrefs'].map(old_to_new))

unmap_subset = mismatch_doid_xref[mismatch_doid_xref['new_id'].isnull()]
unmap_subset
# Out:
#                  id         xrefs                                   id_name  \
# 160    DOID:0040098    DOID:14482                     pemphigus gestationis
# 9701     DOID:10059    DOID:10111                                       NaN
# 9725     DOID:10111    DOID:10059                                       NaN
# 10710    DOID:11099     DOID:1709                                       NaN
# 11799      DOID:122      DOID:284                                       NaN
# 12140    DOID:12647     DOID:9940                                       NaN
# 12853    DOID:13469     DOID:5000                                       NaN
# 13785    DOID:14482  DOID:0040098                    pemphigoid gestationis
# 14216     DOID:1709    DOID:11099                                       NaN
# 15423     DOID:2778     DOID:2779                                       NaN
# 15424     DOID:2779     DOID:2778                                       NaN
# 15498      DOID:284      DOID:122                                       NaN
# 18503     DOID:5000    DOID:13469                                       NaN
# 19580     DOID:5603  DOID:0050523       T-cell acute lymphoblastic leukemia
# 21795     DOID:7235     DOID:7735           pancreatic mucinous cystadenoma
# 22438     DOID:7735     DOID:7235            pancreatic colloid cystadenoma
# 24597     DOID:9940    DOID:12647                                       NaN
# 29118  DOID:0050134     DOID:1563                         cutaneous mycosis
# 29191  DOID:0050341     DOID:2313                                       NaN
# 29508  DOID:0050523     DOID:5603                     adult T-cell leukemia
# 29955  DOID:0050747  DOID:0060901                lymphoplasmacytic lymphoma
# 31820  DOID:0060901  DOID:0050747          Waldenstroem's macroglobulinemia
# 32338  DOID:0080545     DOID:3261                        hyper IgE syndrome
# 38813     DOID:2313  DOID:0050341                                       NaN
# 39881     DOID:3261  DOID:0080545  hyper IgE recurrent infection syndrome 1
# 43827     DOID:9498     DOID:5870                    pulmonary eosinophilia
# 46828     DOID:1563  DOID:0050134                            dermatomycosis
# 46877     DOID:5870     DOID:9498                    eosinophilic pneumonia
#
#                                       xref_name  \
# 160                      pemphigoid gestationis
# 9701                                        NaN
# 9725                                        NaN
# 10710                                       NaN
# 11799                                       NaN
# 12140                                       NaN
# 12853                                       NaN
# 13785                     pemphigus gestationis
# 14216                                       NaN
# 15423                                       NaN
# 15424                                       NaN
# 15498                                       NaN
# 18503                                       NaN
# 19580                     adult T-cell leukemia
# 21795            pancreatic colloid cystadenoma
# 22438           pancreatic mucinous cystadenoma
# 24597                                       NaN
# 29118                            dermatomycosis
# 29191                                       NaN
# 29508       T-cell acute lymphoblastic leukemia
# 29955          Waldenstroem's macroglobulinemia
# 31820                lymphoplasmacytic lymphoma
# 32338  hyper IgE recurrent infection syndrome 1
# 38813                                       NaN
# 39881                        hyper IgE syndrome
# 43827                    eosinophilic pneumonia
# 46828                         cutaneous mycosis
# 46877                    pulmonary eosinophilia
#
#                                                  nw_name new_id
# 160                                   herpes gestationis    NaN
# 9701   Congenital or acquired abnormality of vagina c...    NaN
# 9725   Congenital or acquired abnormality of vagina c...    NaN
# 10710          primary Rickettsiaceae infectious disease    NaN
# 11799                                   abdominal cancer    NaN
# 12140  congenital or acquired abnormality of vulva co...    NaN
# 12853                       secondary cutaneous syphilis    NaN
# 13785                                 herpes gestationis    NaN
# 14216                                      rickettsiosis    NaN
# 15423            tumors of body of uterus, with delivery    NaN
# 15424            tumors of body of uterus, with delivery    NaN
# 15498                                   abdominal cancer    NaN
# 18503                       secondary cutaneous syphilis    NaN
# 19580                              acute T cell leukemia    NaN
# 21795                    Pancreatic mucinous cystadenoma    NaN
# 22438                    Pancreatic mucinous cystadenoma    NaN
# 24597  congenital or acquired abnormality of vulva co...    NaN
# 29118                                     dermatomycosis    NaN
# 29191                 Actinomycetales infectious disease    NaN
# 29508                     Adult T-cell leukemia/lymphoma    NaN
# 29955                    Waldenström's macroglobulinemia    NaN
# 31820                    Waldenström's macroglobulinemia    NaN
# 32338                                     Job's syndrome    NaN
# 38813                 Actinomycetales infectious disease    NaN
# 39881                                     Job's syndrome    NaN
# 43827                             eosinophilic pneumonia    NaN
# 46828                                     dermatomycosis    NaN
# 46877                             eosinophilic pneumonia    NaN

# %%
len(unmap_subset)
# Out:
# 28

# %%
unmap_subset.drop_duplicates(subset='nw_name', keep=False)
# Out:
#                  id         xrefs                              id_name  \
# 10710    DOID:11099     DOID:1709                                  NaN
# 14216     DOID:1709    DOID:11099                                  NaN
# 19580     DOID:5603  DOID:0050523  T-cell acute lymphoblastic leukemia
# 29508  DOID:0050523     DOID:5603                adult T-cell leukemia
#
#                                  xref_name  \
# 10710                                  NaN
# 14216                                  NaN
# 19580                adult T-cell leukemia
# 29508  T-cell acute lymphoblastic leukemia
#
#                                          nw_name new_id
# 10710  primary Rickettsiaceae infectious disease    NaN
# 14216                              rickettsiosis    NaN
# 19580                      acute T cell leukemia    NaN
# 29508             Adult T-cell leukemia/lymphoma    NaN

# %% [markdown]
# These two are very close, we'll do them by hand

# %%
old_to_new = {**{'DOID:11099': 'DOID:1709', 'DOID:1709': 'DOID:1709',
                 'DOID:0050523': 'DOID:0050523', 'DOID:5603':'DOID:0050523'}, **old_to_new}

# %%
mismatch_doid_xref['new_id'] = mismatch_doid_xref['id'].map(old_to_new)
mismatch_doid_xref['new_id'] = mismatch_doid_xref['new_id'].fillna(mismatch_doid_xref['xrefs'].map(old_to_new))
unmap_subset = mismatch_doid_xref[mismatch_doid_xref['new_id'].isnull()]
unmap_subset
# Out:
#                  id         xrefs                                   id_name  \
# 160    DOID:0040098    DOID:14482                     pemphigus gestationis
# 9701     DOID:10059    DOID:10111                                       NaN
# 9725     DOID:10111    DOID:10059                                       NaN
# 11799      DOID:122      DOID:284                                       NaN
# 12140    DOID:12647     DOID:9940                                       NaN
# 12853    DOID:13469     DOID:5000                                       NaN
# 13785    DOID:14482  DOID:0040098                    pemphigoid gestationis
# 15423     DOID:2778     DOID:2779                                       NaN
# 15424     DOID:2779     DOID:2778                                       NaN
# 15498      DOID:284      DOID:122                                       NaN
# 18503     DOID:5000    DOID:13469                                       NaN
# 21795     DOID:7235     DOID:7735           pancreatic mucinous cystadenoma
# 22438     DOID:7735     DOID:7235            pancreatic colloid cystadenoma
# 24597     DOID:9940    DOID:12647                                       NaN
# 29118  DOID:0050134     DOID:1563                         cutaneous mycosis
# 29191  DOID:0050341     DOID:2313                                       NaN
# 29955  DOID:0050747  DOID:0060901                lymphoplasmacytic lymphoma
# 31820  DOID:0060901  DOID:0050747          Waldenstroem's macroglobulinemia
# 32338  DOID:0080545     DOID:3261                        hyper IgE syndrome
# 38813     DOID:2313  DOID:0050341                                       NaN
# 39881     DOID:3261  DOID:0080545  hyper IgE recurrent infection syndrome 1
# 43827     DOID:9498     DOID:5870                    pulmonary eosinophilia
# 46828     DOID:1563  DOID:0050134                            dermatomycosis
# 46877     DOID:5870     DOID:9498                    eosinophilic pneumonia
#
#                                       xref_name  \
# 160                      pemphigoid gestationis
# 9701                                        NaN
# 9725                                        NaN
# 11799                                       NaN
# 12140                                       NaN
# 12853                                       NaN
# 13785                     pemphigus gestationis
# 15423                                       NaN
# 15424                                       NaN
# 15498                                       NaN
# 18503                                       NaN
# 21795            pancreatic colloid cystadenoma
# 22438           pancreatic mucinous cystadenoma
# 24597                                       NaN
# 29118                            dermatomycosis
# 29191                                       NaN
# 29955          Waldenstroem's macroglobulinemia
# 31820                lymphoplasmacytic lymphoma
# 32338  hyper IgE recurrent infection syndrome 1
# 38813                                       NaN
# 39881                        hyper IgE syndrome
# 43827                    eosinophilic pneumonia
# 46828                         cutaneous mycosis
# 46877                    pulmonary eosinophilia
#
#                                                  nw_name new_id
# 160                                   herpes gestationis    NaN
# 9701   Congenital or acquired abnormality of vagina c...    NaN
# 9725   Congenital or acquired abnormality of vagina c...    NaN
# 11799                                   abdominal cancer    NaN
# 12140  congenital or acquired abnormality of vulva co...    NaN
# 12853                       secondary cutaneous syphilis    NaN
# 13785                                 herpes gestationis    NaN
# 15423            tumors of body of uterus, with delivery    NaN
# 15424            tumors of body of uterus, with delivery    NaN
# 15498                                   abdominal cancer    NaN
# 18503                       secondary cutaneous syphilis    NaN
# 21795                    Pancreatic mucinous cystadenoma    NaN
# 22438                    Pancreatic mucinous cystadenoma    NaN
# 24597  congenital or acquired abnormality of vulva co...    NaN
# 29118                                     dermatomycosis    NaN
# 29191                 Actinomycetales infectious disease    NaN
# 29955                    Waldenström's macroglobulinemia    NaN
# 31820                    Waldenström's macroglobulinemia    NaN
# 32338                                     Job's syndrome    NaN
# 38813                 Actinomycetales infectious disease    NaN
# 39881                                     Job's syndrome    NaN
# 43827                             eosinophilic pneumonia    NaN
# 46828                                     dermatomycosis    NaN
# 46877                             eosinophilic pneumonia    NaN

# %%
dup_ids = unmap_subset.drop_duplicates(subset='nw_name')['id'].unique()
dup_xref = unmap_subset.drop_duplicates(subset='nw_name')['xrefs'].unique()

# %%
len(set(unmap_subset[['id', 'xrefs']].stack()))
# Out:
# 24

# %%
len(unmap_subset.query('id in @dup_xref'))
# Out:
# 12

# %%
old_to_new = {**unmap_subset.query('id in @dup_ids').set_index('xrefs')['id'].to_dict(), **old_to_new}
old_to_new = {**{_id:_id for _id in dup_ids}, **old_to_new}

mismatch_doid_xref['new_id'] = mismatch_doid_xref['id'].map(old_to_new)
mismatch_doid_xref['new_id'] = mismatch_doid_xref['new_id'].fillna(mismatch_doid_xref['xrefs'].map(old_to_new))
mismatch_doid_xref.count()
# Out:
# id           108
# xrefs        108
# id_name       54
# xref_name     54
# nw_name      108
# new_id       108
# dtype: int64

# %%
len(mismatch_doid_xref['new_id'].drop_duplicates())
# Out:
# 51

# %%
to_query = mismatch_doid_xref['id'].unique()
to_fix = diseases.query('id in @to_query')
fix_idx = to_fix.index

diseases = diseases.drop(fix_idx)

# %%
to_fix = expand_col_on_char(to_fix, 'xrefs', '|')
to_fix['id'] = to_fix['id'].map(old_to_new)
fixed = combine_group_cols_on_char(to_fix, ['id'], ['xrefs'], sort=True, prog=False)

len(fixed)
# Out:
# 51

# %%
diseases = pd.concat([diseases, fixed], sort=False, ignore_index=True)

# %%
fixed_ids = list(old_to_new.keys())

# %%
fix_edges = edges.query('start_id in @fixed_ids or end_id in @fixed_ids').copy()
fix_idx = fix_edges.index

edges = edges.drop(fix_idx)

# %%
fix_edges['start_id'] = fix_edges['start_id'].map(old_to_new).fillna(fix_edges['start_id'])
fix_edges['end_id'] = fix_edges['end_id'].map(old_to_new).fillna(fix_edges['end_id'])

# %%
fix_edges = combine_group_cols_on_char(fix_edges, ['start_id', 'end_id', 'type'], sort=True, prog=False)

edges = pd.concat([edges, fix_edges], ignore_index=True, sort=False)

# %%
pd.DataFrame({'id_old': old_to_new.keys(), 'id': old_to_new.values()}).to_csv(out_dir.joinpath('old_to_new_map.csv'), index=False)

# %%
nodes = pd.concat([nodes.query('label != "Disease"'), diseases], sort=False, ignore_index=True)

# %%
nodes.to_csv(out_dir.joinpath('nodes.csv'), index=False)
edges.to_csv(out_dir.joinpath('edges.csv'), index=False)
