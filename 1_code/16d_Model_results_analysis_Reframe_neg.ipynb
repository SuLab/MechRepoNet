# %% [markdown]
# # Examine some of the results for ReFrame compounds
#
# Here we will look at ReFrame compounds and the diseases they're predicted to treat. For this, we will only use the subset of diseases with no known treatments within the network.

# %%
import pickle
import numpy as np
import pandas as pd
from pathlib import Path

# %matplotlib inline
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
load_dir = Path('../2_pipeline').resolve()
model_name = '15_Final_Model_Training'

nw_dir = load_dir.joinpath('12d_Preprocessing-Abbreviations_and_Biolink', 'out')
hyp_dir = load_dir.joinpath('13c_Model_Prep_Hyperparam_tuning', 'out')
model_dir = load_dir.joinpath(model_name, 'out')

# %%
this_name = '16d_Model_results_analysis_Reframe_neg'
out_dir = load_dir.joinpath(this_name, 'out')

out_dir.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ### Load and process the network

# %%
nodes = pd.read_csv(nw_dir.joinpath('nodes_biolink.csv'), dtype=str)
edges = pd.read_csv(nw_dir.joinpath('edges_biolink.csv'), dtype=str)

# %%
best_param = pickle.load(open(hyp_dir.joinpath('best_param.pkl'), 'rb'))

# %%
from hetnet_ml.extractor import MatrixFormattedGraph
mg = MatrixFormattedGraph(nodes, edges, 'ChemicalSubstance', 'Disease', max_length=4, w=best_param['w'], n_jobs=30)
# Out:
# Processing node and edge data...
# Initializing metagraph...
# Generating adjacency matrices...
# 100%|██████████| 68/68 [00:56<00:00,  1.21it/s]
# Determining degrees for each node and metaedge
# 100%|██████████| 68/68 [00:34<00:00,  1.97it/s]
# Weighting matrices by degree with dampening factor 0.5665616931869023...
# 100%|██████████| 68/68 [00:00<00:00, 129.87it/s]

# %% [markdown]
# ### Get relevent elements of model

# %%
model = pickle.load(open(model_dir.joinpath('model.pkl'), 'rb'))
# Out:
# /opt/mmayers/software/anaconda3/envs/ml/lib/python3.6/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
res = pd.read_csv(model_dir.joinpath('results.csv'))
coef = pd.read_csv(model_dir.joinpath('coef.csv'))
len(res)
# Out:
# 90996724

# %%
metapaths = coef.query('feature != "intercept"')['feature'].tolist()

# %%
from data_tools.graphs import dataframes_to_metagraph, metapaths_to_json
metagraph = dataframes_to_metagraph(nodes, edges)

all_metapaths = metagraph.extract_metapaths('ChemicalSubstance', 'Disease', 4)
mp_info = {mp.abbrev: mp for mp in all_metapaths if mp.abbrev in metapaths}

# %%
id_to_name = nodes.set_index('id')['name'].to_dict()
res['chem_name'] = res['chemicalsubstance_id'].map(id_to_name)
res['dis_name'] = res['disease_id'].map(id_to_name)
res = res.sort_values('proba', ascending=False).reset_index(drop=True)

res.head(2)
# Out:
#   chemicalsubstance_id     disease_id  status     proba          chem_name  \
# 0          CHEBI:53769  MONDO:0005399       0  0.997371  (S)-acenocoumarol
# 1          CHEBI:50438  MONDO:0005399       0  0.997320      phenprocoumon
#
#                  dis_name
# 0  venous thromboembolism
# 1  venous thromboembolism

# %%
pos_coef = coef.query('coef > 0')['feature'].tolist()

# %%
msat = model[0]
max_abs = model[1]

# %%
ini_means = {f: m for f, m in zip(metapaths, msat.initial_mean_)}
ma_scale = {f: m for f, m in zip(metapaths, max_abs.scale_)}
feat_coef = coef.set_index('feature')['coef'].to_dict()
feat_zcoef = coef.set_index('feature')['zcoef'].to_dict()

# %% [markdown]
# ### Definie routines for extracting and weighting paths

# %%
def get_model_metric(path_df):
    totals = path_df.groupby('metapath')['metric'].sum().to_dict()
    percent_of_total = path_df['metric'] / path_df['metapath'].map(totals)
    
    trans_metric = np.arcsinh(path_df['metapath'].map(totals) / path_df['metapath'].map(ini_means))
    scal_metric = trans_metric / path_df['metapath'].map(ma_scale)
    
    model_metric = scal_metric * path_df['metapath'].map(feat_coef) * percent_of_total
    return model_metric

# %%
def get_std_model_metric(path_df):
    
    totals = path_df.groupby('metapath')['metric'].sum().to_dict()
    percent_of_total = path_df['metric'] / path_df['metapath'].map(totals)
    
    trans_metric = np.arcsinh(path_df['metric'] / path_df['metapath'].map(ini_means))
    scal_metric = trans_metric / path_df['metapath'].map(ma_scale)
    
    model_metric = scal_metric * path_df['metapath'].map(feat_zcoef) * percent_of_total
    return model_metric

# %%
def get_path_info(compound, disease, n_jobs=30):
    path_df = pd.DataFrame(mg.extract_paths(compound, disease, pos_coef, n_jobs=n_jobs))
    path_df['model_metric'] = get_model_metric(path_df)
    path_df['std_metric'] = get_std_model_metric(path_df)
    
    return path_df

# %%
ref_c = nodes[~nodes['source'].isnull()]['id'].unique()
len(ref_c)
# Out:
# 5970

# %% [markdown]
# #### Subset diseases to those not treated

# %%
all_dis = nodes.query('label == "Disease"')['id'].unique()
treat_disease = edges.query('type == "treats_CtD"')['end_id'].unique()

utreat_dis = list(set(all_dis) - set(treat_disease))

len(utreat_dis)
# Out:
# 8333

# %% [markdown]
# ### Get probabilities from model for ReFrame - Disease pairs

# %%
(ref_pairs, out_mp), dwpc = mg.extract_dwpc(metapaths=metapaths, start_nodes=ref_c, 
                                        end_nodes=list(utreat_dis), n_jobs=30, return_sparse=True, sparse_df=False)
# Out:
# Preparing function arguments...
# Calculating DWPCs...
# 100%|██████████| 156/156 [03:39<00:00,  1.40s/it]
# Reshaping Result Matrices...
# 100%|██████████| 156/156 [00:35<00:00,  4.34it/s]
# Stacking columns...

# %%
ref_pairs['proba'] = model.predict_proba(dwpc)[:, 1]

# %%
ref_pairs['chem_name'] = ref_pairs['chemicalsubstance_id'].map(id_to_name)
ref_pairs['dis_name'] = ref_pairs['disease_id'].map(id_to_name)

# %%
pos_tups = set(edges.query('type == "treats_CtD"')[['start_id', 'end_id']].apply(tuple, axis=1))

# %%
status = []
for row in ref_pairs.itertuples():
    tup = (row.chemicalsubstance_id, row.disease_id)
    status.append(int(bool(pos_tups & {tup})))

# %%
ref_pairs['status'] = status
ref_pairs.sample(10)
# Out:
#                       chemicalsubstance_id     disease_id     proba  \
# 40575330  IKEY:MXDSJQHFFDGFDK-CYBMUJFWSA-N   DOID:0110052  0.006323
# 39064087  IKEY:KSHMINBVGAHXNS-PXYKVGKMSA-L  MONDO:0013806  0.005566
# 10266523                       CHEBI:31257   DOID:0050600  0.002919
# 29275516                        CHEBI:9207   DOID:0080501  0.014845
# 25473397                       CHEBI:78652    OMIM:612560  0.005682
# 25532382                       CHEBI:78887   DOID:0050098  0.005229
# 33207087  IKEY:BLTVBQXJFVRPFK-UHFFFAOYSA-N   DOID:0050111  0.005413
# 36804651  IKEY:HVASDHJNLYRZEA-UHFFFAOYSA-I   MESH:C562704  0.005413
# 24748963                       CHEBI:76277   WD:Q53951712  0.005413
# 39094764  IKEY:KSPYMJJKQMWWNB-UHFFFAOYSA-N      DOID:4305  0.003964
#
#                                              chem_name  \
# 40575330                                      AZD-3759
# 39064087                 Magnesium L-lactate dihydrate
# 10266523                                      bendazac
# 29275516                         sotalol hydrochloride
# 25473397  1-octadecyl-2-methylglycero-3-phosphocholine
# 25532382                                  tirapazamine
# 33207087                                      Azd-1080
# 36804651                      Pentetate zinc trisodium
# 24748963                                     tepoxalin
# 39094764                                  Cipamfylline
#
#                                                    dis_name  status
# 40575330                    amelogenesis imperfecta type 1B       0
# 39064087  familial cutaneous telangiectasia and orophary...       0
# 10266523                                      ABCD syndrome       0
# 29275516                          GM1 gangliosidosis type 2       0
# 25473397   BONE MINERAL DENSITY QUANTITATIVE TRAIT LOCUS 12       0
# 25532382       obsolete Microsporum audouinii tinea capitis       0
# 33207087          obsolete Microsporum fulvum tinea capitis       0
# 36804651        Isolated Growth Hormone Deficiency, Type II       0
# 24748963               hard palate mucoepidermoid carcinoma       0
# 39094764                              bone giant cell tumor       0

# %% [markdown]
# ### Save out results

# %%
ref_pairs.to_csv(out_dir.joinpath('reframe_probas.csv'), index=False)

# %%
ref_pairs = ref_pairs.sort_values('proba', ascending=False)

# %%
ref_pairs = ref_pairs.reset_index(drop=True)

# %%
# %matplotlib inline

# %% [markdown]
# ### Plot a few example paths

# %%
# Choose custom node colors
node_color_map = {'AnatomicalEntity': "#8c88d7",
                'BiologicalProcessOrActivity': "#b75970",
                'MacromolecularMachine': "#e71761",
                'Disease': "#70c6ca",
                'Pathway': "#b1d34f",
                'PhenotypicFeature': "#154e56",
                'GeneFamily': "#5a3386",
                'PhysiologicalProcess': '#ec102f',
                'OrganismTaxon': "#e9bf98",
                'ChemicalSubstance': "#01c472",}

node_id_to_color = nodes.set_index('id')['label'].map(node_color_map).to_dict()
id_to_label = nodes.set_index('id')['label'].to_dict()

edge_info = pd.read_csv('../0_data/manual/edge_semtypes.csv')
inv_map = edge_info.set_index('fwd_edge')['rev_edge'].to_dict()

import graph_plots as gp

def draw_top_paths(path_df, head_num=10, metric='model_metric', poi_idx=None, proba=None, sort=True):


    if sort:
        top_n_paths = path_df.sort_values(metric, ascending=False).head(head_num)
    else:
        top_n_paths = path_df.head(head_num)

    # Get the list of paths
    list_of_paths = top_n_paths['node_ids'].tolist()
    path_weights = top_n_paths[metric].tolist()

    # Get the edge names
    list_of_edges = []
    for mp in top_n_paths['metapath']:
        list_of_edges.append(gp.parse_metapath_to_edge_names(mp, mp_info, inv_map))

   
    if type(poi_idx) == list:
        ec = []
        for idx in poi_idx:
            poi = path_df.loc[idx, 'node_ids']
            ec.append(gp.highlight_path_of_interest(list_of_paths, poi))
        
        # Take the edges from the first highlighted poi
        edge_color_map = ec[0]
        for ecm in ec[1:]:
            for k, v in ecm.items():
                # Any other highlihted paths get marked
                # seaborn 1 is highlight color.
                if v == sns.color_palette().as_hex()[1]:
                    edge_color_map[k] = v
        
    elif poi_idx is not None:
        path_of_interest = path_df.loc[poi_idx, 'node_ids']
        edge_color_map = gp.highlight_path_of_interest(list_of_paths, path_of_interest)
    else:
        path_of_interest = []
        edge_color_map = gp.highlight_path_of_interest(list_of_paths, path_of_interest)
    
    

    G = gp.build_explanitory_graph(list_of_paths, list_of_edges, path_weights=path_weights, 
                                node_id_to_label=id_to_label, node_id_to_color=node_id_to_color, 
                                edge_id_to_color=edge_color_map, min_dist=3)

    return gp.draw_explanitory_graph(G, node_id_to_name=id_to_name, node_names=None, proba=proba, n_paths=10, xscale=17);

# %%
# networkx throws LOTS of matplotlib warnings when plotting, so we're silencing
import warnings
warnings.simplefilter('ignore')

# %%
ref_pairs.query('status == 0').head(50)
# Out:
#    chemicalsubstance_id     disease_id     proba  \
# 0           CHEBI:49105   DOID:0050659  0.574642
# 1           CHEBI:16586   DOID:0111592  0.486447
# 2           CHEBI:15367   DOID:0110323  0.425395
# 3           CHEBI:17823   DOID:0060896  0.420092
# 4           CHEBI:53795   DOID:0070268  0.419263
# 5           CHEBI:33216   DOID:0111667  0.413385
# 6           CHEBI:29081   DOID:0070268  0.411624
# 7           CHEBI:33216   DOID:0050754  0.396758
# 8           CHEBI:39427   DOID:0080626  0.395868
# 9           CHEBI:45906   DOID:0060679  0.394386
# 10          CHEBI:16469   DOID:0070268  0.393978
# 11          CHEBI:39427  MONDO:0012524  0.393941
# 12          CHEBI:33216   DOID:0111741  0.393884
# 13          CHEBI:39867   DOID:0060612  0.393527
# 14          CHEBI:39867  MONDO:0014609  0.392418
# 15          CHEBI:33216  MONDO:0010506  0.391624
# 16          CHEBI:33216   DOID:0110602  0.391146
# 17          CHEBI:33216   DOID:0110611  0.390865
# 18          CHEBI:34583   DOID:0060896  0.382395
# 19          CHEBI:23414   DOID:0070268  0.378217
# 20          CHEBI:29081   DOID:0080343  0.376409
# 21          CHEBI:16469   DOID:0060676  0.375958
# 22           CHEBI:4031  MONDO:0009206  0.375934
# 23           CHEBI:8892  MONDO:0012545  0.375772
# 24         CHEBI:134718   DOID:0111730  0.374997
# 25          CHEBI:39867   DOID:0050983  0.374133
# 26          CHEBI:59877  MONDO:0009970  0.372491
# 27          CHEBI:39867   DOID:0111667  0.371498
# 28          CHEBI:29081   DOID:0110611  0.371347
# 29          CHEBI:16469   DOID:0111667  0.370987
# 30           CHEBI:4031   DOID:0070157  0.369587
# 31          CHEBI:33216   DOID:0070307  0.367163
# 32          CHEBI:15407  MONDO:0007751  0.364189
# 33          CHEBI:39867   DOID:0111024  0.358105
# 34          CHEBI:39867  MONDO:0010506  0.357580
# 35          CHEBI:29081   DOID:0060270  0.353027
# 36          CHEBI:92215   DOID:0110379  0.352663
# 37          CHEBI:94355  MONDO:0009970  0.348690
# 38         CHEBI:142433     DOID:13099  0.346443
# 39          CHEBI:31580   DOID:0060612  0.346340
# 40          CHEBI:39867   DOID:0060896  0.345789
# 41          CHEBI:33216   DOID:0080064  0.344467
# 42          CHEBI:31580   DOID:0110464  0.343754
# 43          CHEBI:94355  MONDO:0012524  0.343713
# 44           CHEBI:4031  MONDO:0013800  0.343208
# 45          CHEBI:28748   DOID:0080343  0.343132
# 46          CHEBI:94355   DOID:0080626  0.342489
# 47          CHEBI:29081   DOID:0111274  0.342349
# 48           CHEBI:9468   DOID:0060676  0.339351
# 49          CHEBI:33216   DOID:0111170  0.338014
#
#                                             chem_name  \
# 0                              thiamine hydrochloride
# 1                                6-aminohexanoic acid
# 2                             all-trans-retinoic acid
# 3                                          calcitriol
# 4                                      (R)-amlodipine
# 5                                         bisphenol A
# 6                                          synephrine
# 7                                         bisphenol A
# 8                                     perfluorohexane
# 9                                             suramin
# 10                                   17beta-estradiol
# 11                                    perfluorohexane
# 12                                        bisphenol A
# 13                                      valproic acid
# 14                                      valproic acid
# 15                                        bisphenol A
# 16                                        bisphenol A
# 17                                        bisphenol A
# 18                                        Bolasterone
# 19                                 copper(II) sulfate
# 20                                         synephrine
# 21                                   17beta-estradiol
# 22                                      cyclosporin A
# 23                              rosiglitazone maleate
# 24                                         safinamide
# 25                                      valproic acid
# 26                              enalaprilat dihydrate
# 27                                      valproic acid
# 28                                         synephrine
# 29                                   17beta-estradiol
# 30                                      cyclosporin A
# 31                                        bisphenol A
# 32                                      (-)-ephedrine
# 33                                      valproic acid
# 34                                      valproic acid
# 35                                         synephrine
# 36  5-(2-propoxyphenyl)-2,3-dihydrotriazolo[4,5-d]...
# 37  4-(5,6,7,8-tetrahydroimidazo[1,5-a]pyridin-5-y...
# 38                                         cinaciguat
# 39                               ethynodiol diacetate
# 40                                      valproic acid
# 41                                        bisphenol A
# 42                               ethynodiol diacetate
# 43  4-(5,6,7,8-tetrahydroimidazo[1,5-a]pyridin-5-y...
# 44                                      cyclosporin A
# 45                                        doxorubicin
# 46  4-(5,6,7,8-tetrahydroimidazo[1,5-a]pyridin-5-y...
# 47                                         synephrine
# 48                                         tetracaine
# 49                                        bisphenol A
#
#                                              dis_name  status
# 0             biotin-responsive basal ganglia disease       0
# 1                       plasminogen deficiency type I       0
# 2                      hypertrophic cardiomyopathy 17       0
# 3                              Parkinson's disease 23       0
# 4       congenital disorder of glycosylation type IIp       0
# 5                             enterokinase deficiency       0
# 6       congenital disorder of glycosylation type IIp       0
# 7               ataxia with oculomotor apraxia type 1       0
# 8           corticosterone methyloxidase deficiency 1       0
# 9   catecholaminergic polymorphic ventricular tach...       0
# 10      congenital disorder of glycosylation type IIp       0
# 11     corticosterone methyloxidase type 2 deficiency       0
# 12                                X-linked deafness 5       0
# 13             abdominal obesity-metabolic syndrome 3       0
# 14  cognitive impairment-coarse facies-heart defec...       0
# 15        intellectual disability, X-linked 61; MRX61       0
# 16                      primary ciliary dyskinesia 11       0
# 17                      primary ciliary dyskinesia 27       0
# 18                             Parkinson's disease 23       0
# 19      congenital disorder of glycosylation type IIp       0
# 20  autosomal recessive pyridoxine-refractory side...       0
# 21  catecholaminergic polymorphic ventricular tach...       0
# 22  factor v and Factor VIII, combined deficiency ...       0
# 23                     neutral lipid storage myopathy       0
# 24                  familial episodic pain syndrome 2       0
# 25                     spinocerebellar ataxia type 36       0
# 26         renal tubular dysgenesis of genetic origin       0
# 27                            enterokinase deficiency       0
# 28                      primary ciliary dyskinesia 27       0
# 29                            enterokinase deficiency       0
# 30  hereditary sensory and autonomic neuropathy ty...       0
# 31                   craniolenticulosutural dysplasia       0
# 32   hypercholesterolemia, autosomal dominant, type b       0
# 33                              cone-rod dystrophy 18       0
# 34        intellectual disability, X-linked 61; MRX61       0
# 35                 pontocerebellar hypoplasia type 2D       0
# 36                            retinitis pigmentosa 43       0
# 37         renal tubular dysgenesis of genetic origin       0
# 38                                   Moyamoya disease       0
# 39             abdominal obesity-metabolic syndrome 3       0
# 40                             Parkinson's disease 23       0
# 41      autosomal recessive spinocerebellar ataxia 17       0
# 42      autosomal recessive nonsyndromic deafness 103       0
# 43     corticosterone methyloxidase type 2 deficiency       0
# 44  Ehlers-Danlos syndrome, kyphoscoliotic and dea...       0
# 45  autosomal recessive pyridoxine-refractory side...       0
# 46          corticosterone methyloxidase deficiency 1       0
# 47                                     CODAS syndrome       0
# 48  catecholaminergic polymorphic ventricular tach...       0
# 49                autosomal dominant sensory ataxia 1       0

# %% [markdown]
# ### Load a subset of Rare Diseases for examination

# %%
rare_dis = pd.read_csv('../0_data/manual/rare_disease_ids.txt', header=None)[0].tolist()

# %%
ref_pairs.query('disease_id in @rare_dis').head(50)
# Out:
#     chemicalsubstance_id    disease_id     proba  \
# 0            CHEBI:49105  DOID:0050659  0.574642
# 2            CHEBI:15367  DOID:0110323  0.425395
# 4            CHEBI:53795  DOID:0070268  0.419263
# 6            CHEBI:29081  DOID:0070268  0.411624
# 7            CHEBI:33216  DOID:0050754  0.396758
# 9            CHEBI:45906  DOID:0060679  0.394386
# 10           CHEBI:16469  DOID:0070268  0.393978
# 19           CHEBI:23414  DOID:0070268  0.378217
# 25           CHEBI:39867  DOID:0050983  0.374133
# 30            CHEBI:4031  DOID:0070157  0.369587
# 31           CHEBI:33216  DOID:0070307  0.367163
# 33           CHEBI:39867  DOID:0111024  0.358105
# 35           CHEBI:29081  DOID:0060270  0.353027
# 38          CHEBI:142433    DOID:13099  0.346443
# 41           CHEBI:33216  DOID:0080064  0.344467
# 50           CHEBI:53795  DOID:0070157  0.337638
# 51           CHEBI:29081  DOID:0110171  0.337361
# 55           CHEBI:39867  DOID:0111155  0.334552
# 56           CHEBI:28748  DOID:0111024  0.334245
# 58           CHEBI:15367  DOID:0070268  0.330518
# 59           CHEBI:33216  DOID:0070015  0.330194
# 60           CHEBI:88667  DOID:0050993  0.329890
# 61           CHEBI:31580  DOID:0060694  0.329523
# 62           CHEBI:29081  DOID:0111024  0.327912
# 67           CHEBI:29081  DOID:0110174  0.320387
# 70           CHEBI:34583  DOID:0070268  0.318803
# 71           CHEBI:53795  DOID:0110800  0.317082
# 72            CHEBI:8502  DOID:0050963  0.316978
# 75           CHEBI:31580     DOID:2960  0.314221
# 76           CHEBI:33216  DOID:0050943  0.313659
# 81           CHEBI:80366     DOID:2230  0.311620
# 82           CHEBI:17026  DOID:0110931  0.311562
# 83           CHEBI:80366     DOID:2229  0.311324
# 86           CHEBI:42588  DOID:0110768  0.310796
# 87           CHEBI:33216  DOID:0080315  0.310084
# 92           CHEBI:16240  DOID:0050754  0.308233
# 93           CHEBI:31580  DOID:0111012  0.308232
# 98           CHEBI:92215  DOID:0110863  0.305431
# 99           CHEBI:41879  DOID:0060793  0.305344
# 101          CHEBI:37537  DOID:0070268  0.304694
# 105           CHEBI:1391  DOID:0110197  0.302964
# 109          CHEBI:28748  DOID:0070157  0.301143
# 114          CHEBI:31580  DOID:0060270  0.298892
# 115           CHEBI:4031  DOID:0050754  0.298402
# 117           CHEBI:1391  DOID:0111012  0.297837
# 119          CHEBI:39867  DOID:0110304  0.297318
# 120          CHEBI:53795  DOID:0110323  0.296997
# 121          CHEBI:15367  DOID:0060694  0.296766
# 124          CHEBI:16469  DOID:0111024  0.295894
# 126          CHEBI:15407  DOID:0111062  0.295437
#
#                                              chem_name  \
# 0                               thiamine hydrochloride
# 2                              all-trans-retinoic acid
# 4                                       (R)-amlodipine
# 6                                           synephrine
# 7                                          bisphenol A
# 9                                              suramin
# 10                                    17beta-estradiol
# 19                                  copper(II) sulfate
# 25                                       valproic acid
# 30                                       cyclosporin A
# 31                                         bisphenol A
# 33                                       valproic acid
# 35                                          synephrine
# 38                                          cinaciguat
# 41                                         bisphenol A
# 50                                      (R)-amlodipine
# 51                                          synephrine
# 55                                       valproic acid
# 56                                         doxorubicin
# 58                             all-trans-retinoic acid
# 59                                         bisphenol A
# 60                        Octyl 4-methoxycinnamic acid
# 61                                ethynodiol diacetate
# 62                                          synephrine
# 67                                          synephrine
# 70                                         Bolasterone
# 71                                      (R)-amlodipine
# 72                               6-propyl-2-thiouracil
# 75                                ethynodiol diacetate
# 76                                         bisphenol A
# 81   (5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid ethy...
# 82                                        progesterone
# 83   (5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid ethy...
# 86                          4-hydroxyphenyl retinamide
# 87                                         bisphenol A
# 92                                   hydrogen peroxide
# 93                                ethynodiol diacetate
# 98   5-(2-propoxyphenyl)-2,3-dihydrotriazolo[4,5-d]...
# 99                                       dexamethasone
# 101                    phorbol 13-acetate 12-myristate
# 105                  3,4-methylenedioxymethamphetamine
# 109                                        doxorubicin
# 114                               ethynodiol diacetate
# 115                                      cyclosporin A
# 117                  3,4-methylenedioxymethamphetamine
# 119                                      valproic acid
# 120                                     (R)-amlodipine
# 121                            all-trans-retinoic acid
# 124                                   17beta-estradiol
# 126                                      (-)-ephedrine
#
#                                               dis_name  status
# 0              biotin-responsive basal ganglia disease       0
# 2                       hypertrophic cardiomyopathy 17       0
# 4        congenital disorder of glycosylation type IIp       0
# 6        congenital disorder of glycosylation type IIp       0
# 7                ataxia with oculomotor apraxia type 1       0
# 9    catecholaminergic polymorphic ventricular tach...       0
# 10       congenital disorder of glycosylation type IIp       0
# 19       congenital disorder of glycosylation type IIp       0
# 25                      spinocerebellar ataxia type 36       0
# 30   hereditary sensory and autonomic neuropathy ty...       0
# 31                    craniolenticulosutural dysplasia       0
# 33                               cone-rod dystrophy 18       0
# 35                  pontocerebellar hypoplasia type 2D       0
# 38                                    Moyamoya disease       0
# 41       autosomal recessive spinocerebellar ataxia 17       0
# 50   hereditary sensory and autonomic neuropathy ty...       0
# 51          Charcot-Marie-Tooth disease axonal type 2S       0
# 55       autosomal recessive spinocerebellar ataxia 21       0
# 56                               cone-rod dystrophy 18       0
# 58       congenital disorder of glycosylation type IIp       0
# 59        autosomal recessive dyskeratosis congenita 1       0
# 60                              episodic ataxia type 5       0
# 61                       Cayman type cerebellar ataxia       0
# 62                               cone-rod dystrophy 18       0
# 67          Charcot-Marie-Tooth disease axonal type 2L       0
# 70       congenital disorder of glycosylation type IIp       0
# 71                    hereditary spastic paraplegia 48       0
# 72                      spinocerebellar ataxia type 13       0
# 75                  photosensitive trichothiodystrophy       0
# 76                                    spastic ataxia 4       0
# 81                                 obsolete hemophilia       0
# 82                                nemaline myopathy 10       0
# 83                                factor XI deficiency       0
# 86                    hereditary spastic paraplegia 15       0
# 87   megalencephalic leukoencephalopathy with subco...       0
# 92               ataxia with oculomotor apraxia type 1       0
# 93                                cone-rod dystrophy 7       0
# 98   congenital stationary night blindness autosoma...       0
# 99                    hypomyelinating leukodystrophy 5       0
# 101      congenital disorder of glycosylation type IIp       0
# 105  Charcot-Marie-Tooth disease dominant intermedi...       0
# 109  hereditary sensory and autonomic neuropathy ty...       0
# 114                 pontocerebellar hypoplasia type 2D       0
# 115              ataxia with oculomotor apraxia type 1       0
# 117                               cone-rod dystrophy 7       0
# 119  autosomal dominant limb-girdle muscular dystro...       0
# 120                     hypertrophic cardiomyopathy 17       0
# 121                      Cayman type cerebellar ataxia       0
# 124                              cone-rod dystrophy 18       0
# 126                 familial hypobetalipoproteinemia 1       0

# %%
def plot_idx(test_idx, njob=30):

    cid = ref_pairs.loc[test_idx, 'chemicalsubstance_id']
    did = ref_pairs.loc[test_idx, 'disease_id']
    prob = ref_pairs.loc[test_idx, 'proba']

    print('Extracting data for: {} -TREATS- {}'.format(id_to_name[cid], id_to_name[did]))
    path_df = get_path_info(cid, did, njob)

    draw_top_paths(path_df, 10, proba=prob)

# %%
plot_idx(0)
# Out:
# Extracting data for: thiamine hydrochloride -TREATS- biotin-responsive basal ganglia disease
# 100%|██████████| 89/89 [00:00<00:00, 101.16it/s]

# %%
plot_idx(4)
# Out:
# Extracting data for: (R)-amlodipine -TREATS- congenital disorder of glycosylation type IIp
# 100%|██████████| 89/89 [01:12<00:00,  1.22it/s]

# %%
plot_idx(6)
# Out:
# Extracting data for: synephrine -TREATS- congenital disorder of glycosylation type IIp
# 100%|██████████| 89/89 [01:39<00:00,  1.12s/it]

# %% [markdown]
# **renal tubular dysgenesis of genetic origin** - Renal tubular dysgenesis is a severe kidney disorder characterized by abnormal development of the kidneys before birth. In particular, kidney structures called proximal tubules are absent or underdeveloped. These structures help to reabsorb needed nutrients, water, and other materials into the blood and excrete everything else into the urine. Without functional proximal tubules, the kidneys cannot produce urine (a condition called anuria).
#
# https://ghr.nlm.nih.gov/condition/renal-tubular-dysgenesis
#
# **trandolaprilat** - The active metabolite of the prodrug **Trandolapril** - Trandolapril is an ACE inhibitor used to treat high blood pressure, it may also be used to treat other conditions. It was patented in 1981 and approved for medical use in 1993.[1] It is marketed by Abbott Laboratories under the brand name Mavik.
#
# https://www.drugbank.ca/drugs/DB00519
#
# https://en.wikipedia.org/wiki/Trandolapril

# %%
ref_pairs.query('chem_name == "trandolaprilat" and dis_name == "renal tubular dysgenesis of genetic origin"')
# Out:
#       chemicalsubstance_id     disease_id    proba       chem_name  \
# 76021         CHEBI:141521  MONDO:0009970  0.05091  trandolaprilat
#
#                                          dis_name  status
# 76021  renal tubular dysgenesis of genetic origin       0

# %%
plot_idx(76021)
# Out:
# Extracting data for: trandolaprilat -TREATS- renal tubular dysgenesis of genetic origin
# 100%|██████████| 89/89 [00:00<00:00, 103.74it/s]

# %% [markdown]
# **Liddle syndrome** is a rare, inherited condition that is primarily characterized by severe high blood pressure (hypertension) that often develops at an early age. Although the condition may not be associated with signs and symptoms initially, untreated hypertension can eventually lead to heart disease or stroke.
#
# https://rarediseases.info.nih.gov/diseases/7381/liddle-syndrome
#
# **aldosterone** the main mineralocorticoid hormone, is a steroid hormone produced by the zona glomerulosa of the adrenal cortex in the adrenal gland.[1][2] It is essential for sodium conservation in the kidney, salivary glands, sweat glands and colon.[3] It plays a central role in the homeostatic regulation of blood pressure, plasma sodium (Na+), and potassium (K+) levels.
#
# https://en.wikipedia.org/wiki/Aldosterone

# %%
ref_pairs.query('chem_name == "aldosterone" and dis_name == "Liddle syndrome"')
# Out:
#          chemicalsubstance_id    disease_id     proba    chem_name  \
# 49728356          CHEBI:27584  DOID:0050477  0.000576  aldosterone
#
#                  dis_name  status
# 49728356  Liddle syndrome       0

# %%
plot_idx(49728356)

# %% [markdown]
# Appeaers to be a contraindication? Hyperthroxinemia is too much T4 (thyroxane), T4 is convted to 3,3',5'-triiodo-L-thyronine (T3) in the body.

# %%
ref_pairs.query('chemicalsubstance_id == "CHEBI:28774" and dis_name == "hyperthyroxinemia"')
# Out:
#        chemicalsubstance_id disease_id    proba                 chem_name  \
# 645429          CHEBI:28774  DOID:2855  0.01948  3,3',5'-triiodothyronine
#
#                  dis_name  status
# 645429  hyperthyroxinemia       0

# %%
plot_idx(645429)

# %% [markdown]
# **Brugada syndrome 8** - characterized by an ST segment elevation in the right precordial electrocardiogram leads
#
# https://www.omim.org/entry/613123
#
# **tetrodotoxin** - a potent neurotoxin. Its name derives from Tetraodontiformes, an order that includes pufferfish, porcupinefish, ocean sunfish, and triggerfish;
#
# https://en.wikipedia.org/wiki/Tetrodotoxin#Modern_therapeutic_research

# %%
ref_pairs.query('chem_name == "tetrodotoxin" and dis_name == "Brugada syndrome 8"')
# Out:
#        chemicalsubstance_id    disease_id     proba     chem_name  \
# 153261           CHEBI:9506  DOID:0110225  0.037447  tetrodotoxin
#
#                   dis_name  status
# 153261  Brugada syndrome 8       0

# %%
ref_pairs.query('chem_name == "tetrodotoxin"').reset_index(drop=True).query('dis_name == "Brugada syndrome 8"')
# Out:
#    chemicalsubstance_id    disease_id     proba     chem_name  \
# 33           CHEBI:9506  DOID:0110225  0.037447  tetrodotoxin
#
#               dis_name  status
# 33  Brugada syndrome 8       0

# %%
ref_pairs.query('dis_name == "Brugada syndrome 8"').reset_index(drop=True).query('chem_name == "tetrodotoxin"')
# Out:
#     chemicalsubstance_id    disease_id     proba     chem_name  \
# 143           CHEBI:9506  DOID:0110225  0.037447  tetrodotoxin
#
#                dis_name  status
# 143  Brugada syndrome 8       0

# %%
# Brugada syndrome 8  https://www.omim.org/entry/613123
# tetrodotoxin https://en.wikipedia.org/wiki/Tetrodotoxin

plot_idx(153261)

# %% [markdown]
# **5,6,7,8-tetrahydrobiopterin (aka sapropterin dihydrochloride)** Tetrahydrobiopterin (BH4, THB), also known as sapropterin (INN),[2][3] is a cofactor of the three aromatic amino acid hydroxylase enzymes,[4] used in the degradation of amino acid phenylalanine and in the biosynthesis of the neurotransmitters serotonin (5-hydroxytryptamine, 5-HT), melatonin, dopamine, norepinephrine (noradrenaline), epinephrine (adrenaline), and is a cofactor for the production of nitric oxide (NO) by the nitric oxide synthases.[5] Chemically, its structure is that of a reduced pteridine derivative.
#
# https://en.wikipedia.org/wiki/Tetrahydrobiopterin
#
# **GTP cyclohydrolase I deficiency** GTP-cyclohydrolase I deficiency, an autosomal recessive genetic disorder, is one of the causes of malignant hyperphenylalaninemia due to tetrahydrobiopterin deficiency. Not only does tetrahydrobiopterin deficiency cause hyperphenylalaninemia, it is also responsible for defective neurotransmission of monoamines because of malfunctioning tyrosine and tryptophan hydroxylases, both tetrahydrobiopterin-dependent hydroxylases.
#
# https://rarediseases.info.nih.gov/diseases/2844/gtp-cyclohydrolase-i-deficiency

# %%
ref_pairs.query('chemicalsubstance_id == "CHEBI:32120" and dis_name == "GTP cyclohydrolase I deficiency"')
# Out:
#     chemicalsubstance_id     disease_id     proba  \
# 265          CHEBI:32120  MONDO:0009314  0.264322
#
#                        chem_name                         dis_name  status
# 265  sapropterin dihydrochloride  GTP cyclohydrolase I deficiency       0

# %%
ref_pairs.query('chemicalsubstance_id == "CHEBI:32120"').reset_index().query('dis_name == "GTP cyclohydrolase I deficiency"')
# Out:
#    index chemicalsubstance_id     disease_id     proba  \
# 0    265          CHEBI:32120  MONDO:0009314  0.264322
#
#                      chem_name                         dis_name  status
# 0  sapropterin dihydrochloride  GTP cyclohydrolase I deficiency       0

# %%
ref_pairs.query('dis_name == "GTP cyclohydrolase I deficiency"').reset_index().query('chemicalsubstance_id == "CHEBI:32120"')
# Out:
#    index chemicalsubstance_id     disease_id     proba  \
# 1    265          CHEBI:32120  MONDO:0009314  0.264322
#
#                      chem_name                         dis_name  status
# 1  sapropterin dihydrochloride  GTP cyclohydrolase I deficiency       0

# %%
plot_idx(265)
# Out:
# Extracting data for: sapropterin dihydrochloride -TREATS- GTP cyclohydrolase I deficiency
# 100%|██████████| 89/89 [00:01<00:00, 78.02it/s]

# %% [markdown]
# There's a few interesting paths here... Lets redraw ith some of them highlighted

# %%
test_idx = 71

cid = ref_pairs.loc[test_idx, 'chemicalsubstance_id']
did = ref_pairs.loc[test_idx, 'disease_id']
prob = ref_pairs.loc[test_idx, 'proba']

print('Extracting data for: {} -TREATS- {}'.format(id_to_name[cid], id_to_name[did]))
path_df = get_path_info(cid, did, 30)
# Out:
# Extracting data for: sapropterin dihydrochloride -TREATS- GTP cyclohydrolase I deficiency
# 100%|██████████| 113/113 [00:02<00:00, 49.46it/s]

# %%
path_df.sort_values('model_metric', ascending=False).head(10)
# Out:
#             metapath    metric  \
# 0           CafBPawD  0.001442
# 73       CinGpoPWawD  0.007349
# 72         CinGmPpsD  0.000294
# 1050      CaGpoPWawD  0.003266
# 1044     CafGmPmGawD  0.005857
# 1045     CafGmPmGawD  0.005857
# 2227     CaGawPmGawD  0.000957
# 101    CafGpoApoGawD  0.000014
# 2700        CaGmPpsD  0.002498
# 1825  CafGpoPWawPpsD  0.000160
#
#                                                node_ids  \
# 0              [CHEBI:32120, GO:0051000, MONDO:0009314]
# 73    [CHEBI:32120, NCBIGene:2643, WP:WP4156, MONDO:...
# 72    [CHEBI:32120, NCBIGene:2643, HP:0002063, MONDO...
# 1050  [CHEBI:32120, NCBIGene:2643, WP:WP4156, MONDO:...
# 1044  [CHEBI:32120, NCBIGene:5053, HP:0004923, NCBIG...
# 1045  [CHEBI:32120, NCBIGene:5053, HP:0005982, NCBIG...
# 2227  [CHEBI:32120, NCBIGene:5053, HP:0005982, NCBIG...
# 101   [CHEBI:32120, NCBIGene:7166, GO:0043005, NCBIG...
# 2700  [CHEBI:32120, NCBIGene:5053, HP:0004923, MONDO...
# 1825  [CHEBI:32120, NCBIGene:5053, KEGG:hsa00400, HP...
#
#                                                   nodes  model_metric  \
# 0     [sapropterin dihydrochloride, positive regulat...      1.322905
# 73    [sapropterin dihydrochloride, GCH1, Biosynthes...      1.309209
# 72    [sapropterin dihydrochloride, GCH1, Rigidity, ...      0.667755
# 1050  [sapropterin dihydrochloride, GCH1, Biosynthes...      0.565541
# 1044  [sapropterin dihydrochloride, PAH, Hyperphenyl...      0.420780
# 1045  [sapropterin dihydrochloride, PAH, Reduced phe...      0.420780
# 2227  [sapropterin dihydrochloride, PAH, Reduced phe...      0.294508
# 101   [sapropterin dihydrochloride, TPH1, neuron pro...      0.291795
# 2700  [sapropterin dihydrochloride, PAH, Hyperphenyl...      0.267675
# 1825  [sapropterin dihydrochloride, PAH, Phenylalani...      0.248419
#
#       std_metric
# 0       0.096072
# 73      0.127629
# 72      0.046016
# 1050    0.046769
# 1044    0.026889
# 1045    0.026889
# 2227    0.020386
# 101     0.018732
# 2700    0.021622
# 1825    0.022244

# %%
draw_top_paths(path_df, 10, proba=prob, poi_idx=[2700, 1825]);
#plt.savefig('sap_gtp_pah1.png', dpi=600);

# %% [markdown]
# **disopyramide** is an Antiarrhythmic -- It can treat irregular heartbeats (arrhythmias).
#
# https://en.wikipedia.org/wiki/Disopyramide

# %%
ref_pairs.query('chem_name == "disopyramide" and disease_id == "DOID:0110225"')
# Out:
#     chemicalsubstance_id    disease_id     proba     chem_name  \
# 465           CHEBI:4657  DOID:0110225  0.295754  disopyramide
#
#                dis_name  status
# 465  Brugada syndrome 8       0

# %%
plot_idx(465)
# Out:
# Extracting data for: disopyramide -TREATS- Brugada syndrome 8
# 100%|██████████| 113/113 [00:01<00:00, 72.89it/s]

# %% [markdown]
# Appears to be a known positive...
#
# **Biotin-thiamine-responsive basal ganglia disease** - a disorder that affects the nervous system, including a group of structures in the brain called the basal ganglia, which help control movement. As its name suggests, the condition may improve if the vitamins biotin and thiamine are given as treatment. Without early and lifelong vitamin treatment, people with biotin-thiamine-responsive basal ganglia disease experience a variety of neurological problems that gradually get worse. The occurrence of specific neurological problems and their severity vary even among affected individuals within the same family.
#
# https://ghr.nlm.nih.gov/condition/biotin-thiamine-responsive-basal-ganglia-disease
#
# **thiamine hydrochloride** - Thiamine, also known as thiamin or vitamin B1, is a vitamin found in food, and manufactured as a dietary supplement and medication.[2][3] Supplements and medications are available to treat and prevent thiamine deficiency and disorders that result from it, including beriberi and Wernicke encephalopathy.[1] Other uses include the treatment of maple syrup urine disease and Leigh syndrome.[1] They are typically taken by mouth, but may also be given by intravenous or intramuscular injection.[1][5]

# %%
ref_pairs.query('chem_name == "thiamine hydrochloride" and dis_name == "biotin-responsive basal ganglia disease"')
# Out:
#      chemicalsubstance_id    disease_id     proba               chem_name  \
# 2684          CHEBI:49105  DOID:0050659  0.144806  thiamine hydrochloride
#
#                                      dis_name  status
# 2684  biotin-responsive basal ganglia disease       0

# %%
ref_pairs.query('chem_name == "thiamine hydrochloride"').reset_index(drop=True).query('dis_name == "biotin-responsive basal ganglia disease"')
# Out:
#   chemicalsubstance_id    disease_id     proba               chem_name  \
# 0          CHEBI:49105  DOID:0050659  0.144806  thiamine hydrochloride
#
#                                   dis_name  status
# 0  biotin-responsive basal ganglia disease       0

# %%
ref_pairs.query('dis_name == "biotin-responsive basal ganglia disease"').reset_index(drop=True).query('chem_name == "thiamine hydrochloride"')
# Out:
#   chemicalsubstance_id    disease_id     proba               chem_name  \
# 0          CHEBI:49105  DOID:0050659  0.144806  thiamine hydrochloride
#
#                                   dis_name  status
# 0  biotin-responsive basal ganglia disease       0

# %%
plot_idx(2684)
# Out:
# Extracting data for: thiamine hydrochloride -TREATS- biotin-responsive basal ganglia disease
# 100%|██████████| 113/113 [00:02<00:00, 51.24it/s]

# %% [markdown]
# **SLC39A8-CDG** - Congenital disorder of glycosylation type IIn (CDG2N) is an autosomal recessive severe multisystem developmental disorder characterized by delayed psychomotor development apparent from infancy, hypotonia, and variable additional features, such as short stature, seizures, visual impairment, and cerebellar atrophy.
#
# https://omim.org/entry/616721
#
# **N,N,N',N'-tetrakis(2-pyridylmethyl)ethylenediamine** -  N,N,N′,N′-Tetrakis(2-pyridylmethyl)ethylenediamine (TPEN) elicits pro-apoptotic effect in human acute promyelocytic NB4 cells by inhibiting nitric oxide signalling and Zn2+ signaling.[1] In microglia pretreated with zinc, TPEN inhibits the interleukin 6 secretion and nitric oxide synthase (iNOS) mRNA expression.[2] It induces damage on DNA structure by activating ATM (ataxia telangiectasia mutated) and ATR (ATM-Rad3-related) signaling in human colon cancer cells.[3]
#
# https://www.sigmaaldrich.com/catalog/product/sigma/p4413?lang=en&region=US

# %%
ref_pairs.query('chem_name == "N,N,N\',N\'-tetrakis(2-pyridylmethyl)ethylenediamine" and dis_name == "SLC39A8-CDG"')
# Out:
#    chemicalsubstance_id    disease_id     proba  \
# 55          CHEBI:88217  DOID:0070266  0.547388
#
#                                             chem_name     dis_name  status
# 55  N,N,N',N'-tetrakis(2-pyridylmethyl)ethylenedia...  SLC39A8-CDG       0

# %%
plot_idx(55)
# Out:
# Extracting data for: N,N,N',N'-tetrakis(2-pyridylmethyl)ethylenediamine -TREATS- SLC39A8-CDG
# 100%|██████████| 113/113 [00:08<00:00, 13.56it/s]

# %% [markdown]
# **holoprosencephaly**  -	is a cephalic disorder in which the prosencephalon (the forebrain of the embryo) fails to develop into two hemispheres. Normally, the forebrain is formed and the face begins to develop in the fifth and sixth weeks of human pregnancy.
#
# **sonidegib** -	Sonidegib (INN; also known as LDE225 and erismodegib; trade name Odomzo[3]) is a Hedgehog signaling pathway inhibitor (via smoothened antagonism) being developed as an anticancer agent by Novartis

# %%
ref_pairs.query('chem_name == "sonidegib" and dis_name == "holoprosencephaly"')
# Out:
#    chemicalsubstance_id disease_id     proba  chem_name           dis_name  \
# 41          CHEBI:90863  DOID:4621  0.579371  sonidegib  holoprosencephaly
#
#     status
# 41       0

# %%
plot_idx(41)
# Out:
# Extracting data for: sonidegib -TREATS- holoprosencephaly
# 100%|██████████| 113/113 [00:02<00:00, 38.90it/s]

# %% [markdown]
# # NGLY1 Deficiency
#
#
# Look at some potential hits for NGLY1 Deficiency

# %%
ref_pairs.query('disease_id == "DOID:0060728"').head(50)
# Out:
#                     chemicalsubstance_id    disease_id     proba  \
# 184809                       CHEBI:93147  DOID:0060728  0.022709
# 194709                       CHEBI:31947  DOID:0060728  0.022249
# 209880                       CHEBI:31229  DOID:0060728  0.021616
# 210901                        CHEBI:6437  DOID:0060728  0.021574
# 214549  IKEY:JLVNEHKORQFVQJ-PYIJOLGTSA-N  DOID:0060728  0.021430
# 249622                        CHEBI:9683  DOID:0060728  0.020211
# 289686                      CHEBI:102484  DOID:0060728  0.019091
# 298185                      CHEBI:135568  DOID:0060728  0.018883
# 311109                      CHEBI:135686  DOID:0060728  0.018579
# 313269                        CHEBI:5792  DOID:0060728  0.018531
# 313514                       CHEBI:31621  DOID:0060728  0.018525
# 319656                        CHEBI:8428  DOID:0060728  0.018389
# 347254                        CHEBI:8485  DOID:0060728  0.017820
# 348493                       CHEBI:94720  DOID:0060728  0.017796
# 348604                       CHEBI:10429  DOID:0060728  0.017794
# 357643                        CHEBI:8212  DOID:0060728  0.017623
# 380174                        CHEBI:7458  DOID:0060728  0.017224
# 380940                       CHEBI:49029  DOID:0060728  0.017211
# 384383                       CHEBI:63589  DOID:0060728  0.017153
# 385666                       CHEBI:43362  DOID:0060728  0.017132
# 386419                       CHEBI:91366  DOID:0060728  0.017120
# 420821                        CHEBI:9316  DOID:0060728  0.016584
# 433481                        CHEBI:3213  DOID:0060728  0.016404
# 458594                        CHEBI:5125  DOID:0060728  0.016065
# 481467                       CHEBI:85157  DOID:0060728  0.015776
# 496440                       CHEBI:78432  DOID:0060728  0.015600
# 497569                        CHEBI:7911  DOID:0060728  0.015587
# 512821  IKEY:BMPDWHIDQYTSHX-AWEZNQCLSA-N  DOID:0060728  0.015414
# 516938  IKEY:JOZGNYDSEBIJDH-UHFFFAOYSA-N  DOID:0060728  0.015370
# 521487                        CHEBI:9571  DOID:0060728  0.015320
# 557063                      CHEBI:135939  DOID:0060728  0.014956
# 592643  IKEY:JHDKZFFAIZKUCU-ZRDIBKRKSA-N  DOID:0060728  0.014615
# 602684                       CHEBI:94713  DOID:0060728  0.014527
# 609069                        CHEBI:6970  DOID:0060728  0.014472
# 609501                       CHEBI:31305  DOID:0060728  0.014468
# 615851                       CHEBI:91368  DOID:0060728  0.014414
# 618615                       CHEBI:92907  DOID:0060728  0.014390
# 637805                       CHEBI:85170  DOID:0060728  0.014231
# 668575                       CHEBI:32264  DOID:0060728  0.013990
# 672591                        CHEBI:3013  DOID:0060728  0.013959
# 688311                       CHEBI:48045  DOID:0060728  0.013842
# 695030                       CHEBI:32316  DOID:0060728  0.013794
# 695163                       CHEBI:76607  DOID:0060728  0.013793
# 697105                        CHEBI:3242  DOID:0060728  0.013779
# 704250                       CHEBI:94767  DOID:0060728  0.013728
# 706852                       CHEBI:52172  DOID:0060728  0.013709
# 710719  IKEY:ZXFRFPSZAKNPQQ-YTWAJWBKSA-N  DOID:0060728  0.013682
# 714448  IKEY:MYBGWENAVMIGMM-GIFXNVAJSA-N  DOID:0060728  0.013657
# 714449  IKEY:CTAIFVHCDONNPS-BDQAORGHSA-N  DOID:0060728  0.013657
# 714935                       CHEBI:90942  DOID:0060728  0.013653
#
#                                                 chem_name          dis_name  \
# 184809  benzoic acid [2-methyl-2-(propylamino)propyl] ...  NGLY1-deficiency
# 194709                                        Oxethazaine  NGLY1-deficiency
# 209880                            Aprindine hydrochloride  NGLY1-deficiency
# 210901                                      levetiracetam  NGLY1-deficiency
# 214549                                           AIKO-150  NGLY1-deficiency
# 249622                                 trichlormethiazide  NGLY1-deficiency
# 289686                                      sulfisoxazole  NGLY1-deficiency
# 298185                                         lorcainide  NGLY1-deficiency
# 311109                                          alvimopan  NGLY1-deficiency
# 313269                                     Hydroquinidine  NGLY1-deficiency
# 313514                          Flunarizine hydrochloride  NGLY1-deficiency
# 319656                                       procainamide  NGLY1-deficiency
# 347254                                       Proparacaine  NGLY1-deficiency
# 348493  1-(3-chlorophenyl)-3-[5-[2-(4-thieno[3,2-d]pyr...  NGLY1-deficiency
# 348604                                     beta-lapachone  NGLY1-deficiency
# 357643                                           pimozide  NGLY1-deficiency
# 380174                                         Nalorphine  NGLY1-deficiency
# 380940                           N-hydroxyacetimidic acid  NGLY1-deficiency
# 384383                                         etravirine  NGLY1-deficiency
# 385666                                       immucillin H  NGLY1-deficiency
# 386419  4-[[9-chloro-7-(2,6-difluorophenyl)-5H-pyrimid...  NGLY1-deficiency
# 420821                                         sufentanil  NGLY1-deficiency
# 433481                                         bumetanide  NGLY1-deficiency
# 458594                             Fluphenazine enanthate  NGLY1-deficiency
# 481467                         palonosetron hydrochloride  NGLY1-deficiency
# 496440                                          ceritinib  NGLY1-deficiency
# 497569                                          Panipenem  NGLY1-deficiency
# 512821                                    Eslicarbazepine  NGLY1-deficiency
# 516938                                         Eniluracil  NGLY1-deficiency
# 521487                                        Thiothixene  NGLY1-deficiency
# 557063                                         lacosamide  NGLY1-deficiency
# 592643                                             SB-939  NGLY1-deficiency
# 602684  9-[3-[(3S,5R)-3,5-dimethyl-1-piperazinyl]propy...  NGLY1-deficiency
# 609069                                         mometasone  NGLY1-deficiency
# 609501                                        Bromperidol  NGLY1-deficiency
# 615851  3-(1-methyl-3-indolyl)-4-[1-[1-(2-pyridinylmet...  NGLY1-deficiency
# 618615  N-(6-propoxy-1H-benzimidazol-2-yl)carbamic aci...  NGLY1-deficiency
# 637805                                 nintedanib esylate  NGLY1-deficiency
# 668575                                          Tripamide  NGLY1-deficiency
# 672591                                bendroflumethiazide  NGLY1-deficiency
# 688311                                  salinosporamide A  NGLY1-deficiency
# 695030                                           zotepine  NGLY1-deficiency
# 695163                                         macitentan  NGLY1-deficiency
# 697105                                        butorphanol  NGLY1-deficiency
# 704250  N'-[(4-chlorophenyl)methyl]-N,N-dimethyl-N'-(2...  NGLY1-deficiency
# 706852                                          nilotinib  NGLY1-deficiency
# 710719                                         Tezampanel  NGLY1-deficiency
# 714448                                            MK-0731  NGLY1-deficiency
# 714449                            Filanesib hydrochloride  NGLY1-deficiency
# 714935                                           ixazomib  NGLY1-deficiency
#
#         status
# 184809       0
# 194709       0
# 209880       0
# 210901       0
# 214549       0
# 249622       0
# 289686       0
# 298185       0
# 311109       0
# 313269       0
# 313514       0
# 319656       0
# 347254       0
# 348493       0
# 348604       0
# 357643       0
# 380174       0
# 380940       0
# 384383       0
# 385666       0
# 386419       0
# 420821       0
# 433481       0
# 458594       0
# 481467       0
# 496440       0
# 497569       0
# 512821       0
# 516938       0
# 521487       0
# 557063       0
# 592643       0
# 602684       0
# 609069       0
# 609501       0
# 615851       0
# 618615       0
# 637805       0
# 668575       0
# 672591       0
# 688311       0
# 695030       0
# 695163       0
# 697105       0
# 704250       0
# 706852       0
# 710719       0
# 714448       0
# 714449       0
# 714935       0

# %%
plot_idx(194709)
# Out:
# Extracting data for: Oxethazaine -TREATS- NGLY1-deficiency
# 100%|██████████| 113/113 [00:01<00:00, 61.17it/s]

# %%
plot_idx(184809)
# Out:
# Extracting data for: benzoic acid [2-methyl-2-(propylamino)propyl] ester -TREATS- NGLY1-deficiency
# 100%|██████████| 113/113 [00:01<00:00, 58.85it/s]

# %%
plot_idx(210901)
# Out:
# Extracting data for: levetiracetam -TREATS- NGLY1-deficiency
# 100%|██████████| 113/113 [00:02<00:00, 46.22it/s]

# %%
plot_idx(214549)
# Out:
# Extracting data for: AIKO-150 -TREATS- NGLY1-deficiency
# 100%|██████████| 113/113 [00:01<00:00, 65.43it/s]

# %%
plot_idx(249622)
# Out:
# Extracting data for: trichlormethiazide -TREATS- NGLY1-deficiency
# 100%|██████████| 113/113 [00:02<00:00, 53.90it/s]
