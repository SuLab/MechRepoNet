# %% [markdown]
# # De-duplication
#
# It's come to light that some of the diseases and phenotypes with the same names more than 1 identifier... These should be merged into one unique concept

# %%
import pandas as pd
from pathlib import Path
from data_tools import df_processing as dfp
from data_tools import graphs as gt
# Out:
# /opt/mmayers/software/anaconda3/envs/ml/lib/python3.6/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
nw_name = '10c_Diseae_Phenotype_Cleanup_do_hp_node_merging'
nw_dir = Path('../2_pipeline').resolve().joinpath(nw_name, 'out')

owl_name = '10a_Disease_Pheno_Cleanup_parse_owls'
owl_dir = nw_dir.parent.parent.joinpath(owl_name, 'out')

# %%
this_name = '10d_Diseae_Phenotype_Cleanup_deduplication'
out_dir = Path('../2_pipeline').resolve().joinpath(this_name, 'out')

out_dir.mkdir(parents=True, exist_ok=True)

# %%
do_info = pd.read_csv(owl_dir.joinpath('DO_node_info.csv'))

# %%
nodes = pd.read_csv(nw_dir.joinpath('nodes.csv'), dtype=str)
edges = pd.read_csv(nw_dir.joinpath('edges.csv'), dtype=str)

# %%
id_to_name = nodes.set_index('id')['name'].to_dict()

# %%
nodes['name'] = nodes['name'].str.lower()

# %%
nodes.query('id == "DOID:4952"')
# Out:
#                id                        name    label  \
# 322395  DOID:4952  postpoliomyelitis syndrome  Disease
#
#                                                     xrefs source  \
# 322395  DOID:4952|GARD:4454|ICD10CM:G14|MESH:D016262|M...    NaN
#
#                   synonyms alt_ids subsets
# 322395  Postpolio syndrome     NaN     NaN

# %% [markdown]
# # Issue 1: Duplicated Names...

# %%
pheno_dis = nodes.query('label == "Phenotype" or label == "Disease"').copy()

# %% [markdown]
# Do we mostly have disease-disease duplications, or Disease-Phenotype duplications?

# %%
comb_type = pheno_dis[pheno_dis['name'].duplicated(keep=False)].groupby('name')['label'].apply(tuple)
comb_type.value_counts()
# Out:
# (Disease, Phenotype)                                                                                                                                                                                    234
# (Disease, Disease)                                                                                                                                                                                      233
# (Phenotype, Phenotype)                                                                                                                                                                                   23
# (Disease, Disease, Phenotype)                                                                                                                                                                            15
# (Disease, Phenotype, Phenotype)                                                                                                                                                                           9
# (Disease, Disease, Disease, Phenotype)                                                                                                                                                                    2
# (Disease, Phenotype, Phenotype, Phenotype)                                                                                                                                                                1
# (Disease, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype)      1
# (Disease, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype, Phenotype)                                                                                                         1
# (Disease, Disease, Disease)                                                                                                                                                                               1
# Name: label, dtype: int64

# %%
do_info.query('id == "DOID:0070309" or id == "DOID:50701"')
# Out:
#                 id              name synonyms         xrefs alt_ids subsets
# 2172  DOID:0070309  absence epilepsy      NaN  MESH:D004832     NaN     NaN

# %% [markdown]
# ## Disease-Disease Duplications

# %%
dual_dis = comb_type[comb_type == ('Disease', 'Disease')].index.tolist()
pheno_dis.query('name in @dual_dis').sort_values('name').head(6)
# Out:
#                   id              name    label  \
# 313735  DOID:0050600     abcd syndrome  Disease
# 325581  MESH:C535334     abcd syndrome  Disease
# 322546    DOID:50701  absence epilepsy  Disease
# 315266  DOID:0070309  absence epilepsy  Disease
# 325684  MESH:C536129   achromatopsia 3  Disease
# 316068  DOID:0110008   achromatopsia 3  Disease
#
#                                                     xrefs source  \
# 313735                           DOID:0050600|OMIM:600501    NaN
# 325581                                                NaN    NaN
# 322546                                       MESH:D004832    NaN
# 315266                          DOID:0070309|MESH:D004832    NaN
# 325684                                                NaN    NaN
# 316068  DOID:0110008|GARD:9650|MONDO:0009875|OMIM:2623...    NaN
#
#                                                  synonyms alt_ids subsets
# 313735  ABCDS|albinism, black lock, cell migration dis...     NaN     NaN
# 325581                                                NaN     NaN     NaN
# 322546                                                NaN     NaN     NaN
# 315266                                                NaN     NaN     NaN
# 325684                                                NaN     NaN     NaN
# 316068  ACHM1|ACHM3|Pingelapese blindness|RMCH1|rod mo...     NaN     NaN

# %% [markdown]
# ### Dual DOID...

# %%
pheno_dis['do'] = pheno_dis['id'].str.startswith('DOID:')
pheno_dis['hp'] = pheno_dis['id'].str.startswith('HP:')
pheno_dis['curi'] = pheno_dis['id'].apply(lambda s: s.split(':')[0])

num_do = pheno_dis.query('name in @dual_dis').groupby('name')['do'].sum()
dual_doid = num_do[num_do > 1].index.tolist()

pheno_dis.query('name in @dual_doid').sort_values('name')
# Out:
#                   id                           name    label  \
# 315266  DOID:0070309               absence epilepsy  Disease
# 322546    DOID:50701               absence epilepsy  Disease
# 322532    DOID:50605   acrodermatitis enteropathica  Disease
# 313740  DOID:0050605   acrodermatitis enteropathica  Disease
# 322536    DOID:50631  allan-herndon-dudley syndrome  Disease
# ...              ...                            ...      ...
# 313326  DOID:0050175        tick-borne encephalitis  Disease
# 313415  DOID:0050266                      tungiasis  Disease
# 322473    DOID:50266                      tungiasis  Disease
# 322524    DOID:50562                  west syndrome  Disease
# 313700  DOID:0050562                  west syndrome  Disease
#
#                                                     xrefs source  \
# 315266                          DOID:0070309|MESH:D004832    NaN
# 322546                                       MESH:D004832    NaN
# 322532                                       MESH:C538178    NaN
# 313740  DOID:0050605|GARD:5723|MESH:C538178|MONDO:0008...    NaN
# 322536                                       MESH:D038901    NaN
# ...                                                   ...    ...
# 313326  DOID:0050175|GARD:5216|ICD10CM:A84.1|ICD9CM:06...    NaN
# 313415  DOID:0050266|GARD:393|MESH:D058285|MONDO:00194...    NaN
# 322473                          MESH:D058267|MESH:D058285    NaN
# 322524                                       MESH:D013036    NaN
# 313700  DOID:0050562|GARD:7887|MESH:D013036|NCI:C84788...    NaN
#
#                                                  synonyms  \
# 315266                                                NaN
# 322546                                                NaN
# 322532                                                NaN
# 313740                                                NaN
# 322536                                                NaN
# ...                                                   ...
# 313326  Central European encephalitis|Far Eastern TBE|...
# 313415                                                NaN
# 322473                                                NaN
# 322524                                                NaN
# 313700                                                NaN
#
#                                    alt_ids                        subsets  \
# 315266                                 NaN                            NaN
# 322546                                 NaN                            NaN
# 322532                                 NaN                            NaN
# 313740                                 NaN                            NaN
# 322536                                 NaN                            NaN
# ...                                    ...                            ...
# 313326  DOID:0050176|DOID:10251|DOID:10252  tick-borne_infectious_disease
# 313415                                 NaN                            NaN
# 322473                                 NaN                            NaN
# 322524                                 NaN                            NaN
# 313700                                 NaN                   NCIthesaurus
#
#           do     hp  curi
# 315266  True  False  DOID
# 322546  True  False  DOID
# 322532  True  False  DOID
# 313740  True  False  DOID
# 322536  True  False  DOID
# ...      ...    ...   ...
# 313326  True  False  DOID
# 313415  True  False  DOID
# 322473  True  False  DOID
# 322524  True  False  DOID
# 313700  True  False  DOID
#
# [108 rows x 11 columns]

# %%
current_doids = do_info['id'].unique()

dual_do_current = pheno_dis.query('name in @dual_doid and id in @current_doids')
dual_do_expired = pheno_dis.query('name in @dual_doid and id not in @current_doids')

mrg_map = dual_do_current[['id', 'name']].merge(dual_do_expired[['id', 'name']], on='name', suffixes=('', '_old'))

# %%
depricate_names = pheno_dis.query('do and id not in @current_doids')['name'].unique()
len(depricate_names)
# Out:
# 170

# %%
some_current_do = pheno_dis.query('name in @depricate_names and id in @current_doids')
some_expired_do = pheno_dis.query('do and id not in @current_doids')

mrg_map2 = some_current_do[['id', 'name']].merge(some_expired_do[['id', 'name']], on='name', suffixes=('', '_old'))
mrg_map2
# Out:
#               id                                 name      id_old
# 0   DOID:0050052         rocky mountain spotted fever  DOID:50052
# 1   DOID:0050073               invasive aspergillosis  DOID:50073
# 2   DOID:0050147                           otomycosis  DOID:50147
# 3   DOID:0050156        idiopathic pulmonary fibrosis  DOID:50156
# 4   DOID:0050169        cutaneous lupus erythematosus  DOID:50169
# ..           ...                                  ...         ...
# 59    DOID:10955                     strongyloidiasis  DOID:50009
# 60      DOID:162                               cancer  DOID:60072
# 61     DOID:2377                   multiple sclerosis  DOID:50785
# 62     DOID:5603  t-cell acute lymphoblastic leukemia  DOID:50523
# 63     DOID:9778             irritable bowel syndrome  DOID:50589
#
# [64 rows x 3 columns]

# %%
mrg_map = pd.concat([mrg_map, mrg_map2], sort=False, ignore_index=True).drop_duplicates()

# %% [markdown]
# ### DOID + Other

# %%
one_doid = num_do[num_do == 1].index.tolist()
pheno_dis.query('name in @one_doid').sort_values('name')
# Out:
#                   id                        name    label  \
# 313735  DOID:0050600               abcd syndrome  Disease
# 325581  MESH:C535334               abcd syndrome  Disease
# 316068  DOID:0110008             achromatopsia 3  Disease
# 325684  MESH:C536129             achromatopsia 3  Disease
# 313761  DOID:0050629  aicardi-goutieres syndrome  Disease
# ...              ...                         ...      ...
# 326192  MESH:C565346        tuberous sclerosis 1  Disease
# 326260  MESH:C566021        tuberous sclerosis 2  Disease
# 315610  DOID:0080325        tuberous sclerosis 2  Disease
# 325748  MESH:C536709         winchester syndrome  Disease
# 315899  DOID:0080696         winchester syndrome  Disease
#
#                                                     xrefs source  \
# 313735                           DOID:0050600|OMIM:600501    NaN
# 325581                                                NaN    NaN
# 316068  DOID:0110008|GARD:9650|MONDO:0009875|OMIM:2623...    NaN
# 325684                                                NaN    NaN
# 313761  DOID:0050629|GARD:575|ICD10CM:G31.8|MONDO:0009...    NaN
# ...                                                   ...    ...
# 326192                                                NaN    NaN
# 326260                                                NaN    NaN
# 315610                           DOID:0080325|OMIM:613254    NaN
# 325748                                                NaN    NaN
# 315899                              GARD:7894|OMIM:277950    NaN
#
#                                                  synonyms alt_ids  \
# 313735  ABCDS|albinism, black lock, cell migration dis...     NaN
# 325581                                                NaN     NaN
# 316068  ACHM1|ACHM3|Pingelapese blindness|RMCH1|rod mo...     NaN
# 325684                                                NaN     NaN
# 313761                                  Cree encephalitis     NaN
# ...                                                   ...     ...
# 326192                                                NaN     NaN
# 326260                                                NaN     NaN
# 315610                                                NaN     NaN
# 325748                                                NaN     NaN
# 315899                                                NaN     NaN
#
#              subsets     do     hp  curi
# 313735           NaN   True  False  DOID
# 325581           NaN  False  False  MESH
# 316068           NaN   True  False  DOID
# 325684           NaN  False  False  MESH
# 313761  DO_rare_slim   True  False  DOID
# ...              ...    ...    ...   ...
# 326192           NaN  False  False  MESH
# 326260           NaN  False  False  MESH
# 315610           NaN   True  False  DOID
# 325748           NaN  False  False  MESH
# 315899           NaN   True  False  DOID
#
# [150 rows x 11 columns]

# %%
keep = pheno_dis.query('name in @one_doid and do')
drop = pheno_dis.query('name in @one_doid and not do')

mrg_map2 = keep[['id', 'name']].merge(drop[['id', 'name']], on='name', suffixes=('', '_old'))

# %%
mrg_map = pd.concat([mrg_map, mrg_map2], sort=False, ignore_index=True).drop_duplicates()

# %%
mrg_map
# Out:
#                id                               name        id_old
# 0    DOID:0050052       rocky mountain spotted fever    DOID:50052
# 1    DOID:0050073             invasive aspergillosis    DOID:50073
# 2    DOID:0050147                         otomycosis    DOID:50147
# 3    DOID:0050156      idiopathic pulmonary fibrosis    DOID:50156
# 4    DOID:0050169      cutaneous lupus erythematosus    DOID:50169
# ..            ...                                ...           ...
# 134    DOID:50421           streptococcal infections  MESH:D013290
# 135    DOID:50597      schistosoma mansoni infection  MESH:D012550
# 136     DOID:5746  ovarian serous cystadenocarcinoma  WD:Q53673344
# 137     DOID:8158  complement component 5 deficiency  MESH:C537005
# 138      DOID:999         hypereosinophilic syndrome  MESH:D017681
#
# [139 rows x 3 columns]

# %% [markdown]
# ### 2 non-DOID

# %%
no_doid = num_do[num_do == 0].index.tolist()
pheno_dis.query('name in @no_doid').sort_values('name')
# Out:
#                    id                                               name  \
# 328066  MONDO:0014420                     acid-labile subunit deficiency
# 328802    OMIM:615961                     acid-labile subunit deficiency
# 328857    OMIM:616459                                  al-raqad syndrome
# 328126  MONDO:0014648                                  al-raqad syndrome
# 328024  MONDO:0014219  alacrima, achalasia, and mental retardation sy...
# ...               ...                                                ...
# 327740  MONDO:0011518                         wiedemann-steiner syndrome
# 328985    OMIM:617321                                       yao syndrome
# 328280  MONDO:0015019                                       yao syndrome
# 328233  MONDO:0014936                                      zttk syndrome
# 328945    OMIM:617140                                      zttk syndrome
#
#           label                                              xrefs source  \
# 328066  Disease            MONDO:0014420|OMIM:615961|UMLS:C3900122    NaN
# 328802  Disease                                                NaN    NaN
# 328857  Disease                                                NaN    NaN
# 328126  Disease            MONDO:0014648|OMIM:616459|UMLS:C4085595    NaN
# 328024  Disease            MONDO:0014219|OMIM:615510|UMLS:C3809738    NaN
# ...         ...                                                ...    ...
# 327740  Disease  MONDO:0011518|OMIM:605130|UMLS:C1854630|UMLS:C...    NaN
# 328985  Disease                                                NaN    NaN
# 328280  Disease            MONDO:0015019|OMIM:617321|UMLS:C4310620    NaN
# 328233  Disease            MONDO:0014936|OMIM:617140|UMLS:C4310696    NaN
# 328945  Disease                                                NaN    NaN
#
#        synonyms alt_ids subsets     do     hp   curi
# 328066      NaN     NaN     NaN  False  False  MONDO
# 328802      NaN     NaN     NaN  False  False   OMIM
# 328857      NaN     NaN     NaN  False  False   OMIM
# 328126      NaN     NaN     NaN  False  False  MONDO
# 328024      NaN     NaN     NaN  False  False  MONDO
# ...         ...     ...     ...    ...    ...    ...
# 327740      NaN     NaN     NaN  False  False  MONDO
# 328985      NaN     NaN     NaN  False  False   OMIM
# 328280      NaN     NaN     NaN  False  False  MONDO
# 328233      NaN     NaN     NaN  False  False  MONDO
# 328945      NaN     NaN     NaN  False  False   OMIM
#
# [208 rows x 11 columns]

# %%
dual_non_doid = pheno_dis.query('name in @no_doid').copy()

dual_non_doid.groupby('name')['curi'].apply(tuple).value_counts()
# Out:
# (MONDO, OMIM)     71
# (UMLS, UMLS)       9
# (MONDO, MONDO)     9
# (MESH, OMIM)       5
# (MESH, MONDO)      4
# (MESH, MESH)       2
# (MESH, WD)         2
# (UMLS, WD)         1
# (MESH, UMLS)       1
# Name: curi, dtype: int64

# %%
dual_non_doid['curi'].unique()
# Out:
# array(['MESH', 'MONDO', 'OMIM', 'UMLS', 'WD'], dtype=object)

# %% [markdown]
# Lets use this order:
#
#     MESH > UMLS > OMIM > MONDO > WD
#
# This is pretty much order of easiest to map to other ontologies, to most difficult.
#
# In cases of conflict, honestly don't care...

# %%
curi_order = {'MESH': 0, 'UMLS': 1, 'OMIM': 2, 'MONDO': 3, 'WD':4}

dual_non_doid['curi_rank'] = dual_non_doid['curi'].map(curi_order)

# %%
keep = dual_non_doid.sort_values(['curi_rank', 'id']).drop_duplicates(subset=['name'])
drop = dual_non_doid.sort_values(['curi_rank', 'id'], ascending=False).drop_duplicates(subset=['name'])

mrg_map2 = keep[['id', 'name']].merge(drop[['id', 'name']], on='name', suffixes=('', '_old'))

# %%
mrg_map2
# Out:
#                 id                                               name  \
# 0     MESH:C535705  mandibuloacral dysplasia with type a lipodystr...
# 1     MESH:C535706  mandibuloacral dysplasia with type b lipodystr...
# 2     MESH:C562935            myopathy with abnormal lipid metabolism
# 3     MESH:C563481                          otofaciocervical syndrome
# 4     MESH:C563985                melanoma-pancreatic cancer syndrome
# ..             ...                                                ...
# 99   MONDO:0011937                             exfoliative ichthyosis
# 100  MONDO:0014315                            mitchell-riley syndrome
# 101  MONDO:0017049                          boylan dew greco syndrome
# 102  MONDO:0021201                                     skin infection
# 103  MONDO:0023035                                     eagle syndrome
#
#             id_old
# 0      OMIM:248370
# 1      OMIM:608612
# 2    MONDO:0009703
# 3    MONDO:0008163
# 4    MONDO:0011713
# ..             ...
# 99   MONDO:0017339
# 100  MONDO:0017400
# 101  MONDO:0022025
# 102  MONDO:0024294
# 103  MONDO:0023037
#
# [104 rows x 3 columns]

# %%
mrg_map = pd.concat([mrg_map, mrg_map2], sort=False, ignore_index=True).drop_duplicates()
mrg_map
# Out:
#                 id                           name         id_old
# 0     DOID:0050052   rocky mountain spotted fever     DOID:50052
# 1     DOID:0050073         invasive aspergillosis     DOID:50073
# 2     DOID:0050147                     otomycosis     DOID:50147
# 3     DOID:0050156  idiopathic pulmonary fibrosis     DOID:50156
# 4     DOID:0050169  cutaneous lupus erythematosus     DOID:50169
# ..             ...                            ...            ...
# 238  MONDO:0011937         exfoliative ichthyosis  MONDO:0017339
# 239  MONDO:0014315        mitchell-riley syndrome  MONDO:0017400
# 240  MONDO:0017049      boylan dew greco syndrome  MONDO:0022025
# 241  MONDO:0021201                 skin infection  MONDO:0024294
# 242  MONDO:0023035                 eagle syndrome  MONDO:0023037
#
# [243 rows x 3 columns]

# %% [markdown]
# ## Phentype-Phenotype Duplications
#
# Should be easy...

# %%
dual_pheno = comb_type[comb_type == ('Phenotype', 'Phenotype')].index.tolist()
pheno_dis.query('name in @dual_pheno').sort_values('name')
# Out:
#                   id                          name      label  \
# 584982    WD:Q143877             cogwheel rigidity  Phenotype
# 580469    HP:0002396             cogwheel rigidity  Phenotype
# 585020  WD:Q21110084                    dark urine  Phenotype
# 584571    HP:0040319                    dark urine  Phenotype
# 585023  WD:Q21110117  decreased pulmonary function  Phenotype
# 581903    HP:0005952  decreased pulmonary function  Phenotype
# 584840    HP:0410019               epigastric pain  Phenotype
# 585180   WD:Q3589142               epigastric pain  Phenotype
# 585089  WD:Q21119928                  facial edema  Phenotype
# 579379    HP:0000282                  facial edema  Phenotype
# 580004    HP:0001508             failure to thrive  Phenotype
# 584900  MESH:D005183             failure to thrive  Phenotype
# 580461    HP:0002378                   hand tremor  Phenotype
# 585033  WD:Q21112075                   hand tremor  Phenotype
# 580555    HP:0002573                  hematochezia  Phenotype
# 584986   WD:Q1642049                  hematochezia  Phenotype
# 584906  MESH:D006791                     hostility  Phenotype
# 584440    HP:0031473                     hostility  Phenotype
# 579748    HP:0000962                hyperkeratosis  Phenotype
# 583152     HP:000962                hyperkeratosis  Phenotype
# 584979   WD:Q1429154                 hyperreflexia  Phenotype
# 579936    HP:0001347                 hyperreflexia  Phenotype
# 584561    HP:0040264                      jaw pain  Phenotype
# 585085  WD:Q21119540                      jaw pain  Phenotype
# 580737    HP:0002919                     ketonuria  Phenotype
# 584992   WD:Q1739905                     ketonuria  Phenotype
# 585173   WD:Q3061764             morbilliform rash  Phenotype
# 583940    HP:0012282             morbilliform rash  Phenotype
# 584870    HP:0410291                    negativism  Phenotype
# 584914  MESH:D009341                    negativism  Phenotype
# 584994   WD:Q1756015                  opisthotonus  Phenotype
# 580343    HP:0002179                  opisthotonus  Phenotype
# 585215   WD:Q7098794             optic disc pallor  Phenotype
# 579522    HP:0000543             optic disc pallor  Phenotype
# 580298    HP:0002098          respiratory distress  Phenotype
# 585217   WD:Q7315912          respiratory distress  Phenotype
# 579610    HP:0000711                  restlessness  Phenotype
# 585078  WD:Q21118175                  restlessness  Phenotype
# 579626    HP:0000736          short attention span  Phenotype
# 585130  WD:Q21515325          short attention span  Phenotype
# 585065  WD:Q21117191                slurred speech  Phenotype
# 579939    HP:0001350                slurred speech  Phenotype
# 585086  WD:Q21119551                 unsteady gait  Phenotype
# 580422    HP:0002317                 unsteady gait  Phenotype
# 585179   WD:Q3539327                   webbed neck  Phenotype
# 579480    HP:0000465                   webbed neck  Phenotype
#
#                                                     xrefs source synonyms  \
# 584982                                                NaN    NaN      NaN
# 580469         MESH:D009127|SNOMED:55630000|UMLS:C0151564    NaN      NaN
# 585020                                                NaN    NaN      NaN
# 584571                                                NaN    NaN      NaN
# 585023                                                NaN    NaN      NaN
# 581903                                       MESH:D012131    NaN      NaN
# 584840                                                NaN    NaN      NaN
# 585180                                                NaN    NaN      NaN
# 585089                                                NaN    NaN      NaN
# 579379                     SNOMED:445088006|UMLS:C0542571    NaN      NaN
# 580004  SNOMED:36440009|SNOMED:432788009|UMLS:C0231246...    NaN      NaN
# 584900                                       MESH:D005183    NaN      NaN
# 580461                                      UMLS:C0239842    NaN      NaN
# 585033                                                NaN    NaN      NaN
# 580555                                       MESH:D006471    NaN      NaN
# 584986                                                NaN    NaN      NaN
# 584906                                       MESH:D006791    NaN      NaN
# 584440                                                NaN    NaN      NaN
# 579748  SNOMED:26996000|SNOMED:396228006|SNOMED:399955...    NaN      NaN
# 583152                                          HP:000962    NaN      NaN
# 584979                                                NaN    NaN      NaN
# 579936                HP:0001347|MESH:D012021|OMIM:145290    NaN      NaN
# 584561                     SNOMED:274667000|UMLS:C0236000    NaN      NaN
# 585085                                                NaN    NaN      NaN
# 580737  MESH:D007662|SNOMED:274783007|SNOMED:36815008|...    NaN      NaN
# 584992                                                NaN    NaN      NaN
# 585173                                                NaN    NaN      NaN
# 583940     SNOMED:247470007|SNOMED:50495000|UMLS:C0234918    NaN      NaN
# 584870                                                NaN    NaN      NaN
# 584914                                       MESH:D009341    NaN      NaN
# 584994                                                NaN    NaN      NaN
# 580343                       SNOMED:8652009|UMLS:C0151818    NaN      NaN
# 585215                                                NaN    NaN      NaN
# 579522                     SNOMED:302200001|UMLS:C0554970    NaN      NaN
# 580298  MESH:D004417|SNOMED:230145002|SNOMED:267036007...    NaN      NaN
# 585217                                                NaN    NaN      NaN
# 579610                     SNOMED:162221009|UMLS:C3887611    NaN      NaN
# 585078                                                NaN    NaN      NaN
# 579626                     SNOMED:247762003|UMLS:C0262630    NaN      NaN
# 585130                                                NaN    NaN      NaN
# 585065                                                NaN    NaN      NaN
# 579939                     SNOMED:289195008|UMLS:C0234518    NaN      NaN
# 585086                                                NaN    NaN      NaN
# 580422  MESH:D020233|SNOMED:22631008|SNOMED:394616008|...    NaN      NaN
# 585179                                                NaN    NaN      NaN
# 579480                      SNOMED:11731003|UMLS:C0221217    NaN      NaN
#
#        alt_ids subsets     do     hp  curi
# 584982     NaN     NaN  False  False    WD
# 580469     NaN     NaN  False   True    HP
# 585020     NaN     NaN  False  False    WD
# 584571     NaN     NaN  False   True    HP
# 585023     NaN     NaN  False  False    WD
# 581903     NaN     NaN  False   True    HP
# 584840     NaN     NaN  False   True    HP
# 585180     NaN     NaN  False  False    WD
# 585089     NaN     NaN  False  False    WD
# 579379     NaN     NaN  False   True    HP
# 580004     NaN     NaN  False   True    HP
# 584900     NaN     NaN  False  False  MESH
# 580461     NaN     NaN  False   True    HP
# 585033     NaN     NaN  False  False    WD
# 580555     NaN     NaN  False   True    HP
# 584986     NaN     NaN  False  False    WD
# 584906     NaN     NaN  False  False  MESH
# 584440     NaN     NaN  False   True    HP
# 579748     NaN     NaN  False   True    HP
# 583152     NaN     NaN  False   True    HP
# 584979     NaN     NaN  False  False    WD
# 579936     NaN     NaN  False   True    HP
# 584561     NaN     NaN  False   True    HP
# 585085     NaN     NaN  False  False    WD
# 580737     NaN     NaN  False   True    HP
# 584992     NaN     NaN  False  False    WD
# 585173     NaN     NaN  False  False    WD
# 583940     NaN     NaN  False   True    HP
# 584870     NaN     NaN  False   True    HP
# 584914     NaN     NaN  False  False  MESH
# 584994     NaN     NaN  False  False    WD
# 580343     NaN     NaN  False   True    HP
# 585215     NaN     NaN  False  False    WD
# 579522     NaN     NaN  False   True    HP
# 580298     NaN     NaN  False   True    HP
# 585217     NaN     NaN  False  False    WD
# 579610     NaN     NaN  False   True    HP
# 585078     NaN     NaN  False  False    WD
# 579626     NaN     NaN  False   True    HP
# 585130     NaN     NaN  False  False    WD
# 585065     NaN     NaN  False  False    WD
# 579939     NaN     NaN  False   True    HP
# 585086     NaN     NaN  False  False    WD
# 580422     NaN     NaN  False   True    HP
# 585179     NaN     NaN  False  False    WD
# 579480     NaN     NaN  False   True    HP

# %% [markdown]
# Nice in that all of these are HPO vs Something else... easy to chouse HPO versions

# %%
pheno_conflict = pheno_dis.query('name in @dual_pheno').copy()

# %%
pheno_conflict['hp'] = pheno_conflict['curi'] == "HP"

# %%
def create_map(keep, drop):
    return keep[['id', 'name']].merge(drop[['id', 'name']], on='name', suffixes=('', '_old'))

# %%
keep = pheno_conflict.query('hp')
drop = pheno_conflict.query('not hp')

mrg_map2 = keep[['id', 'name']].merge(drop[['id', 'name']], on='name', suffixes=('', '_old'))

# %%
mrg_map2
# Out:
#             id                          name        id_old
# 0   HP:0000282                  facial edema  WD:Q21119928
# 1   HP:0000465                   webbed neck   WD:Q3539327
# 2   HP:0000543             optic disc pallor   WD:Q7098794
# 3   HP:0000711                  restlessness  WD:Q21118175
# 4   HP:0000736          short attention span  WD:Q21515325
# 5   HP:0001347                 hyperreflexia   WD:Q1429154
# 6   HP:0001350                slurred speech  WD:Q21117191
# 7   HP:0001508             failure to thrive  MESH:D005183
# 8   HP:0002098          respiratory distress   WD:Q7315912
# 9   HP:0002179                  opisthotonus   WD:Q1756015
# 10  HP:0002317                 unsteady gait  WD:Q21119551
# 11  HP:0002378                   hand tremor  WD:Q21112075
# 12  HP:0002396             cogwheel rigidity    WD:Q143877
# 13  HP:0002573                  hematochezia   WD:Q1642049
# 14  HP:0002919                     ketonuria   WD:Q1739905
# 15  HP:0005952  decreased pulmonary function  WD:Q21110117
# 16  HP:0012282             morbilliform rash   WD:Q3061764
# 17  HP:0031473                     hostility  MESH:D006791
# 18  HP:0040264                      jaw pain  WD:Q21119540
# 19  HP:0040319                    dark urine  WD:Q21110084
# 20  HP:0410019               epigastric pain   WD:Q3589142
# 21  HP:0410291                    negativism  MESH:D009341

# %%
mrg_map = pd.concat([mrg_map, mrg_map2], sort=False, ignore_index=True).drop_duplicates()
mrg_map
# Out:
#                id                           name        id_old
# 0    DOID:0050052   rocky mountain spotted fever    DOID:50052
# 1    DOID:0050073         invasive aspergillosis    DOID:50073
# 2    DOID:0050147                     otomycosis    DOID:50147
# 3    DOID:0050156  idiopathic pulmonary fibrosis    DOID:50156
# 4    DOID:0050169  cutaneous lupus erythematosus    DOID:50169
# ..            ...                            ...           ...
# 260    HP:0031473                      hostility  MESH:D006791
# 261    HP:0040264                       jaw pain  WD:Q21119540
# 262    HP:0040319                     dark urine  WD:Q21110084
# 263    HP:0410019                epigastric pain   WD:Q3589142
# 264    HP:0410291                     negativism  MESH:D009341
#
# [265 rows x 3 columns]

# %% [markdown]
# ## Disease-Phenotype Conflicts

# %%
het_names = comb_type[comb_type == ('Disease', 'Phenotype')].index.tolist()
hetero_conflict = pheno_dis.query('name in @het_names').copy()
hetero_conflict.sort_values('name')
# Out:
#                   id                         name      label  \
# 314456  DOID:0060336  3-methylglutaconic aciduria    Disease
# 581096    HP:0003535  3-methylglutaconic aciduria  Phenotype
# 324301     DOID:7693    abdominal aortic aneurysm    Disease
# 581596    HP:0005112    abdominal aortic aneurysm  Phenotype
# 583569    HP:0011224                   ablepharon  Phenotype
# ...              ...                          ...        ...
# 323376    DOID:60674       ventricular arrhythmia    Disease
# 582135    HP:0006562              viral hepatitis  Phenotype
# 320294     DOID:1884              viral hepatitis    Disease
# 314356  DOID:0060236                  xanthinuria    Disease
# 583506    HP:0010934                  xanthinuria  Phenotype
#
#                                                     xrefs source  \
# 314456  DOID:0060336|ICD10CM:E71.111|MESH:C579867|MOND...    NaN
# 581096                           MESH:C579867|OMIM:250950    NaN
# 324301  DOID:7693|EFO:0004214|GARD:9181|MESH:D017544|M...    NaN
# 581596                                      UMLS:C4025248    NaN
# 583569  SNOMED:13401001|SNOMED:708541009|UMLS:C0266574...    NaN
# ...                                                   ...    ...
# 323376                          MESH:C536334|MESH:D017180    NaN
# 582135                       SNOMED:3738000|UMLS:C0042721    NaN
# 320294  DOID:1884|MESH:D006524|MESH:D006525|MONDO:0025...    NaN
# 314356  DOID:0060236|MESH:C562584|MESH:C566358|MONDO:0...    NaN
# 583506     SNOMED:190919008|SNOMED:54627004|UMLS:C0220988    NaN
#
#                                                  synonyms  \
# 314456                                                NaN
# 581096                                                NaN
# 324301              AORTIC ANEURYSM, FAMILIAL ABDOMINAL 1
# 581596                                                NaN
# 583569                                                NaN
# ...                                                   ...
# 323376                                                NaN
# 582135                                                NaN
# 320294  Viral hepatitis with hepatic coma|animal viral...
# 314356  xanthine dehydrogenase deficiency|xanthine oxi...
# 583506                                                NaN
#
#                                alt_ids                       subsets     do  \
# 314456                             NaN                  DO_rare_slim   True
# 581096                             NaN                           NaN  False
# 324301                             NaN                  NCIthesaurus   True
# 581596                             NaN                           NaN  False
# 583569                             NaN                           NaN  False
# ...                                ...                           ...    ...
# 323376                             NaN                           NaN   True
# 582135                             NaN                           NaN  False
# 320294  DOID:12548|DOID:1331|DOID:1885                           NaN   True
# 314356                             NaN  DO_FlyBase_slim|DO_rare_slim   True
# 583506                             NaN                           NaN  False
#
#            hp  curi
# 314456  False  DOID
# 581096   True    HP
# 324301  False  DOID
# 581596   True    HP
# 583569   True    HP
# ...       ...   ...
# 323376  False  DOID
# 582135   True    HP
# 320294  False  DOID
# 314356  False  DOID
# 583506   True    HP
#
# [468 rows x 11 columns]

# %%
hetero_conflict['do'] = hetero_conflict['do'].astype(int)

# %%
hetero_conflict.groupby('name')['do'].sum().value_counts()
# Out:
# 1    178
# 0     56
# Name: do, dtype: int64

# %%
no_do_conf = hetero_conflict.groupby('name')['do'].sum()
no_do_conf = no_do_conf[no_do_conf == 0].index.tolist()

hetero_conflict.query("name == @no_do_conf").sort_values('name').head(30)
# Out:
#                    id                           name      label  \
# 583569     HP:0011224                     ablepharon  Phenotype
# 329682     WD:Q322370                     ablepharon    Disease
# 583830     HP:0012050                       anasarca  Phenotype
# 329834     WD:Q486485                       anasarca    Disease
# 581470     HP:0004823            anisopoikilocytosis  Phenotype
# 329240  UMLS:C2675920            anisopoikilocytosis    Disease
# 328431  MONDO:0019780                         anotia    Disease
# 583252     HP:0009892                         anotia  Phenotype
# 584195     HP:0025478              atrial standstill  Phenotype
# 326075   MESH:C563984              atrial standstill    Disease
# 326610   MESH:D002543            cerebral hemorrhage    Disease
# 579933     HP:0001342            cerebral hemorrhage  Phenotype
# 326613   MESH:D002647                     chilblains    Disease
# 583165     HP:0009710                     chilblains  Phenotype
# 326616   MESH:D002832             choroid hemorrhage    Disease
# 583754     HP:0011887             choroid hemorrhage  Phenotype
# 327185   MESH:D020256   choroidal neovascularization    Disease
# 583652     HP:0011506   choroidal neovascularization  Phenotype
# 583456     HP:0010774                cor triatriatum  Phenotype
# 328288  MONDO:0015450                cor triatriatum    Disease
# 329393     WD:Q160796                       delirium    Disease
# 584419     HP:0031258                       delirium  Phenotype
# 582806     HP:0008341  distal renal tubular acidosis  Phenotype
# 328533    OMIM:179800  distal renal tubular acidosis    Disease
# 329179  UMLS:C0858618                dyschromatopsia    Disease
# 582539     HP:0007641                dyschromatopsia  Phenotype
# 326657   MESH:D004646                      emphysema    Disease
# 580297     HP:0002097                      emphysema  Phenotype
# 580348     HP:0002189   excessive daytime sleepiness  Phenotype
# 329663    WD:Q3144201   excessive daytime sleepiness    Disease
#
#                                                     xrefs source synonyms  \
# 583569  SNOMED:13401001|SNOMED:708541009|UMLS:C0266574...    NaN      NaN
# 329682                                                NaN    NaN      NaN
# 583830  MESH:D004487|SNOMED:16740003|SNOMED:442433009|...    NaN      NaN
# 329834                                                NaN    NaN      NaN
# 581470                                      UMLS:C2675920    NaN      NaN
# 329240                                      UMLS:C2675920    NaN      NaN
# 328431  MESH:C537772|MONDO:0019780|OMIM:600674|UMLS:C0...    NaN      NaN
# 583252  MESH:D065817|SNOMED:57436000|UMLS:C0702139|UML...    NaN      NaN
# 584195                                                NaN    NaN      NaN
# 326075                                                NaN    NaN      NaN
# 326610                                       MESH:D002543    NaN      NaN
# 579933  MESH:D002543|MESH:D020300|SNOMED:230706003|SNO...    NaN      NaN
# 326613                         MESH:D002647|UMLS:C0008058    NaN      NaN
# 583165                                      UMLS:C4024224    NaN      NaN
# 326616                                                NaN    NaN      NaN
# 583754                                         HP:0011887    NaN      NaN
# 327185                                       MESH:D020256    NaN      NaN
# 583652                                      UMLS:C4023323    NaN      NaN
# 583456                                      UMLS:C4023708    NaN      NaN
# 328288           MESH:D003310|MONDO:0015450|UMLS:C0009995    NaN      NaN
# 329393                                                NaN    NaN      NaN
# 584419                                                NaN    NaN      NaN
# 582806   MESH:D000141|OMIM:179830|OMIM:267200|OMIM:602722    NaN      NaN
# 328533                                        OMIM:179800    NaN      NaN
# 329179                                      UMLS:C0858618    NaN      NaN
# 582539                                      UMLS:C0858618    NaN      NaN
# 326657                                                NaN    NaN      NaN
# 580297                           MESH:D011656|OMIM:130700    NaN      NaN
# 580348                                      UMLS:C0694563    NaN      NaN
# 329663                                                NaN    NaN      NaN
#
#        alt_ids subsets  do     hp   curi
# 583569     NaN     NaN   0   True     HP
# 329682     NaN     NaN   0  False     WD
# 583830     NaN     NaN   0   True     HP
# 329834     NaN     NaN   0  False     WD
# 581470     NaN     NaN   0   True     HP
# 329240     NaN     NaN   0  False   UMLS
# 328431     NaN     NaN   0  False  MONDO
# 583252     NaN     NaN   0   True     HP
# 584195     NaN     NaN   0   True     HP
# 326075     NaN     NaN   0  False   MESH
# 326610     NaN     NaN   0  False   MESH
# 579933     NaN     NaN   0   True     HP
# 326613     NaN     NaN   0  False   MESH
# 583165     NaN     NaN   0   True     HP
# 326616     NaN     NaN   0  False   MESH
# 583754     NaN     NaN   0   True     HP
# 327185     NaN     NaN   0  False   MESH
# 583652     NaN     NaN   0   True     HP
# 583456     NaN     NaN   0   True     HP
# 328288     NaN     NaN   0  False  MONDO
# 329393     NaN     NaN   0  False     WD
# 584419     NaN     NaN   0   True     HP
# 582806     NaN     NaN   0   True     HP
# 328533     NaN     NaN   0  False   OMIM
# 329179     NaN     NaN   0  False   UMLS
# 582539     NaN     NaN   0   True     HP
# 326657     NaN     NaN   0  False   MESH
# 580297     NaN     NaN   0   True     HP
# 580348     NaN     NaN   0   True     HP
# 329663     NaN     NaN   0  False     WD

# %%
hetero_conflict.query("name == @no_do_conf").groupby('name')['hp'].sum().value_counts()
# Out:
# True    56
# Name: hp, dtype: int64

# %% [markdown]
# So if there's no DOID we can convert it to an HPO and call it a Phenotype, otherwise, we can convert it to a DOID and call it a disease

# %%
keep = hetero_conflict.query('do == 1')
keep_names = keep['name'].unique()
drop = hetero_conflict.query('do == 0 and name in @keep_names')

mrg2 = create_map(keep, drop)

keep = hetero_conflict.query('hp == 1 and name not in @keep_names')
keep_names = keep['name'].unique()
drop = hetero_conflict.query('hp == 0 and name in @keep_names')

mrg3 = create_map(keep, drop)

# %%
len(mrg2)
# Out:
# 178

# %%
len(mrg3)
# Out:
# 56

# %%
len(mrg2) + len(mrg3) == hetero_conflict['name'].nunique()
# Out:
# True

# %%
mrg_map = pd.concat([mrg_map, mrg2, mrg3], sort=False, ignore_index=True).drop_duplicates()
mrg_map
# Out:
#                id                           name         id_old
# 0    DOID:0050052   rocky mountain spotted fever     DOID:50052
# 1    DOID:0050073         invasive aspergillosis     DOID:50073
# 2    DOID:0050147                     otomycosis     DOID:50147
# 3    DOID:0050156  idiopathic pulmonary fibrosis     DOID:50156
# 4    DOID:0050169  cutaneous lupus erythematosus     DOID:50169
# ..            ...                            ...            ...
# 494    HP:0031295        left atrial enlargement  UMLS:C0238705
# 495    HP:0031814                      palilalia    WD:Q1757666
# 496    HP:0100578                    lipoatrophy    WD:Q3500973
# 497    HP:0100806                         sepsis   MESH:D016470
# 498    HP:0200057              marcus gunn pupil    WD:Q6758201
#
# [499 rows x 3 columns]

# %% [markdown]
# ## 3 or more IDs per name

# %%
size = pheno_dis[pheno_dis['name'].duplicated(keep=False)].groupby('name').apply(len) 
size[size > 2].sort_values(ascending=False)
# Out:
# name
# prostate cancer                    18
# hyperinsulinemic hypoglycemia       9
# primary congenital glaucoma         4
# muscle spasm                        4
# pain                                4
# vitamin b12 deficiency              3
# ductal carcinoma in situ            3
# glucose intolerance                 3
# glomerulosclerosis                  3
# dyscalculia                         3
# congenital muscular dystrophy       3
# insomnia                            3
# congenital adrenal hyperplasia      3
# chronic myelomonocytic leukemia     3
# ankylosis                           3
# amenorrhea                          3
# hypophosphatemia                    3
# lattice corneal dystrophy           3
# lamb-shaffer syndrome               3
# visual agnosia                      3
# lung abscess                        3
# meconium ileus                      3
# microcephaly                        3
# osteoblastoma                       3
# pheochromocytoma                    3
# scoliosis                           3
# stomach cancer                      3
# torticollis                         3
# trigonocephaly                      3
# allergy                             3
# dtype: int64

# %%
comb_type[size[size == 3].index.tolist()].value_counts()
# Out:
# (Disease, Disease, Phenotype)      15
# (Disease, Phenotype, Phenotype)     9
# (Disease, Disease, Disease)         1
# Name: label, dtype: int64

# %% [markdown]
# ### 2 pheno, 1 disease

# %%
this_names = comb_type[comb_type == ('Disease', 'Phenotype', 'Phenotype')].index.tolist()
curr_conflict = pheno_dis.query('name in @this_names').copy()

# %%
curr_conflict.sort_values('name')
# Out:
#                   id                       name      label  \
# 584893  MESH:D000568                 amenorrhea  Phenotype
# 579298    HP:0000141                 amenorrhea  Phenotype
# 319698    DOID:13938                 amenorrhea    Disease
# 584894  MESH:D000844                  ankylosis  Phenotype
# 584388    HP:0031013                  ankylosis  Phenotype
# 320532      DOID:227                  ankylosis    Disease
# 580486    HP:0002442                dyscalculia  Phenotype
# 584934  MESH:D060705                dyscalculia  Phenotype
# 319054    DOID:12568                dyscalculia    Disease
# 318052    DOID:10603        glucose intolerance    Disease
# 580216    HP:0001952        glucose intolerance  Phenotype
# 584924  MESH:D018149        glucose intolerance  Phenotype
# 325001     DOID:8943  lattice corneal dystrophy    Disease
# 579837    HP:0001149  lattice corneal dystrophy  Phenotype
# 584886  MESH:C537935  lattice corneal dystrophy  Phenotype
# 318191    DOID:10907               microcephaly    Disease
# 584912  MESH:D008831               microcephaly  Phenotype
# 579360    HP:0000252               microcephaly  Phenotype
# 580593    HP:0002650                  scoliosis  Phenotype
# 584918  MESH:D012600                  scoliosis  Phenotype
# 314369  DOID:0060249                  scoliosis    Disease
# 584970   OMIM:613659             stomach cancer  Phenotype
# 584938   OMIM:137215             stomach cancer  Phenotype
# 318004    DOID:10534             stomach cancer    Disease
# 584258    HP:0030222             visual agnosia  Phenotype
# 584883  MESH:C531604             visual agnosia  Phenotype
# 314275  DOID:0060155             visual agnosia    Disease
#
#                                                     xrefs source  \
# 584893                                       MESH:D000568    NaN
# 579298                                      UMLS:C2219717    NaN
# 319698  DOID:13938|ICD10CM:N91.2|ICD9CM:626.0|MESH:D00...    NaN
# 584894                                       MESH:D000844    NaN
# 584388                                                NaN    NaN
# 320532  DOID:227|ICD10CM:M24.6|ICD9CM:718.5|MESH:D0008...    NaN
# 580486        SNOMED:47916000|UMLS:C1411876|UMLS:C4280576    NaN
# 584934                                       MESH:D060705    NaN
# 319054  DOID:12568|MESH:D060705|MONDO:0001552|UMLS:C08...    NaN
# 318052  DOID:10603|ICD10CM:R73.03|MESH:D018149|MONDO:0...    NaN
# 580216                                      UMLS:C0235401    NaN
# 584924                                       MESH:D018149    NaN
# 325001   DOID:8943|MESH:C537935|MONDO:0004686|OMIM:122200    NaN
# 579837  MESH:D028227|SNOMED:1192004|SNOMED:361199007|U...    NaN
# 584886                           MESH:C537935|OMIM:122200    NaN
# 318191  DOID:10907|GARD:3603|GARD:7038|ICD10CM:Q02|ICD...    NaN
# 584912  MESH:D008831|OMIM:251200|OMIM:604321|OMIM:6048...    NaN
# 579360                     SNOMED:271611007|UMLS:C0424688    NaN
# 580593  MESH:D013121|SNOMED:111266001|SNOMED:64217002|...    NaN
# 584918                                       MESH:D012600    NaN
# 314369  DOID:0060249|ICD10CM:M41.9|MESH:D012600|MONDO:...    NaN
# 584970                            OMIM:137215|OMIM:613659    NaN
# 584938                            OMIM:137215|OMIM:613659    NaN
# 318004  DOID:10534|GARD:7704|ICD10CM:C16|ICD10CM:C16.2...    NaN
# 584258                                       MESH:D000377    NaN
# 584883                                       MESH:C531604    NaN
# 314275  DOID:0060155|MESH:C531604|MONDO:0000685|UMLS:C...    NaN
#
#                                                  synonyms  \
# 584893                                                NaN
# 579298                                                NaN
# 319698                     absence of menstruation|amenia
# 584894                                                NaN
# 584388                                                NaN
# 320532                                                NaN
# 580486                                                NaN
# 584934                                                NaN
# 319054  Mathematics disorder|disorder of arithmetical ...
# 318052  Glucose: intolerance|Glucose: malabsorption|Ma...
# 580216                                                NaN
# 584924                                                NaN
# 325001          familial amyloid neuropathy, Finnish type
# 579837                                                NaN
# 584886                                                NaN
# 318191                       Microcephalus|microencephaly
# 584912                                                NaN
# 579360                                                NaN
# 580593                                                NaN
# 584918                                                NaN
# 314369                                                NaN
# 584970                                                NaN
# 584938                                                NaN
# 318004                    gastric cancer|gastric neoplasm
# 584258                                                NaN
# 584883                                                NaN
# 314275                                                NaN
#
#                                            alt_ids  \
# 584893                                         NaN
# 579298                                         NaN
# 319698                                         NaN
# 584894                                         NaN
# 584388                                         NaN
# 320532                                         NaN
# 580486                                         NaN
# 584934                                         NaN
# 319054                                         NaN
# 318052                                         NaN
# 580216                                         NaN
# 584924                                         NaN
# 325001                                         NaN
# 579837                                         NaN
# 584886                                         NaN
# 318191                                         NaN
# 584912                                         NaN
# 579360                                         NaN
# 580593                                         NaN
# 584918                                         NaN
# 314369                                         NaN
# 584970                                         NaN
# 584938                                         NaN
# 318004  DOID:10539|DOID:10542|DOID:10543|DOID:4713
# 584258                                         NaN
# 584883                                         NaN
# 314275                                         NaN
#
#                                                   subsets     do     hp  curi
# 584893                                                NaN  False  False  MESH
# 579298                                                NaN  False   True    HP
# 319698                                       NCIthesaurus   True  False  DOID
# 584894                                                NaN  False  False  MESH
# 584388                                                NaN  False   True    HP
# 320532                                                NaN   True  False  DOID
# 580486                                                NaN  False   True    HP
# 584934                                                NaN  False  False  MESH
# 319054                                                NaN   True  False  DOID
# 318052                                       NCIthesaurus   True  False  DOID
# 580216                                                NaN  False   True    HP
# 584924                                                NaN  False  False  MESH
# 325001                                                NaN   True  False  DOID
# 579837                                                NaN  False   True    HP
# 584886                                                NaN  False  False  MESH
# 318191                       DO_FlyBase_slim|NCIthesaurus   True  False  DOID
# 584912                                                NaN  False  False  MESH
# 579360                                                NaN  False   True    HP
# 580593                                                NaN  False   True    HP
# 584918                                                NaN  False  False  MESH
# 314369                                       NCIthesaurus   True  False  DOID
# 584970                                                NaN  False  False  OMIM
# 584938                                                NaN  False  False  OMIM
# 318004  DO_FlyBase_slim|DO_cancer_slim|NCIthesaurus|To...   True  False  DOID
# 584258                                                NaN  False   True    HP
# 584883                                                NaN  False  False  MESH
# 314275                                                NaN   True  False  DOID

# %%
curr_conflict.groupby('name')['do'].sum()
# Out:
# name
# amenorrhea                   True
# ankylosis                    True
# dyscalculia                  True
# glucose intolerance          True
# lattice corneal dystrophy    True
# microcephaly                 True
# scoliosis                    True
# stomach cancer               True
# visual agnosia               True
# Name: do, dtype: bool

# %% [markdown]
# All have their disease annotated as a DOID... we'll set them to diseases.

# %%
keep = curr_conflict.query('do == True')
keep_names = keep['name'].unique()
drop = curr_conflict.query('do == False and name in @keep_names')

mrg2 = create_map(keep, drop)

# %%
mrg_map = pd.concat([mrg_map, mrg2], sort=False, ignore_index=True).drop_duplicates()
mrg_map
# Out:
#                id                           name        id_old
# 0    DOID:0050052   rocky mountain spotted fever    DOID:50052
# 1    DOID:0050073         invasive aspergillosis    DOID:50073
# 2    DOID:0050147                     otomycosis    DOID:50147
# 3    DOID:0050156  idiopathic pulmonary fibrosis    DOID:50156
# 4    DOID:0050169  cutaneous lupus erythematosus    DOID:50169
# ..            ...                            ...           ...
# 512    DOID:13938                     amenorrhea  MESH:D000568
# 513      DOID:227                      ankylosis    HP:0031013
# 514      DOID:227                      ankylosis  MESH:D000844
# 515     DOID:8943      lattice corneal dystrophy    HP:0001149
# 516     DOID:8943      lattice corneal dystrophy  MESH:C537935
#
# [517 rows x 3 columns]

# %%
mrg_map['id_old'].nunique(), mrg_map['id'].nunique()
# Out:
# (517, 508)

# %% [markdown]
# ### 2 Disease + Pheno

# %%
this_names = comb_type[comb_type == ('Disease', 'Disease', 'Phenotype')].index.tolist()
curr_conflict = pheno_dis.query('name in @this_names').copy()

# %%
curr_conflict.groupby('name')['do'].sum()
# Out:
# name
# allergy                            2.0
# chronic myelomonocytic leukemia    2.0
# congenital adrenal hyperplasia     2.0
# congenital muscular dystrophy      2.0
# ductal carcinoma in situ           2.0
# glomerulosclerosis                 2.0
# hypophosphatemia                   2.0
# insomnia                           1.0
# lung abscess                       2.0
# meconium ileus                     0.0
# osteoblastoma                      2.0
# pheochromocytoma                   2.0
# torticollis                        1.0
# trigonocephaly                     0.0
# vitamin b12 deficiency             2.0
# Name: do, dtype: float64

# %% [markdown]
# Those with 2 DOIDs we'll treat like a DO-DO conflict above, Those with 1, we'll take the DOID, those wtih 0, we'll see if there's an HPO Id and take that... othereise do something else

# %% [markdown]
# #### Dual DO

# %%
num_do = curr_conflict.groupby('name')['do'].sum()
dual_doid = num_do[num_do > 1].index.tolist()

dual_do_current = curr_conflict.query('name in @dual_doid and id in @current_doids')
dual_do_expired = curr_conflict.query('name in @dual_doid and id not in @current_doids')

# %%
dual_do_current['name'].nunique(), dual_do_expired['name'].nunique()
# Out:
# (10, 11)

# %% [markdown]
# One had 2 doids, neither current....

# %%
found_names = dual_do_current['name'].unique()
dual_do_expired.query('name not in @found_names')
# Out:
#                 id     name      label  \
# 323303  DOID:60056  allergy    Disease
# 323362  DOID:60496  allergy    Disease
# 583983  HP:0012393  allergy  Phenotype
#
#                                               xrefs source synonyms alt_ids  \
# 323303       MESH:D000707|MESH:D006967|MESH:D065631    NaN      NaN     NaN
# 323362                    MESH:D006967|MESH:D012141    NaN      NaN     NaN
# 583983  MESH:D006967|SNOMED:419076005|UMLS:C1527304    NaN      NaN     NaN
#
#        subsets     do     hp  curi
# 323303     NaN   True  False  DOID
# 323362     NaN   True  False  DOID
# 583983     NaN  False   True    HP

# %% [markdown]
# Does not seem to be correct.... All 3 instances have the same MESH Xref, though: `MESH:D006967`

# %%
xref_res = dfp.expand_col_on_char(do_info, 'xrefs', '|', True)[['id', 'name', 'xrefs']].query('xrefs == "MESH:D006967"')
xref_res
# Out:
#               id              name         xrefs
# 14964  DOID:1205  allergic disease  MESH:D006967

# %%
to_rename = dual_do_expired.query('name not in @found_names').copy()
# Remove them
dual_do_expired = dual_do_expired.drop(to_rename.index)
to_rename['name'] = xref_res.iloc[0].loc['name']

# %%
dual_do_expired.sort_values('name')
# Out:
#                   id                             name      label  \
# 322505    DOID:50458  chronic myelomonocytic leukemia    Disease
# 583960    HP:0012325  chronic myelomonocytic leukemia  Phenotype
# 322575    DOID:50811   congenital adrenal hyperplasia    Disease
# 582775    HP:0008258   congenital adrenal hyperplasia  Phenotype
# 322521    DOID:50557    congenital muscular dystrophy    Disease
# 581192    HP:0003741    congenital muscular dystrophy  Phenotype
# 584239    HP:0030075         ductal carcinoma in situ  Phenotype
# 323308    DOID:60074         ductal carcinoma in situ    Disease
# 322589    DOID:50851               glomerulosclerosis    Disease
# 579276    HP:0000096               glomerulosclerosis  Phenotype
# 322485    DOID:50336                 hypophosphatemia    Disease
# 580321    HP:0002148                 hypophosphatemia  Phenotype
# 323343    DOID:60317                     lung abscess    Disease
# 584909  MESH:D008169                     lung abscess  Phenotype
# 323313    DOID:60098                    osteoblastoma    Disease
# 583734    HP:0011846                    osteoblastoma  Phenotype
# 322609    DOID:50936                 pheochromocytoma    Disease
# 580602    HP:0002666                 pheochromocytoma  Phenotype
# 584644    HP:0100502           vitamin b12 deficiency  Phenotype
# 322553    DOID:50731           vitamin b12 deficiency    Disease
#
#                                                  xrefs source synonyms  \
# 322505                                    MESH:D015477    NaN      NaN
# 583960                                    MESH:D015477    NaN      NaN
# 322575                                    MESH:D000312    NaN      NaN
# 582775     MESH:D000312|SNOMED:237751000|UMLS:C0001627    NaN      NaN
# 322521                                    MESH:D009136    NaN      NaN
# 581192                  SNOMED:240059009|UMLS:C0699743    NaN      NaN
# 584239                                    MESH:D002285    NaN      NaN
# 323308                                    MESH:D002285    NaN      NaN
# 322589                                    MESH:D005923    NaN      NaN
# 579276  SNOMED:197661001|SNOMED:82646005|UMLS:C0178664    NaN      NaN
# 322485                                    MESH:D017674    NaN      NaN
# 580321                                    MESH:D017674    NaN      NaN
# 323343                                    MESH:D008169    NaN      NaN
# 584909                                    MESH:D008169    NaN      NaN
# 323313                                    MESH:D018215    NaN      NaN
# 583734                                    MESH:D018215    NaN      NaN
# 322609                                    MESH:D010673    NaN      NaN
# 580602                        MESH:D010673|OMIM:171300    NaN      NaN
# 584644                                    MESH:D014806    NaN      NaN
# 322553                                    MESH:D014806    NaN      NaN
#
#        alt_ids subsets     do     hp  curi
# 322505     NaN     NaN   True  False  DOID
# 583960     NaN     NaN  False   True    HP
# 322575     NaN     NaN   True  False  DOID
# 582775     NaN     NaN  False   True    HP
# 322521     NaN     NaN   True  False  DOID
# 581192     NaN     NaN  False   True    HP
# 584239     NaN     NaN  False   True    HP
# 323308     NaN     NaN   True  False  DOID
# 322589     NaN     NaN   True  False  DOID
# 579276     NaN     NaN  False   True    HP
# 322485     NaN     NaN   True  False  DOID
# 580321     NaN     NaN  False   True    HP
# 323343     NaN     NaN   True  False  DOID
# 584909     NaN     NaN  False  False  MESH
# 323313     NaN     NaN   True  False  DOID
# 583734     NaN     NaN  False   True    HP
# 322609     NaN     NaN   True  False  DOID
# 580602     NaN     NaN  False   True    HP
# 584644     NaN     NaN  False   True    HP
# 322553     NaN     NaN   True  False  DOID

# %%
mrg2 = create_map(dual_do_current, dual_do_expired)
mrg3 = create_map(xref_res, to_rename)

# %%
mrg_map = pd.concat([mrg_map, mrg2, mrg3], sort=False, ignore_index=True).drop_duplicates()
mrg_map.tail(20)
# Out:
#                id                             name        id_old
# 510    DOID:12568                      dyscalculia  MESH:D060705
# 511    DOID:13938                       amenorrhea    HP:0000141
# 512    DOID:13938                       amenorrhea  MESH:D000568
# 513      DOID:227                        ankylosis    HP:0031013
# 514      DOID:227                        ankylosis  MESH:D000844
# 515     DOID:8943        lattice corneal dystrophy    HP:0001149
# 516     DOID:8943        lattice corneal dystrophy  MESH:C537935
# 518  DOID:0050336                 hypophosphatemia    HP:0002148
# 520  DOID:0050557    congenital muscular dystrophy    HP:0003741
# 522  DOID:0050731           vitamin b12 deficiency    HP:0100502
# 524  DOID:0050771                 pheochromocytoma    HP:0002666
# 526  DOID:0050811   congenital adrenal hyperplasia    HP:0008258
# 528  DOID:0050851               glomerulosclerosis    HP:0000096
# 530  DOID:0060074         ductal carcinoma in situ    HP:0030075
# 532  DOID:0060098                    osteoblastoma    HP:0011846
# 534  DOID:0060317                     lung abscess  MESH:D008169
# 536  DOID:0080188  chronic myelomonocytic leukemia    HP:0012325
# 537     DOID:1205                 allergic disease    DOID:60056
# 538     DOID:1205                 allergic disease    DOID:60496
# 539     DOID:1205                 allergic disease    HP:0012393

# %% [markdown]
# #### Single DO

# %%
sing_doid = num_do[num_do == 1].index.tolist()
keep = curr_conflict.query('name in @sing_doid and do')
drop = curr_conflict.query('name in @sing_doid and not do')

mrg2 = create_map(keep, drop)
mrg2
# Out:
#            id         name        id_old
# 0  DOID:50433     insomnia  MESH:D012892
# 1  DOID:50433     insomnia    HP:0100785
# 2  DOID:50840  torticollis  MESH:D014103
# 3  DOID:50840  torticollis    HP:0000473

# %%
mrg_map = pd.concat([mrg_map, mrg2], sort=False, ignore_index=True).drop_duplicates()

# %% [markdown]
# #### No DO, but hpo

# %%
no_doid = num_do[num_do < 1].index.tolist()
keep = curr_conflict.query('name in @no_doid and hp')
drop = curr_conflict.query('name in @no_doid and not hp')

mrg2 = create_map(keep, drop)
mrg2
# Out:
#            id            name         id_old
# 0  HP:0000243  trigonocephaly  MONDO:0000156
# 1  HP:0000243  trigonocephaly  MONDO:0013774
# 2  HP:0004401  meconium ileus    OMIM:614665
# 3  HP:0004401  meconium ileus  UMLS:C0546982

# %%
mrg_map = pd.concat([mrg_map, mrg2], sort=False, ignore_index=True).drop_duplicates()

# %% [markdown]
# ### 3 Disease

# %%
this_names = comb_type[comb_type == ('Disease', 'Disease', 'Disease')].index.tolist()
curr_conflict = pheno_dis.query('name in @this_names').copy()

# %%
curr_conflict
# Out:
#                    id                   name    label  \
# 328161  MONDO:0014778  lamb-shaffer syndrome  Disease
# 328346  MONDO:0017782  lamb-shaffer syndrome  Disease
# 328883    OMIM:616803  lamb-shaffer syndrome  Disease
#
#                                                     xrefs source synonyms  \
# 328161  MONDO:0014778|MONDO:0017782|OMIM:616803|UMLS:C...    NaN      NaN
# 328346  MONDO:0014778|MONDO:0017782|OMIM:616803|UMLS:C...    NaN      NaN
# 328883                                                NaN    NaN      NaN
#
#        alt_ids subsets     do     hp   curi
# 328161     NaN     NaN  False  False  MONDO
# 328346     NaN     NaN  False  False  MONDO
# 328883     NaN     NaN  False  False   OMIM

# %%
curr_conflict['order'] = curr_conflict['curi'].map(curi_order)

# %%
keep = curr_conflict.sort_values('order').drop_duplicates(subset=['name'], keep='first')
keep_ids = keep['id'].unique()

drop = curr_conflict.query('id not in @keep_ids')

# Check that all names have been accounted for in the keep dataframe
assert(keep['name'].nunique() == drop['name'].nunique())

# %%
mrg2 = create_map(keep, drop)
mrg2
# Out:
#             id                   name         id_old
# 0  OMIM:616803  lamb-shaffer syndrome  MONDO:0014778
# 1  OMIM:616803  lamb-shaffer syndrome  MONDO:0017782

# %%
mrg_map = pd.concat([mrg_map, mrg2], sort=False, ignore_index=True).drop_duplicates()

# %% [markdown]
# ### 4 conflcits

# %%
comb_type[size[size == 4].index.tolist()].value_counts()
# Out:
# (Disease, Disease, Disease, Phenotype)        2
# (Disease, Phenotype, Phenotype, Phenotype)    1
# Name: label, dtype: int64

# %%
this_names = comb_type[comb_type == ('Disease', 'Phenotype', 'Phenotype', 'Phenotype')].index.tolist()
curr_conflict = pheno_dis.query('name in @this_names').copy()

keep = curr_conflict.query('do')
drop = curr_conflict.query('not do')

mrg2 = create_map(keep, drop)
mrg2
# Out:
#              id                         name       id_old
# 0  DOID:0050593  primary congenital glaucoma   HP:0008007
# 1  DOID:0050593  primary congenital glaucoma  OMIM:613085
# 2  DOID:0050593  primary congenital glaucoma  OMIM:613086

# %%
this_names = comb_type[comb_type == ('Disease', 'Disease', 'Disease', 'Phenotype')].index.tolist()
curr_conflict = pheno_dis.query('name in @this_names').copy()
curr_conflict.groupby('name')['do'].sum()
# Out:
# name
# muscle spasm    False
# pain             True
# Name: do, dtype: bool

# %%
this_names = comb_type[comb_type == ('Disease', 'Disease', 'Disease', 'Phenotype')].index.tolist()
curr_conflict = pheno_dis.query('name in @this_names').copy()
curr_conflict.groupby('name')['hp'].sum()
# Out:
# name
# muscle spasm    True
# pain            True
# Name: hp, dtype: bool

# %% [markdown]
# Pain will be a disease, and muscle spasam a phenotype

# %%
keep = curr_conflict.query('do')
keep_names = keep['name'].unique()

keep2 = curr_conflict.query('hp and name not in @keep_names')
keep = pd.concat([keep, keep2], sort=False)

keep_ids = keep['id'].unique()

drop = curr_conflict.query('id not in @keep_ids')

mrg3 = create_map(keep, drop)
mrg3
# Out:
#            id          name        id_old
# 0  DOID:60145          pain  MESH:D000758
# 1  DOID:60145          pain  MESH:D000759
# 2  DOID:60145          pain    HP:0012531
# 3  HP:0003394  muscle spasm  MESH:D007442
# 4  HP:0003394  muscle spasm  MESH:D009119
# 5  HP:0003394  muscle spasm  MESH:D014691

# %%
mrg_map = pd.concat([mrg_map, mrg2, mrg3], sort=False, ignore_index=True).drop_duplicates()
mrg_map
# Out:
#                id                           name        id_old
# 0    DOID:0050052   rocky mountain spotted fever    DOID:50052
# 1    DOID:0050073         invasive aspergillosis    DOID:50073
# 2    DOID:0050147                     otomycosis    DOID:50147
# 3    DOID:0050156  idiopathic pulmonary fibrosis    DOID:50156
# 4    DOID:0050169  cutaneous lupus erythematosus    DOID:50169
# ..            ...                            ...           ...
# 544    DOID:60145                           pain  MESH:D000759
# 545    DOID:60145                           pain    HP:0012531
# 546    HP:0003394                   muscle spasm  MESH:D007442
# 547    HP:0003394                   muscle spasm  MESH:D009119
# 548    HP:0003394                   muscle spasm  MESH:D014691
#
# [549 rows x 3 columns]

# %% [markdown]
# ### More than 4

# %%
this_names = size[size > 4].index.tolist()

curr_conflict = pheno_dis.query('name in @this_names').copy()
curr_conflict.groupby('name')['do'].sum()
# Out:
# name
# hyperinsulinemic hypoglycemia    True
# prostate cancer                  True
# Name: do, dtype: bool

# %%
keep = curr_conflict.query('do')
drop = curr_conflict.query('not do')

mrg2 = create_map(keep, drop)

# %%
mrg_map = pd.concat([mrg_map, mrg2], sort=False, ignore_index=True).drop_duplicates()

# %%
'Merged {} Disease and Phenotype entities into {}.'.format(mrg_map['id'].nunique()+mrg_map['id_old'].nunique(), mrg_map['id'].nunique())
# Out:
# 'Merged 1093 Disease and Phenotype entities into 519.'

# %% [markdown]
# ### Final checks before merge

# %%
old_ids = set(mrg_map['id_old'])
new_ids = set(mrg_map['id'])

overlap = old_ids & new_ids
len(overlap)
# Out:
# 0

# %%
mrg_ids = list(old_ids | new_ids)

to_keep = nodes.query('id not in @mrg_ids')
to_mrg = nodes.query('id in @mrg_ids')

len(to_mrg)
# Out:
# 1093

# %%
keep = to_mrg.query('id in @new_ids')
drop = to_mrg.query('id in @old_ids')

drop = drop.rename(columns={'id': 'id_old'}).merge(mrg_map[['id', 'id_old']], on='id_old', how='left')

drop['xrefs'] = drop['id_old'] + '|' + drop['xrefs']
drop['xrefs'] = drop['xrefs'].fillna(drop['id_old'])
drop = drop.drop('id_old', axis=1)

fixed_nodes = dfp.combine_group_cols_on_char(pd.concat([keep, drop], sort=False), ['id'], 
                                             [c for c in keep.columns if c not in ['id', 'name', 'label']], 
                                             sort=True, prog=False)

fixed_nodes['label'].value_counts()
# Out:
# Disease      438
# Phenotype     81
# Name: label, dtype: int64

# %%
nodes = pd.concat([to_keep, fixed_nodes], sort=False).sort_values(['label', 'id']).reset_index(drop=True)
nodes
# Out:
#                     id                                      name    label  \
# 0       UBERON:0000002                                    cervix  Anatomy
# 1       UBERON:0000004                                human nose  Anatomy
# 2       UBERON:0000005                        chemosensory organ  Anatomy
# 3       UBERON:0000006                       islet of langerhans  Anatomy
# 4       UBERON:0000007                           pituitary gland  Anatomy
# ...                ...                                       ...      ...
# 792407     WD:Q9094469                               ssdna virus    Taxon
# 792408     WD:Q9094478  positive-sense single-stranded rna virus    Taxon
# 792409     WD:Q9285327    negative-sense single strand rna virus    Taxon
# 792410      WD:Q934657                                warble fly    Taxon
# 792411      WD:Q983850   kaposi's sarcoma-associated herpesvirus    Taxon
#
#                               xrefs source synonyms alt_ids subsets
# 0       MESH:D002584|UBERON:0000002    NaN      NaN     NaN     NaN
# 1       MESH:D009666|UBERON:0000004    NaN      NaN     NaN     NaN
# 2                               NaN    NaN      NaN     NaN     NaN
# 3       MESH:D007515|UBERON:0000006    NaN      NaN     NaN     NaN
# 4       MESH:D010902|UBERON:0000007    NaN      NaN     NaN     NaN
# ...                             ...    ...      ...     ...     ...
# 792407                          NaN    NaN      NaN     NaN     NaN
# 792408                          NaN    NaN      NaN     NaN     NaN
# 792409                          NaN    NaN      NaN     NaN     NaN
# 792410                          NaN    NaN      NaN     NaN     NaN
# 792411                          NaN    NaN      NaN     NaN     NaN
#
# [792412 rows x 8 columns]

# %%
edges = gt.re_id_edges(edges, mrg_map, old_id_col='id_old', new_id_col='id')
print('{:,}'.format(len(edges)))
edges = dfp.combine_group_cols_on_char(edges, ['start_id', 'type', 'end_id'], sort=True, prog=True)
print('{:,}'.format(len(edges)))
# Out:
# 9,420,646
# HBox(children=(FloatProgress(value=0.0, description='total_progress', max=6.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='dsrc_type', max=131808.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='comp_type', max=131808.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='p_val', max=131808.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='source', max=131808.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='license', max=131808.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='pmids', max=131808.0, style=ProgressStyle(description_wid…
# 9,281,977

# %% [markdown]
# # Issue 2: Xrefs to other nodes
#
# X-refs in our network should mean 'concepts that have been subsumed by this node' Therefore an X-ref should never refer to the identifier of another node in the network.
#
# However, becasue some external identifier vocuabularies can be more general than what's in our network, a multiple nodes containing the same external xref can be possible, as long as the CURI is different from the primary identifier

# %%
xref_map = dfp.expand_col_on_char(nodes, 'xrefs', '|', True)

# %%
xref_map = xref_map.query('id != xrefs')
xref_map
# Out:
#                         id                 name    label              xrefs  \
# 0           UBERON:0000002               cervix  Anatomy       MESH:D002584
# 2           UBERON:0000004           human nose  Anatomy       MESH:D009666
# 4           UBERON:0000006  islet of langerhans  Anatomy       MESH:D007515
# 6           UBERON:0000007      pituitary gland  Anatomy       MESH:D010902
# 9           UBERON:0000009            submucosa  Anatomy     UBERON:0004925
# ...                    ...                  ...      ...                ...
# 1542642  NCBITaxon:1960534    influenza b virus    Taxon   NCBITaxon:682049
# 1546362   NCBITaxon:407754    influenza a virus    Taxon    NCBITaxon:11320
# 1548828   NCBITaxon:682049    influenza b virus    Taxon    NCBITaxon:11520
# 1548829   NCBITaxon:682049    influenza b virus    Taxon  NCBITaxon:1600125
# 1548830   NCBITaxon:682049    influenza b virus    Taxon  NCBITaxon:1960534
#
#         source synonyms alt_ids subsets
# 0          NaN      NaN     NaN     NaN
# 2          NaN      NaN     NaN     NaN
# 4          NaN      NaN     NaN     NaN
# 6          NaN      NaN     NaN     NaN
# 9          NaN      NaN     NaN     NaN
# ...        ...      ...     ...     ...
# 1542642    NaN      NaN     NaN     NaN
# 1546362    NaN      NaN     NaN     NaN
# 1548828    NaN      NaN     NaN     NaN
# 1548829    NaN      NaN     NaN     NaN
# 1548830    NaN      NaN     NaN     NaN
#
# [1001125 rows x 8 columns]

# %% [markdown]
# ## Potential problem a: duplicated xrefs from the same CURI

# %%
node_ids = edges[['start_id', 'end_id']].stack().unique()

# %%
duped_xref = xref_map[xref_map['xrefs'].duplicated(keep=False)].sort_values('xrefs').copy()
duped_xref['id_curi'] = duped_xref['id'].apply(lambda s: s.split(':')[0])
duped_xref['xref_curi'] = duped_xref['xrefs'].apply(lambda s: s.split(':')[0])

duped_xref.query('id_curi == xref_curi and id in @node_ids')['label'].value_counts()
# Out:
# Protein     2033
# Disease       21
# Taxon         12
# Compound       1
# Name: label, dtype: int64

# %%
combo = gt.combine_nodes_and_edges(nodes, edges)

def qq(start_id, end_id=None, cols=None):
    if cols is None:
        cols = ['start_id', 'end_id', 'start_name', 'type', 'end_name', 'start_label', 'end_label', 'source', 'dsrc_type']
    
    if end_id is not None:
        return combo.query('start_id == @start_id and end_id == @end_id')[cols]
    else:
        return combo.query('start_id == @start_id or end_id == @start_id')[cols]

# %% [markdown]
# #### Compounds
#
# We did a good job of wangling compounds in notebooks 7... so shouldn't be any issue here...

# %%
duped_xref.query('id_curi == xref_curi and label == "Compound"')
# Out:
#                  id                   name     label       xrefs source  \
# 173431  CHEBI:48432  ile(5)-angiotensin ii  Compound  CHEBI:2719    NaN
#
#        synonyms alt_ids subsets id_curi xref_curi
# 173431      NaN     NaN     NaN   CHEBI     CHEBI

# %%
duped_xref.query('xrefs == "CHEBI:2719"')
# Out:
#                    id                   name     label       xrefs source  \
# 173431    CHEBI:48432  ile(5)-angiotensin ii  Compound  CHEBI:2719    NaN
# 1221996  NCBIGene:183                    agt      Gene  CHEBI:2719    NaN
#
#         synonyms alt_ids subsets   id_curi xref_curi
# 173431       NaN     NaN     NaN     CHEBI     CHEBI
# 1221996      NaN     NaN     NaN  NCBIGene     CHEBI

# %% [markdown]
# Appears to be a gene and chemical version of the same protein substance...

# %% [markdown]
# #### Diseases
#
# We've done a lot of work on diseases, these are small, but bigger than we'd Like

# %%
duped_xref.query('id_curi == xref_curi and label == "Disease" and id in @node_ids')
# Out:
#                   id                                      name    label  \
# 820763  DOID:0050785  progressive relapsing multiple sclerosis  Disease
# 820753  DOID:0050784    primary progressive multiple sclerosis  Disease
# 820764  DOID:0050785  progressive relapsing multiple sclerosis  Disease
# 820743  DOID:0050783  secondary progressive multiple sclerosis  Disease
# 820755  DOID:0050784    primary progressive multiple sclerosis  Disease
# 820744  DOID:0050783  secondary progressive multiple sclerosis  Disease
# 826703  DOID:0060859                             salmonellosis  Disease
# 849121    DOID:12785                   diabetic polyneuropathy  Disease
# 845078    DOID:11503             diabetic autonomic neuropathy  Disease
# 826704  DOID:0060859                             salmonellosis  Disease
# 860862     DOID:2848                               melancholia  Disease
# 855624     DOID:1595                     endogenous depression  Disease
# 854755     DOID:1470                 major depressive disorder  Disease
# 860863     DOID:2848                               melancholia  Disease
# 845079    DOID:11503             diabetic autonomic neuropathy  Disease
# 849123    DOID:12785                   diabetic polyneuropathy  Disease
# 820756  DOID:0050784    primary progressive multiple sclerosis  Disease
# 820745  DOID:0050783  secondary progressive multiple sclerosis  Disease
# 820766  DOID:0050785  progressive relapsing multiple sclerosis  Disease
# 854756     DOID:1470                 major depressive disorder  Disease
# 855626     DOID:1595                     endogenous depression  Disease
#
#                xrefs source  \
# 820763  DOID:0050783    NaN
# 820753  DOID:0050783    NaN
# 820764  DOID:0050784    NaN
# 820743  DOID:0050784
# 820755  DOID:0050785    NaN
# 820744  DOID:0050785
# 826703    DOID:11092    NaN
# 849121    DOID:11503    NaN
# 845078    DOID:12785    NaN
# 826704     DOID:1466    NaN
# 860862     DOID:1470    NaN
# 855624     DOID:1470    NaN
# 854755     DOID:1595    NaN
# 860863     DOID:1595    NaN
# 845079     DOID:2370    NaN
# 849123     DOID:2370    NaN
# 820756     DOID:2376    NaN
# 820745     DOID:2376
# 820766     DOID:2376    NaN
# 854756     DOID:2848    NaN
# 855626     DOID:2848    NaN
#
#                                                  synonyms  \
# 820763                      PRMS|Progressive-relapsing MS
# 820753                        PPMS|Primary-progressive MS
# 820764                      PRMS|Progressive-relapsing MS
# 820743                      SPMS|Secondary-progressive MS
# 820755                        PPMS|Primary-progressive MS
# 820744                      SPMS|Secondary-progressive MS
# 826703                               Salmonella infection
# 849121  Diabetes mellitus with polyneuropathy|Diabetic...
# 845078                      Diabetic autonomic neuropathy
# 826704                               Salmonella infection
# 860862                                                NaN
# 855624            clinical depression|unipolar depression
# 854755  recurrent major depression|single major depres...
# 860863                                                NaN
# 845079                      Diabetic autonomic neuropathy
# 849123  Diabetes mellitus with polyneuropathy|Diabetic...
# 820756                        PPMS|Primary-progressive MS
# 820745                      SPMS|Secondary-progressive MS
# 820766                      PRMS|Progressive-relapsing MS
# 854756  recurrent major depression|single major depres...
# 855626            clinical depression|unipolar depression
#
#                                          alt_ids       subsets id_curi  \
# 820763                                       NaN           NaN    DOID
# 820753                                       NaN           NaN    DOID
# 820764                                       NaN           NaN    DOID
# 820743                                                            DOID
# 820755                                       NaN           NaN    DOID
# 820744                                                            DOID
# 826703                                       NaN           NaN    DOID
# 849121                                       NaN           NaN    DOID
# 845078                                       NaN  NCIthesaurus    DOID
# 826704                                       NaN           NaN    DOID
# 860862                                       NaN  NCIthesaurus    DOID
# 855624                                 DOID:6340  NCIthesaurus    DOID
# 854755  DOID:10614|DOID:2240|DOID:2241|DOID:7580  NCIthesaurus    DOID
# 860863                                       NaN  NCIthesaurus    DOID
# 845079                                       NaN  NCIthesaurus    DOID
# 849123                                       NaN           NaN    DOID
# 820756                                       NaN           NaN    DOID
# 820745                                                            DOID
# 820766                                       NaN           NaN    DOID
# 854756  DOID:10614|DOID:2240|DOID:2241|DOID:7580  NCIthesaurus    DOID
# 855626                                 DOID:6340  NCIthesaurus    DOID
#
#        xref_curi
# 820763      DOID
# 820753      DOID
# 820764      DOID
# 820743      DOID
# 820755      DOID
# 820744      DOID
# 826703      DOID
# 849121      DOID
# 845078      DOID
# 826704      DOID
# 860862      DOID
# 855624      DOID
# 854755      DOID
# 860863      DOID
# 845079      DOID
# 849123      DOID
# 820756      DOID
# 820745      DOID
# 820766      DOID
# 854756      DOID
# 855626      DOID

# %%
duped_xref.query('id_curi == xref_curi and label == "Disease" and id in @node_ids and id not in @current_doids')
# Out:
# Empty DataFrame
# Columns: [id, name, label, xrefs, source, synonyms, alt_ids, subsets, id_curi, xref_curi]
# Index: []

# %% [markdown]
# All these seem fine... mostly mis-mappings of the xref, or maping to obsolete terms... I'm going to ignore it

# %% [markdown]
# ### Taxon

# %%
duped_xref.query('id_curi == xref_curi and label == "Taxon" and id in @node_ids')
# Out:
#                         id               name  label              xrefs  \
# 1541035  NCBITaxon:1600125  influenza b virus  Taxon    NCBITaxon:11520
# 1542639  NCBITaxon:1960534  influenza b virus  Taxon    NCBITaxon:11520
# 1548828   NCBITaxon:682049  influenza b virus  Taxon    NCBITaxon:11520
# 1542640  NCBITaxon:1960534  influenza b virus  Taxon  NCBITaxon:1600125
# 1538751    NCBITaxon:11520  influenza b virus  Taxon  NCBITaxon:1600125
# 1548829   NCBITaxon:682049  influenza b virus  Taxon  NCBITaxon:1600125
# 1538752    NCBITaxon:11520  influenza b virus  Taxon  NCBITaxon:1960534
# 1541037  NCBITaxon:1600125  influenza b virus  Taxon  NCBITaxon:1960534
# 1548830   NCBITaxon:682049  influenza b virus  Taxon  NCBITaxon:1960534
# 1542642  NCBITaxon:1960534  influenza b virus  Taxon   NCBITaxon:682049
# 1541038  NCBITaxon:1600125  influenza b virus  Taxon   NCBITaxon:682049
# 1538753    NCBITaxon:11520  influenza b virus  Taxon   NCBITaxon:682049
#
#         source synonyms alt_ids subsets    id_curi  xref_curi
# 1541035    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1542639    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1548828    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1542640    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1538751    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1548829    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1538752    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1541037    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1548830    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1542642    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1541038    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon
# 1538753    NaN      NaN     NaN     NaN  NCBITaxon  NCBITaxon

# %% [markdown]
# Some of these are a problem and highlight our second, more important issue... Xrefs that map to other node items...
#
# in this case its all one taxa, influenza b virus. So we'll go with the cannonical id for that `11520`

# %%
keep_id = 'NCBITaxon:11520'

subsumed_ids = duped_xref.query('id_curi == xref_curi and label == "Taxon" and id in @node_ids')[['id', 'xrefs']].stack().unique()
subsumed_ids = [sid for sid in subsumed_ids if sid != keep_id]

new_mrg_map = pd.DataFrame({'id': [keep_id for i in range(len(subsumed_ids))], 'id_old': subsumed_ids})
new_mrg_map
# Out:
#                 id             id_old
# 0  NCBITaxon:11520  NCBITaxon:1600125
# 1  NCBITaxon:11520  NCBITaxon:1960534
# 2  NCBITaxon:11520   NCBITaxon:682049

# %%
duped_xref.query('id_curi == xref_curi and label == "Protein" and id in @node_ids').sort_values('xrefs')
# Out:
#                          id                                        name  \
# 1438130  UniProt:A0A068W9M3                            egrg_000749900.3
# 1437684  UniProt:A0A068W7A3                            egrg_000749900.1
# 1438131  UniProt:A0A068W9M3                            egrg_000749900.3
# 1437595  UniProt:A0A068W6U3                            egrg_000749900.2
# 1437596  UniProt:A0A068W6U3                            egrg_000749900.2
# ...                     ...                                         ...
# 1537861      UniProt:V9PWX7                                smp_089320.1
# 1518046      UniProt:Q6TMX9            nicotinic acetylcholine receptor
# 1474677      UniProt:G4VN55            nicotinic acetylcholine receptor
# 1474674      UniProt:G4VN54  nicotinic acetylcholine receptor non alpha
# 1518043      UniProt:Q6TMX8  nicotinic acetylcholine receptor non alpha
#
#            label               xrefs source synonyms alt_ids subsets  id_curi  \
# 1438130  Protein  UniProt:A0A068W6U3    NaN      NaN     NaN     NaN  UniProt
# 1437684  Protein  UniProt:A0A068W6U3    NaN      NaN     NaN     NaN  UniProt
# 1438131  Protein  UniProt:A0A068W7A3    NaN      NaN     NaN     NaN  UniProt
# 1437595  Protein  UniProt:A0A068W7A3    NaN      NaN     NaN     NaN  UniProt
# 1437596  Protein  UniProt:A0A068W9M3    NaN      NaN     NaN     NaN  UniProt
# ...          ...                 ...    ...      ...     ...     ...      ...
# 1537861  Protein      UniProt:V9PWX8    NaN      NaN     NaN     NaN  UniProt
# 1518046  Protein      UniProt:V9TII8    NaN      NaN     NaN     NaN  UniProt
# 1474677  Protein      UniProt:V9TII8    NaN      NaN     NaN     NaN  UniProt
# 1474674  Protein      UniProt:V9TMX9    NaN      NaN     NaN     NaN  UniProt
# 1518043  Protein      UniProt:V9TMX9    NaN      NaN     NaN     NaN  UniProt
#
#         xref_curi
# 1438130   UniProt
# 1437684   UniProt
# 1438131   UniProt
# 1437595   UniProt
# 1437596   UniProt
# ...           ...
# 1537861   UniProt
# 1518046   UniProt
# 1474677   UniProt
# 1474674   UniProt
# 1518043   UniProt
#
# [2033 rows x 10 columns]

# %% [markdown]
# Too many proteins to handle right now, and most of them have the also follow inder Issue B Below...

# %% [markdown]
# ## B: Nodes with xrefs to other nodes

# %%
xref_mrg = pd.merge(xref_map.drop_duplicates(subset=['id']).drop('xrefs', axis=1), xref_map, left_on=['id'], right_on=['xrefs'], how='inner', suffixes=['_id', '_xref'])

# %%
xref_mrg['id_curi'] = xref_mrg['id_id'].apply(lambda s: s.split(':')[0])
xref_mrg['xref_curi'] = xref_mrg['id_xref'].apply(lambda s: s.split(':')[0])

# %%
xref_mrg['label_id'].value_counts()
# Out:
# Protein      5451
# Disease       116
# Anatomy        56
# Phenotype      18
# Taxon          14
# Gene           10
# Compound        2
# Name: label_id, dtype: int64

# %%
xref_mrg.query('label_id == "Disease"')
# Out:
#              id_id                                         name_id label_id  \
# 58    DOID:0040098                           pemphigus gestationis  Disease
# 59    DOID:0050047                   flinders island spotted fever  Disease
# 60    DOID:0050053         obsolete rickettsia honei spotted fever  Disease
# 61    DOID:0050119  obsolete west nile virus neurological syndrome  Disease
# 62    DOID:0050134                               cutaneous mycosis  Disease
# ..             ...                                             ...      ...
# 169   MESH:D002828                                      choristoma  Disease
# 170   MESH:D009410                              nerve degeneration  Disease
# 171   MESH:D058267                                       pulicosis  Disease
# 172   MESH:D060050                                   stable angina  Disease
# 173  UMLS:C0151908                                         dryness  Disease
#
#     source_id                                synonyms_id    alt_ids_id  \
# 58        NaN                                        NaN           NaN
# 59        NaN                           Thai tick typhus  DOID:0050048
# 60        NaN                                        NaN           NaN
# 61        NaN  WNND|WNNS|West nile neuroinvasive disease           NaN
# 62        NaN                                        NaN           NaN
# ..        ...                                        ...           ...
# 169       NaN                                        NaN           NaN
# 170       NaN                                        NaN           NaN
# 171       NaN                                        NaN           NaN
# 172       NaN                                        NaN           NaN
# 173
#
#                                             subsets_id       id_xref  \
# 58                                        DO_IEDB_slim    DOID:14482
# 59   gram-negative_bacterial_infectious_disease|tic...  DOID:0050053
# 60   gram-negative_bacterial_infectious_disease|tic...  DOID:0050047
# 61                         zoonotic_infectious_disease     DOID:2365
# 62                                                 NaN     DOID:1563
# ..                                                 ...           ...
# 169                                                NaN    HP:0002282
# 170                                                NaN     DOID:1289
# 171                                                NaN  DOID:0050266
# 172                                                NaN    DOID:60164
# 173                                                       HP:0000958
#
#                                    name_xref label_xref          xrefs  \
# 58                    pemphigoid gestationis    Disease   DOID:0040098
# 59   obsolete rickettsia honei spotted fever    Disease   DOID:0050047
# 60             flinders island spotted fever    Disease   DOID:0050053
# 61                    west nile encephalitis    Disease   DOID:0050119
# 62                            dermatomycosis    Disease   DOID:0050134
# ..                                       ...        ...            ...
# 169                  gray matter heterotopia  Phenotype   MESH:D002828
# 170                neurodegenerative disease    Disease   MESH:D009410
# 171                                tungiasis    Disease   MESH:D058267
# 172                              pain relief    Disease   MESH:D060050
# 173                                 dry skin  Phenotype  UMLS:C0151908
#
#     source_xref                                      synonyms_xref  \
# 58          NaN              Gestational herpes|herpes gestationis
# 59          NaN                                                NaN
# 60          NaN                                   Thai tick typhus
# 61          NaN  West Nile Fever with encephalitis|West Nile fe...
# 62          NaN                                                NaN
# ..          ...                                                ...
# 169
# 170         NaN     Neurodegenerative disease|degenerative disease
# 171
# 172         NaN                                                NaN
# 173         NaN                                                NaN
#
#      alt_ids_xref                                       subsets_xref id_curi  \
# 58            NaN                                       NCIthesaurus    DOID
# 59            NaN  gram-negative_bacterial_infectious_disease|tic...    DOID
# 60   DOID:0050048  gram-negative_bacterial_infectious_disease|tic...    DOID
# 61            NaN                        zoonotic_infectious_disease    DOID
# 62            NaN                                                NaN    DOID
# ..            ...                                                ...     ...
# 169                                                                     MESH
# 170     DOID:4874                       DO_FlyBase_slim|NCIthesaurus    MESH
# 171                                                                     MESH
# 172           NaN                                                NaN    MESH
# 173           NaN                                                NaN    UMLS
#
#     xref_curi
# 58       DOID
# 59       DOID
# 60       DOID
# 61       DOID
# 62       DOID
# ..        ...
# 169        HP
# 170      DOID
# 171      DOID
# 172      DOID
# 173        HP
#
# [116 rows x 17 columns]

# %%
xref_mrg.query('label_id == "Disease"')[['id_curi', 'xref_curi']].apply(tuple, axis=1).value_counts()
# Out:
# (DOID, DOID)    110
# (MESH, DOID)      4
# (UMLS, HP)        1
# (MESH, HP)        1
# dtype: int64

# %% [markdown]
# DOID, DOID should just remian and have the offending xref removed....

# %%
def remove_xref(xref_str, xref_to_remove, sep_char='|'):
    """
    Remvoes a single xref from a string of xrefs sparated by `sep_char`.
    
    For example 'DOID:0040098|DOID:0050053|DOID:0050119' separeated by `sep_char`='|' with xref_to_remove='DOID:0050053'
    becomes:
      'DOID:0040098|DOID:0050119'
    """
    
    xref_str = xref_str.replace(xref_to_remove, '')
    
    # only xref
    if xref_str == '':
        return float('nan')
   
    # removed from middle
    xref_str = xref_str.replace(2*sep_char, sep_char)
    # removed from start
    xref_str = xref_str.lstrip(sep_char)
    # removed from end
    xref_str = xref_str.rstrip(sep_char)
    return xref_str

# %%
combo_type = xref_mrg.query('label_id == "Disease"')[['id_curi', 'xref_curi']].apply(tuple, axis=1)
dual_do_idx = combo_type[combo_type == ('DOID', 'DOID')].index

xref_mrg.loc[dual_do_idx, 'name_id'].str.startswith('obsolete').sum()
# Out:
# 48

# %% [markdown]
# A lot are obsolete, so we'll fix those and merge them...

# %%
obsolete_idx = xref_mrg.loc[dual_do_idx][xref_mrg.loc[dual_do_idx, 'name_id'].str.startswith('obsolete')].index

overlap = set(xref_mrg.loc[obsolete_idx]['id_id']) & set(xref_mrg.loc[obsolete_idx]['id_xref'])

# %%
lens = {}
for oid in overlap:
    lens[oid] = len(qq(oid))

# %%
lens
# Out:
# {'DOID:284': 0,
#  'DOID:2779': 0,
#  'DOID:0050341': 3518,
#  'DOID:5000': 0,
#  'DOID:1709': 42,
#  'DOID:13469': 0,
#  'DOID:12647': 2,
#  'DOID:10059': 0,
#  'DOID:1466': 0,
#  'DOID:2778': 1,
#  'DOID:11099': 0,
#  'DOID:2313': 0,
#  'DOID:9940': 0,
#  'DOID:10111': 0,
#  'DOID:122': 0,
#  'DOID:11092': 0}

# %% [markdown]
# most are unpopulated... I just don't htink its worth doing anything with these...

# %%
lens = {}
for oid in xref_mrg.loc[obsolete_idx]['id_id']:
    if oid not in overlap:
        lens[oid] = len(qq(oid))

# %%
lens
# Out:
# {'DOID:0050053': 0,
#  'DOID:0050119': 0,
#  'DOID:0050287': 0,
#  'DOID:0050309': 0,
#  'DOID:0050329': 0,
#  'DOID:0050399': 0,
#  'DOID:0060052': 0,
#  'DOID:0060120': 0,
#  'DOID:0080013': 0,
#  'DOID:12052': 0,
#  'DOID:12255': 0,
#  'DOID:12269': 0,
#  'DOID:1550': 0,
#  'DOID:157': 0,
#  'DOID:2370': 0,
#  'DOID:2376': 0,
#  'DOID:2947': 0,
#  'DOID:3166': 31,
#  'DOID:3680': 0,
#  'DOID:4121': 0,
#  'DOID:5928': 0,
#  'DOID:8524': 0,
#  'DOID:9195': 0,
#  'DOID:9678': 0,
#  'DOID:9829': 0,
#  'DOID:9915': 0,
#  'DOID:9929': 0}

# %%
nonzero = [k for k, v in lens.items() if v > 0]

lens1 = {}
for oid in xref_mrg.loc[obsolete_idx].query('id_id in @nonzero')['id_xref']:
    if oid not in overlap:
        lens1[oid] = len(qq(oid))
lens1
# Out:
# {'DOID:0060888': 4}

# %%
nodes.query('id == "DOID:0060888"')
# Out:
#                   id                                   name    label  \
# 314941  DOID:0060888  transient myeloproliferative syndrome  Disease
#
#                                                     xrefs source  \
# 314941  DOID:0060888|DOID:3166|GARD:12765|ICD10CM:D47....
#
#                                                  synonyms alt_ids subsets
# 314941  MST|TAM|transient abnormal myelopoiesis|transi...

# %%
nodes.query('id == "DOID:3166"')
# Out:
#                id                         name    label  \
# 321132  DOID:3166  obsolete leukemoid reaction  Disease
#
#                                                     xrefs source synonyms  \
# 321132  DOID:0060888|DOID:3166|ICD10CM:D72.823|ICD9CM:...    NaN      NaN
#
#        alt_ids       subsets
# 321132     NaN  NCIthesaurus

# %% [markdown]
# Obsolete has this NCIThesaurs tag.... I just don't htink its worth touching these...

# %%
mesh_do_idx = combo_type[combo_type == ('MESH', 'DOID')].index
xref_mrg.loc[mesh_do_idx]
# Out:
#             id_id               name_id label_id source_id synonyms_id  \
# 168  MESH:C537436  aromatase deficiency  Disease       NaN         NaN
# 170  MESH:D009410    nerve degeneration  Disease       NaN         NaN
# 171  MESH:D058267             pulicosis  Disease       NaN         NaN
# 172  MESH:D060050         stable angina  Disease       NaN         NaN
#
#     alt_ids_id subsets_id       id_xref                  name_xref label_xref  \
# 168        NaN        NaN  DOID:0090122  aromatase excess syndrome    Disease
# 170        NaN        NaN     DOID:1289  neurodegenerative disease    Disease
# 171        NaN        NaN  DOID:0050266                  tungiasis    Disease
# 172        NaN        NaN    DOID:60164                pain relief    Disease
#
#             xrefs source_xref  \
# 168  MESH:C537436         NaN
# 170  MESH:D009410         NaN
# 171  MESH:D058267
# 172  MESH:D060050         NaN
#
#                                          synonyms_xref alt_ids_xref  \
# 168  AEXS|familial hyperestrogenism|hereditary prep...          NaN
# 170     Neurodegenerative disease|degenerative disease    DOID:4874
# 171
# 172                                                NaN          NaN
#
#                      subsets_xref id_curi xref_curi
# 168                           NaN    MESH      DOID
# 170  DO_FlyBase_slim|NCIthesaurus    MESH      DOID
# 171                                  MESH      DOID
# 172                           NaN    MESH      DOID

# %%
to_mrg = xref_mrg.loc[mesh_do_idx, ['id_id', 'id_xref']].rename(columns={'id_id': 'id_old', 'id_xref': 'id'})
to_mrg
# Out:
#            id_old            id
# 168  MESH:C537436  DOID:0090122
# 170  MESH:D009410     DOID:1289
# 171  MESH:D058267  DOID:0050266
# 172  MESH:D060050    DOID:60164

# %%
new_mrg_map = pd.concat([new_mrg_map, to_mrg], sort=False, ignore_index=True)
new_mrg_map
# Out:
#                 id             id_old
# 0  NCBITaxon:11520  NCBITaxon:1600125
# 1  NCBITaxon:11520  NCBITaxon:1960534
# 2  NCBITaxon:11520   NCBITaxon:682049
# 3     DOID:0090122       MESH:C537436
# 4        DOID:1289       MESH:D009410
# 5     DOID:0050266       MESH:D058267
# 6       DOID:60164       MESH:D060050

# %%
mesh_hp_idx = combo_type[combo_type == ('MESH', 'HP')].index
xref_mrg.loc[mesh_hp_idx]
# Out:
#             id_id     name_id label_id source_id synonyms_id alt_ids_id  \
# 169  MESH:D002828  choristoma  Disease       NaN         NaN        NaN
#
#     subsets_id     id_xref                name_xref label_xref         xrefs  \
# 169        NaN  HP:0002282  gray matter heterotopia  Phenotype  MESH:D002828
#
#     source_xref synonyms_xref alt_ids_xref subsets_xref id_curi xref_curi
# 169                                                        MESH        HP

# %%
to_mrg = xref_mrg.loc[mesh_hp_idx, ['id_id', 'id_xref']].rename(columns={'id_id': 'id_old', 'id_xref': 'id'})
new_mrg_map = pd.concat([new_mrg_map, to_mrg], sort=False, ignore_index=True)
new_mrg_map
# Out:
#                 id             id_old
# 0  NCBITaxon:11520  NCBITaxon:1600125
# 1  NCBITaxon:11520  NCBITaxon:1960534
# 2  NCBITaxon:11520   NCBITaxon:682049
# 3     DOID:0090122       MESH:C537436
# 4        DOID:1289       MESH:D009410
# 5     DOID:0050266       MESH:D058267
# 6       DOID:60164       MESH:D060050
# 7       HP:0002282       MESH:D002828

# %% [markdown]
# ## Anatomy

# %%
anat_issue = xref_mrg.query('label_id == "Anatomy"').copy()
anat_issue
# Out:
#              id_id                        name_id label_id source_id  \
# 0   UBERON:0000009                      submucosa  Anatomy       NaN
# 1   UBERON:0000037               ovarian follicle  Anatomy       NaN
# 2   UBERON:0000065              respiratory tract  Anatomy       NaN
# 3   UBERON:0000082                         kidney  Anatomy       NaN
# 4   UBERON:0000093                         sulcus  Anatomy       NaN
# 5   UBERON:0000396                vallate papilla  Anatomy       NaN
# 6   UBERON:0000915      thoracic segment of trunk  Anatomy       NaN
# 7   UBERON:0000935            anterior commissure  Anatomy       NaN
# 8   UBERON:0001005              respiratory tract  Anatomy       NaN
# 9   UBERON:0001015                         muscle  Anatomy       NaN
# 10  UBERON:0001020                          nerve  Anatomy       NaN
# 11  UBERON:0001021               peripheral nerve  Anatomy       NaN
# 12  UBERON:0001042                        pharynx  Anatomy       NaN
# 13  UBERON:0001305               ovarian follicle  Anatomy       NaN
# 14  UBERON:0001436                        phalanx  Anatomy       NaN
# 15  UBERON:0001443                         thorax  Anatomy       NaN
# 16  UBERON:0001449                        phalanx  Anatomy       NaN
# 17  UBERON:0001630                         muscle  Anatomy       NaN
# 18  UBERON:0001640                  celiac artery  Anatomy       NaN
# 19  UBERON:0001649         glossopharyngeal nerve  Anatomy       NaN
# 20  UBERON:0001758     tooth supporting structure  Anatomy       NaN
# 21  UBERON:0001982                      capillary  Anatomy       NaN
# 22  UBERON:0002113                         kidney  Anatomy       NaN
# 23  UBERON:0002127       inferior olivary nucleus  Anatomy       NaN
# 24  UBERON:0002360                       meninges  Anatomy       NaN
# 25  UBERON:0002370                         thymus  Anatomy       NaN
# 26  UBERON:0002372                         thymus  Anatomy       NaN
# 27  UBERON:0002694            anterior commissure  Anatomy       NaN
# 28  UBERON:0002727  medullary laminae of thalamus  Anatomy       NaN
# 29  UBERON:0002765  medullary laminae of thalamus  Anatomy       NaN
# 30  UBERON:0003409                  lingual gland  Anatomy       NaN
# 31  UBERON:0004086             ventricular system  Anatomy       NaN
# 32  UBERON:0004925                      submucosa  Anatomy       NaN
# 33  UBERON:0005282             ventricular system  Anatomy       NaN
# 34  UBERON:0005734                 tunica externa  Anatomy       NaN
# 35  UBERON:0005742                 tunica externa  Anatomy       NaN
# 36  UBERON:0006090         glossopharyngeal nerve  Anatomy       NaN
# 37  UBERON:0006330                  lingual gland  Anatomy       NaN
# 38  UBERON:0006562                        pharynx  Anatomy       NaN
# 39  UBERON:0006637                  celiac artery  Anatomy       NaN
# 40  UBERON:0007244       inferior olivary nucleus  Anatomy       NaN
# 41  UBERON:0008266     tooth supporting structure  Anatomy       NaN
# 42  UBERON:0008334                cerebral sulcus  Anatomy       NaN
# 43  UBERON:0010743                       meninges  Anatomy       NaN
# 44  UBERON:0012102                   buccal gland  Anatomy       NaN
# 45  UBERON:0013118                cerebral sulcus  Anatomy       NaN
# 46  UBERON:0014389              gustatory papilla  Anatomy       NaN
# 47  UBERON:0014764                         sulcus  Anatomy       NaN
# 48  UBERON:0014802                    nuchal line  Anatomy       NaN
# 49  UBERON:0014802                    nuchal line  Anatomy       NaN
# 50  UBERON:0014803                    nuchal line  Anatomy       NaN
# 51  UBERON:0014803                    nuchal line  Anatomy       NaN
# 52  UBERON:0014804                    nuchal line  Anatomy       NaN
# 53  UBERON:0014804                    nuchal line  Anatomy       NaN
# 54  UBERON:0017654                   buccal gland  Anatomy       NaN
# 55  UBERON:2005259                      capillary  Anatomy       NaN
#
#    synonyms_id alt_ids_id subsets_id         id_xref  \
# 0          NaN        NaN        NaN  UBERON:0004925
# 1          NaN        NaN        NaN  UBERON:0001305
# 2          NaN        NaN        NaN  UBERON:0001005
# 3          NaN        NaN        NaN  UBERON:0002113
# 4          NaN        NaN        NaN  UBERON:0014764
# 5          NaN        NaN        NaN  UBERON:0014389
# 6          NaN        NaN        NaN  UBERON:0001443
# 7          NaN        NaN        NaN  UBERON:0002694
# 8          NaN        NaN        NaN  UBERON:0000065
# 9          NaN        NaN        NaN  UBERON:0001630
# 10         NaN        NaN        NaN  UBERON:0001021
# 11         NaN        NaN        NaN  UBERON:0001020
# 12         NaN        NaN        NaN  UBERON:0006562
# 13         NaN        NaN        NaN  UBERON:0000037
# 14         NaN        NaN        NaN  UBERON:0001449
# 15         NaN        NaN        NaN  UBERON:0000915
# 16         NaN        NaN        NaN  UBERON:0001436
# 17         NaN        NaN        NaN  UBERON:0001015
# 18         NaN        NaN        NaN  UBERON:0006637
# 19         NaN        NaN        NaN  UBERON:0006090
# 20         NaN        NaN        NaN  UBERON:0008266
# 21         NaN        NaN        NaN  UBERON:2005259
# 22         NaN        NaN        NaN  UBERON:0000082
# 23         NaN        NaN        NaN  UBERON:0007244
# 24         NaN        NaN        NaN  UBERON:0010743
# 25         NaN        NaN        NaN  UBERON:0002372
# 26         NaN        NaN        NaN  UBERON:0002370
# 27         NaN        NaN        NaN  UBERON:0000935
# 28         NaN        NaN        NaN  UBERON:0002765
# 29         NaN        NaN        NaN  UBERON:0002727
# 30         NaN        NaN        NaN  UBERON:0006330
# 31         NaN        NaN        NaN  UBERON:0005282
# 32         NaN        NaN        NaN  UBERON:0000009
# 33         NaN        NaN        NaN  UBERON:0004086
# 34         NaN        NaN        NaN  UBERON:0005742
# 35         NaN        NaN        NaN  UBERON:0005734
# 36         NaN        NaN        NaN  UBERON:0001649
# 37         NaN        NaN        NaN  UBERON:0003409
# 38         NaN        NaN        NaN  UBERON:0001042
# 39         NaN        NaN        NaN  UBERON:0001640
# 40         NaN        NaN        NaN  UBERON:0002127
# 41         NaN        NaN        NaN  UBERON:0001758
# 42         NaN        NaN        NaN  UBERON:0013118
# 43         NaN        NaN        NaN  UBERON:0002360
# 44         NaN        NaN        NaN  UBERON:0017654
# 45         NaN        NaN        NaN  UBERON:0008334
# 46         NaN        NaN        NaN  UBERON:0000396
# 47         NaN        NaN        NaN  UBERON:0000093
# 48         NaN        NaN        NaN  UBERON:0014803
# 49         NaN        NaN        NaN  UBERON:0014804
# 50         NaN        NaN        NaN  UBERON:0014802
# 51         NaN        NaN        NaN  UBERON:0014804
# 52         NaN        NaN        NaN  UBERON:0014802
# 53         NaN        NaN        NaN  UBERON:0014803
# 54         NaN        NaN        NaN  UBERON:0012102
# 55         NaN        NaN        NaN  UBERON:0001982
#
#                         name_xref label_xref           xrefs source_xref  \
# 0                       submucosa    Anatomy  UBERON:0000009         NaN
# 1                ovarian follicle    Anatomy  UBERON:0000037         NaN
# 2               respiratory tract    Anatomy  UBERON:0000065         NaN
# 3                          kidney    Anatomy  UBERON:0000082         NaN
# 4                          sulcus    Anatomy  UBERON:0000093         NaN
# 5               gustatory papilla    Anatomy  UBERON:0000396         NaN
# 6                          thorax    Anatomy  UBERON:0000915         NaN
# 7             anterior commissure    Anatomy  UBERON:0000935         NaN
# 8               respiratory tract    Anatomy  UBERON:0001005         NaN
# 9                          muscle    Anatomy  UBERON:0001015         NaN
# 10               peripheral nerve    Anatomy  UBERON:0001020         NaN
# 11                          nerve    Anatomy  UBERON:0001021         NaN
# 12                        pharynx    Anatomy  UBERON:0001042         NaN
# 13               ovarian follicle    Anatomy  UBERON:0001305         NaN
# 14                        phalanx    Anatomy  UBERON:0001436         NaN
# 15      thoracic segment of trunk    Anatomy  UBERON:0001443         NaN
# 16                        phalanx    Anatomy  UBERON:0001449         NaN
# 17                         muscle    Anatomy  UBERON:0001630         NaN
# 18                  celiac artery    Anatomy  UBERON:0001640         NaN
# 19         glossopharyngeal nerve    Anatomy  UBERON:0001649         NaN
# 20     tooth supporting structure    Anatomy  UBERON:0001758         NaN
# 21                      capillary    Anatomy  UBERON:0001982         NaN
# 22                         kidney    Anatomy  UBERON:0002113         NaN
# 23       inferior olivary nucleus    Anatomy  UBERON:0002127         NaN
# 24                       meninges    Anatomy  UBERON:0002360         NaN
# 25                         thymus    Anatomy  UBERON:0002370         NaN
# 26                         thymus    Anatomy  UBERON:0002372         NaN
# 27            anterior commissure    Anatomy  UBERON:0002694         NaN
# 28  medullary laminae of thalamus    Anatomy  UBERON:0002727         NaN
# 29  medullary laminae of thalamus    Anatomy  UBERON:0002765         NaN
# 30                  lingual gland    Anatomy  UBERON:0003409         NaN
# 31             ventricular system    Anatomy  UBERON:0004086         NaN
# 32                      submucosa    Anatomy  UBERON:0004925         NaN
# 33             ventricular system    Anatomy  UBERON:0005282         NaN
# 34                 tunica externa    Anatomy  UBERON:0005734         NaN
# 35                 tunica externa    Anatomy  UBERON:0005742         NaN
# 36         glossopharyngeal nerve    Anatomy  UBERON:0006090         NaN
# 37                  lingual gland    Anatomy  UBERON:0006330         NaN
# 38                        pharynx    Anatomy  UBERON:0006562         NaN
# 39                  celiac artery    Anatomy  UBERON:0006637         NaN
# 40       inferior olivary nucleus    Anatomy  UBERON:0007244         NaN
# 41     tooth supporting structure    Anatomy  UBERON:0008266         NaN
# 42                cerebral sulcus    Anatomy  UBERON:0008334         NaN
# 43                       meninges    Anatomy  UBERON:0010743         NaN
# 44                   buccal gland    Anatomy  UBERON:0012102         NaN
# 45                cerebral sulcus    Anatomy  UBERON:0013118         NaN
# 46                vallate papilla    Anatomy  UBERON:0014389         NaN
# 47                         sulcus    Anatomy  UBERON:0014764         NaN
# 48                    nuchal line    Anatomy  UBERON:0014802         NaN
# 49                    nuchal line    Anatomy  UBERON:0014802         NaN
# 50                    nuchal line    Anatomy  UBERON:0014803         NaN
# 51                    nuchal line    Anatomy  UBERON:0014803         NaN
# 52                    nuchal line    Anatomy  UBERON:0014804         NaN
# 53                    nuchal line    Anatomy  UBERON:0014804         NaN
# 54                   buccal gland    Anatomy  UBERON:0017654         NaN
# 55                      capillary    Anatomy  UBERON:2005259         NaN
#
#    synonyms_xref alt_ids_xref subsets_xref id_curi xref_curi
# 0            NaN          NaN          NaN  UBERON    UBERON
# 1            NaN          NaN          NaN  UBERON    UBERON
# 2            NaN          NaN          NaN  UBERON    UBERON
# 3            NaN          NaN          NaN  UBERON    UBERON
# 4            NaN          NaN          NaN  UBERON    UBERON
# 5            NaN          NaN          NaN  UBERON    UBERON
# 6            NaN          NaN          NaN  UBERON    UBERON
# 7            NaN          NaN          NaN  UBERON    UBERON
# 8            NaN          NaN          NaN  UBERON    UBERON
# 9            NaN          NaN          NaN  UBERON    UBERON
# 10           NaN          NaN          NaN  UBERON    UBERON
# 11           NaN          NaN          NaN  UBERON    UBERON
# 12           NaN          NaN          NaN  UBERON    UBERON
# 13           NaN          NaN          NaN  UBERON    UBERON
# 14           NaN          NaN          NaN  UBERON    UBERON
# 15           NaN          NaN          NaN  UBERON    UBERON
# 16           NaN          NaN          NaN  UBERON    UBERON
# 17           NaN          NaN          NaN  UBERON    UBERON
# 18           NaN          NaN          NaN  UBERON    UBERON
# 19           NaN          NaN          NaN  UBERON    UBERON
# 20           NaN          NaN          NaN  UBERON    UBERON
# 21           NaN          NaN          NaN  UBERON    UBERON
# 22           NaN          NaN          NaN  UBERON    UBERON
# 23           NaN          NaN          NaN  UBERON    UBERON
# 24           NaN          NaN          NaN  UBERON    UBERON
# 25           NaN          NaN          NaN  UBERON    UBERON
# 26           NaN          NaN          NaN  UBERON    UBERON
# 27           NaN          NaN          NaN  UBERON    UBERON
# 28           NaN          NaN          NaN  UBERON    UBERON
# 29           NaN          NaN          NaN  UBERON    UBERON
# 30           NaN          NaN          NaN  UBERON    UBERON
# 31           NaN          NaN          NaN  UBERON    UBERON
# 32           NaN          NaN          NaN  UBERON    UBERON
# 33           NaN          NaN          NaN  UBERON    UBERON
# 34           NaN          NaN          NaN  UBERON    UBERON
# 35           NaN          NaN          NaN  UBERON    UBERON
# 36           NaN          NaN          NaN  UBERON    UBERON
# 37           NaN          NaN          NaN  UBERON    UBERON
# 38           NaN          NaN          NaN  UBERON    UBERON
# 39           NaN          NaN          NaN  UBERON    UBERON
# 40           NaN          NaN          NaN  UBERON    UBERON
# 41           NaN          NaN          NaN  UBERON    UBERON
# 42           NaN          NaN          NaN  UBERON    UBERON
# 43           NaN          NaN          NaN  UBERON    UBERON
# 44           NaN          NaN          NaN  UBERON    UBERON
# 45           NaN          NaN          NaN  UBERON    UBERON
# 46           NaN          NaN          NaN  UBERON    UBERON
# 47           NaN          NaN          NaN  UBERON    UBERON
# 48           NaN          NaN          NaN  UBERON    UBERON
# 49           NaN          NaN          NaN  UBERON    UBERON
# 50           NaN          NaN          NaN  UBERON    UBERON
# 51           NaN          NaN          NaN  UBERON    UBERON
# 52           NaN          NaN          NaN  UBERON    UBERON
# 53           NaN          NaN          NaN  UBERON    UBERON
# 54           NaN          NaN          NaN  UBERON    UBERON
# 55           NaN          NaN          NaN  UBERON    UBERON

# %%
import obonet

# %%
uber = obonet.read_obo('http://purl.obolibrary.org/obo/uberon/basic.obo')

# %%
uber_to_name = {id_: data.get('name') for id_, data in uber.nodes(data=True)}

# %%
anat_issue['uber_id_name'] = anat_issue['id_id'].map(uber_to_name)
anat_issue['uber_xref_name'] = anat_issue['id_xref'].map(uber_to_name)

# %%
len(anat_issue)
# Out:
# 56

# %%
to_mrg = anat_issue[anat_issue['name_id'] == anat_issue['uber_id_name']][['id_id', 'id_xref']].rename(columns={'id_id': 'id', 'id_xref': 'id_old'})
to_mrg
# Out:
#                 id          id_old
# 0   UBERON:0000009  UBERON:0004925
# 2   UBERON:0000065  UBERON:0001005
# 4   UBERON:0000093  UBERON:0014764
# 5   UBERON:0000396  UBERON:0014389
# 6   UBERON:0000915  UBERON:0001443
# 7   UBERON:0000935  UBERON:0002694
# 13  UBERON:0001305  UBERON:0000037
# 18  UBERON:0001640  UBERON:0006637
# 19  UBERON:0001649  UBERON:0006090
# 21  UBERON:0001982  UBERON:2005259
# 22  UBERON:0002113  UBERON:0000082
# 25  UBERON:0002370  UBERON:0002372
# 38  UBERON:0006562  UBERON:0001042
# 40  UBERON:0007244  UBERON:0002127
# 54  UBERON:0017654  UBERON:0012102

# %%
new_mrg_map = pd.concat([new_mrg_map, to_mrg], sort=False, ignore_index=True)

# %%
mrg_ids = to_mrg[['id', 'id_old']].stack().unique()

# %%
anat_issue.query('id_id not in @mrg_ids and id_xref not in @mrg_ids')[['id_id', 'name_id', 'uber_id_name', 'id_xref', 'name_xref', 'uber_xref_name']]
# Out:
#              id_id                        name_id  \
# 9   UBERON:0001015                         muscle
# 10  UBERON:0001020                          nerve
# 11  UBERON:0001021               peripheral nerve
# 14  UBERON:0001436                        phalanx
# 16  UBERON:0001449                        phalanx
# 17  UBERON:0001630                         muscle
# 20  UBERON:0001758     tooth supporting structure
# 24  UBERON:0002360                       meninges
# 28  UBERON:0002727  medullary laminae of thalamus
# 29  UBERON:0002765  medullary laminae of thalamus
# 30  UBERON:0003409                  lingual gland
# 31  UBERON:0004086             ventricular system
# 33  UBERON:0005282             ventricular system
# 34  UBERON:0005734                 tunica externa
# 35  UBERON:0005742                 tunica externa
# 37  UBERON:0006330                  lingual gland
# 41  UBERON:0008266     tooth supporting structure
# 42  UBERON:0008334                cerebral sulcus
# 43  UBERON:0010743                       meninges
# 45  UBERON:0013118                cerebral sulcus
# 48  UBERON:0014802                    nuchal line
# 49  UBERON:0014802                    nuchal line
# 50  UBERON:0014803                    nuchal line
# 51  UBERON:0014803                    nuchal line
# 52  UBERON:0014804                    nuchal line
# 53  UBERON:0014804                    nuchal line
#
#                                    uber_id_name         id_xref  \
# 9                                   musculature  UBERON:0001630
# 10                    nervous system commissure  UBERON:0001021
# 11                                        nerve  UBERON:0001020
# 14                             phalanx of manus  UBERON:0001449
# 16                               phalanx of pes  UBERON:0001436
# 17                                 muscle organ  UBERON:0001015
# 20                                 periodontium  UBERON:0008266
# 24                                       meninx  UBERON:0010743
# 28   medial medullary lamina of globus pallidus  UBERON:0002765
# 29  lateral medullary lamina of globus pallidus  UBERON:0002727
# 30                              gland of tongue  UBERON:0006330
# 31                              brain ventricle  UBERON:0005282
# 33                  ventricular system of brain  UBERON:0004086
# 34            tunica adventitia of blood vessel  UBERON:0005742
# 35                                   adventitia  UBERON:0005734
# 37                       anterior lingual gland  UBERON:0003409
# 41                         periodontal ligament  UBERON:0001758
# 42                          subarachnoid sulcus  UBERON:0013118
# 43                            meningeal cluster  UBERON:0002360
# 45                              sulcus of brain  UBERON:0008334
# 48          highest nuchal line attachment site  UBERON:0014803
# 49          highest nuchal line attachment site  UBERON:0014804
# 50         superior nuchal line attachment site  UBERON:0014802
# 51         superior nuchal line attachment site  UBERON:0014804
# 52           median nuchal line attachment site  UBERON:0014802
# 53           median nuchal line attachment site  UBERON:0014803
#
#                         name_xref                               uber_xref_name
# 9                          muscle                                 muscle organ
# 10               peripheral nerve                                        nerve
# 11                          nerve                    nervous system commissure
# 14                        phalanx                               phalanx of pes
# 16                        phalanx                             phalanx of manus
# 17                         muscle                                  musculature
# 20     tooth supporting structure                         periodontal ligament
# 24                       meninges                            meningeal cluster
# 28  medullary laminae of thalamus  lateral medullary lamina of globus pallidus
# 29  medullary laminae of thalamus   medial medullary lamina of globus pallidus
# 30                  lingual gland                       anterior lingual gland
# 31             ventricular system                  ventricular system of brain
# 33             ventricular system                              brain ventricle
# 34                 tunica externa                                   adventitia
# 35                 tunica externa            tunica adventitia of blood vessel
# 37                  lingual gland                              gland of tongue
# 41     tooth supporting structure                                 periodontium
# 42                cerebral sulcus                              sulcus of brain
# 43                       meninges                                       meninx
# 45                cerebral sulcus                          subarachnoid sulcus
# 48                    nuchal line         superior nuchal line attachment site
# 49                    nuchal line           median nuchal line attachment site
# 50                    nuchal line          highest nuchal line attachment site
# 51                    nuchal line           median nuchal line attachment site
# 52                    nuchal line          highest nuchal line attachment site
# 53                    nuchal line         superior nuchal line attachment site

# %% [markdown]
# ## Proteins
#
# These are a mess, we will just have to blanket fix them...
#
# If it's xrefed to a gene, we can keep, but if its xref'd to anotehr protein, we will just pick one and drop the remainder.

# %%
prot_issue = xref_mrg.query('label_id == "Protein"').copy()
prot_issue
# Out:
#                    id_id                                     name_id label_id  \
# 202   UniProt:A0A068W6U3                            egrg_000749900.2  Protein
# 203   UniProt:A0A068W6U3                            egrg_000749900.2  Protein
# 204   UniProt:A0A068W7A3                            egrg_000749900.1  Protein
# 205   UniProt:A0A068W7A3                            egrg_000749900.1  Protein
# 206   UniProt:A0A068W7P1                            egrg_000776300.2  Protein
# ...                  ...                                         ...      ...
# 5648      UniProt:V9TJE9            nicotinic acetylcholine receptor  Protein
# 5649      UniProt:V9TKF5            nicotinic acetylcholine receptor  Protein
# 5650      UniProt:V9TMX9  nicotinic acetylcholine receptor non alpha  Protein
# 5651      UniProt:V9TMX9  nicotinic acetylcholine receptor non alpha  Protein
# 5652      UniProt:X5CY48                       histone deacetylase 1  Protein
#
#      source_id synonyms_id alt_ids_id subsets_id             id_xref  \
# 202        NaN         NaN        NaN        NaN  UniProt:A0A068W7A3
# 203        NaN         NaN        NaN        NaN  UniProt:A0A068W9M3
# 204        NaN         NaN        NaN        NaN  UniProt:A0A068W6U3
# 205        NaN         NaN        NaN        NaN  UniProt:A0A068W9M3
# 206        NaN         NaN        NaN        NaN  UniProt:A0A068WAF9
# ...        ...         ...        ...        ...                 ...
# 5648       NaN         NaN        NaN        NaN      UniProt:G4VE52
# 5649       NaN         NaN        NaN        NaN      UniProt:G4VRZ9
# 5650       NaN         NaN        NaN        NaN      UniProt:G4VN54
# 5651       NaN         NaN        NaN        NaN      UniProt:Q6TMX8
# 5652       NaN         NaN        NaN        NaN  UniProt:A0A087WLN3
#
#                                        name_xref label_xref  \
# 202                             egrg_000749900.1    Protein
# 203                             egrg_000749900.3    Protein
# 204                             egrg_000749900.2    Protein
# 205                             egrg_000749900.3    Protein
# 206                             egrg_000776300.1    Protein
# ...                                          ...        ...
# 5648            nicotinic acetylcholine receptor    Protein
# 5649            nicotinic acetylcholine receptor    Protein
# 5650  nicotinic acetylcholine receptor non alpha    Protein
# 5651  nicotinic acetylcholine receptor non alpha    Protein
# 5652                       histone deacetylase 1    Protein
#
#                    xrefs source_xref synonyms_xref alt_ids_xref subsets_xref  \
# 202   UniProt:A0A068W6U3         NaN           NaN          NaN          NaN
# 203   UniProt:A0A068W6U3         NaN           NaN          NaN          NaN
# 204   UniProt:A0A068W7A3         NaN           NaN          NaN          NaN
# 205   UniProt:A0A068W7A3         NaN           NaN          NaN          NaN
# 206   UniProt:A0A068W7P1         NaN           NaN          NaN          NaN
# ...                  ...         ...           ...          ...          ...
# 5648      UniProt:V9TJE9         NaN           NaN          NaN          NaN
# 5649      UniProt:V9TKF5         NaN           NaN          NaN          NaN
# 5650      UniProt:V9TMX9         NaN           NaN          NaN          NaN
# 5651      UniProt:V9TMX9         NaN           NaN          NaN          NaN
# 5652      UniProt:X5CY48         NaN           NaN          NaN          NaN
#
#       id_curi xref_curi
# 202   UniProt   UniProt
# 203   UniProt   UniProt
# 204   UniProt   UniProt
# 205   UniProt   UniProt
# 206   UniProt   UniProt
# ...       ...       ...
# 5648  UniProt   UniProt
# 5649  UniProt   UniProt
# 5650  UniProt   UniProt
# 5651  UniProt   UniProt
# 5652  UniProt   UniProt
#
# [5451 rows x 17 columns]

# %%
from queue import Queue
from tqdm import tqdm

def get_subnets(input_adj_list):

    all_identifiers = list(input_adj_list.keys())

    subnets = defaultdict(set)
    visited = set()

    for net_id in tqdm(all_identifiers):
        if net_id not in visited:
            visited.add(net_id)
            q = Queue()
            q.put(net_id)

            while not q.empty():
                cur = q.get()
                visited.add(cur)

                for neighbour in input_adj_list[cur]:
                    subnets[net_id].add(neighbour)
                    if neighbour not in visited:
                        q.put(neighbour)
                        visited.add(neighbour)

    return subnets

# %%
from collections import defaultdict

adj_list = defaultdict(set)

for row in prot_issue.query('id_curi == "UniProt" and xref_curi == "UniProt"').itertuples():
    adj_list[row.id_xref].add(row.id_id)
    adj_list[row.id_id].add(row.id_xref)

# %%
subnets = get_subnets(adj_list)
# Out:
# 100%|██████████| 2512/2512 [00:00<00:00, 89242.02it/s]

# %%
to_mrg = []
for k, v in subnets.items():
    this_mrg = pd.DataFrame({'id':[k for i in v], 'id_old': list(v)})
    to_mrg.append(this_mrg)
to_mrg = pd.concat(to_mrg)
to_mrg
# Out:
#                     id              id_old
# 0   UniProt:A0A068W7A3  UniProt:A0A068W7A3
# 1   UniProt:A0A068W7A3  UniProt:A0A068W9M3
# 2   UniProt:A0A068W7A3  UniProt:A0A068W6U3
# 0   UniProt:A0A068WAF9  UniProt:A0A068WAF9
# 1   UniProt:A0A068WAF9  UniProt:A0A068W7P1
# ..                 ...                 ...
# 4       UniProt:Q70W85      UniProt:Q9B8X8
# 0       UniProt:Q6WVP6      UniProt:Q6WVP6
# 1       UniProt:Q6WVP6      UniProt:Q6TA39
# 0       UniProt:Q94759      UniProt:Q94759
# 1       UniProt:Q94759      UniProt:Q7KPG1
#
# [2512 rows x 2 columns]

# %%
to_mrg['id'].nunique()
# Out:
# 1104

# %%
new_mrg_map = pd.concat([new_mrg_map, to_mrg], sort=False, ignore_index=True)

# %% [markdown]
# ## Cleanup and merge

# %%
mrg_ids = new_mrg_map.stack().unique()

# %%
len(mrg_ids)
# Out:
# 2556

# %%
len(mrg_ids) - len(new_mrg_map['id'].unique())
# Out:
# 1431

# %%
not_merged = xref_mrg.query('id_id not in @mrg_ids')
len(not_merged)
# Out:
# 1770

# %%
# Remove offensive Xrefs from those we don't merge

for row in tqdm(not_merged.itertuples(), total=len(not_merged)):
    q_id = row.id_id
    idx = nodes.query('id == @q_id').index.tolist()[0]
    nodes.loc[idx, 'xrefs'] = remove_xref(row.id_xref, nodes.loc[idx, 'xrefs'])
# Out:
# 100%|██████████| 1770/1770 [00:37<00:00, 47.14it/s]

# %%
to_fix = nodes.query('id in @mrg_ids').copy()
to_keep = nodes.query('id not in @mrg_ids')

# %%
new_mrg_map.nunique()
# Out:
# id        1125
# id_old    2535
# dtype: int64

# %%
# make sure many to 1 and not many to many
len(new_mrg_map.set_index('id_old')['id'].to_dict()) == len(new_mrg_map)
# Out:
# True

# %%
new_mrg_map_dict = new_mrg_map.set_index('id_old')['id'].to_dict()

to_fix['id'] = to_fix['id'].map(new_mrg_map_dict).fillna(to_fix['id'])

to_fix = dfp.combine_group_cols_on_char(to_fix, ['id'], [c for c in to_fix.columns if c not in ['id', 'name', 'label']],
                                        sort=True, prog=False)

# %%
nodes = pd.concat([to_keep, to_fix], sort=False).sort_values(['label', 'id']).reset_index(drop=True)

# %%
edges = gt.re_id_edges(edges, new_mrg_map, 'id_old', 'id')

# %%
print('{:,}'.format(len(edges)))
edges = dfp.combine_group_cols_on_char(edges, ['start_id', 'type', 'end_id'], sort=True, prog=True)
print('{:,}'.format(len(edges)))
# Out:
# 9,281,977
# HBox(children=(FloatProgress(value=0.0, description='total_progress', max=5.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='p_val', max=15853.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='adj_p', max=15853.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='source', max=15853.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='license', max=15853.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='pmids', max=15853.0, style=ProgressStyle(description_widt…
# 9,263,585

# %%
nodes_ids = nodes['id'].unique()

# %%
edge_ids = edges[['start_id', 'end_id']].stack().unique()

# %%
set(edge_ids) - set(node_ids) == set()
# Out:
# True

# %%
# Since we have the obo, lets get the correct uberon names...
nodes['name'] = nodes['id'].map(uber_to_name).fillna(nodes['name'])

# %%
nodes.count()
# Out:
# id          790981
# name        790966
# label       790981
# xrefs       557235
# source       14322
# synonyms      9695
# alt_ids       2469
# subsets       6864
# dtype: int64

# %%
noname_idx = nodes[nodes['name'].isnull()].index

nodes.loc[noname_idx]
# Out:
#                                       id name label  \
# 331008                      CHEBI:144367  NaN  Drug
# 334432  IKEY:AKLMFDDQCHURPW-ISIOAQNYSA-N  NaN  Drug
# 335068  IKEY:CJGOZEVWXQGMCS-UHFFFAOYSA-N  NaN  Drug
# 335190  IKEY:CSOBIBXVIYAXFM-UHFFFAOYSA-N  NaN  Drug
# 335220  IKEY:CUKZGIUJLFWPNP-UHFFFAOYSA-N  NaN  Drug
# 336079  IKEY:GHUYIIGPWBMOGY-KRWDZBQOSA-N  NaN  Drug
# 336399  IKEY:HHRDZACHVMGHOB-UHFFFAOYSA-N  NaN  Drug
# 336624  IKEY:HXLOHDZQBKCUCR-FNNAPWSISA-N  NaN  Drug
# 336724  IKEY:IFPBSRFVNPCZMK-UHFFFAOYSA-N  NaN  Drug
# 337119  IKEY:JGPNCLKRECLYTO-UHFFFAOYSA-N  NaN  Drug
# 341053  IKEY:VMQRILJWEHBRPV-UHFFFAOYSA-L  NaN  Drug
# 341335  IKEY:WJAVQCPRFGVNSN-HEVIKAOCSA-N  NaN  Drug
# 341439  IKEY:WRNQYBXJRPAGNS-UHFFFAOYSA-N  NaN  Drug
# 342088  IKEY:YQNRVGJCPCNMKT-UHFFFAOYSA-N  NaN  Drug
# 342427  IKEY:ZROLHBHDLIHEMS-UHFFFAOYSA-N  NaN  Drug
#
#                                                     xrefs  \
# 331008  3po|CHEBI:144367|IKEY:UJJUKZPBUMCSJZ-BQYQJAHWS...
# 334432  1pyrrolidineacetamiden5ar6as7s10as9aminocarbon...
# 335068  IKEY:CJGOZEVWXQGMCS-UHFFFAOYSA-N|IKEY:YCWROMXN...
# 335190  2910dimethoxy4oxo2246trimethylphenylimino67dih...
# 335220  IKEY:CUKZGIUJLFWPNP-UHFFFAOYSA-N|IKEY:YJPVTCSB...
# 336079  IKEY:CYHWMBVXXDIZNZ-KRWDZBQOSA-N|IKEY:GHUYIIGP...
# 336399  225dimethylaminomethylfurfurylthioethylamino56...
# 336624  3quinolinecarboxamide12dihydron3endo82r2hydrox...
# 336724  18naphthyridine3carboxylicacid1cyclopropyl6flu...
# 337119  5nitro2furaldehyde2ethylsemicarbazone|IKEY:JGP...
# 341053  IKEY:LTRMJGWQJOWOPE-UHFFFAOYSA-L|IKEY:VMQRILJW...
# 341335  IKEY:GCDHMGROXQUFNR-HEVIKAOCSA-N|IKEY:WJAVQCPR...
# 341439  IKEY:WRNQYBXJRPAGNS-QURGRASLSA-N|IKEY:WRNQYBXJ...
# 342088  1piperazineaceticacid|1piperazineaceticacid4ph...
# 342427  6hdibenzobdpyran1ol6a7810atetrahydro669trimeth...
#
#                        source synonyms alt_ids subsets
# 331008                informa      NaN     NaN     NaN
# 334432          gvk|integrity      NaN     NaN     NaN
# 335068  gvk|informa|integrity      NaN     NaN     NaN
# 335190  gvk|informa|integrity      NaN     NaN     NaN
# 335220                    gvk      NaN     NaN     NaN
# 336079          gvk|integrity      NaN     NaN     NaN
# 336399                informa      NaN     NaN     NaN
# 336624  gvk|informa|integrity      NaN     NaN     NaN
# 336724                    gvk      NaN     NaN     NaN
# 337119                    gvk      NaN     NaN     NaN
# 341053                    gvk      NaN     NaN     NaN
# 341335                    gvk      NaN     NaN     NaN
# 341439                    gvk      NaN     NaN     NaN
# 342088          gvk|integrity      NaN     NaN     NaN
# 342427          gvk|integrity      NaN     NaN     NaN

# %%
nodes.loc[noname_idx, 'name'] = nodes.loc[noname_idx, 'xrefs'].apply(lambda s: s.split('|')[0])
nodes.loc[noname_idx]
# Out:
#                                       id  \
# 331008                      CHEBI:144367
# 334432  IKEY:AKLMFDDQCHURPW-ISIOAQNYSA-N
# 335068  IKEY:CJGOZEVWXQGMCS-UHFFFAOYSA-N
# 335190  IKEY:CSOBIBXVIYAXFM-UHFFFAOYSA-N
# 335220  IKEY:CUKZGIUJLFWPNP-UHFFFAOYSA-N
# 336079  IKEY:GHUYIIGPWBMOGY-KRWDZBQOSA-N
# 336399  IKEY:HHRDZACHVMGHOB-UHFFFAOYSA-N
# 336624  IKEY:HXLOHDZQBKCUCR-FNNAPWSISA-N
# 336724  IKEY:IFPBSRFVNPCZMK-UHFFFAOYSA-N
# 337119  IKEY:JGPNCLKRECLYTO-UHFFFAOYSA-N
# 341053  IKEY:VMQRILJWEHBRPV-UHFFFAOYSA-L
# 341335  IKEY:WJAVQCPRFGVNSN-HEVIKAOCSA-N
# 341439  IKEY:WRNQYBXJRPAGNS-UHFFFAOYSA-N
# 342088  IKEY:YQNRVGJCPCNMKT-UHFFFAOYSA-N
# 342427  IKEY:ZROLHBHDLIHEMS-UHFFFAOYSA-N
#
#                                                      name label  \
# 331008                                                3po  Drug
# 334432  1pyrrolidineacetamiden5ar6as7s10as9aminocarbon...  Drug
# 335068                   IKEY:CJGOZEVWXQGMCS-UHFFFAOYSA-N  Drug
# 335190  2910dimethoxy4oxo2246trimethylphenylimino67dih...  Drug
# 335220                   IKEY:CUKZGIUJLFWPNP-UHFFFAOYSA-N  Drug
# 336079                   IKEY:CYHWMBVXXDIZNZ-KRWDZBQOSA-N  Drug
# 336399  225dimethylaminomethylfurfurylthioethylamino56...  Drug
# 336624  3quinolinecarboxamide12dihydron3endo82r2hydrox...  Drug
# 336724  18naphthyridine3carboxylicacid1cyclopropyl6flu...  Drug
# 337119              5nitro2furaldehyde2ethylsemicarbazone  Drug
# 341053                   IKEY:LTRMJGWQJOWOPE-UHFFFAOYSA-L  Drug
# 341335                   IKEY:GCDHMGROXQUFNR-HEVIKAOCSA-N  Drug
# 341439                   IKEY:WRNQYBXJRPAGNS-QURGRASLSA-N  Drug
# 342088                              1piperazineaceticacid  Drug
# 342427  6hdibenzobdpyran1ol6a7810atetrahydro669trimeth...  Drug
#
#                                                     xrefs  \
# 331008  3po|CHEBI:144367|IKEY:UJJUKZPBUMCSJZ-BQYQJAHWS...
# 334432  1pyrrolidineacetamiden5ar6as7s10as9aminocarbon...
# 335068  IKEY:CJGOZEVWXQGMCS-UHFFFAOYSA-N|IKEY:YCWROMXN...
# 335190  2910dimethoxy4oxo2246trimethylphenylimino67dih...
# 335220  IKEY:CUKZGIUJLFWPNP-UHFFFAOYSA-N|IKEY:YJPVTCSB...
# 336079  IKEY:CYHWMBVXXDIZNZ-KRWDZBQOSA-N|IKEY:GHUYIIGP...
# 336399  225dimethylaminomethylfurfurylthioethylamino56...
# 336624  3quinolinecarboxamide12dihydron3endo82r2hydrox...
# 336724  18naphthyridine3carboxylicacid1cyclopropyl6flu...
# 337119  5nitro2furaldehyde2ethylsemicarbazone|IKEY:JGP...
# 341053  IKEY:LTRMJGWQJOWOPE-UHFFFAOYSA-L|IKEY:VMQRILJW...
# 341335  IKEY:GCDHMGROXQUFNR-HEVIKAOCSA-N|IKEY:WJAVQCPR...
# 341439  IKEY:WRNQYBXJRPAGNS-QURGRASLSA-N|IKEY:WRNQYBXJ...
# 342088  1piperazineaceticacid|1piperazineaceticacid4ph...
# 342427  6hdibenzobdpyran1ol6a7810atetrahydro669trimeth...
#
#                        source synonyms alt_ids subsets
# 331008                informa      NaN     NaN     NaN
# 334432          gvk|integrity      NaN     NaN     NaN
# 335068  gvk|informa|integrity      NaN     NaN     NaN
# 335190  gvk|informa|integrity      NaN     NaN     NaN
# 335220                    gvk      NaN     NaN     NaN
# 336079          gvk|integrity      NaN     NaN     NaN
# 336399                informa      NaN     NaN     NaN
# 336624  gvk|informa|integrity      NaN     NaN     NaN
# 336724                    gvk      NaN     NaN     NaN
# 337119                    gvk      NaN     NaN     NaN
# 341053                    gvk      NaN     NaN     NaN
# 341335                    gvk      NaN     NaN     NaN
# 341439                    gvk      NaN     NaN     NaN
# 342088          gvk|integrity      NaN     NaN     NaN
# 342427          gvk|integrity      NaN     NaN     NaN

# %%
#Fix the lowercase names...
nodes['name'] = nodes['id'].map(id_to_name).fillna(nodes['name'])

# %%
mrg_map.to_csv(out_dir.joinpath('merge_map_1.csv'), index=False)
new_mrg_map.to_csv(out_dir.joinpath('merge_map_2.csv'), index=False)

nodes.to_csv(out_dir.joinpath('nodes.csv'), index=False)
edges.to_csv(out_dir.joinpath('edges.csv'), index=False)
