# %% [markdown]
# Compound identifiers are a mess.  We have 3 different sources of data, each with 3 different primary identifiers... Previously we used CTD (MESH), which also has some ChEBI terms included. Next we looked up records from Inxight Drugs, which happen to use UNII as the primary identifier.  We've converted as many as possilbe to Inchi-key.  Finally, we will be incorporating ReFRAME, which uses Inchi-key as the primary identifier. Many Steps will be required to get maximum overlap from the 3 data Sources.
#
# 1. We must resolve mappings from ChEBI to MeSH.
#     - ChEBI and MeSH both have tree-like (ontology) structure and many higher-level terms (like chemical classes) are similar
#     - Direct mappings between ChEBI and MeSH are difficult to come by
#     - The following may have some direct mappings
#         - mychem.info
#         - wikidata
#     - Indirect mappings through other Identifiers may also be useful
# 2. We need maps from this ChEBI/MeSH to UNII and InchiKey
#     - ChEBI to Inchi-key is well definied
#     - inchikey to unii is only somewhat defined, large percnetage missing
# 3. String Matching will be usd as a last resort

# %%
import zipfile
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import tools.biothings_processing as bp
from tools.processing import expand_col_on_char, load_api_results, expand_split_col, expand_df_on_col
from tools.plot import venn2_pretty, venn3_pretty
from tools.obo_tools import get_ontology_edges, get_ontology_nodes, get_children, get_lineage

from wikidataintegrator.wdi_core import WDItemEngine

from hetnet_ml.src import graph_tools as gt

# %%
# Get Data Dir
data_dir = Path('../2_pipeline/00_download_data/out/').resolve()


# Get Output Directory ready
this_file = '09_Resolving_Chemical_Identifiers'
out_dir = Path('../2_pipeline/').resolve()
out_dir = out_dir.joinpath(this_file).joinpath('out')

if not out_dir.exists():
    out_dir.mkdir(parents=True)

# %%
ix_nodes = pd.read_csv('../2_pipeline/08_More_Drug_to_Target_Edges/out/nodes_inxight.csv', dtype=str)
ix_nodes.head(2)
# Out:
#                             id               name     label     chebi_id  \
# 0  FZERHIULMFGESH-UHFFFAOYSA-N        Acetanilide  Compound  CHEBI:28884
# 1  SWMPGCCDXNLPED-NSCUHMNNSA-N  Acetylfuratrizine  Compound          NaN
#
#       chembl_id drugbank_id                         ikey       mesh_id  \
# 0  CHEMBL269644         NaN  FZERHIULMFGESH-UHFFFAOYSA-N  MESH:C508827
# 1           NaN         NaN  SWMPGCCDXNLPED-NSCUHMNNSA-N  MESH:C005910
#
#       unii_id source    ...     target_chembl_id target_type tax_id id_source  \
# 0  SP86R356CC   ikey    ...                  NaN         NaN    NaN       NaN
# 1  C50C4V19SU   ikey    ...                  NaN         NaN    NaN       NaN
#
#   xrefs gene_symbol organism swissprot_entry target_class uniprot_id
# 0   NaN         NaN      NaN             NaN          NaN        NaN
# 1   NaN         NaN      NaN             NaN          NaN        NaN
#
# [2 rows x 21 columns]

# %%
ix_nodes.head(2)
# Out:
#                             id               name     label     chebi_id  \
# 0  FZERHIULMFGESH-UHFFFAOYSA-N        Acetanilide  Compound  CHEBI:28884
# 1  SWMPGCCDXNLPED-NSCUHMNNSA-N  Acetylfuratrizine  Compound          NaN
#
#       chembl_id drugbank_id                         ikey       mesh_id  \
# 0  CHEMBL269644         NaN  FZERHIULMFGESH-UHFFFAOYSA-N  MESH:C508827
# 1           NaN         NaN  SWMPGCCDXNLPED-NSCUHMNNSA-N  MESH:C005910
#
#       unii_id source    ...     target_chembl_id target_type tax_id id_source  \
# 0  SP86R356CC   ikey    ...                  NaN         NaN    NaN       NaN
# 1  C50C4V19SU   ikey    ...                  NaN         NaN    NaN       NaN
#
#   xrefs gene_symbol organism swissprot_entry target_class uniprot_id
# 0   NaN         NaN      NaN             NaN          NaN        NaN
# 1   NaN         NaN      NaN             NaN          NaN        NaN
#
# [2 rows x 21 columns]

# %%
comp_cols = ['id', 'name', 'label', 'chebi_id', 'chembl_id', 'drugbank_id', 'ikey', 'mesh_id', 'unii_id', 'source']
ix_comps = ix_nodes.query('label == "Compound"').loc[:,comp_cols]
len(ix_comps)
# Out:
# 105893

# %%
prev_nodes = gt.remove_colons(pd.read_csv('../2_pipeline/07_Filter_non_human_annotations/out/nodes_filt.csv', dtype=str))
prev_comps = prev_nodes.query('label == "Compound"').copy()

prev_comps.head(2)
# Out:
#              id                     name     label  \
# 0  MESH:C046983  06-Paris-LA-66 protocol  Compound
# 1  MESH:C534883                 10074-G5  Compound
#
#                                         tree_numbers drug_bank_ids  \
# 0  D02.455.426.559.847.562.050.200/C046983|D03.13...           NaN
# 1                        D03.383.129.462.580/C534883           NaN
#
#   alt_disease_ids gene_symbol alt_gene_ids bio_gridids pharm_gkbids  \
# 0             NaN         NaN          NaN         NaN          NaN
# 1             NaN         NaN          NaN         NaN          NaN
#
#   uni_prot_ids uniprot_id mesh_ids chebi_ids
# 0          NaN        NaN      NaN       NaN
# 1          NaN        NaN      NaN       NaN

# %%
ref = pd.read_csv('../0_data/manual/reframe_merged.csv', dtype=str)
ref = ref.drop_duplicates().reset_index(drop=True)
ref.head(2)
# Out:
#       gvk_id  drug_name                   phase drug_roa  \
# 0  5916161.0    A-49816  Clinical Phase Unknown      NaN
# 1  5913712.0  Elmustine  Clinical Phase Unknown      NaN
#
#                 category              mechanism  \
# 0  High-Ceiling Diuretic  High-Ceiling Diuretic
# 1             Anticancer             Anticancer
#
#                                           sub_smiles  \
# 0  Cl[H].[H]OC1=C(CN([H])[H])C=C(C=C1)C(=O)C2=CC=...
# 1                        [H]OCCN([H])C(=O)N(CCCl)N=O
#
#                                 synonyms_gvk                         ikey  \
# 0                               Abbott-49816  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1  BRN-1956525|FFC-33|HECNU|Hecnu|NSC-294895  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#     name_inf          ...                  id     status  \
# 0        NaN          ...            145141.0   Clinical
# 1  Elmustine          ...             91016.0  Phase III
#
#                                           smiles_itg   name_itg  \
# 0  CCOC(=O)COc1ccc(c(c1Cl)Cl)C(=O)c2ccc(c(c2)CN)O.Cl    A-49816
# 1                              C(CO)NC(=O)N(CCCl)N=O  Elmustine
#
#   integrity_note  int_thera_group             int_MoA wikidata_itg  \
# 0            NaN        Diuretics                 NaN    Q27270440
# 1            NaN  Oncolytic Drugs  DNA-Damaging Drugs    Q27284767
#
#    PubChem CID                 source
# 0  CID92009045          gvk|integrity
# 1     CID68804  gvk|informa|integrity
#
# [2 rows x 32 columns]

# %%
len(ref)
# Out:
# 17220

# %%
ref_ikeys = ref['ikey'].unique()
res = load_api_results(out_dir.joinpath('reframe_mychem_info_{}.pkl'), scrape_function=bp.download_mychem_ids, 
                         chem_ids=ref_ikeys)


ref_comps = bp.process_chemicals_in_mychem_results(res)

# %%
ref_comps.head(2)
# Out:
#   chebi_id     chembl_id drugbank_id                         ikey  \
# 0      NaN  CHEMBL543295         NaN  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1      NaN  CHEMBL284907         NaN  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#         mesh_id                   name                            q  \
# 0           NaN  A-49816 hydrochloride  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1  MESH:C013876              Elmustine  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#       unii_id                           id source
# 0  8GKF50WX7S  WYFYYAHANZQLGG-UHFFFAOYSA-N   ikey
# 1  NAT2FD82D7  YJZJEQBSODVMTH-UHFFFAOYSA-N   ikey

# %%
len(ref_comps)
# Out:
# 17091

# %%
# how many returned at least SOME kind of result?
len(ref_comps.drop('q', axis=1).dropna(how='all'))
# Out:
# 14833

# %%
chebi = get_ontology_nodes(data_dir.joinpath('chebi.obo'), props=['http://purl.obolibrary.org/obo/chebi/inchikey'])
chebi = chebi.rename(columns={'http://purl.obolibrary.org/obo/chebi/inchikey': 'ikey'})
chebi.head(2)
# Out:
#   alt_id                                                def ikey           id  \
# 0    NaN  "A chemical entity is a physical entity of int...  NaN  CHEBI:24431
# 1    NaN  "Any constitutionally or isotopically distinct...  NaN  CHEBI:23367
#
#    is_obsolete              name  subset xref id_src
# 0        False   chemical entity  3_STAR  NaN  CHEBI
# 1        False  molecular entity  3_STAR  NaN  CHEBI

# %%
len(chebi.dropna(subset=['ikey']))
# Out:
# 92700

# %% [markdown]
# ### Wikidata to query chebi to mesh

# %%
query = """
SELECT DISTINCT ?chebi ?mesh ?item ?itemLabel
WHERE 
{
  # ?item wdt:P486 ?mesh.
  # ?item wdt:P683 ?chebi.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
ORDER BY ?itemLabel
"""

# %%
chebi_to_mesh = WDItemEngine.execute_sparql_query(query, as_dataframe=True)

# %%
bad_mesh = chebi_to_mesh['mesh'].str.startswith('M')
bad_mesh = bad_mesh[bad_mesh].index
chebi_to_mesh = chebi_to_mesh.drop(bad_mesh)
chebi_to_mesh['chebi'] = 'CHEBI:' + chebi_to_mesh['chebi']
chebi_to_mesh['mesh'] = 'MESH:' + chebi_to_mesh['mesh']

# %%
ix = chebi_to_mesh['mesh'].duplicated(keep=False)
chebi_duped = chebi_to_mesh.loc[ix[ix].index]
len(chebi_duped)
# Out:
# 698

# %% [markdown]
# These are instances of multiple CHEBI ids for a single WIKIDATA item... (where that item has at least 1 MESH id)
#
# We will try to resolve these...

# %%
ix = chebi_to_mesh['chebi'].duplicated(keep=False)
mesh_duped = chebi_to_mesh.loc[ix[ix].index]
len(mesh_duped)
# Out:
# 22

# %% [markdown]
# These are instances of a Mutiple MESH ids for a single WIKIDATA item (with at least one CHEBI id).
#
# May be small enought to resolve

# %% [markdown]
# ### Look at only the 1 to 1 mappings and see if we can merge to chebi ontology

# %%
unique_chebi_to_mesh = chebi_to_mesh.drop_duplicates(subset=['chebi'], keep=False).drop_duplicates(subset=['mesh'], keep=False)

# %%
len(unique_chebi_to_mesh)
# Out:
# 4031

# %%
len(chebi)
# Out:
# 113750

# %%
chebi = pd.merge(chebi, unique_chebi_to_mesh[['chebi', 'mesh']], how='left', left_on='id', right_on='chebi').drop('chebi', axis=1)

# %%
chebi.dropna(subset=['mesh']).sample(10)
# Out:
#                                                    alt_id  \
# 1304                                                  NaN
# 49834                                                 NaN
# 20247                                                 NaN
# 113374                                                NaN
# 54837                                                 NaN
# 68051                                                 NaN
# 65164   CHEBI:15328|CHEBI:253147|CHEBI:46522|CHEBI:100...
# 24422                                                 NaN
# 55727                  CHEBI:23901|CHEBI:42328|CHEBI:4764
# 38234                                         CHEBI:42526
#
#                                                       def  \
# 1304    "A potassium salt that is the dipotassium salt...
# 49834   "A sulfoxide that is dimethylsulfoxide in whic...
# 20247   "A polyamino carboxylic acid, the structure of...
# 113374  "A substance used in the prophylaxis or therap...
# 54837   "A leptomycin having a (2E,10E,12E,16Z,18E)-do...
# 68051   "A cyclodiene organochlorine insecticide that ...
# 65164   "A pentitol (five-carbon sugar alcohol) having...
# 24422   "An aminoquinoline that is 1,3-di(piperazin-1-...
# 55727   "An icosapentaenoic acid having five cis-doubl...
# 38234   "Propylphosphonic acid in which one of the hyd...
#
#                                ikey            id  is_obsolete  \
# 1304    KMUONIBRACKNSN-UHFFFAOYSA-N   CHEBI:53444        False
# 49834   YFGHCGITMMYXAQ-UHFFFAOYSA-N   CHEBI:77585        False
# 20247   BOMWLYNXTGNSSE-UHFFFAOYSA-N   CHEBI:60889        False
# 113374                          NaN   CHEBI:35441        False
# 54837   YACHGFWEQXFSBS-XYERBDPFSA-N   CHEBI:52646        False
# 68051   FRCCEHPWNOQAEU-UHFFFAOYSA-N   CHEBI:34785        False
# 65164   HEBKCHPVOIAQTA-SCDXWVJYSA-N   CHEBI:17151        False
# 24422   UCRHFBCYFMIWHC-UHFFFAOYSA-N   CHEBI:91231        False
# 55727   JAZBEHYOTPTENJ-JLNKQSITSA-N   CHEBI:28364        False
# 38234   GJXWDTUCERCKIX-UHFFFAOYSA-N  CHEBI:443725        False
#
#                                              name  subset  \
# 1304                         potassium dichromate  3_STAR
# 49834       2-[(diphenylmethyl)sulfinyl]acetamide  3_STAR
# 20247                         5,5'-dimethyl-BAPTA  3_STAR
# 113374                        antiinfective agent  3_STAR
# 54837                                leptomycin B  3_STAR
# 68051                                  heptachlor  3_STAR
# 65164                                     xylitol  3_STAR
# 24422                                 piperaquine  3_STAR
# 55727   all-cis-5,8,11,14,17-icosapentaenoic acid  3_STAR
# 38234                                fosmidomycin  3_STAR
#
#                                                      xref id_src          mesh
# 1304    CAS:7778-50-9 "NIST Chemistry WebBook"|PMID:14...  CHEBI  MESH:D011192
# 49834                                      LINCS:LSM-1343  CHEBI  MESH:C048833
# 20247                         CAS:91416-19-2 "ChemIDplus"  CHEBI  MESH:C058180
# 113374                                                NaN  CHEBI  MESH:D000890
# 54837   PMID:16964287 "Europe PMC"|Beilstein:7958583 "...  CHEBI  MESH:C038753
# 68051   CAS:76-44-8 "NIST Chemistry WebBook"|PMID:2457...  CHEBI  MESH:D006533
# 65164   Reaxys:1720523 "Reaxys"|PMID:23287496 "Europe ...  CHEBI  MESH:D014993
# 24422   PMID:18378269 "Europe PMC"|Drug_Central:4193 "...  CHEBI  MESH:C034759
# 55727   Drug_Central:3174 "DrugCentral"|PMID:18638380 ...  CHEBI  MESH:D015118
# 38234   PMID:16439126 "ChEMBL"|Reaxys:4133006 "Reaxys"...  CHEBI  MESH:C024640

# %%
chebi_ids = chebi['id'].unique()

# %%
len(unique_chebi_to_mesh.query('chebi not in @chebi_ids'))
# Out:
# 98

# %%
chebi_alt_ids = set(('|'.join(chebi['alt_id'].dropna().values)).split('|'))
# Any duplicated Alt-Ids?
len(chebi_alt_ids) != len(('|'.join(chebi['alt_id'].dropna().values)).split('|'))
# Out:
# False

# %%
len(chebi_alt_ids)
# Out:
# 18332

# %%
unique_chebi_to_mesh.query('chebi not in @chebi_ids and chebi not in @chebi_alt_ids')
# Out:
#               chebi                                     item  \
# 538    CHEBI:231177   http://www.wikidata.org/entity/Q426269
# 778    CHEBI:609247   http://www.wikidata.org/entity/Q421809
# 825   CHEBI:1201724   http://www.wikidata.org/entity/Q241516
# 1517   CHEBI:355377   http://www.wikidata.org/entity/Q834660
# 1577   CHEBI:200929   http://www.wikidata.org/entity/Q425838
# 2616   CHEBI:553487  http://www.wikidata.org/entity/Q5404861
# 2976    CHEBI:88619   http://www.wikidata.org/entity/Q113820
# 3109   CHEBI:345108  http://www.wikidata.org/entity/Q6015692
# 3243  CHEBI:1201185  http://www.wikidata.org/entity/Q1707877
# 5070   CHEBI:518452   http://www.wikidata.org/entity/Q945537
#
#                                               itemLabel          mesh
# 538                                Ethyl biscoumacetate  MESH:D005017
# 778   O-ethyl S-2-diisopropylaminoethyl methylphosph...  MESH:C009680
# 825                                     Povidone-iodine  MESH:D011206
# 1517                                         bopindolol  MESH:C036007
# 1577                                         bupranolol  MESH:D002046
# 2616                                          etozoline  MESH:C015208
# 2976                                     heptyl alcohol  MESH:D019850
# 3109                                         indanidine  MESH:C034204
# 3243                                         lanreotide  MESH:C060347
# 5070                                          tofisopam  MESH:C012582

# %%
alt_to_standard_chebi = chebi.dropna(subset=['alt_id']).set_index('alt_id')['id'].to_dict()

# %%
alt_to_standard_chebi = {k: v for ks, v in alt_to_standard_chebi.items() for k in ks.split('|') }
len(alt_to_standard_chebi)
# Out:
# 18332

# %%
more_chebi_to_mesh = (unique_chebi_to_mesh.query('chebi not in @chebi_ids')
                      .set_index('mesh')['chebi']
                      .map(alt_to_standard_chebi)
                      .dropna()
                      .to_dict())
more_chebi_to_mesh = {v: k for k, v in more_chebi_to_mesh.items()}

# %%
len(more_chebi_to_mesh)
# Out:
# 88

# %%
before = chebi['mesh'].count()
before
# Out:
# 3933

# %%
chebi['mesh'] = chebi['mesh'].fillna(chebi['id'].map(more_chebi_to_mesh))
after = chebi['mesh'].count()
after - before
# Out:
# 88

# %% [markdown]
# All 88 alt ids were assigned...

# %% [markdown]
# ### The 706 Chebi items that have multiple chebi ids...

# %%
chebi_duped.head(2)
# Out:
#           chebi                                    item      itemLabel  \
# 34    CHEBI:336  http://www.wikidata.org/entity/Q410215  (R)-amygdalin
# 35  CHEBI:17019  http://www.wikidata.org/entity/Q410215  (R)-amygdalin
#
#             mesh
# 34  MESH:D000678
# 35  MESH:D000678

# %%
chebi_duped['item'].nunique()
# Out:
# 329

# %%
chebi_duped['new_chebi'] = chebi_duped['chebi'].map(alt_to_standard_chebi)
chebi_duped['new_chebi'].count()
# Out:
# 329

# %%
chebi_duped['new_chebi'] = chebi_duped['new_chebi'].fillna(chebi_duped['chebi'])
chebi_duped['new_chebi'].nunique()
# Out:
# 409

# %% [markdown]
# Still more chebi ids than wikidata items...

# %%
in_ontology = pd.merge(chebi_duped, chebi, how='inner', left_on='new_chebi', right_on='id')
in_ontology['new_chebi'].nunique(), in_ontology['item'].nunique()
# Out:
# (409, 329)

# %% [markdown]
# All can be mapped to the ontology!

# %%
in_ontology.drop_duplicates(subset=['new_chebi', 'item', 'mesh_x']).nunique()
# Out:
# chebi          410
# item           329
# itemLabel      329
# mesh_x         328
# new_chebi      409
# alt_id         329
# def            360
# ikey           336
# id             409
# is_obsolete      1
# name           409
# subset           2
# xref           377
# id_src           1
# mesh_y           2
# dtype: int64

# %%
in_ontology = in_ontology.drop_duplicates(subset=['new_chebi', 'item', 'mesh_x'])

# %%
new_1t1 = (in_ontology.drop_duplicates(subset=['mesh_x'], keep=False)
                .drop_duplicates(subset=['new_chebi'], keep=False))
len(new_1t1)
# Out:
# 250

# %%
more_chebi_to_mesh = new_1t1.set_index('new_chebi')['mesh_x'].to_dict()

# %% [markdown]
# These may be legitimate one-to-many Chebi to mesh relationships... MeSH is less specific than Chebi in some instances...
#
# We'll sample some

# %%
# See some duplicated MeSH IDs for some unique CHEBI IDs...
duped = in_ontology[in_ontology['mesh_x'].duplicated()]['mesh_x'].sample(10).values
in_ontology.query('mesh_x in @duped').sort_values('mesh_x')[['itemLabel', 'name', 'mesh_x', 'id']]
# Out:
#                            itemLabel  \
# 535                    phenothiazine
# 534                    phenothiazine
# 447                   levulinic acid
# 446                   levulinic acid
# 386                    glucaric acid
# 387                    glucaric acid
# 388                    glucaric acid
# 419                        ibuprofen
# 418                        ibuprofen
# 441                          krypton
# 440                          krypton
# 51                         D-mannose
# 52                         D-mannose
# 561                        queuosine
# 562                        queuosine
# 582  reverse-transcriptase inhibitor
# 583  reverse-transcriptase inhibitor
# 257                  clavulanic acid
# 255                  clavulanic acid
# 61                     DL-methionine
# 60                     DL-methionine
#
#                                                   name        mesh_x  \
# 535                                      phenothiazine  MESH:C031637
# 534                                  10H-phenothiazine  MESH:C031637
# 447                                4-oxopentanoic acid  MESH:C032246
# 446                                       valeric acid  MESH:C032246
# 386                                      glucarate(2-)  MESH:D005937
# 387                                    D-glucaric acid  MESH:D005937
# 388                                      glucaric acid  MESH:D005937
# 419                                          ibuprofen  MESH:D007052
# 418                                       dexibuprofen  MESH:D007052
# 441                                         krypton(0)  MESH:D007726
# 440                                       krypton atom  MESH:D007726
# 51                                             mannose  MESH:D008358
# 52                                     D-mannopyranose  MESH:D008358
# 561                                  queuosine residue  MESH:D009704
# 562                                          queuosine  MESH:D009704
# 582  EC 2.7.7.49 (RNA-directed DNA polymerase) inhi...  MESH:D018894
# 583  EC 3.1.26.13 (retroviral ribonuclease H) inhib...  MESH:D018894
# 257                                        clavulanate  MESH:D019818
# 255                                    clavulanic acid  MESH:D019818
# 61                                          methionine  MESH:D064697
# 60                                        L-methionine  MESH:D064697
#
#                id
# 535   CHEBI:37932
# 534   CHEBI:37931
# 447   CHEBI:45630
# 446   CHEBI:17418
# 386   CHEBI:30613
# 387   CHEBI:16002
# 388   CHEBI:17301
# 419    CHEBI:5855
# 418   CHEBI:43415
# 441   CHEBI:49695
# 440   CHEBI:49696
# 51    CHEBI:37684
# 52     CHEBI:4208
# 561   CHEBI:64299
# 562   CHEBI:60193
# 582   CHEBI:59897
# 583   CHEBI:52629
# 257  CHEBI:487869
# 255   CHEBI:48947
# 61    CHEBI:16811
# 60    CHEBI:16643

# %% [markdown]
# We'll keep this one to many relationship...

# %%
found = list(more_chebi_to_mesh.keys())
more_chebi_to_mesh.update(in_ontology.query('new_chebi not in @found')
                                     .drop_duplicates(subset=['new_chebi'], keep=False)
                                     .set_index('new_chebi')['mesh_x']
                                     .to_dict())

# %%
# Examine where chebi ids are duplicated.... (but potentially uniqe items or mesh_ids...)
(in_ontology[in_ontology['new_chebi'].duplicated(keep=False)]   
 .sort_values('new_chebi')[['itemLabel', 'name', 'new_chebi', 'mesh_x', 'item']])
# Out:
#            itemLabel             name    new_chebi        mesh_x  \
# 53  DL-ascorbic acid  L-ascorbic acid  CHEBI:29073  MESH:D001205
# 54         vitamin C  L-ascorbic acid  CHEBI:29073  MESH:D001205
#
#                                       item
# 53  http://www.wikidata.org/entity/Q193598
# 54  http://www.wikidata.org/entity/Q199678

# %% [markdown]
# - Vitamin C and asorbic acid are same... don't know why wikidata consideres them different...
#
# - Insoine
#     - D007288 - Correct...
#     - D007292	Inosine Nucleotides
#
# - Guanidine
#     - D019791 is correct
#     - D006146 is the class of compounds.... (Guanidines)

# %%
more_chebi_to_mesh['CHEBI:29073'] = 'MESH:D001205'
more_chebi_to_mesh['CHEBI:42820'] = 'MESH:D019791'
more_chebi_to_mesh['CHEBI:17596'] = 'MESH:D007288'

# %%
len(more_chebi_to_mesh)
# Out:
# 409

# %%
before = chebi['mesh'].count()
before
# Out:
# 4021

# %%
chebi['mesh'] = chebi['mesh'].fillna(chebi['id'].map(more_chebi_to_mesh))
after = chebi['mesh'].count()
after - before
# Out:
# 407

# %% [markdown]
# 2 Didn't map, but for now we're about as good was we can get from WikiData

# %%
chebi.dropna(subset=['mesh']).sample(20)
# Out:
#                                                    alt_id  \
# 48500                             CHEBI:47611|CHEBI:31284
# 87036                                                 NaN
# 82648                                        CHEBI:619601
# 100577                                                NaN
# 22855                                                 NaN
# 113383                                                NaN
# 22525   CHEBI:45079|CHEBI:44885|CHEBI:6282|CHEBI:21370...
# 52170                                                 NaN
# 24126                                                 NaN
# 49807                                                 NaN
# 82650                                         CHEBI:74488
# 22467                  CHEBI:14029|CHEBI:23406|CHEBI:3910
# 112191                                                NaN
# 84164                                                 NaN
# 19408                                                 NaN
# 24137                                                 NaN
# 17444                                        CHEBI:101354
# 113023                                                NaN
# 35201                                                 NaN
# 72883                                                 NaN
#
#                                                       def  \
# 48500   "A monocarboxylic acid amide obtained by the f...
# 87036   "A nucleobase-containing molecular entity with...
# 82648   "A pyrimidine 2',3'-dideoxyribonucleoside comp...
# 100577                                                NaN
# 22855   "A carboxamide resulting from the formal conde...
# 113383  "A loosely defined grouping of drugs that have...
# 22525             "The L-enantiomer of phenylalanine." []
# 52170                                                 NaN
# 24126   "A quinoline-based antimycobacterial drug used...
# 49807   "A thienothiazine-derived monocarboxylic acid ...
# 82650   "A pyrimidine 5'-deoxyribonucleoside that is 5...
# 22467   "A lactam obtained by formal cyclocondensation...
# 112191  "A hormone that stimulates or controls the dev...
# 84164                                                 NaN
# 19408   "A clathrate complex consisting of a lipid enw...
# 24137   "An aromatic ether that is the 2,4-dichlorophe...
# 17444   "A  propanolamine that is 3-aminopropane-1,2-d...
# 113023  "A substance used for its pharmacological acti...
# 35201   "A phosphonic ester that is dimethyl phosphona...
# 72883   "Any steroid lactone that is a  C23 steroid wi...
#
#                                ikey           id  is_obsolete  \
# 48500   IIBYAHWJQTYFKB-UHFFFAOYSA-N  CHEBI:47612        False
# 87036                           NaN   CHEBI:7754        False
# 82648   HBOMLICNUCNMMY-XLPZGREQSA-N  CHEBI:10110        False
# 100577  RFCWHQNNCOJYTR-IRCAEPKSSA-N   CHEBI:9414        False
# 22855   VVSLYIKSEBPRSN-PELKAZGASA-N  CHEBI:83601        False
# 113383                          NaN  CHEBI:35471        False
# 22525   COLNVLDHVKWLRT-QMMMGPOBSA-N  CHEBI:17295        False
# 52170   BDYYDXJSHYEDGB-UHFFFAOYSA-N   CHEBI:4601        False
# 24126   QUIJNHUBAXPXFS-XLJNKUFUSA-N  CHEBI:72292        False
# 49807   LZNWYQJJBLGYLT-UHFFFAOYSA-N  CHEBI:32192        False
# 82650   ZWAOHEXOSAUJHY-ZIYNGMLESA-N  CHEBI:31521        False
# 22467   DDRJAANPRJIHGJ-UHFFFAOYSA-N  CHEBI:16737        False
# 112191                          NaN  CHEBI:50114        False
# 84164   DXPOSRCHIDYWHW-UHFFFAOYSA-N  CHEBI:10055        False
# 19408                           NaN   CHEBI:6495        False
# 24137   BTFHLQRNAMSNLC-UHFFFAOYSA-N   CHEBI:3763        False
# 17444   NWIUTZDMDHAVTP-UHFFFAOYSA-N   CHEBI:3082        False
# 113023                          NaN  CHEBI:35942        False
# 35201   NFACJZMKEDPNKN-UHFFFAOYSA-N   CHEBI:6908        False
# 72883                           NaN  CHEBI:74634        False
#
#                           name  subset  \
# 48500              bezafibrate  3_STAR
# 87036          oligonucleotide  3_STAR
# 82648               zidovudine  3_STAR
# 100577              Tautomycin  2_STAR
# 22855          benthiavalicarb  3_STAR
# 113383       psychotropic drug  3_STAR
# 22525          L-phenylalanine  3_STAR
# 52170       Diloxanide furoate  2_STAR
# 24126              bedaquiline  3_STAR
# 49807                tenoxicam  3_STAR
# 82650            doxifluridine  3_STAR
# 22467               creatinine  3_STAR
# 112191                estrogen  3_STAR
# 84164                Xamoterol  2_STAR
# 19408              lipoprotein  3_STAR
# 24137               clorgyline  3_STAR
# 17444                betaxolol  3_STAR
# 113023  neurotransmitter agent  3_STAR
# 35201              trichlorfon  3_STAR
# 72883             cardenolides  3_STAR
#
#                                                      xref id_src  \
# 48500   Reaxys:4267656 "Reaxys"|Drug_Central:362 "Drug...  CHEBI
# 87036                                                 NaN  CHEBI
# 82648   MetaCyc:CPD-15110|DrugBank:DB00495|Beilstein:7...  CHEBI
# 100577  KNApSAcK:C00017872|CAS:109946-35-2 "KEGG COMPO...  CHEBI
# 22855   CAS:413615-35-7 "Alan Wood's Pesticides"|Reaxy...  CHEBI
# 113383                        Wikipedia:Psychotropic_drug  CHEBI
# 22525   PMID:22143120 "Europe PMC"|PMID:22209218 "Euro...  CHEBI
# 52170   CAS:3736-81-0 "KEGG COMPOUND"|KEGG:C07637|Drug...  CHEBI
# 24126   CAS:843663-66-1 "ChemIDplus"|Wikipedia:Bedaqui...  CHEBI
# 49807   KEGG:D01767|PMID:23340327 "Europe PMC"|Wikiped...  CHEBI
# 82650   Reaxys:890191 "Reaxys"|CAS:3094-09-5 "KEGG COM...  CHEBI
# 22467   PMID:11256540 "Europe PMC"|PMID:17422601 "Euro...  CHEBI
# 112191                                 Wikipedia:Estrogen  CHEBI
# 84164   KEGG:C11775|Drug_Central:2848 "DrugCentral"|KE...  CHEBI
# 19408                                         KEGG:C01834  CHEBI
# 24137   CAS:17780-72-2 "KEGG COMPOUND"|LINCS:LSM-5808|...  CHEBI
# 17444   CAS:63659-18-7 "ChemIDplus"|Reaxys:1991268 "Re...  CHEBI
# 113023                                                NaN  CHEBI
# 35201   Wikipedia:Metrifonate|KEGG:D00805|KEGG:C07971|...  CHEBI
# 72883                                                 NaN  CHEBI
#
#                    mesh
# 48500      MESH:D001629
# 87036      MESH:D009841
# 82648      MESH:D015215
# 100577     MESH:C053079
# 22855   MESH:C000611525
# 113383     MESH:D011619
# 22525      MESH:D010649
# 52170      MESH:C004932
# 24126      MESH:C493870
# 49807      MESH:C032801
# 82650      MESH:C025034
# 22467      MESH:D003404
# 112191     MESH:D004967
# 84164      MESH:D017307
# 19408      MESH:D008074
# 24137      MESH:D003010
# 17444      MESH:D015784
# 113023     MESH:D018377
# 35201      MESH:D014236
# 72883      MESH:D002298

# %% [markdown]
# # Look at previous MyChem Results...

# %%
ref_comps.head(2)
# Out:
#   chebi_id     chembl_id drugbank_id                         ikey  \
# 0      NaN  CHEMBL543295         NaN  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1      NaN  CHEMBL284907         NaN  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#         mesh_id                   name                            q  \
# 0           NaN  A-49816 hydrochloride  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1  MESH:C013876              Elmustine  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#       unii_id                           id source
# 0  8GKF50WX7S  WYFYYAHANZQLGG-UHFFFAOYSA-N   ikey
# 1  NAT2FD82D7  YJZJEQBSODVMTH-UHFFFAOYSA-N   ikey

# %%
prev_comps.head(2)
# Out:
#              id                     name     label  \
# 0  MESH:C046983  06-Paris-LA-66 protocol  Compound
# 1  MESH:C534883                 10074-G5  Compound
#
#                                         tree_numbers drug_bank_ids  \
# 0  D02.455.426.559.847.562.050.200/C046983|D03.13...           NaN
# 1                        D03.383.129.462.580/C534883           NaN
#
#   alt_disease_ids gene_symbol alt_gene_ids bio_gridids pharm_gkbids  \
# 0             NaN         NaN          NaN         NaN          NaN
# 1             NaN         NaN          NaN         NaN          NaN
#
#   uni_prot_ids uniprot_id mesh_ids chebi_ids
# 0          NaN        NaN      NaN       NaN
# 1          NaN        NaN      NaN       NaN

# %%
ix_comps.head(2)
# Out:
#                             id               name     label     chebi_id  \
# 0  FZERHIULMFGESH-UHFFFAOYSA-N        Acetanilide  Compound  CHEBI:28884
# 1  SWMPGCCDXNLPED-NSCUHMNNSA-N  Acetylfuratrizine  Compound          NaN
#
#       chembl_id drugbank_id                         ikey       mesh_id  \
# 0  CHEMBL269644         NaN  FZERHIULMFGESH-UHFFFAOYSA-N  MESH:C508827
# 1           NaN         NaN  SWMPGCCDXNLPED-NSCUHMNNSA-N  MESH:C005910
#
#       unii_id source
# 0  SP86R356CC   ikey
# 1  C50C4V19SU   ikey

# %%
prev_comps.dropna(subset=['chebi_ids']).head(10)
# Out:
#                id                                               name  \
# 30   MESH:C034152                       11,14,17-eicosatrienoic acid
# 193  MESH:C031263                          12-hydroxydodecanoic acid
# 206  MESH:C040756                                 1,2-naphthoquinone
# 417  MESH:D019326                       17-alpha-Hydroxyprogesterone
# 422  MESH:C448659  17-(dimethylaminoethylamino)-17-demethoxygelda...
# 424  MESH:C021183                               1,7-dimethylxanthine
# 555  MESH:D015655                        1-Methyl-4-phenylpyridinium
# 570  MESH:C004981                               1,N(6)-ethenoadenine
# 654  MESH:C532162  2-(1H-indazol-4-yl)-6-(4-methanesulfonylpipera...
# 908  MESH:C005959                            2,4-diaminobutyric acid
#
#         label                                       tree_numbers  \
# 30   Compound                        D10.251.355.255.207/C034152
# 193  Compound                                D10.251.500/C031263
# 206  Compound  D02.455.426.559.847.638.721/C040756|D02.806.55...
# 417  Compound  D04.210.500.745.745.654.829.395.400|D06.472.33...
# 422  Compound  D02.065.589.327/C448659|D02.806.250/C448659|D0...
# 424  Compound  D03.132.960.751/C021183|D03.633.100.759.758.82...
# 555  Compound                                D03.383.725.762.550
# 570  Compound                        D03.633.100.759.138/C004981
# 654  Compound  D02.065.884/C532162|D02.886.590.700/C532162|D0...
# 908  Compound                        D02.241.081.114.500/C005959
#
#     drug_bank_ids alt_disease_ids gene_symbol alt_gene_ids bio_gridids  \
# 30            NaN             NaN         NaN          NaN         NaN
# 193       DB03704             NaN         NaN          NaN         NaN
# 206           NaN             NaN         NaN          NaN         NaN
# 417       DB14570             NaN         NaN          NaN         NaN
# 422       DB12442             NaN         NaN          NaN         NaN
# 424           NaN             NaN         NaN          NaN         NaN
# 555           NaN             NaN         NaN          NaN         NaN
# 570       DB01952             NaN         NaN          NaN         NaN
# 654       DB11663             NaN         NaN          NaN         NaN
# 908       DB03817             NaN         NaN          NaN         NaN
#
#     pharm_gkbids uni_prot_ids uniprot_id mesh_ids    chebi_ids
# 30           NaN          NaN        NaN      NaN  CHEBI:53460
# 193          NaN          NaN        NaN      NaN  CHEBI:39567
# 206          NaN          NaN        NaN      NaN  CHEBI:34055
# 417          NaN          NaN        NaN      NaN  CHEBI:17252
# 422          NaN          NaN        NaN      NaN  CHEBI:65324
# 424          NaN          NaN        NaN      NaN  CHEBI:25858
# 555          NaN          NaN        NaN      NaN    CHEBI:641
# 570          NaN          NaN        NaN      NaN  CHEBI:29146
# 654          NaN          NaN        NaN      NaN  CHEBI:65326
# 908          NaN          NaN        NaN      NaN  CHEBI:48950

# %%
col_map = {'chebi_ids':'chebi_id', 'id': 'mesh_id', 'drug_bank_ids': 'drugbank_id'}
cs = ['chebi_id', 'mesh_id', 'drugbank_id', 'name']

prev_res = pd.concat([ref_comps.dropna(subset=['chebi_id', 'mesh_id']),ix_comps.dropna(subset=['chebi_id', 'mesh_id']),
          prev_comps.dropna(subset=['chebi_ids']).rename(columns=col_map)[cs]],
          ignore_index=True, sort=False)

# %%
prev_res['chebi_id'] = prev_res['chebi_id'].apply(lambda c: '|'.join(c) if type(c) == list else c)

# %%
prev_res['mesh_id'] = prev_res['mesh_id'].apply(lambda c: '|'.join(c) if type(c) == list else c)

# %%
prev_res = expand_col_on_char(prev_res, 'chebi_id', '|')
prev_res = expand_col_on_char(prev_res, 'mesh_id', '|')

# %%
len(prev_res)
# Out:
# 9625

# %% [markdown]
# Could be some duplicates

# %%
prev_res = prev_res.drop_duplicates(subset=['chebi_id', 'mesh_id'])
len(prev_res)
# Out:
# 6789

# %%
one_2_one = prev_res.drop_duplicates(subset=['chebi_id'], keep=False).drop_duplicates(subset=['mesh_id'], keep=False)
len(one_2_one)
# Out:
# 5592

# %% [markdown]
# This means about 1200 conflicts within the 3 previous sources themselves....

# %%
chebs = set(one_2_one['chebi_id'])
len(chebi.query('id in @chebs')), chebi.query('id in @chebs')['mesh'].count()
# Out:
# (5591, 2313)

# %%
c2m_dict = one_2_one.set_index('chebi_id')['mesh_id'].to_dict()

# %% [markdown]
# ### With different sources for the mapping, there may be some conflict here...

# %%
idx = (chebi.query('id in @chebs').dropna(subset=['mesh'])['id'].map(c2m_dict) != 
     chebi.query('id in @chebs').dropna(subset=['mesh'])['mesh'])
idx.sum()
# Out:
# 35

# %%
idx = idx[idx].index
conflict = chebi.loc[idx]
conflict['other_mesh'] = conflict['id'].map(c2m_dict)

# %%
import pickle
# Previously parsed MeSH XML dump in semmed repo to get a MeSH ID to Name Map...
# See https://github.com/mmayers12/semmed/blob/master/prepare/04-Parse_MeSH_data.ipynb
# Which can be run entirely indpendently from the rest of the repo.
m2name = pickle.load(open('../../semmed/data/MeSH_DescUID_to_Name.pkl', 'rb'))

# %%
conflict['mesh_name'] = conflict['mesh'].apply(lambda m: m2name.get(m.split(':')[1], float('nan')))
conflict['other_mesh_name'] = conflict['other_mesh'].apply(lambda m: m2name.get(m.split(':')[1], float('nan')))

confl_col = ['id', 'name', 'mesh', 'mesh_name', 'other_mesh', 'other_mesh_name']
conflict[confl_col]
# Out:
#                  id                       name             mesh  \
# 47      CHEBI:63020           yttrium chloride     MESH:D015019
# 891      CHEBI:8389     estrone sodium sulfate     MESH:D004966
# 12857   CHEBI:90960                 tiotropium  MESH:D000069447
# 14335   CHEBI:70839      dasatinib monohydrate  MESH:D000069439
# 15028   CHEBI:40538                benzylamine     MESH:D001596
# 17951   CHEBI:34543                argipressin     MESH:D001127
# 20346   CHEBI:70752                 dabigatran  MESH:D000069604
# 21748   CHEBI:18089           N-benzoylglycine     MESH:D006626
# 24656   CHEBI:85260               spiramycin I     MESH:D015572
# 24681   CHEBI:87346  acridine orange free base     MESH:D000165
# 34724   CHEBI:44215             NAD zwitterion     MESH:D038961
# 49311   CHEBI:46936                 nonivamide     MESH:C040937
# 53554   CHEBI:36595         succinic anhydride     MESH:D013387
# 56083   CHEBI:17418               valeric acid     MESH:C032246
# 56708   CHEBI:43415               dexibuprofen     MESH:D007052
# 58356   CHEBI:32374      trans-4-coumaric acid     MESH:C495469
# 60049   CHEBI:28324           11-deoxycortisol     MESH:D003350
# 60176    CHEBI:8116                    phorbol     MESH:D010703
# 60354   CHEBI:17327                     phytol     MESH:D010836
# 62165   CHEBI:27810                 resorcinol     MESH:D012118
# 63253   CHEBI:18145       (+)-alpha-tocopherol     MESH:D024502
# 65212   CHEBI:30742            ethylene glycol     MESH:D005026
# 66520    CHEBI:5134                fluticasone  MESH:D000068298
# 67260   CHEBI:27789         1,2-dichloroethane     MESH:D005025
# 67342   CHEBI:16598                        DDE     MESH:D003633
# 67557   CHEBI:36404                cyclohexene     MESH:D053138
# 68130   CHEBI:51687                   chrysene     MESH:D002911
# 70006   CHEBI:16226                    limonin     MESH:D036701
# 70361   CHEBI:10362         beta-cryptoxanthin  MESH:D000072743
# 71300   CHEBI:16898                 pyrimidine     MESH:D011742
# 76299   CHEBI:34876   N-Phenyl-1-naphthylamine     MESH:C005444
# 80018   CHEBI:22154               acenaphthene     MESH:D000073
# 100441  CHEBI:18067              phylloquinone     MESH:D010837
# 100544  CHEBI:36610           acetic anhydride     MESH:D000089
# 110299  CHEBI:31941                oxaliplatin     MESH:C030110
#
#                                           mesh_name       other_mesh  \
# 47                                          Yttrium     MESH:C064782
# 891                     Estrogens, Conjugated (USP)     MESH:C017296
# 12857                            Tiotropium Bromide     MESH:C079890
# 14335                                     Dasatinib     MESH:C488369
# 15028                                  Benzylamines     MESH:C030796
# 17951                          Arginine Vasopressin     MESH:C016671
# 20346                                    Dabigatran     MESH:C554682
# 21748                                    Hippurates     MESH:C030514
# 24656                                    Spiramycin     MESH:C017186
# 24681                               Acridine Orange     MESH:C019380
# 34724                           O-Acetyl-ADP-Ribose     MESH:D009243
# 49311                                    nonivamide     MESH:C005871
# 53554                           Succinic Anhydrides     MESH:C031801
# 56083                                levulinic acid     MESH:C038780
# 56708                                     Ibuprofen     MESH:C539402
# 58356   trans-3-(4'-hydroxyphenyl)-2-propenoic acid     MESH:C032171
# 60049                                   Cortodoxone     MESH:C058175
# 60176                                Phorbol Esters     MESH:C033085
# 60354                                        Phytol     MESH:C494251
# 62165                                   Resorcinols     MESH:C031389
# 63253                              alpha-Tocopherol     MESH:D014810
# 65212                              Ethylene Glycols     MESH:D019855
# 66520                                   Fluticasone     MESH:C065382
# 67260                          Ethylene Dichlorides     MESH:C024565
# 67342             Dichlorodiphenyl Dichloroethylene     MESH:C017175
# 67557                                  Cyclohexenes     MESH:C052568
# 68130                                     Chrysenes     MESH:C031180
# 70006                                      Limonins     MESH:C001546
# 70361                            Beta-Cryptoxanthin     MESH:C010564
# 71300                        Pyrimidine Nucleotides     MESH:C030986
# 76299                      N-phenyl-1-naphthylamine     MESH:C466319
# 80018                                 Acenaphthenes     MESH:C042552
# 100441                                  Vitamin K 1     MESH:D014812
# 100544                            Acetic Anhydrides     MESH:C031800
# 110299                                  oxaliplatin  MESH:D000077150
#
#                other_mesh_name
# 47            yttrium chloride
# 891            estrone sulfate
# 12857                      NaN
# 14335                      NaN
# 15028              benzylamine
# 17951        pitressin tannate
# 20346                      NaN
# 21748            hippuric acid
# 24656   demycarosylturimycin H
# 24681                      NaN
# 34724                      NAD
# 49311    vanillyl-N-nonylamide
# 53554       succinic anhydride
# 56083         n-pentanoic acid
# 56708             dexibuprofen
# 58356                      NaN
# 60049                 cortifen
# 60176                  phorbol
# 60354             trans-phytol
# 62165               resorcinol
# 63253                Vitamin E
# 65212          Ethylene Glycol
# 66520                      NaN
# 67260      ethylene dichloride
# 67342                      NaN
# 67557              cyclohexene
# 68130                 chrysene
# 70006                  limonin
# 70361                      NaN
# 71300               pyrimidine
# 76299    1-naphthylphenylamine
# 80018             acenaphthene
# 100441               Vitamin K
# 100544        acetic anhydride
# 110299                     NaN

# %%
# String Matching or one fo the names didn't map...
keep_mesh = conflict['name'].str.lower() == conflict['mesh_name'].str.lower()
keep_mesh = keep_mesh | conflict['other_mesh_name'].isnull()

# %%
# String Matching
keep_other = conflict['name'].str.lower() == conflict['other_mesh_name'].str.lower()

# %%
# ensure both IDs didn't pass the test...
(keep_mesh & keep_other).sum() == 0
# Out:
# True

# %%
c2m_dict.update(conflict[keep_mesh].set_index('id')['mesh'].to_dict())
c2m_dict.update(conflict[keep_other].set_index('id')['other_mesh'].to_dict())

# %%
# how many more conflicts to resolve?
(~(keep_mesh | keep_other)).sum()
# Out:
# 10

# %%
conflict[~(keep_mesh | keep_other)][confl_col]
# Out:
#                  id                    name          mesh  \
# 891      CHEBI:8389  estrone sodium sulfate  MESH:D004966
# 17951   CHEBI:34543             argipressin  MESH:D001127
# 21748   CHEBI:18089        N-benzoylglycine  MESH:D006626
# 24656   CHEBI:85260            spiramycin I  MESH:D015572
# 34724   CHEBI:44215          NAD zwitterion  MESH:D038961
# 56083   CHEBI:17418            valeric acid  MESH:C032246
# 60049   CHEBI:28324        11-deoxycortisol  MESH:D003350
# 63253   CHEBI:18145    (+)-alpha-tocopherol  MESH:D024502
# 67260   CHEBI:27789      1,2-dichloroethane  MESH:D005025
# 100441  CHEBI:18067           phylloquinone  MESH:D010837
#
#                           mesh_name    other_mesh         other_mesh_name
# 891     Estrogens, Conjugated (USP)  MESH:C017296         estrone sulfate
# 17951          Arginine Vasopressin  MESH:C016671       pitressin tannate
# 21748                    Hippurates  MESH:C030514           hippuric acid
# 24656                    Spiramycin  MESH:C017186  demycarosylturimycin H
# 34724           O-Acetyl-ADP-Ribose  MESH:D009243                     NAD
# 56083                levulinic acid  MESH:C038780        n-pentanoic acid
# 60049                   Cortodoxone  MESH:C058175                cortifen
# 63253              alpha-Tocopherol  MESH:D014810               Vitamin E
# 67260          Ethylene Dichlorides  MESH:C024565     ethylene dichloride
# 100441                  Vitamin K 1  MESH:D014812               Vitamin K

# %%
# Searched names in MeSH Browser to find best fit...
c2m_dict['CHEBI:8389'] = 'MESH:C017296'
c2m_dict['CHEBI:34543'] = 'MESH:D001127'
c2m_dict['CHEBI:18089'] = 'MESH:C030514'
c2m_dict['CHEBI:85260'] = 'MESH:C017186'
c2m_dict['CHEBI:44215'] = 'MESH:D009243'
c2m_dict['CHEBI:17418'] = 'MESH:C038780'
c2m_dict['CHEBI:28324'] = 'MESH:D003350'
c2m_dict['CHEBI:18145'] = 'MESH:D024502'
c2m_dict['CHEBI:27789'] = 'MESH:C024565'
c2m_dict['CHEBI:18067'] = 'MESH:D010837'

# %%
prev_map = chebi.dropna(subset=['mesh']).set_index('id')['mesh'].to_dict()
# update with latest mappings...
c2m_dict = {**prev_map, **c2m_dict}
chebi['mesh'] = chebi['id'].map(c2m_dict)

# %%
chebi['mesh'].count()
# Out:
# 7706

# %%
# use this now as our final map, and update directly...
c2m_dict = {**prev_map, **c2m_dict}

# %% [markdown]
# ### Now look at the duplicates in the compiled set...

# %%
# Multiple mesh for a single chebi...
ix = prev_res['chebi_id'].duplicated(keep=False)
ix = ix[ix].index
mult_mesh = prev_res.loc[ix]
len(mult_mesh)
# Out:
# 635

# %%
mult_mesh['mesh_name'] = mult_mesh['mesh_id'].apply(lambda m: m2name.get(m.split(':')[1], float('nan')))
mult_mesh['cheb_name'] = mult_mesh['chebi_id'].map(chebi.set_index('id')['name'].to_dict())

mult_mesh[['chebi_id', 'mesh_id', 'name', 'mesh_name', 'cheb_name']].head(10)
# Out:
#        chebi_id          mesh_id          name  \
# 8   CHEBI:53760  MESH:D000069582   Eszopiclone
# 9   CHEBI:53760     MESH:C515051   Eszopiclone
# 19  CHEBI:31348     MESH:C110904  Capecitabine
# 20  CHEBI:31348  MESH:D000069287  Capecitabine
# 55  CHEBI:90943  MESH:C000603933   Osimertinib
# 56  CHEBI:90943  MESH:C000596361   Osimertinib
# 70  CHEBI:63452     MESH:C059539   Midostaurin
# 71  CHEBI:63452     MESH:C411007   Midostaurin
# 74  CHEBI:73286     MESH:C084956  Piclidenoson
# 75  CHEBI:73286     MESH:C478920  Piclidenoson
#
#                                             mesh_name  \
# 8                                         Eszopiclone
# 9                                                 NaN
# 19                                                NaN
# 20                                       Capecitabine
# 55                                        osimertinib
# 56                                            AZD9291
# 70                                        midostaurin
# 71                                                NaN
# 74  N(6)-(3-iodobenzyl)-5'-N-methylcarboxamidoaden...
# 75                                              CF101
#
#                                        cheb_name
# 8                                    eszopiclone
# 9                                    eszopiclone
# 19                                  capecitabine
# 20                                  capecitabine
# 55                                   osimertinib
# 56                                   osimertinib
# 70                                   midostaurin
# 71                                   midostaurin
# 74  3-iodobenzyl-5'-N-methylcarboxamidoadenosine
# 75  3-iodobenzyl-5'-N-methylcarboxamidoadenosine

# %%
# First, name-matching between chebi and mesh...
ix = mult_mesh['mesh_name'].str.lower() == mult_mesh['cheb_name'].str.lower()
ix.sum(), mult_mesh['chebi_id'].nunique(), mult_mesh[ix]['chebi_id'].nunique()
# Out:
# (195, 307, 195)

# %% [markdown]
# Got about 2/3 of the total chebi id's resolved by this method...

# %%
c2m_dict.update(mult_mesh[ix].set_index('chebi_id')['mesh_id'].to_dict())

# %%
# Next, name matching between mesh name and the accepted name from MYCHEM...
remain_mult_mesh = mult_mesh.loc[ix[~ix].index]
ix = remain_mult_mesh['mesh_name'].str.lower() == remain_mult_mesh['name'].str.lower()
ix.sum(), remain_mult_mesh['chebi_id'].nunique(), remain_mult_mesh[ix]['chebi_id'].nunique()
# Out:
# (64, 307, 64)

# %% [markdown]
# looks like another 64... so we've got maybe 50 more to resolve...?

# %%
c2m_dict.update(remain_mult_mesh[ix].set_index('chebi_id')['mesh_id'].to_dict())

# %%
curr_cheb_ids = list(c2m_dict.keys())
mult_mesh.query('chebi_id not in @curr_cheb_ids')['chebi_id'].nunique()
# Out:
# 45

# %%
mult_mesh.query('chebi_id not in @curr_cheb_ids')[['chebi_id', 'mesh_id', 'name', 'mesh_name', 'cheb_name']].head(10)
# Out:
#         chebi_id          mesh_id          name  \
# 74   CHEBI:73286     MESH:C084956  Piclidenoson
# 75   CHEBI:73286     MESH:C478920  Piclidenoson
# 251  CHEBI:63115  MESH:D000068876    Fingolimod
# 252  CHEBI:63115     MESH:C098720    Fingolimod
# 255  CHEBI:70735  MESH:D000069056    Lurasidone
# 256  CHEBI:70735     MESH:C525644    Lurasidone
# 280  CHEBI:40237     MESH:C496398   Sitagliptin
# 281  CHEBI:40237  MESH:D000068900   Sitagliptin
# 310  CHEBI:87723  MESH:D000068799     Prasugrel
# 311  CHEBI:87723     MESH:C408153     Prasugrel
#
#                                              mesh_name  \
# 74   N(6)-(3-iodobenzyl)-5'-N-methylcarboxamidoaden...
# 75                                               CF101
# 251                           Fingolimod Hydrochloride
# 252                                                NaN
# 255                           Lurasidone Hydrochloride
# 256                                                NaN
# 280                                                NaN
# 281                              Sitagliptin Phosphate
# 310                            Prasugrel Hydrochloride
# 311                                                NaN
#
#                                              cheb_name
# 74        3-iodobenzyl-5'-N-methylcarboxamidoadenosine
# 75        3-iodobenzyl-5'-N-methylcarboxamidoadenosine
# 251                                         fingolimod
# 252                                         fingolimod
# 255                                         lurasidone
# 256                                         lurasidone
# 280                                        sitagliptin
# 281                                        sitagliptin
# 310  5-[2-cyclopropyl-1-(2-fluorophenyl)-2-oxoethyl...
# 311  5-[2-cyclopropyl-1-(2-fluorophenyl)-2-oxoethyl...

# %% [markdown]
# Still some NA values that we can use to our advantage.....

# %%
c2m_dict.update(mult_mesh.query('chebi_id not in @curr_cheb_ids')
     .dropna(subset=['mesh_name'])
     .drop_duplicates(subset=['chebi_id'], keep=False)
     .set_index('chebi_id')['mesh_id'].to_dict())

curr_cheb_ids = list(c2m_dict.keys())
mult_mesh.query('chebi_id not in @curr_cheb_ids')['chebi_id'].nunique()
# Out:
# 20

# %% [markdown]
# got us another 27 mappings...

# %%
mult_mesh.query('chebi_id not in @curr_cheb_ids').sort_values('chebi_id')[['chebi_id', 'mesh_id', 'name', 'mesh_name', 'cheb_name']]
# Out:
#           chebi_id          mesh_id                                 name  \
# 5583     CHEBI:125     MESH:C004497                            Levomenol
# 5584     CHEBI:125     MESH:C056251                            Levomenol
# 2856  CHEBI:134714  MESH:C000609743                           Sacubitril
# 2855  CHEBI:134714     MESH:C549068                           Sacubitril
# 567   CHEBI:134964     MESH:C108042                         Perflubutane
# 568   CHEBI:134964     MESH:C069727                         Perflubutane
# 1813  CHEBI:135144     MESH:C025079                          Mebhydrolin
# 1814  CHEBI:135144     MESH:C005139                          Mebhydrolin
# 3953  CHEBI:135333     MESH:C021702                           Lodoxamide
# 3952  CHEBI:135333     MESH:C022028                           Lodoxamide
# 7355  CHEBI:135611     MESH:C015163                      Benzododecinium
# 7356  CHEBI:135611     MESH:D001548                      Benzododecinium
# 2415  CHEBI:135771     MESH:C069156                           Temocapril
# 2416  CHEBI:135771     MESH:C055603                           Temocapril
# 3592  CHEBI:136009     MESH:C569381                     Levomefolic acid
# 3593  CHEBI:136009     MESH:C005984                     Levomefolic acid
# 3595   CHEBI:15641     MESH:C005984                     Levomefolic acid
# 3594   CHEBI:15641     MESH:C569381                     Levomefolic acid
# 6576   CHEBI:28064     MESH:C428983                    Keracyanin cation
# 6575   CHEBI:28064     MESH:C020386                    Keracyanin cation
# 8175   CHEBI:29021     MESH:D006586                               Hexane
# 8176   CHEBI:29021     MESH:C026385                               Hexane
# 3140   CHEBI:32596     MESH:C018392  Anhydrous dibasic calcium phosphate
# 3141   CHEBI:32596     MESH:C020243  Anhydrous dibasic calcium phosphate
# 8500   CHEBI:33128     MESH:C069837                 Buckminsterfullerene
# 8499   CHEBI:33128     MESH:D037741                 Buckminsterfullerene
# 7034   CHEBI:39115     MESH:C054159                       S-bioallethrin
# 7036   CHEBI:39115     MESH:C018465                       S-bioallethrin
# 7035   CHEBI:39115     MESH:D000487                       S-bioallethrin
# 6668    CHEBI:4753     MESH:C061212                        Echothiophate
# 6669    CHEBI:4753     MESH:D004456                        Echothiophate
# 1487   CHEBI:59888     MESH:D005680            .gamma.-aminobutyric acid
# 1486   CHEBI:59888     MESH:D000613            .gamma.-aminobutyric acid
# 3749   CHEBI:62088     MESH:D004177                           Metamizole
# 3750   CHEBI:62088     MESH:C024864                           Metamizole
# 833    CHEBI:67040     MESH:D012436                         Ademetionine
# 832    CHEBI:67040     MESH:C011501                         Ademetionine
# 75     CHEBI:73286     MESH:C478920                         Piclidenoson
# 74     CHEBI:73286     MESH:C084956                         Piclidenoson
# 1196   CHEBI:76254     MESH:C411103                          Naproxcinod
# 1197   CHEBI:76254     MESH:C094069                          Naproxcinod
# 1195   CHEBI:76254     MESH:C111751                          Naproxcinod
#
#                                               mesh_name  \
# 5583                                          bisabolol
# 5584                                         Kamillosan
# 2856                                             LBQ657
# 2855                                            LCZ 696
# 567                                     perfluorobutane
# 568                                            Sonazoid
# 1813                                          diazoline
# 1814                                       mebhydroline
# 3953                                   lodoxamide ethyl
# 3952                            lodoxamide tromethamine
# 7355                      dimethyldodecylbenzylammonium
# 7356                             Benzalkonium Compounds
# 2415                                       temocaprilat
# 2416                           temocapril hydrochloride
# 3592                               levomefolate calcium
# 3593                           5-methyltetrahydrofolate
# 3595                           5-methyltetrahydrofolate
# 3594                               levomefolate calcium
# 6576                              cyanidin 3-rutinoside
# 6575                                         keracyanin
# 8175                                            Hexanes
# 8176                                           n-hexane
# 3140                               tricalcium phosphate
# 3141                                  calcium phosphate
# 8500                                      fullerene C60
# 8499                                         Fullerenes
# 7034                                         esbiothrin
# 7036                                       bioallethrin
# 7035                                          Allethrin
# 6668                                        phospholine
# 6669                               Echothiophate Iodide
# 1487                            gamma-Aminobutyric Acid
# 1486                                     Aminobutyrates
# 3749                                           Dipyrone
# 3750                               metamizole magnesium
# 833                                S-Adenosylmethionine
# 832                               methioninyl adenylate
# 75                                                CF101
# 74    N(6)-(3-iodobenzyl)-5'-N-methylcarboxamidoaden...
# 1196                                           HCT 3012
# 1197                                      nitronaproxen
# 1195                           naproxen-n-butyl nitrate
#
#                                          cheb_name
# 5583                           (-)-alpha-Bisabolol
# 5584                           (-)-alpha-Bisabolol
# 2856                                    sacubitril
# 2855                                    sacubitril
# 567                                   perflubutane
# 568                                   perflubutane
# 1813                                   mebhydrolin
# 1814                                   mebhydrolin
# 3953                                    lodoxamide
# 3952                                    lodoxamide
# 7355                                  benzalkonium
# 7356                                  benzalkonium
# 2415                                    temocapril
# 2416                                    temocapril
# 3592                              levomefolic acid
# 3593                              levomefolic acid
# 3595                  5-methyltetrahydrofolic acid
# 3594                  5-methyltetrahydrofolic acid
# 6576                       cyanidin 3-O-rutinoside
# 6575                       cyanidin 3-O-rutinoside
# 8175                                        hexane
# 8176                                        hexane
# 3140                     calcium hydrogenphosphate
# 3141                     calcium hydrogenphosphate
# 8500                                 C60 fullerene
# 8499                                 C60 fullerene
# 7034                       (+)-trans-(S)-allethrin
# 7036                       (+)-trans-(S)-allethrin
# 7035                       (+)-trans-(S)-allethrin
# 6668                                   ecothiopate
# 6669                                   ecothiopate
# 1487            gamma-aminobutyric acid zwitterion
# 1486            gamma-aminobutyric acid zwitterion
# 3749                                    metamizole
# 3750                                    metamizole
# 833                      S-adenosyl-L-methioninate
# 832                      S-adenosyl-L-methioninate
# 75    3-iodobenzyl-5'-N-methylcarboxamidoadenosine
# 74    3-iodobenzyl-5'-N-methylcarboxamidoadenosine
# 1196                                   naproxcinod
# 1197                                   naproxcinod
# 1195                                   naproxcinod

# %%
# A few more to do by hand...
c2m_dict['CHEBI:125'] = 'MESH:C004497'
c2m_dict['CHEBI:134714'] = 'MESH:C549068'
c2m_dict['CHEBI:134964'] = 'MESH:C108042'
c2m_dict['CHEBI:135144'] = 'MESH:C005139'
c2m_dict['CHEBI:135333'] = 'MESH:C021702'
c2m_dict['CHEBI:135611'] = 'MESH:D001548'
c2m_dict['CHEBI:135771'] = 'MESH:C055603'
c2m_dict['CHEBI:136009'] = 'MESH:C005984'
c2m_dict['CHEBI:15641'] = 'MESH:C005984'
c2m_dict['CHEBI:16027'] = 'MESH:D000249'
c2m_dict['CHEBI:28064'] = 'MESH:C020386'
c2m_dict['CHEBI:29021'] = 'MESH:D006586'
c2m_dict['CHEBI:30863'] = 'MESH:D010094'
c2m_dict['CHEBI:32596'] = 'MESH:C485829'
c2m_dict['CHEBI:33128'] = 'MESH:C069837'
c2m_dict['CHEBI:39115'] = 'MESH:C018465'
c2m_dict['CHEBI:4753'] = 'MESH:C061212'
c2m_dict['CHEBI:59888'] = 'MESH:D005680'
c2m_dict['CHEBI:62088'] = 'MESH:D004177'
c2m_dict['CHEBI:67040'] = 'MESH:D012436'
c2m_dict['CHEBI:73286'] = 'MESH:C084956'
c2m_dict['CHEBI:76254'] = 'MESH:C111751'

# %% [markdown]
# #### Multiple CHEBI for a single mesh...

# %%
# Multiple chebi for a single mesh...
ix = prev_res['mesh_id'].duplicated(keep=False)
ix = ix[ix].index
mult_cheb = prev_res.loc[ix]
len(mult_cheb)
# Out:
# 772

# %%
mult_cheb['chebi_id'].nunique()
# Out:
# 746

# %%
mult_cheb_mrg = (pd.merge(mult_cheb, chebi[['id', 'name', 'ikey', 'mesh']],
                     how='left', left_on='chebi_id', right_on='id', suffixes=('', '_cheb'))
                .sort_values('mesh_id')[['chebi_id', 'name', 'name_cheb', 'mesh_id', 'mesh', 'ikey','ikey_cheb']])

# %%
mult_cheb_mrg.head(10)
# Out:
#          chebi_id                                 name  \
# 633   CHEBI:17917                             Allysine
# 632   CHEBI:58321                             Allysine
# 736   CHEBI:85005                           Anticapsin
# 737   CHEBI:84310                           Anticapsin
# 59    CHEBI:15422               Adenosine triphosphate
# 247    CHEBI:9978                           Vidarabine
# 560   CHEBI:34647  Clindamycin palmitate hydrochloride
# 561  CHEBI:135866                Clindamycin palmitate
# 41    CHEBI:58112                            Cetraxate
# 42    CHEBI:17340                            Cetraxate
#
#                                name_cheb       mesh_id          mesh  \
# 633                           L-allysine  MESH:C000061           NaN
# 632                L-allysine zwitterion  MESH:C000061           NaN
# 736                           anticapsin  MESH:C000097           NaN
# 737                anticapsin zwitterion  MESH:C000097           NaN
# 59                                   ATP  MESH:C000101  MESH:D000255
# 247               vidarabine monohydrate  MESH:C000101           NaN
# 560  Clindamycin palmitate hydrochloride  MESH:C000489           NaN
# 561                clindamycin palmitate  MESH:C000489           NaN
# 41                  cetraxate zwitterion  MESH:C000665           NaN
# 42                             cetraxate  MESH:C000665           NaN
#
#                             ikey                    ikey_cheb
# 633  GFXYTQPNNXGICT-YFKPBYRVSA-N  GFXYTQPNNXGICT-YFKPBYRVSA-N
# 632  GFXYTQPNNXGICT-YFKPBYRVSA-N  GFXYTQPNNXGICT-YFKPBYRVSA-N
# 736  KHVZXXWDPSCGEK-MGVQOFIGSA-N  KHVZXXWDPSCGEK-MGVQOFIGSA-N
# 737  KHVZXXWDPSCGEK-MGVQOFIGSA-N  KHVZXXWDPSCGEK-MGVQOFIGSA-N
# 59   ZKHQWZAMYRWXGA-KQYNXXCUSA-N  ZKHQWZAMYRWXGA-KQYNXXCUSA-N
# 247  ZTHWFVSEMLMLKT-CAMOTBBTSA-N  ZTHWFVSEMLMLKT-CAMOTBBTSA-N
# 560  GTNDZRUWKHDICY-DJHAJVGHSA-N  GTNDZRUWKHDICY-DJHAJVGHSA-N
# 561  OYSKUZDIHNKWLV-PRUAPSLNSA-N  OYSKUZDIHNKWLV-PRUAPSLNSA-N
# 41   FHRSHSOEWXUORL-HDJSIYSDSA-N  FHRSHSOEWXUORL-HDJSIYSDSA-N
# 42   FHRSHSOEWXUORL-HDJSIYSDSA-N  FHRSHSOEWXUORL-HDJSIYSDSA-N

# %% [markdown]
# Mostly looks like we have differet inoic states of the same thing... some potential conflicts though, will have to check those.

# %%
mult_cheb_mrg.tail(10)
# Out:
#          chebi_id                    name  \
# 505  CHEBI:135997        Iobenguane i-131
# 695   CHEBI:17712                Xanthine
# 694   CHEBI:48517                Xanthine
# 195    CHEBI:6129               Ketorolac
# 193   CHEBI:76223               Ketorolac
# 194   CHEBI:76223               Ketorolac
# 196    CHEBI:6129               Ketorolac
# 281    CHEBI:6130  Ketorolac tromethamine
# 768   CHEBI:18170            Selenic Acid
# 234   CHEBI:77775         Sodium selenate
#
#                                              name_cheb       mesh_id  \
# 505                                  iobenguane (131I)  MESH:D019797
# 695                                        9H-xanthine  MESH:D019820
# 694                                        7H-xanthine  MESH:D019820
# 195                                          ketorolac  MESH:D020910
# 193  5-benzoyl-2,3-dihydro-1H-pyrrolizine-1-carboxy...  MESH:D020910
# 194  5-benzoyl-2,3-dihydro-1H-pyrrolizine-1-carboxy...  MESH:D020911
# 196                                          ketorolac  MESH:D020911
# 281                             ketorolac tromethamine  MESH:D020911
# 768                                       selenic acid  MESH:D064586
# 234                                    sodium selenate  MESH:D064586
#
#              mesh                         ikey                    ikey_cheb
# 505           NaN  PDWUPXJEEYOOTR-JRGAVVOBSA-N  PDWUPXJEEYOOTR-JRGAVVOBSA-N
# 695  MESH:D019820  LRFVTYWOQMYALW-UHFFFAOYSA-N  LRFVTYWOQMYALW-UHFFFAOYSA-N
# 694           NaN  LRFVTYWOQMYALW-UHFFFAOYSA-N  LRFVTYWOQMYALW-UHFFFAOYSA-N
# 195  MESH:D020910  OZWKMVRBQXNZKK-UHFFFAOYSA-N  OZWKMVRBQXNZKK-UHFFFAOYSA-N
# 193           NaN  OZWKMVRBQXNZKK-UHFFFAOYSA-N  OZWKMVRBQXNZKK-UHFFFAOYSA-N
# 194           NaN  OZWKMVRBQXNZKK-UHFFFAOYSA-N  OZWKMVRBQXNZKK-UHFFFAOYSA-N
# 196  MESH:D020910  OZWKMVRBQXNZKK-UHFFFAOYSA-N  OZWKMVRBQXNZKK-UHFFFAOYSA-N
# 281  MESH:D020911  BWHLPLXXIDYSNW-UHFFFAOYSA-N  BWHLPLXXIDYSNW-UHFFFAOYSA-N
# 768  MESH:D064586                          NaN  QYHFIVBSNOWOCQ-UHFFFAOYSA-N
# 234           NaN  MHQOTKLEMKRJIR-UHFFFAOYSA-L  MHQOTKLEMKRJIR-UHFFFAOYSA-L

# %% [markdown]
# ### Start by fixing where the mesh IDs disagree...

# %%
mult_cheb_mrg['mesh_name'] = mult_cheb_mrg['mesh'].str.split(':', expand=True)[1].map(m2name)
mult_cheb_mrg['mesh_id_name'] = mult_cheb_mrg['mesh_id'].str.split(':', expand=True)[1].map(m2name)

# %%
cols = ['chebi_id', 'name', 'name_cheb', 'mesh_id', 'mesh', 'mesh_id_name', 'mesh_name', 'ikey','ikey_cheb']
mult_cheb_mrg[mult_cheb_mrg['mesh'] != mult_cheb_mrg['mesh_id']][cols].dropna(subset=['mesh']).sample(20)
# Out:
#         chebi_id                    name  \
# 3    CHEBI:18012            Fumaric acid
# 409   CHEBI:3614           Chlorhexidine
# 294  CHEBI:16914          Salicylic acid
# 189  CHEBI:80366         Icosapent ethyl
# 262   CHEBI:8024             Perindopril
# 292  CHEBI:16643              Methionine
# 147   CHEBI:6824             Methenamine
# 21   CHEBI:47381              Diclofenac
# 58   CHEBI:49662            Indomethacin
# 253  CHEBI:63599   Fludarabine phosphate
# 274   CHEBI:3505    Cefpodoxime proxetil
# 499  CHEBI:87462             Propamidine
# 104  CHEBI:57305                 Glycine
# 184  CHEBI:52010        Chlorpheniramine
# 108  CHEBI:68845    Azilsartan medoxomil
# 203  CHEBI:63564     Tixocortol pivalate
# 460  CHEBI:31713         Iothalamic acid
# 483  CHEBI:59219              Ceruletide
# 553  CHEBI:70839               Dasatinib
# 158  CHEBI:28177  Theophylline anhydrous
#
#                                              name_cheb       mesh_id  \
# 3                                         fumaric acid  MESH:C032005
# 409                                      chlorhexidine  MESH:C010882
# 294                                     salicylic acid  MESH:D012980
# 189  (5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid ethy...  MESH:C495711
# 262                                        perindopril  MESH:C053500
# 292                                       L-methionine  MESH:D008715
# 147                             hexamethylenetetramine  MESH:C011481
# 21                                          diclofenac  MESH:C064142
# 58                                         indometacin  MESH:C017472
# 253                              fludarabine phosphate  MESH:C024352
# 274                               cefpodoxime proxetil  MESH:C053268
# 499                                        propamidine  MESH:C046651
# 104                                 glycine zwitterion  MESH:C011080
# 184                                     chlorphenamine  MESH:C018904
# 108                               azilsartan medoxomil  MESH:C521273
# 203                                tixocortol pivalate  MESH:C040971
# 460                                     Iotalamic acid  MESH:D007482
# 483                                         ceruletide  MESH:C032637
# 553                              dasatinib monohydrate  MESH:C488369
# 158                                       theophylline  MESH:D000628
#
#                 mesh                        mesh_id_name  \
# 3       MESH:D005650                        fumaric acid
# 409     MESH:D002710             chlorhexidine gluconate
# 294     MESH:D020156                   Sodium Salicylate
# 189     MESH:C035276         ethyl eicosapentaenoic acid
# 262     MESH:D020913                       perindoprilat
# 292     MESH:D064697                          Methionine
# 147     MESH:D008709               methenamine hippurate
# 21      MESH:D004008  diclofenac hydroxyethylpyrrolidine
# 58      MESH:D007213                           lonazolac
# 253     MESH:C042382                         fludarabine
# 274     MESH:C053267                         cefpodoxime
# 499     MESH:C005555             propamidine isethionate
# 104     MESH:D005998                         polyglycine
# 184     MESH:D002744                 dexchlorpheniramine
# 108     MESH:C557413                          azilsartan
# 203     MESH:C019112                          tixocortol
# 460     MESH:D007483               Iothalamate Meglumine
# 483     MESH:D002108             ceruletide diethylamine
# 553  MESH:D000069439                                 NaN
# 158     MESH:D013806                       Aminophylline
#
#                              mesh_name                         ikey  \
# 3                            Fumarates  VZCYOOQTPOCHFL-OWOJBTEDSA-N
# 409                      Chlorhexidine  GHXZTYHSJHQHIJ-UHFFFAOYSA-N
# 294                     Salicylic Acid  YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 189  eicosapentaenoic acid ethyl ester  SSQPWTVBQMWLSZ-AAQCHOMXSA-N
# 262                        Perindopril  IPVQLZZIHOAWMC-QXKUPLGCSA-N
# 292                     Racemethionine  FFEARJCKVFRZRR-BYPYZUCNSA-N
# 147                        Methenamine  VKYKSIONXSXAKP-UHFFFAOYSA-N
# 21                          Diclofenac  DCOPUUMXTXDBNB-UHFFFAOYSA-N
# 58                        Indomethacin  CGIGDMFJXJATDK-UHFFFAOYSA-N
# 253              fludarabine phosphate  GIUYCYHIANZCFB-FJFJXFQQSA-N
# 274               cefpodoxime proxetil  LTINZAODLRIQIX-FBXRGJNPSA-N
# 499                        propamidine  WTFXJFJYEJZMFO-UHFFFAOYSA-N
# 104                            Glycine  DHMQDGOQFOQNFH-UHFFFAOYSA-N
# 184                   Chlorpheniramine  SOYKEARSMXGVTM-UHFFFAOYSA-N
# 108               azilsartan medoxomil  QJFSABGVXDWMIW-UHFFFAOYSA-N
# 203                tixocortol pivalate  BISFDZNIUZIKJD-XDANTLIUSA-N
# 460                    Iothalamic Acid  UXIGWFXRQKWHHA-UHFFFAOYSA-N
# 483                         Ceruletide  YRALAIOMGQZKOW-HYAOXDFASA-N
# 553                          Dasatinib  XHXFZZNHDVTMLI-UHFFFAOYSA-N
# 158                       Theophylline  ZFXYFBGIUFBOJW-UHFFFAOYSA-N
#
#                        ikey_cheb
# 3    VZCYOOQTPOCHFL-OWOJBTEDSA-N
# 409  GHXZTYHSJHQHIJ-UHFFFAOYSA-N
# 294  YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 189  SSQPWTVBQMWLSZ-AAQCHOMXSA-N
# 262  IPVQLZZIHOAWMC-QXKUPLGCSA-N
# 292  FFEARJCKVFRZRR-BYPYZUCNSA-N
# 147  VKYKSIONXSXAKP-UHFFFAOYSA-N
# 21   DCOPUUMXTXDBNB-UHFFFAOYSA-N
# 58   CGIGDMFJXJATDK-UHFFFAOYSA-N
# 253  GIUYCYHIANZCFB-FJFJXFQQSA-N
# 274  LTINZAODLRIQIX-FBXRGJNPSA-N
# 499  WTFXJFJYEJZMFO-UHFFFAOYSA-N
# 104  DHMQDGOQFOQNFH-UHFFFAOYSA-N
# 184  SOYKEARSMXGVTM-UHFFFAOYSA-N
# 108  QJFSABGVXDWMIW-UHFFFAOYSA-N
# 203  BISFDZNIUZIKJD-XDANTLIUSA-N
# 460  UXIGWFXRQKWHHA-UHFFFAOYSA-N
# 483  YRALAIOMGQZKOW-HYAOXDFASA-N
# 553  XHXFZZNHDVTMLI-UHFFFAOYSA-N
# 158  ZFXYFBGIUFBOJW-UHFFFAOYSA-N

# %% [markdown]
# A lot of these look like they could have the correct value in the ontology already...

# %%
subset = mult_cheb_mrg[mult_cheb_mrg['mesh'] != mult_cheb_mrg['mesh_id']][cols].dropna(subset=['mesh'])
ix = (subset['name'].str.lower() == subset['mesh_name'].str.lower()) | (subset['name_cheb'].str.lower() == subset['mesh_name'].str.lower())
(ix).sum(), len(subset)
# Out:
# (59, 66)

# %%
c2m_dict.update(subset[ix].set_index('chebi_id')['mesh'].to_dict())

# %%
subset[~ix]
# Out:
#          chebi_id                                      name  \
# 96   CHEBI:383703  3,6-diamino-10-methylacridinium chloride
# 3     CHEBI:18012                              Fumaric acid
# 78    CHEBI:63625                       Tenofovir anhydrous
# 487   CHEBI:30863                                  Oteracil
# 189   CHEBI:80366                           Icosapent ethyl
# 292   CHEBI:16643                                Methionine
# 508   CHEBI:26689                                    Oxygen
#
#                                              name_cheb       mesh_id  \
# 96            3,6-diamino-10-methylacridinium chloride  MESH:C026620
# 3                                         fumaric acid  MESH:C032005
# 78                               tenofovir (anhydrous)  MESH:C096918
# 487                                   5-azaorotic acid  MESH:C489337
# 189  (5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid ethy...  MESH:C495711
# 292                                       L-methionine  MESH:D008715
# 508                                   singlet dioxygen  MESH:D010100
#
#                 mesh                     mesh_id_name  \
# 96      MESH:D000167  3,6-diamino-10-methylacridinium
# 3       MESH:D005650                     fumaric acid
# 78   MESH:D000068698                              NaN
# 487     MESH:D010094                potassium oxonate
# 189     MESH:C035276      ethyl eicosapentaenoic acid
# 292     MESH:D064697                       Methionine
# 508     MESH:D026082                           Oxygen
#
#                              mesh_name                         ikey  \
# 96                         Acriflavine  KKAJSJJFBSOMGS-UHFFFAOYSA-N
# 3                            Fumarates  VZCYOOQTPOCHFL-OWOJBTEDSA-N
# 78                           Tenofovir  SGOIRFVFHAKUTI-ZCFIWIBFSA-N
# 487                        Oxonic Acid  RYYCJUAHISIHTL-UHFFFAOYSA-N
# 189  eicosapentaenoic acid ethyl ester  SSQPWTVBQMWLSZ-AAQCHOMXSA-N
# 292                     Racemethionine  FFEARJCKVFRZRR-BYPYZUCNSA-N
# 508                     Singlet Oxygen  MYMOFIZGZYHOMD-UHFFFAOYSA-N
#
#                        ikey_cheb
# 96   KKAJSJJFBSOMGS-UHFFFAOYSA-N
# 3    VZCYOOQTPOCHFL-OWOJBTEDSA-N
# 78   SGOIRFVFHAKUTI-ZCFIWIBFSA-N
# 487  RYYCJUAHISIHTL-UHFFFAOYSA-N
# 189  SSQPWTVBQMWLSZ-AAQCHOMXSA-N
# 292  FFEARJCKVFRZRR-BYPYZUCNSA-N
# 508  MYMOFIZGZYHOMD-UHFFFAOYSA-N

# %% [markdown]
# Some of these don't have a meshID name, so automatically drop those and take them MeSH ID..
#
# Also, it looks like we did some of these already... but definitely not others... make sure these aren't yet manually entered...

# %%
c2m_dict.update(subset[~ix][subset[~ix]['mesh_id_name'].isnull()].set_index('chebi_id')['mesh'].to_dict())

# %%
already_manulally_annotated = set(mult_mesh.query('chebi_id not in @curr_cheb_ids')['chebi_id'])

# %%
subset[~ix].query('chebi_id not in @already_manulally_annotated').dropna(subset=['mesh_id_name'])
# Out:
#          chebi_id                                      name  \
# 96   CHEBI:383703  3,6-diamino-10-methylacridinium chloride
# 3     CHEBI:18012                              Fumaric acid
# 487   CHEBI:30863                                  Oteracil
# 189   CHEBI:80366                           Icosapent ethyl
# 292   CHEBI:16643                                Methionine
# 508   CHEBI:26689                                    Oxygen
#
#                                              name_cheb       mesh_id  \
# 96            3,6-diamino-10-methylacridinium chloride  MESH:C026620
# 3                                         fumaric acid  MESH:C032005
# 487                                   5-azaorotic acid  MESH:C489337
# 189  (5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid ethy...  MESH:C495711
# 292                                       L-methionine  MESH:D008715
# 508                                   singlet dioxygen  MESH:D010100
#
#              mesh                     mesh_id_name  \
# 96   MESH:D000167  3,6-diamino-10-methylacridinium
# 3    MESH:D005650                     fumaric acid
# 487  MESH:D010094                potassium oxonate
# 189  MESH:C035276      ethyl eicosapentaenoic acid
# 292  MESH:D064697                       Methionine
# 508  MESH:D026082                           Oxygen
#
#                              mesh_name                         ikey  \
# 96                         Acriflavine  KKAJSJJFBSOMGS-UHFFFAOYSA-N
# 3                            Fumarates  VZCYOOQTPOCHFL-OWOJBTEDSA-N
# 487                        Oxonic Acid  RYYCJUAHISIHTL-UHFFFAOYSA-N
# 189  eicosapentaenoic acid ethyl ester  SSQPWTVBQMWLSZ-AAQCHOMXSA-N
# 292                     Racemethionine  FFEARJCKVFRZRR-BYPYZUCNSA-N
# 508                     Singlet Oxygen  MYMOFIZGZYHOMD-UHFFFAOYSA-N
#
#                        ikey_cheb
# 96   KKAJSJJFBSOMGS-UHFFFAOYSA-N
# 3    VZCYOOQTPOCHFL-OWOJBTEDSA-N
# 487  RYYCJUAHISIHTL-UHFFFAOYSA-N
# 189  SSQPWTVBQMWLSZ-AAQCHOMXSA-N
# 292  FFEARJCKVFRZRR-BYPYZUCNSA-N
# 508  MYMOFIZGZYHOMD-UHFFFAOYSA-N

# %%
### Let's reconcile these last few...
c2m_dict['CHEBI:383703'] = 'MESH:C026620'
c2m_dict['CHEBI:18012'] = 'MESH:C032005'
c2m_dict['CHEBI:80366'] = 'MESH:C035276'
c2m_dict['CHEBI:16643'] = 'MESH:D008715'
c2m_dict['CHEBI:26689'] = 'MESH:D026082'

# %%
curr_cheb_ids = list(c2m_dict.keys())
mult_cheb_mrg.query('chebi_id not in @curr_cheb_ids').sort_values('mesh_id')[cols].head(10)
# Out:
#          chebi_id                                 name  \
# 633   CHEBI:17917                             Allysine
# 632   CHEBI:58321                             Allysine
# 736   CHEBI:85005                           Anticapsin
# 737   CHEBI:84310                           Anticapsin
# 560   CHEBI:34647  Clindamycin palmitate hydrochloride
# 561  CHEBI:135866                Clindamycin palmitate
# 41    CHEBI:58112                            Cetraxate
# 42    CHEBI:17340                            Cetraxate
# 702   CHEBI:57486              4-guanidinobutyric acid
# 703   CHEBI:15728              4-guanidinobutyric acid
#
#                                name_cheb       mesh_id mesh  \
# 633                           L-allysine  MESH:C000061  NaN
# 632                L-allysine zwitterion  MESH:C000061  NaN
# 736                           anticapsin  MESH:C000097  NaN
# 737                anticapsin zwitterion  MESH:C000097  NaN
# 560  Clindamycin palmitate hydrochloride  MESH:C000489  NaN
# 561                clindamycin palmitate  MESH:C000489  NaN
# 41                  cetraxate zwitterion  MESH:C000665  NaN
# 42                             cetraxate  MESH:C000665  NaN
# 702  4-guanidinobutanoic acid zwitterion  MESH:C001317  NaN
# 703             4-guanidinobutanoic acid  MESH:C001317  NaN
#
#                     mesh_id_name mesh_name                         ikey  \
# 633                     allysine       NaN  GFXYTQPNNXGICT-YFKPBYRVSA-N
# 632                     allysine       NaN  GFXYTQPNNXGICT-YFKPBYRVSA-N
# 736                   anticapsin       NaN  KHVZXXWDPSCGEK-MGVQOFIGSA-N
# 737                   anticapsin       NaN  KHVZXXWDPSCGEK-MGVQOFIGSA-N
# 560        clindamycin palmitate       NaN  GTNDZRUWKHDICY-DJHAJVGHSA-N
# 561        clindamycin palmitate       NaN  OYSKUZDIHNKWLV-PRUAPSLNSA-N
# 41                     cetraxate       NaN  FHRSHSOEWXUORL-HDJSIYSDSA-N
# 42                     cetraxate       NaN  FHRSHSOEWXUORL-HDJSIYSDSA-N
# 702  gamma-guanidinobutyric acid       NaN  TUHVEAJXIMEOSA-UHFFFAOYSA-N
# 703  gamma-guanidinobutyric acid       NaN  TUHVEAJXIMEOSA-UHFFFAOYSA-N
#
#                        ikey_cheb
# 633  GFXYTQPNNXGICT-YFKPBYRVSA-N
# 632  GFXYTQPNNXGICT-YFKPBYRVSA-N
# 736  KHVZXXWDPSCGEK-MGVQOFIGSA-N
# 737  KHVZXXWDPSCGEK-MGVQOFIGSA-N
# 560  GTNDZRUWKHDICY-DJHAJVGHSA-N
# 561  OYSKUZDIHNKWLV-PRUAPSLNSA-N
# 41   FHRSHSOEWXUORL-HDJSIYSDSA-N
# 42   FHRSHSOEWXUORL-HDJSIYSDSA-N
# 702  TUHVEAJXIMEOSA-UHFFFAOYSA-N
# 703  TUHVEAJXIMEOSA-UHFFFAOYSA-N

# %% [markdown]
# A This point  I think we can just accept these as 1_to_many in the mesh_to_chebi relationship...

# %%
c2m_dict.update(mult_cheb_mrg.query('chebi_id not in @curr_cheb_ids').set_index('chebi_id')['mesh_id'].to_dict())

# %%
chebi['new_mesh'] = chebi['id'].map(c2m_dict)
chebi['new_mesh'].count()
# Out:
# 8243

# %%
subset = chebi.dropna(subset=['mesh'])
(subset['mesh'] != subset['new_mesh']).sum()
# Out:
# 6

# %% [markdown]
# Very few conflicts, let's examine

# %%
idx = subset.query('mesh != new_mesh').index
subset = chebi.loc[idx]
subset['mesh_name'] = subset['mesh'].str.split(':', expand=True)[1].map(m2name)
subset['new_mesh_name'] = subset['new_mesh'].str.split(':', expand=True)[1].map(m2name)
subset[['id', 'name', 'mesh', 'new_mesh', 'mesh_name', 'new_mesh_name']]
# Out:
#                  id                                      name          mesh  \
# 507    CHEBI:383703  3,6-diamino-10-methylacridinium chloride  MESH:D000167
# 14555   CHEBI:59124                        thiosalicylic acid  MESH:C026196
# 14852   CHEBI:16134                                   ammonia  MESH:D009584
# 22034   CHEBI:16643                              L-methionine  MESH:D064697
# 39462   CHEBI:53691                         amidotrizoic acid  MESH:D003973
# 53642   CHEBI:18012                              fumaric acid  MESH:D005650
#
#            new_mesh             mesh_name                    new_mesh_name
# 507    MESH:C026620           Acriflavine  3,6-diamino-10-methylacridinium
# 14555  MESH:C441201  2-thiosalicylic acid               thiosalicylic acid
# 14852  MESH:D000641              Nitrogen                          Ammonia
# 22034  MESH:D008715        Racemethionine                       Methionine
# 39462  MESH:C016826           Diatrizoate                  diatrizoic acid
# 53642  MESH:C032005             Fumarates                     fumaric acid

# %% [markdown]
# The new ones all look correct so let's keep...

# %%
chebi = chebi.drop('mesh', axis=1).rename(columns={'new_mesh':'mesh'})
chebi.head()
# Out:
#   alt_id                                                def ikey           id  \
# 0    NaN  "A chemical entity is a physical entity of int...  NaN  CHEBI:24431
# 1    NaN  "Any constitutionally or isotopically distinct...  NaN  CHEBI:23367
# 2    NaN  "A molecular entity having a net electric char...  NaN  CHEBI:24870
# 3    NaN                                                NaN  NaN  CHEBI:24867
# 4    NaN                                                NaN  NaN  CHEBI:23905
#
#    is_obsolete              name  subset xref id_src mesh
# 0        False   chemical entity  3_STAR  NaN  CHEBI  NaN
# 1        False  molecular entity  3_STAR  NaN  CHEBI  NaN
# 2        False               ion  3_STAR  NaN  CHEBI  NaN
# 3        False    monoatomic ion  3_STAR  NaN  CHEBI  NaN
# 4        False  monoatomic anion  3_STAR  NaN  CHEBI  NaN

# %%
# Non-compound chebi terms
len(chebi[chebi['ikey'].isnull()])
# Out:
# 21050

# %%
chebi[chebi['ikey'].isnull()]['mesh'].count()
# Out:
# 539

# %% [markdown]
# ## MyChem to try and pick up any stragglers
#
# Now Go to mychem to get as many results as we can for the rest...

# %%
cheb_ids = chebi[chebi['mesh'].isnull()]['id'].unique()
res = load_api_results(out_dir.joinpath('chebi_mychem_info_{}.pkl'), scrape_function=bp.download_mychem_ids, 
                         chem_ids=cheb_ids)

cheb_comps = bp.process_chemicals_in_mychem_results(res)

# %%
len(cheb_ids)
# Out:
# 105507

# %%
len(chebi)
# Out:
# 113750

# %%
cheb_comps.drop('q', axis=1).dropna(how='all').count()
# Out:
# chebi_id       93757
# chembl_id      23132
# drugbank_id     1291
# ikey           84994
# mesh_id          384
# name           92792
# unii_id         6737
# id             93757
# source         93757
# dtype: int64

# %%
cheb_comps.drop('q', axis=1).dropna(how='all').head()
# Out:
#         chebi_id      chembl_id drugbank_id                         ikey  \
# 5    CHEBI:33429            NaN         NaN                          NaN
# 6    CHEBI:30151            NaN         NaN  SBLSYFIUPXRQRY-UHFFFAOYSA-N
# 7    CHEBI:16042            NaN         NaN                          NaN
# 9    CHEBI:51990  CHEMBL1078233         NaN  FPGGTKZVZWFYPV-UHFFFAOYSA-M
# 10  CHEBI:135933            NaN     DB11092  ANOBYBYXJXCGBS-UHFFFAOYSA-L
#
#          mesh_id                         name     unii_id  \
# 5            NaN         Monoatomic monoanion         NaN
# 6            NaN                Aluminide(1-)         NaN
# 7            NaN                 Halide anion         NaN
# 9            NaN  Tetrabutylammonium fluoride  2618F0C37I
# 10  MESH:D014002            Stannous fluoride         NaN
#
#                              id source
# 5                   CHEBI:33429  chebi
# 6   SBLSYFIUPXRQRY-UHFFFAOYSA-N   ikey
# 7                   CHEBI:16042  chebi
# 9   FPGGTKZVZWFYPV-UHFFFAOYSA-M   ikey
# 10  ANOBYBYXJXCGBS-UHFFFAOYSA-L   ikey

# %%
cheb_comp_exp = expand_df_on_col(cheb_comps, 'mesh_id')

idx = cheb_comp_exp.dropna(subset=['mesh_id'])['q'].duplicated(keep=False)
idx = idx[idx].index

duped_chebs = cheb_comp_exp.loc[idx].sort_values('q')
duped_chebs
# Out:
# Empty DataFrame
# Columns: [chebi_id, chembl_id, drugbank_id, ikey, mesh_id, name, q, unii_id, id, source]
# Index: []

# %%
duped_chebs['mesh_name'] = duped_chebs['mesh_id'].apply(lambda m: m2name.get(m.split(':')[1], float('nan')))
duped_chebs
# Out:
# Empty DataFrame
# Columns: [chebi_id, chembl_id, drugbank_id, ikey, mesh_id, name, q, unii_id, id, source, mesh_name]
# Index: []

# %%
c2m_dict = {**cheb_comp_exp.set_index('q')['mesh_id'].dropna().to_dict(), 
                      **c2m_dict}

# %%
c2m_dict['CHEBI:134705'] = 'MESH:C448680' # Etimicin, etimicin
c2m_dict['CHEBI:134717'] = 'MESH:C000858' # Decamethoxine, decamethoxine
c2m_dict['CHEBI:135169'] = 'MESH:D004629' # Emepronium, Emepronium
c2m_dict['CHEBI:135443'] = 'MESH:C100295' # Poldine, poldine
c2m_dict['CHEBI:135543'] = 'MESH:C000598259' # Cyclovalone, cyclovalone
c2m_dict['CHEBI:135806'] = 'MESH:C061004' # Benidipine, benidipine
c2m_dict['CHEBI:135901'] = 'MESH:C060347' # Lanreotide, lanreotide
c2m_dict['CHEBI:136049'] = 'MESH:C528396' # Mirodenafil, mirodenafil
c2m_dict['CHEBI:50819'] = 'MESH:C000499' # Ferric oxide, ferric oxide
c2m_dict['CHEBI:53440'] = 'MESH:C029639' # 2-hydroxypropyl methacrylate, 2-hydroxypropyl methacrylate
c2m_dict['CHEBI:63082'] = 'MESH:D000068759' # Formoterol, Formoterol Fumarate
c2m_dict['CHEBI:91829'] = 'MESH:C012725' # Aminopentamide sulfate, aminopentamide
c2m_dict['CHEBI:93235'] = 'MESH:D005475' # 2-[4-[3-[2-(trifluoromethyl)-9-thioxanthenylidene]propyl]-1-piperazinyl]ethanol, Flupenthixol
c2m_dict['CHEBI:9943'] = 'MESH:D000069470' # Venlafaxine, Venlafaxine Hydrochloride

# %% [markdown]
# ### Wikidata for some more ikey to mesh mapping

# %%
query = """
SELECT DISTINCT ?ikey ?mesh ?item ?itemLabel
WHERE 
{
  # ?item wdt:P486 ?mesh.
  # ?item wdt:P235 ?ikey.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
ORDER BY ?itemLabel
"""

# %%
wd_ikey_to_mesh = WDItemEngine.execute_sparql_query(query, as_dataframe=True)

# %%
bad_idx = wd_ikey_to_mesh.index[wd_ikey_to_mesh['mesh'].str.startswith('M')]
wd_ikey_to_mesh = wd_ikey_to_mesh.drop(bad_idx)

wd_ikey_to_mesh['mesh'] = 'MESH:' + wd_ikey_to_mesh['mesh']
ikey_to_mesh = wd_ikey_to_mesh.set_index('ikey')['mesh'].to_dict()

# %%
chebi['mesh'].count()
# Out:
# 8243

# %%
chebi.head(2)
# Out:
#   alt_id                                                def ikey           id  \
# 0    NaN  "A chemical entity is a physical entity of int...  NaN  CHEBI:24431
# 1    NaN  "Any constitutionally or isotopically distinct...  NaN  CHEBI:23367
#
#    is_obsolete              name  subset xref id_src mesh
# 0        False   chemical entity  3_STAR  NaN  CHEBI  NaN
# 1        False  molecular entity  3_STAR  NaN  CHEBI  NaN

# %%
ikey_to_mesh = {**ikey_to_mesh,  **chebi.dropna(subset=['ikey', 'mesh']).set_index('ikey')['mesh'].to_dict()}

# %%
chebi['mesh'] = chebi['mesh'].fillna(chebi['ikey'].map(ikey_to_mesh))
chebi['mesh'] = chebi['mesh'].fillna(chebi['id'].map(c2m_dict))
chebi.count()
# Out:
# alt_id           7513
# def             46478
# ikey            92700
# id             113750
# is_obsolete    113750
# name           113750
# subset         113691
# xref            90947
# id_src         113750
# mesh             8706
# dtype: int64

# %%
# Final chebi to mesh mapper...
chebi_to_mesh = chebi.set_index('id')['mesh'].to_dict()

# %%
query = """
SELECT DISTINCT ?mesh ?item ?itemLabel
WHERE 
{
  # ?item wdt:P486 ?mesh.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
ORDER BY ?itemLabel
"""

# %%
wd_to_mesh = WDItemEngine.execute_sparql_query(query, as_dataframe=True)
wd_to_mesh.head(2)
# Out:
#                                        item  itemLabel     mesh
# 0   http://www.wikidata.org/entity/Q1076488   Q1076488  D002828
# 1  http://www.wikidata.org/entity/Q11002263  Q11002263  D003219

# %%
bad_idx = wd_to_mesh.index[wd_to_mesh['mesh'].str.startswith('M')]
wd_to_mesh = wd_to_mesh.drop(bad_idx)

wd_to_mesh['mesh'] = 'MESH:' + wd_to_mesh['mesh']
wd_to_mesh['item'] = wd_to_mesh['item'].apply(lambda i: i.split('/')[-1])
wd_to_mesh = wd_to_mesh.set_index('item')['mesh'].to_dict()

# %%
query = """
SELECT DISTINCT ?ikey ?unii ?item ?itemLabel
WHERE 
{
  # ?item wdt:P235 ?ikey.
  # ?item wdt:P652 ?unii.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
ORDER BY ?itemLabel
"""

# %%
unii_to_ikey = WDItemEngine.execute_sparql_query(query, as_dataframe=True)
unii_to_ikey.head(2)
# Out:
#                           ikey                                      item  \
# 0  AZQDQWDAXMVUSD-UHFFFAOYSA-N  http://www.wikidata.org/entity/Q15116845
# 1  DLPASUVGCQPFFO-UHFFFAOYSA-N  http://www.wikidata.org/entity/Q15628411
#
#    itemLabel        unii
# 0  Q15116845  J84P40P7BV
# 1  Q15628411  OE3B0ORY4X

# %%
len(unii_to_ikey)
# Out:
# 58345

# %%
unii_to_ikey.nunique()
# Out:
# ikey         58295
# item         58259
# itemLabel    58257
# unii         58306
# dtype: int64

# %%
unii_to_ikey = unii_to_ikey.set_index('unii')['ikey'].to_dict()

# %% [markdown]
# # See how the compound mapping between DBs fare
#
# ID order will be:
# 1. MeSH
# 2. Chebi
# 3. Inchikey

# %%
ref_comps.head(2)
# Out:
#   chebi_id     chembl_id drugbank_id                         ikey  \
# 0      NaN  CHEMBL543295         NaN  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1      NaN  CHEMBL284907         NaN  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#         mesh_id                   name                            q  \
# 0           NaN  A-49816 hydrochloride  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1  MESH:C013876              Elmustine  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#       unii_id                           id source
# 0  8GKF50WX7S  WYFYYAHANZQLGG-UHFFFAOYSA-N   ikey
# 1  NAT2FD82D7  YJZJEQBSODVMTH-UHFFFAOYSA-N   ikey

# %%
ref_comps = expand_df_on_col(ref_comps, 'mesh_id')
ref_comps = expand_df_on_col(ref_comps, 'chebi_id')

# %%
ref_comps['mesh_id'] = ref_comps['ikey'].map(ikey_to_mesh)
ref_comps['mesh_id'] = ref_comps['mesh_id'].fillna(ref_comps['chebi_id'].map(chebi_to_mesh))

ref_comps.drop_duplicates(subset=['ikey'])[['ikey', 'mesh_id']].count()
# Out:
# ikey       14833
# mesh_id     3641
# dtype: int64

# %%
ref.merge(ref_comps[['ikey', 'mesh_id']], how='left', on='ikey')[['ikey', 'mesh_id']].count()
# Out:
# ikey       17220
# mesh_id     3712
# dtype: int64

# %%
ikey_to_chebi = chebi.dropna(subset=['ikey']).set_index('ikey')['id'].to_dict()
ref_comps['chebi_id'] = ref_comps['ikey'].map(ikey_to_chebi)
ref_comps.drop_duplicates(subset=['ikey'])[['ikey', 'chebi_id']].count()
# Out:
# ikey        14833
# chebi_id     4240
# dtype: int64

# %%
ref.columns
# Out:
# Index(['gvk_id', 'drug_name', 'phase', 'drug_roa', 'category', 'mechanism',
#        'sub_smiles', 'synonyms_gvk', 'ikey', 'name_inf', 'highest_phase',
#        'moa', 'target_name', 'target_family', 'origin', 'chem_name',
#        'smiles_inf', 'key', 'pubchem', 'wikidata_inf', 'informa_id',
#        'synonyms_inf', 'id', 'status', 'smiles_itg', 'name_itg',
#        'integrity_note', 'int_thera_group', 'int_MoA', 'wikidata_itg',
#        'PubChem CID', 'source'],
#       dtype='object')

# %%
ref['wikidata_inf'].fillna(ref['wikidata_itg']).count()
# Out:
# 6761

# %%
ref['mesh_id'] = ref['ikey'].map(ikey_to_mesh)
ref['mesh_id'] = ref['mesh_id'].fillna(ref['wikidata_inf'].map(wd_to_mesh)).fillna(ref['wikidata_itg'].map(wd_to_mesh))
ref[['ikey', 'wikidata_inf', 'wikidata_itg', 'mesh_id']].count()
# Out:
# ikey            17220
# wikidata_inf     3432
# wikidata_itg     5391
# mesh_id          3718
# dtype: int64

# %%
ref['final_id'] = ref['mesh_id'].fillna(ref['ikey'].map(ikey_to_chebi).fillna(ref['ikey']))
ref_ids = set(ref['final_id'].dropna())
len(ref_ids)
# Out:
# 17013

# %%
ix_comps = expand_df_on_col(ix_comps, 'mesh_id')
ix_comps = expand_df_on_col(ix_comps, 'chebi_id')

# %%
ix_comps['ikey'] = ix_comps['ikey'].fillna(ix_comps['unii_id'].map(unii_to_ikey))
ix_comps['mesh_id'] = ix_comps['ikey'].map(ikey_to_mesh)
ix_comps['mesh_id'] = ix_comps['mesh_id'].fillna(ix_comps['chebi_id'].map(chebi_to_mesh))

# %%
len(chebi_to_mesh)
# Out:
# 113750

# %%
ix_comps['final_id'] = (ix_comps['mesh_id'].fillna(ix_comps['ikey'].map(ikey_to_chebi)
                                                                   .map(chebi_to_mesh) )
                                           .fillna(ix_comps['ikey'].map(ikey_to_chebi))
                                           .fillna(ix_comps['ikey'])
                                           .fillna(ix_comps['id']))
ix_ids = set(ix_comps['final_id'].dropna())
len(ix_ids)
# Out:
# 105468

# %%
prev_comps['final_id'] = prev_comps['id'].map(chebi_to_mesh).fillna(prev_comps['id'])
prev_ids = set(prev_comps['final_id'].dropna())

# %%
plt.figure(figsize=(10,6))
venn3_pretty([ref_ids, ix_ids, prev_ids], ['Reframe', 'Inxight Drugs', 'Previous'], border=False)

# %% [markdown]
# # Time to call in the big string manipulation guns...

# %%
import re
pattern = re.compile('[\W_]+')

def strip_chars(string):
    return pattern.sub('', string)

# %%
ref.columns
# Out:
# Index(['gvk_id', 'drug_name', 'phase', 'drug_roa', 'category', 'mechanism',
#        'sub_smiles', 'synonyms_gvk', 'ikey', 'name_inf', 'highest_phase',
#        'moa', 'target_name', 'target_family', 'origin', 'chem_name',
#        'smiles_inf', 'key', 'pubchem', 'wikidata_inf', 'informa_id',
#        'synonyms_inf', 'id', 'status', 'smiles_itg', 'name_itg',
#        'integrity_note', 'int_thera_group', 'int_MoA', 'wikidata_itg',
#        'PubChem CID', 'source', 'mesh_id', 'final_id'],
#       dtype='object')

# %%
# chem_name seems dubious... urea was in one that was clearly not Urea...
name_cols = ['drug_name', 'synonyms_gvk', 'name_inf', 'synonyms_inf', 'name_itg']


name_set = []

for row in ref.itertuples():
    out = set()
    for col in name_cols:
        elem = getattr(row, col)
        if not pd.isnull(elem):
            out.update(set(elem.split('|')))
    name_set.append(set([strip_chars(o).lower() for o in out]))
ref['all_names'] = pd.Series(name_set)
ref.head(2)
# Out:
#       gvk_id  drug_name                   phase drug_roa  \
# 0  5916161.0    A-49816  Clinical Phase Unknown      NaN
# 1  5913712.0  Elmustine  Clinical Phase Unknown      NaN
#
#                 category              mechanism  \
# 0  High-Ceiling Diuretic  High-Ceiling Diuretic
# 1             Anticancer             Anticancer
#
#                                           sub_smiles  \
# 0  Cl[H].[H]OC1=C(CN([H])[H])C=C(C=C1)C(=O)C2=CC=...
# 1                        [H]OCCN([H])C(=O)N(CCCl)N=O
#
#                                 synonyms_gvk                         ikey  \
# 0                               Abbott-49816  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1  BRN-1956525|FFC-33|HECNU|Hecnu|NSC-294895  YJZJEQBSODVMTH-UHFFFAOYSA-N
#
#     name_inf                        ...                          name_itg  \
# 0        NaN                        ...                           A-49816
# 1  Elmustine                        ...                         Elmustine
#
#   integrity_note  int_thera_group             int_MoA wikidata_itg  \
# 0            NaN        Diuretics                 NaN    Q27270440
# 1            NaN  Oncolytic Drugs  DNA-Damaging Drugs    Q27284767
#
#    PubChem CID                 source       mesh_id  \
# 0  CID92009045          gvk|integrity           NaN
# 1     CID68804  gvk|informa|integrity  MESH:C013876
#
#                       final_id  \
# 0  WYFYYAHANZQLGG-UHFFFAOYSA-N
# 1                 MESH:C013876
#
#                                           all_names
# 0                             {a49816, abbott49816}
# 1  {elmustine, ffc33, brn1956525, nsc294895, hecnu}
#
# [2 rows x 35 columns]

# %%
ref['all_names'].apply(len).sum()
# Out:
# 67172

# %%
expand_split_col(ref['all_names'])['all_names'].nunique()
# Out:
# 60034

# %%
ref['all_names'] = ref['all_names'].apply(list)
ref_exp = expand_df_on_col(ref, 'all_names')
len(ref_exp)
# Out:
# 67172

# %%
from collections import defaultdict

# %%
name_to_ikeys = defaultdict(set)
for name, df in ref_exp.groupby('all_names'):
    name_to_ikeys[name].update(set(df['ikey']))

# %%
len(name_to_ikeys)
# Out:
# 60034

# %%
tups = [(k, len(v)) for k, v in name_to_ikeys.items()]
names = [t[0] for t in tups]
lens = [t[1] for t in tups]

# %%
name_len = pd.DataFrame({'names': names, 'lens': lens}).sort_values('lens', ascending=False)
name_len.head(10)
# Out:
#                        names  lens
# 37495                 noname    79
# 12242  ceftobiprolemedocaril     4
# 32265                 m14659     4
# 47140               ro239424     4
# 26362                  hp228     3
# 49519              seglitide     3
# 31314             lometrexol     3
# 34370             minopafant     3
# 19227              ebiratide     3
# 31890                 lx2931     3

# %%
# Names belonging to more than one ikey
(name_len['lens'] > 1).sum()
# Out:
# 6271

# %%
# names with fewer than 1 ikey
(name_len['lens'] == 1).sum()
# Out:
# 53763

# %% [markdown]
# Group the ikeys....

# %%
adj_list = defaultdict(set)
for row in ref_exp.itertuples():
    # Skip consolidation of nonames
    if row.all_names != 'noname':
        adj_list[row.final_id].add(row.all_names)
        adj_list[row.all_names].add(row.final_id)

# %% [markdown]
# Add in the other sources...

# %%
# Add the ctd comps...
for row in prev_comps.itertuples():
    name = strip_chars(row.name).lower()
    adj_list[name].add(row.final_id)
    adj_list[row.final_id].add(name)

# %%
# Add all the inxight comps
for row in ix_comps.itertuples():
    if not pd.isnull(row.name):
        name = strip_chars(row.name).lower()
    
        adj_list[name].add(row.final_id)
        adj_list[row.final_id].add(name)

# Expand all the multiple IDs per line... in the inxight drugs
exp_ix_comps = ix_comps.copy()
for c in ix_comps.columns:
    exp_ix_comps = expand_col_on_char(exp_ix_comps, c, '|')

# %%
# Merge Uniis with names
archive = zipfile.ZipFile(data_dir.joinpath('UNIIs.zip'), 'r')
unii_names = pd.read_csv(archive.open('UNII NAMES 7Mar2019.txt'), sep='\t')
    
ix_mrg = exp_ix_comps.merge(unii_names.dropna(subset=['Name']), how='inner', left_on='unii_id', right_on='UNII')

# %%
# Use the synonmyms...
for row in ix_mrg.itertuples():
    name = getattr(row, 'Name')
    if not pd.isnull(name):
        # Some names have superfulous info in a bracket... so strip it out...
        name = name.split('[')[0]
        
        name = strip_chars(name).lower()
        adj_list[name].add(row.final_id)
        adj_list[row.final_id].add(name)

# %%
from queue import Queue
from tqdm import tqdm

def get_subnets(adj_list):

    all_identifiers = set(adj_list.keys())

    subnets = defaultdict(set)
    visited = set()

    for _id in tqdm(all_identifiers):
        if _id not in visited:
            visited.add(_id)
            q = Queue()
            q.put(_id)

            while not q.empty():
                cur = q.get()
                visited.add(cur)

                for neighbour in adj_list[cur]:
                    subnets[_id].add(neighbour)
                    if neighbour not in visited:
                        q.put(neighbour)
                        visited.add(neighbour)

    return subnets

# %%
subnets = get_subnets(adj_list)
# Out:
# 100%|██████████| 787494/787494 [00:08<00:00, 95050.42it/s]

# %%
len(subnets)
# Out:
# 108868

# %%
# Get the special UNIIs
num_unii = unii_names.dropna()[unii_names.dropna()['UNII'].str.isnumeric()]['UNII'].unique()
alpha_unii = unii_names.dropna()[unii_names.dropna()['UNII'].str.isalpha()]['UNII'].unique()
SPECIAL_UNII = list(num_unii) + list(alpha_unii)

# %%
def is_mesh(mid):
    return mid.startswith('MESH:')
def is_chebi(cid):
    return cid.startswith('CHEBI:')
def is_ikey(ikey):
    return tuple(map(len, ikey.split('-'))) == (14, 10, 1)
def is_drugbank(dbid):
    return dbid.startswith('DB') and len(dbid) == 7

def is_unii(uid):
    # The exact restructions on uniis are non-obvious other than length 10....
    if len(uid) != 10:
        return False
    # The uniis here are all capitalized on the alpha chars...
    if not uid.isupper():
        return False
    
    # Most UNIIs are mix of both alpha and numeric... 
    # Only a handful, of pure alpha, or pure num, so check if doesn't pass initial test...
    return (uid.isalnum() and not uid.isalpha() and not uid.isnumeric()) or uid in SPECIAL_UNII

def is_identifier(val):
    return is_mesh(val) or is_chebi(val) or is_chebi(val) or is_drugbank(val) or is_unii(val)

# %%
def get_best_id(list_of_ids, pref_order=None):

    if pref_order is None:
        pref_order = ['mesh', 'chebi', 'ikey', 'drugbank', 'unii']
    
    # Ensure Types
    list_of_ids = list(list_of_ids)


    all_ids = dict()

    # Separate the IDs by type
    all_ids['mesh'] = [i for i in list_of_ids if is_mesh(i)]
    all_ids['chebi'] = [i for i in list_of_ids if is_chebi(i)]
    all_ids['ikey'] = [i for i in list_of_ids if is_ikey(i)]
    all_ids['drugbank'] = [i for i in list_of_ids if is_drugbank(i)]
    all_ids['unii'] = [i for i in list_of_ids if is_unii(i)]
    
    # Find an id of the preferred type.
    for po in pref_order:
        if len(all_ids[po]) > 0:
            return all_ids[po][0]
    
    return list_of_ids[0]

# %%
id_to_subnet = {get_best_id(v): v for v in subnets.values()}
old_to_new_id = {v: k for k, vals in id_to_subnet.items() for v in vals}

# %%
ref['final_id'] = ref['final_id'].map(old_to_new_id).fillna(ref['ikey'])
ref['final_id'].nunique()
# Out:
# 12680

# %%
ix_comps['final_id'] = ix_comps['final_id'].map(old_to_new_id)
ix_comps['final_id'].nunique()
# Out:
# 97256

# %%
ix_comps['final_id'].nunique()
# Out:
# 97256

# %%
prev_comps['final_id'] = prev_comps['final_id'].map(old_to_new_id)
prev_comps['final_id'].nunique()
# Out:
# 16336

# %%
ref_ids = set(ref['final_id'])
ix_ids = set(ix_comps['final_id'])
prev_ids = set(prev_comps['final_id'])

# %%
plt.figure(figsize=(10,6))
venn3_pretty([ref_ids, ix_ids, prev_ids], ['Reframe', 'Inxight Drugs', 'Previous'], border=False)

# %% [markdown]
# In the final network, we will keep everything expect the Orange region...

# %%
keep_ids = ref_ids & prev_ids

# %%
prev_comps.head(2)
# Out:
#              id                     name     label  \
# 0  MESH:C046983  06-Paris-LA-66 protocol  Compound
# 1  MESH:C534883                 10074-G5  Compound
#
#                                         tree_numbers drug_bank_ids  \
# 0  D02.455.426.559.847.562.050.200/C046983|D03.13...           NaN
# 1                        D03.383.129.462.580/C534883           NaN
#
#   alt_disease_ids gene_symbol alt_gene_ids bio_gridids pharm_gkbids  \
# 0             NaN         NaN          NaN         NaN          NaN
# 1             NaN         NaN          NaN         NaN          NaN
#
#   uni_prot_ids uniprot_id mesh_ids chebi_ids      final_id
# 0          NaN        NaN      NaN       NaN  MESH:C046983
# 1          NaN        NaN      NaN       NaN  MESH:C534883

# %%
ix_comps.head(2)
# Out:
#                             id               name     label     chebi_id  \
# 0  FZERHIULMFGESH-UHFFFAOYSA-N        Acetanilide  Compound  CHEBI:28884
# 1  SWMPGCCDXNLPED-NSCUHMNNSA-N  Acetylfuratrizine  Compound          NaN
#
#       chembl_id drugbank_id                         ikey       mesh_id  \
# 0  CHEMBL269644         NaN  FZERHIULMFGESH-UHFFFAOYSA-N  MESH:C508827
# 1           NaN         NaN  SWMPGCCDXNLPED-NSCUHMNNSA-N           NaN
#
#       unii_id source                     final_id
# 0  SP86R356CC   ikey                 MESH:C508827
# 1  C50C4V19SU   ikey  SWMPGCCDXNLPED-NSCUHMNNSA-N

# %%
ref_nodes = ref.loc[:, ['final_id', 'source']]
ref_nodes['label'] = 'Drug'
prev_comp_nodes = prev_comps.loc[:, ['final_id', 'name', 'label']]
ix_comp_nodes = ix_comps.loc[:, ['final_id', 'name']].query('final_id in @keep_ids')
ix_comp_nodes['label'] = 'Drug'

# %%
compounds = pd.concat([ref_nodes, prev_comp_nodes, ix_comp_nodes], ignore_index=True, sort=False)
compounds = gt.order_cols(compounds.drop_duplicates(subset=['final_id'], keep='first').rename(columns={'final_id': 'id'}))

# %%
ref['name'] = ref['drug_name'].fillna(ref['name_inf'].fillna(ref['name_itg']))
id_to_name = chebi.set_index('id')['name'].to_dict()
id_to_name = {**chebi.set_index('mesh')['name'].to_dict(), **id_to_name}
id_to_name = {**chebi.set_index('ikey')['name'].to_dict(), **id_to_name}
id_to_name = {**prev_comps.set_index('id')['name'].to_dict(), **id_to_name}
id_to_name = {**ref.set_index('ikey')['name'].to_dict(), **id_to_name}
id_to_name = {**ref.set_index('mesh_id')['name'].to_dict(), **id_to_name}
id_to_name = {**ix_comps.set_index('id')['name'].to_dict(), **id_to_name}
id_to_name = {**ix_comps.set_index('ikey')['name'].to_dict(), **id_to_name}
id_to_name = {**ix_comps.set_index('unii_id')['name'].to_dict(), **id_to_name}

# %%
compounds['name'] = compounds['name'].fillna(compounds['id'].map(id_to_name))

# %%
len(compounds)
# Out:
# 25499

# %%
compounds['label'].value_counts()
# Out:
# Compound    12819
# Drug        12680
# Name: label, dtype: int64

# %%
compounds.head(2)
# Out:
#                             id          name label                 source
# 0  KWDSYQYCWWCCAV-UHFFFAOYSA-N  Abbott-49816  Drug          gvk|integrity
# 1                 MESH:C013876     Elmustine  Drug  gvk|informa|integrity

# %% [markdown]
# ## Save out our gigantic mapping efforts

# %%
map_results = pd.DataFrame({'old_id': list(old_to_new_id.keys()), 'new_id': list(old_to_new_id.values())})

# %%
id_map_results = map_results[map_results['old_id'].apply(lambda x: is_identifier(x))].copy()
id_map_results['old_name'] = id_map_results['old_id'].map(id_to_name)
id_map_results['new_name'] = id_map_results['new_id'].map(id_to_name)

max_res = map_results['new_id'].value_counts().index[0]

id_map_results.query('new_id == @max_res')
# Out:
#                old_id        new_id  \
# 9159     MESH:C014715  MESH:C014715
# 9273     MESH:D004997  MESH:C014715
# 9309     MESH:D005040  MESH:C014715
# 9322      CHEBI:50900  MESH:C014715
# 9369     MESH:C036657  MESH:C014715
# 9372     MESH:D016912  MESH:C014715
# 9420     MESH:C024262  MESH:C014715
# 9451     MESH:C017576  MESH:C014715
# 9456     MESH:D009644  MESH:C014715
# 9516      CHEBI:91741  MESH:C014715
# 9534  MESH:D000077563  MESH:C014715
# 9552     MESH:D008656  MESH:C014715
# 9559     MESH:D009640  MESH:C014715
#
#                                                old_name new_name
# 9159                                            Norinyl  Norinyl
# 9273                           17alpha-ethynylestradiol  Norinyl
# 9309                               ethynodiol diacetate  Norinyl
# 9322                                     dexonorgestrel  Norinyl
# 9369                                         norlestrin  Norinyl
# 9372                                     levonorgestrel  Norinyl
# 9420                             norethisterone acetate  Norinyl
# 9451                                       norgestimate  Norinyl
# 9456                                         norgestrel  Norinyl
# 9516  (10R,13S,17R)-13-ethyl-17-ethynyl-17-hydroxy-1...  Norinyl
# 9534                              Norethindrone Acetate  Norinyl
# 9552                                          mestranol  Norinyl
# 9559                                     norethisterone  Norinyl

# %%
vc = id_map_results['new_id'].value_counts()
high_val = vc[vc > 5].index

id_map_results.query('new_id in @high_val')
# Out:
#               old_id        new_id  \
# 339      CHEBI:51064  MESH:D000661
# 343     MESH:D000661  MESH:D000661
# 364      CHEBI:51063  MESH:D000661
# 369     MESH:C090411  MESH:D000661
# 466      CHEBI:42724  MESH:D000661
# 479     MESH:D003913  MESH:D000661
# 2668    MESH:C047445  MESH:C047445
# 2669      B4O7C9XKP1  MESH:C047445
# 2683    MESH:C086742  MESH:C047445
# 2685     CHEBI:31369  MESH:C047445
# 2688    MESH:C047444  MESH:C047445
# 2710      L36LY97UH4  MESH:C047445
# 7232     CHEBI:31672  MESH:D006852
# 7247    MESH:D006852  MESH:D006852
# 7257    MESH:D019808  MESH:D006852
# 7302    MESH:C066026  MESH:D006852
# 7344     CHEBI:31804  MESH:D006852
# 7426    MESH:D007548  MESH:D006852
# 7521     CHEBI:51016  MESH:D006852
# 7546    MESH:D014223  MESH:D006852
# 9159    MESH:C014715  MESH:C014715
# 9273    MESH:D004997  MESH:C014715
# 9309    MESH:D005040  MESH:C014715
# 9322     CHEBI:50900  MESH:C014715
# 9369    MESH:C036657  MESH:C014715
# 9372    MESH:D016912  MESH:C014715
# 9420    MESH:C024262  MESH:C014715
# 9451    MESH:C017576  MESH:C014715
# 9456    MESH:D009644  MESH:C014715
# 9516     CHEBI:91741  MESH:C014715
# ...              ...           ...
# 172372  MESH:D003596  MESH:C037254
# 172417  MESH:C014182  MESH:C037254
# 172423   CHEBI:30762  MESH:C037254
# 172438  MESH:D014498  MESH:C037254
# 172451  MESH:D020156  MESH:C037254
# 185333  MESH:D009609  MESH:D009609
# 185354  MESH:C039900  MESH:D009609
# 185383  MESH:D009569  MESH:D009609
# 185404  MESH:D000112  MESH:D009609
# 185412  MESH:C076986  MESH:D009609
# 185419   CHEBI:29120  MESH:D009609
# 313054    43S5D07K8G  MESH:C007005
# 313057    W0X9P59ZQU  MESH:C007005
# 313065    A7C289N0LK  MESH:C007005
# 313067    B3FH65M7R5  MESH:C007005
# 313073    Z79C5A3M2X  MESH:C007005
# 313077  MESH:C007005  MESH:C007005
# 313085    1V5135S169  MESH:C007005
# 361377   CHEBI:83712  MESH:C409722
# 361381  MESH:C409722  MESH:C409722
# 361388   CHEBI:83711  MESH:C409722
# 361397  MESH:C006166  MESH:C409722
# 361410    WX352K63EA  MESH:C409722
# 361411   CHEBI:83713  MESH:C409722
# 421926   CHEBI:35030  MESH:D014299
# 421933  MESH:D014299  MESH:D014299
# 421937    I412286V22  MESH:D014299
# 421940    QJ9MUH57H8  MESH:D014299
# 421941    9K5931C1H5  MESH:D014299
# 421944    D28E1043W5  MESH:D014299
#
#                                                  old_name  \
# 339                               (S)-amphetamine sulfate
# 343                                1-phenylpropan-2-amine
# 364                                   amphetamine sulfate
# 369                                              Adderall
# 466                                       (R)-amphetamine
# 479                                       (S)-amphetamine
# 2668                                    cefetamet pivoxil
# 2669               Dehydroemetine dihydrochloride, (+/-)-
# 2683                                       Dehydroemetine
# 2685                      Cefetamet pivoxil hydrochloride
# 2688                                            cefetamet
# 2710                               Dehydroemetine, (+/-)-
# 7232                            hydralazine hydrochloride
# 7247                                  hydrochlorothiazide
# 7257                                             losartan
# 7302                             losartan carboxylic acid
# 7344                                           Mebutamate
# 7426                                 isosorbide dinitrate
# 7521                             guanethidine monosulfate
# 7546                                          triamterene
# 9159                                              Norinyl
# 9273                             17alpha-ethynylestradiol
# 9309                                 ethynodiol diacetate
# 9322                                       dexonorgestrel
# 9369                                           norlestrin
# 9372                                       levonorgestrel
# 9420                               norethisterone acetate
# 9451                                         norgestimate
# 9456                                           norgestrel
# 9516    (10R,13S,17R)-13-ethyl-17-ethynyl-17-hydroxy-1...
# ...                                                   ...
# 172372                                           cytosine
# 172417                                          salsalate
# 172423                                         salicylate
# 172438                                             uracil
# 172451                                     salicylic acid
# 185333                                   dinitrogen oxide
# 185354                                           nitroxyl
# 185383                                       nitric oxide
# 185404                             3'''-O-acetyldigitoxin
# 185412                                       flutrimazole
# 185419                                  oxidonitrogen(1+)
# 313054                                             Imafen
# 313057                               Imafen hydrochloride
# 313065                                       Imafen, (-)-
# 313067                         Imafen hydrochloride, (+)-
# 313073                         Imafen hydrochloride, (-)-
# 313077                                          carprofen
# 313085                                          Deximafen
# 361377                                   (R)-hexaconazole
# 361381                                       hexaconazole
# 361388  2-(2,4-dichlorophenyl)-1-(1H-1,2,4-triazol-1-y...
# 361397                                         phenothrin
# 361410                                            Kalirin
# 361411                                   (S)-hexaconazole
# 421926                               trimipramine maleate
# 421933                                       trimipramine
# 421937                         Trimipramine maleate, (+)-
# 421940                                 Trimipramine, (+)-
# 421941                                 Trimipramine, (-)-
# 421944                         Trimipramine maleate, (-)-
#
#                                           new_name
# 339                         1-phenylpropan-2-amine
# 343                         1-phenylpropan-2-amine
# 364                         1-phenylpropan-2-amine
# 369                         1-phenylpropan-2-amine
# 466                         1-phenylpropan-2-amine
# 479                         1-phenylpropan-2-amine
# 2668                             cefetamet pivoxil
# 2669                             cefetamet pivoxil
# 2683                             cefetamet pivoxil
# 2685                             cefetamet pivoxil
# 2688                             cefetamet pivoxil
# 2710                             cefetamet pivoxil
# 7232                           hydrochlorothiazide
# 7247                           hydrochlorothiazide
# 7257                           hydrochlorothiazide
# 7302                           hydrochlorothiazide
# 7344                           hydrochlorothiazide
# 7426                           hydrochlorothiazide
# 7521                           hydrochlorothiazide
# 7546                           hydrochlorothiazide
# 9159                                       Norinyl
# 9273                                       Norinyl
# 9309                                       Norinyl
# 9322                                       Norinyl
# 9369                                       Norinyl
# 9372                                       Norinyl
# 9420                                       Norinyl
# 9451                                       Norinyl
# 9456                                       Norinyl
# 9516                                       Norinyl
# ...                                            ...
# 172372  4-amino-2-hydroxybenzoic acid phenyl ester
# 172417  4-amino-2-hydroxybenzoic acid phenyl ester
# 172423  4-amino-2-hydroxybenzoic acid phenyl ester
# 172438  4-amino-2-hydroxybenzoic acid phenyl ester
# 172451  4-amino-2-hydroxybenzoic acid phenyl ester
# 185333                            dinitrogen oxide
# 185354                            dinitrogen oxide
# 185383                            dinitrogen oxide
# 185404                            dinitrogen oxide
# 185412                            dinitrogen oxide
# 185419                            dinitrogen oxide
# 313054                                   carprofen
# 313057                                   carprofen
# 313065                                   carprofen
# 313067                                   carprofen
# 313073                                   carprofen
# 313077                                   carprofen
# 313085                                   carprofen
# 361377                                hexaconazole
# 361381                                hexaconazole
# 361388                                hexaconazole
# 361397                                hexaconazole
# 361410                                hexaconazole
# 361411                                hexaconazole
# 421926                                trimipramine
# 421933                                trimipramine
# 421937                                trimipramine
# 421940                                trimipramine
# 421941                                trimipramine
# 421944                                trimipramine
#
# [198 rows x 4 columns]

# %%
len(high_val)
# Out:
# 29

# %%
id_map_results.to_csv(out_dir.joinpath('compound_identifier_mapping.csv'), index=False)
compounds.to_csv(out_dir.joinpath('compound_nodes.csv'), index=False)
