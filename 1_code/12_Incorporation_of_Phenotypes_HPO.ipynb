# %%
# %matplotlib inline

import pandas as pd
from pathlib import Path
from biothings_client import get_client

from metapaths.tools import obo_tools as ot
from metapaths.tools.processing import expand_col_on_char, expand_split_col
from hetnet_ml.src import graph_tools as gt


data_dir = Path('../2_pipeline/00_download_data/out/').resolve()
this_name = '12_Incorporation_of_Phenotypes_HPO'
out_dir = Path('../2_pipeline/').joinpath(this_name).joinpath('out').resolve()

# %%
if not out_dir.exists():
    out_dir.mkdir(parents=True)

# %%
hp_nodes = ot.get_ontology_nodes(data_dir.joinpath('hpo.obo'))
hp_struct = ot.get_ontology_edges(data_dir.joinpath('hpo.obo'))

# %%
tab_cols = ['db', 'db_object_id', 'db_name', 'qualifier', 'hp_id', 'db_reference', 'evidence_code', 'onset_modifier', 
            'frequency', 'sex', 'modifier', 'aspect', 'date_created', 'assigned_by']

hp_anno = pd.read_csv(data_dir.joinpath('phenotype_annotation.tab'), header=None, 
                       sep='\t', dtype=str, names=tab_cols)
hp_gene = pd.read_csv(data_dir.joinpath('ALL_SOURCES_ALL_FREQUENCIES_genes_to_phenotype.txt'), 
                       sep='\t', header=None, comment='#', dtype=str,
                       names=['gene_id', 'gene_symbol', 'hp_name', 'hp_id'])

# %%
hp_name_map = hp_nodes.set_index('id')['name'].to_dict()
hp_anno['hp_name'] = hp_anno['hp_id'].map(hp_name_map)

# %%
len(hp_anno), len(hp_gene)
# Out:
# (166084, 142947)

# %%
hp_anno.head(2)
# Out:
#          db db_object_id                   db_name qualifier       hp_id  \
# 0  DECIPHER            1  Wolf-Hirschhorn Syndrome       NaN  HP:0000252
# 1  DECIPHER            1  Wolf-Hirschhorn Syndrome       NaN  HP:0001249
#
#   db_reference evidence_code onset_modifier frequency  sex modifier  \
# 0   DECIPHER:1           IEA            NaN       NaN  NaN        P
# 1   DECIPHER:1           IEA            NaN       NaN  NaN        P
#
#                      aspect  date_created assigned_by                  hp_name
# 0  WOLF-HIRSCHHORN SYNDROME  HPO:skoehler         NaN             Microcephaly
# 1  WOLF-HIRSCHHORN SYNDROME  HPO:skoehler         NaN  Intellectual disability

# %%
hp_gene.head(2)
# Out:
#   gene_id gene_symbol        hp_name       hp_id
# 0    8192        CLPP       Seizures  HP:0001250
# 1    8192        CLPP  Short stature  HP:0004322

# %% [markdown]
# ## Examine Genes
#
# Genes are using entrez gene_id, so looking for overlap to the current network should be stratightforward

# %%
hp_genes = hp_gene['gene_id'].unique()

# %%
nodes = gt.remove_colons(pd.read_csv('../2_pipeline/08_Filter_annotations_by_taxonomy/out/nodes_filt.csv', dtype=str))
nodes.query('id in @hp_genes')
# Out:
#            id                                               name label  \
# 22985       2                              alpha-2-macroglobulin  Gene
# 22987  144568                       alpha-2-macroglobulin like 1  Gene
# 22990   53947    alpha 1,4-galactosyltransferase (P blood group)  Gene
# 22993    8086                       aladin WD repeat nucleoporin  Gene
# 23002   79719            alpha and gamma adaptin binding protein  Gene
# 23009      16                             alanyl-tRNA synthetase  Gene
# 23010   57505            alanyl-tRNA synthetase 2, mitochondrial  Gene
# 23014   10157                 aminoadipate-semialdehyde synthase  Gene
# 23019      18                   4-aminobutyrate aminotransferase  Gene
# 23020      19          ATP binding cassette subfamily A member 1  Gene
# 23023   26154         ATP binding cassette subfamily A member 12  Gene
# 23026      21          ATP binding cassette subfamily A member 3  Gene
# 23027      24          ATP binding cassette subfamily A member 4  Gene
# 23028   23461          ATP binding cassette subfamily A member 5  Gene
# 23030   10347          ATP binding cassette subfamily A member 7  Gene
# 23036    8647         ATP binding cassette subfamily B member 11  Gene
# 23039    5244          ATP binding cassette subfamily B member 4  Gene
# 23041   10058  ATP binding cassette subfamily B member 6 (Lan...  Gene
# 23042      22          ATP binding cassette subfamily B member 7  Gene
# 23050    1244          ATP binding cassette subfamily C member 2  Gene
# 23054     368          ATP binding cassette subfamily C member 6  Gene
# 23058    6833          ATP binding cassette subfamily C member 8  Gene
# 23059   10060          ATP binding cassette subfamily C member 9  Gene
# 23060     215          ATP binding cassette subfamily D member 1  Gene
# 23062    5825          ATP binding cassette subfamily D member 3  Gene
# 23063    5826          ATP binding cassette subfamily D member 4  Gene
# 23072   64240          ATP binding cassette subfamily G member 5  Gene
# 23073   64241          ATP binding cassette subfamily G member 8  Gene
# 23078   26090                   abhydrolase domain containing 12  Gene
# 23096   51099                    abhydrolase domain containing 5  Gene
# ...       ...                                                ...   ...
# 47590   51663                    zinc finger RNA binding protein  Gene
# 47598   23503                zinc finger FYVE-type containing 26  Gene
# 47599  118813                zinc finger FYVE-type containing 27  Gene
# 47611    7545                                Zic family member 1  Gene
# 47612    7546                                Zic family member 2  Gene
# 47613    7547                                Zic family member 3  Gene
# 47635   10269                        zinc metallopeptidase STE24  Gene
# 47642   51364                zinc finger MYND-type containing 10  Gene
# 47643   10771                zinc finger MYND-type containing 11  Gene
# 47645   84225                zinc finger MYND-type containing 15  Gene
# 47669    7700                            zinc finger protein 141  Gene
# 47673    7707                            zinc finger protein 148  Gene
# 47802   63925                            zinc finger protein 335  Gene
# 47808   84905                            zinc finger protein 341  Gene
# 47821   22891                            zinc finger protein 365  Gene
# 47842   79797                            zinc finger protein 408  Gene
# 47843    7592                             zinc finger protein 41  Gene
# 47852   23090                            zinc finger protein 423  Gene
# 47883   84627                            zinc finger protein 469  Gene
# 47916  130557                            zinc finger protein 513  Gene
# 47990    9640                            zinc finger protein 592  Gene
# 48030   84146                            zinc finger protein 644  Gene
# 48066   57592                            zinc finger protein 687  Gene
# 48095    7552                            zinc finger protein 711  Gene
# 48123   79755                            zinc finger protein 750  Gene
# 48171  347344                             zinc finger protein 81  Gene
# 48226    9326                  zinc finger HIT-type containing 3  Gene
# 48239   22917                      zona pellucida glycoprotein 1  Gene
# 48242    7784                      zona pellucida glycoprotein 3  Gene
# 48285   57688                 zinc finger SWIM-type containing 6  Gene
#
#       tree_numbers drug_bank_ids alt_disease_ids gene_symbol  \
# 22985          NaN           NaN             NaN         A2M
# 22987          NaN           NaN             NaN       A2ML1
# 22990          NaN           NaN             NaN      A4GALT
# 22993          NaN           NaN             NaN        AAAS
# 23002          NaN           NaN             NaN       AAGAB
# 23009          NaN           NaN             NaN        AARS
# 23010          NaN           NaN             NaN       AARS2
# 23014          NaN           NaN             NaN        AASS
# 23019          NaN           NaN             NaN        ABAT
# 23062         111783|202521|247310                  PA24402
# 23063                       111784                  PA24403
# 23072                       122124                  PA24411
# 23073                       122125                  PA24412
# 23078                117541|218015                  PA25738
# 23096                119288|212211              PA134891622
# ...                            ...                      ...
# 47590                119667|204689                  PA38219
# 47598                       117050              PA134904455
# 47599                       125623              PA134863310
# 47611                113377|204694                  PA37461
# 47612                113378|204695                  PA37462
# 47613                113379|204696                  PA37463
# 47635                115560|260472                  PA37466
# 47642                 119499|64827              PA134981649
# 47643                115989|211523              PA128394578
# 47645                          NaN              PA134873463
# 47669                          NaN                  PA37513
# 47673                       113501                  PA37520
# 47802                       121994                  PA38041
# 47808                       124344                  PA38076
# 47821                       116557              PA134873576
# 47842                       122894              PA134936136
# 47843                       113418                  PA37682
# 47852                       116718              PA134903681
# 47883                       124156              PA134861470
# 47916                       126240              PA134872812
# 47990                       114999  PA134918837|PA147357419
# 48030                       123913              PA134984168
# 48066                       121643              PA142670486
# 48095                       113384                  PA37702
# 48123                       122866              PA145149939
# 48171                       131424                  PA37730
# 48226                       114736                  PA36987
# 48239                          NaN                  PA37755
# 48242                       113565                  PA37757
# 48285                       121714              PA134910181
#
#                                             uni_prot_ids uniprot_id mesh_ids  \
# 22985  A0A1U7TC46|A0A2K5E7U5|A0A2K5KBI2|A0A2K6N6A9|A0...     P01023      NaN
# 22987  A0A0D9RAZ7|A0A1S3AMH8|A0A1U7S0T5|A0A1U7SWH3|A0...     A8K2U0      NaN
# 22990  A0A096N8Q2|A0A0D9SD56|A0A0S2Z5J1|A0A1S2ZRQ3|A0...     Q9NPC4      NaN
# 22993  A0A087XX44|A0A091CTK4|A0A096NFX9|A0A0P7XRK7|A0...     Q9NRG9      NaN
# 23002  A0A087XSX4|A0A091HBL0|A0A091RR32|A0A091SVE7|A0...     Q6PD74      NaN
# 23009  A0A087QNA5|A0A087YD10|A0A091HLZ9|A0A091JF69|A0...     P49588      NaN
# 23010  A0A091DVT7|A0A091FJP6|A0A091LAT9|A0A093BS06|A0...     Q5JTZ9      NaN
# 23014  A0A087VFH2|A0A091DEE2|A0A091GVL3|A0A091HV79|A0...     Q9UDR5      NaN
# 23019  A0A096NLK8|A0A0D9R8N1|A0A1S3EUJ4|A0A1S3WN71|A0...     P80404      NaN
# 23020  A0A096P0Z3|A0A0A0R2Y4|A0A0D9RFW1|A0A0N8ETW3|A0...     O95477      NaN
# 23023  A0A1S3A1T0|A0A1S3F8Z6|A0A1S3PNE6|A0A1U7T2P3|A0...     Q86UK0      NaN
# 23026  A0A087XXW3|A0A091D033|A0A096NL49|A0A0G2K1Q8|A0...     Q99758      NaN
# 23027  A0A1S3FCC2|A0A1S3WRN0|A0A1U7RPS9|A0A1U7V3J2|A0...     P78363      NaN
# 23028  A0A087RA58|A0A087VIV6|A0A091I201|A0A091KDZ7|A0...     Q8WWZ7      NaN
# 23030  A0A151P1R5|A0A1S3FP60|A0A1S3WDM6|A0A1U7RAZ5|A0...     Q8IZY2      NaN
# 23036  A0A0D9RRV8|A0A1A8AFY8|A0A1S3AR49|A0A1S3ARM6|A0...     O95342      NaN
# 47821  A0A091D6G0|A0A0P6JXJ6|A0A1S2ZCV7|A0A1S2ZCW5|A0...     Q70YC5      NaN
# 47842  A0A1S2ZGR6|A0A1S3GB37|A0A1S3KT89|A0A1S3KTE7|A0...     Q9H9D4      NaN
# 47843  A0A024R1C4|A0A096N6N7|A0A1S3GRS9|A0A2I2Y594|A0...     P51814      NaN
# 47852  A0A087XBL5|A0A0D9QZC5|A0A0P6IZ70|A0A1A8AYX8|A0...     Q2M1K9      NaN
# 47883  A0A0F8D0L3|A0A1S3AAM1|A0A1S3EUT8|A0A1W5B4U3|A0...     Q96JG9      NaN
# 47916  A0A096M6I7|A0A096MFQ7|A0A096NQ32|A0A0D9RBU1|A0...     Q8N8E2      NaN
# 47990  A0A087XDF5|A0A093R066|A0A094MJN2|A0A096NN17|A0...     Q92610      NaN
# 48030  A0A096N0M9|A0A0D9S6S7|A0A1A7ZGD0|A0A1D5PEY0|A0...     Q9H582      NaN
# 48066  A0A0P6JJ90|A0A1D5PTU9|A0A1S3A7U9|A0A1S3F382|A0...     Q8N1G0      NaN
# 48095  A0A087Y3G6|A0A096MME0|A0A098KXC1|A0A098KXF5|A0...     Q9Y462      NaN
# 48123  A0A061I2Q4|A0A087R2J2|A0A087VQS6|A0A087XF48|A0...     Q32MQ0      NaN
# 48171  A0A096N7G0|A0A1S3GQ34|A0A1U7SXN2|A0A2I2Z1I9|A0...     P51508      NaN
# 48226  A0A024R0X8|A0A096P508|A0A0D9R135|A0A0F8BRC4|A0...     Q15649      NaN
# 48239  A0A1S2ZI42|A0A1S3G862|A0A1U7SEE5|A0A2R9B9H1|A0...     P60852      NaN
# 48242  A0A096N0R5|A0A1S3GER7|A0A1S3W4X9|A0A1U7Q274|A0...     P21754      NaN
# 48285  A0A1D5PX77|A0A1S3FW11|A0A1S3PFQ4|A0A1S3PFZ9|A0...     Q9HCJ5      NaN
#
#       chebi_ids
# 22985       NaN
# 22987       NaN
# 22990       NaN
# 22993       NaN
# 23002       NaN
# 23009       NaN
# 23010       NaN
# 23014       NaN
# 23019       NaN
# 23020       NaN
# 23023       NaN
# 23026       NaN
# 23027       NaN
# 23028       NaN
# 23030       NaN
# 23036       NaN
# 23039       NaN
# 23041       NaN
# 23042       NaN
# 23050       NaN
# 23054       NaN
# 23058       NaN
# 23059       NaN
# 23060       NaN
# 23062       NaN
# 23063       NaN
# 23072       NaN
# 23073       NaN
# 23078       NaN
# 23096       NaN
# ...         ...
# 47590       NaN
# 47598       NaN
# 47599       NaN
# 47611       NaN
# 47612       NaN
# 47613       NaN
# 47635       NaN
# 47642       NaN
# 47643       NaN
# 47645       NaN
# 47669       NaN
# 47673       NaN
# 47802       NaN
# 47808       NaN
# 47821       NaN
# 47842       NaN
# 47843       NaN
# 47852       NaN
# 47883       NaN
# 47916       NaN
# 47990       NaN
# 48030       NaN
# 48066       NaN
# 48095       NaN
# 48123       NaN
# 48171       NaN
# 48226       NaN
# 48239       NaN
# 48242       NaN
# 48285       NaN
#
# [4015 rows x 14 columns]

# %%
hp_gene['gene_id'].nunique()
# Out:
# 4016

# %%
node_ids = set(nodes['id'])
set(hp_gene['gene_id']) - node_ids
# Out:
# {'101928376'}

# %% [markdown]
# Only 1 gene is missing... Don't think we'll add it, but let's at least look at what it is

# %%
mg = get_client('gene')
mg.getgene(101928376, fields=['name', 'symbol', 'uniprot'])
# Out:
# {'_id': '101928376',
#  '_score': 13.91586,
#  'name': 'IL12A antisense RNA 1',
#  'symbol': 'IL12A-AS1'}

# %% [markdown]
# ## Now HP to Disease Links
#
# HP has OMIM ids for diseases... luckily our CTD network already has xrefs to OMIM for many diseases, so we will use these to merge concepts.

# %%
hp_anno.query('db == "OMIM"')['db_object_id'].nunique()
# Out:
# 7605

# %%
hp_anno['disease_id'] = hp_anno['db'] + ':' + hp_anno['db_object_id']

# %%
nodes.query('label == "Disease"')['id'].nunique()
# Out:
# 7488

# %%
mesh_to_omim = (expand_col_on_char(nodes.query('label == "Disease"'), 'alt_disease_ids', '|')
                    .dropna(subset=['alt_disease_ids'])
                    .set_index('id')['alt_disease_ids'].to_dict())

len(set(hp_anno.query('db == "OMIM"')['disease_id']) - set(mesh_to_omim.values()))
# Out:
# 4917

# %%
missing_diseases = set(hp_anno.query('db == "OMIM"')['disease_id']) - set(mesh_to_omim.values())
hp_anno.query('disease_id in @missing_diseases')['disease_id'].nunique()
# Out:
# 4917

# %%
found_diseases = set(hp_anno.query('db == "OMIM"')['disease_id']) & set(mesh_to_omim.values())
hp_to_dis = hp_anno.query('disease_id in @found_diseases').copy()

print(hp_to_dis['disease_id'].nunique())
print(len(hp_to_dis))
# Out:
# 2688
# 41401

# %%
hp_to_dis['evidence_code'].value_counts()
# Out:
# IEA    21821
# TAS    15415
# PCS     4165
# Name: evidence_code, dtype: int64

# %%
# Tons of edges, so remove the electronic annotations
hp_to_dis = hp_to_dis.query('evidence_code != "IEA"').copy()
hp_to_dis = hp_to_dis.drop_duplicates(subset=['disease_id', 'hp_id'])
hp_to_dis.head(4)
# Out:
#        db db_object_id                                            db_name  \
# 341  OMIM       100100  #100100 PRUNE BELLY SYNDROME; PBS;;ABDOMINAL M...
# 434  OMIM       101000                         NEUROFIBROMATOSIS, TYPE II
# 435  OMIM       101000                         NEUROFIBROMATOSIS, TYPE II
# 436  OMIM       101000                         NEUROFIBROMATOSIS, TYPE II
#
#       qualifier       hp_id  db_reference evidence_code onset_modifier  \
# 341         NaN  HP:0001627   OMIM:100100           TAS            NaN
# 434         NaN  HP:0000360  PMID:1484939           PCS            NaN
# 435  HP:0012833  HP:0000365  PMID:1484939           PCS            NaN
# 436         NaN  HP:0000957  PMID:1484939           PCS            NaN
#
#       frequency  sex modifier aspect   date_created assigned_by  \
# 341         NaN  NaN        P    NaN   HPO:skoehler         NaN
# 434  HP:0040284  NaN        P    NaN  HPO:probinson      12/120
# 435  HP:0040284  NaN        P    NaN  HPO:probinson      42/120
# 436  HP:0040284  NaN        P    NaN        HPO:iea         43%
#
#                        hp_name   disease_id
# 341  Abnormal heart morphology  OMIM:100100
# 434                   Tinnitus  OMIM:101000
# 435         Hearing impairment  OMIM:101000
# 436          Cafe-au-lait spot  OMIM:101000

# %% [markdown]
# So a lot of HPO Items have xrefs to either mesh or omim... thos that are already classified as dieases in our network are not of interest... So we will compare the Xrefs of HPO ids to our network and select those which do not have an xref.

# %%
hp_xrefs = expand_split_col(hp_nodes['xref'].dropna().str.split('|'))['xref'].str.replace('MSH:', 'MESH:').unique()

# %%
hp_to_xref = expand_split_col(hp_nodes.set_index('id')['xref'].dropna().str.split('|')).rename(columns={'old_idx': 'hp_id'})
(hp_to_xref[hp_to_xref['xref'].str.contains('MSH:')]['hp_id'].value_counts() > 1).sum()
# Out:
# 78

# %%
hp_to_xref['hp_id'].nunique()
# Out:
# 11686

# %%
disease_ids = nodes.query('label == "Disease"')['id'].unique()

# %%
hp_to_xref['xref'] = hp_to_xref['xref'].str.replace('MSH:', 'MESH:')
hp_disease_ids = hp_to_xref.query('xref in @disease_ids')['hp_id'].unique()
non_disease_hp = hp_to_xref.query('xref not in @disease_ids').copy()
non_disease_hp['name'] = non_disease_hp['hp_id'].map(hp_name_map)
len(non_disease_hp[non_disease_hp['xref'].str.contains('MESH:')])
# Out:
# 397

# %%
hp_to_dis = hp_to_dis.query('hp_id not in @hp_disease_ids').copy()
print(len(hp_to_dis))
print(hp_to_dis['hp_id'].nunique())
print(hp_to_dis['disease_id'].nunique())
# Out:
# 12425
# 2803
# 2250

# %%
hp_to_dis.sample(10)
# Out:
#          db db_object_id                                            db_name  \
# 16258  OMIM       191830  #191830 RENAL HYPODYSPLASIA/APLASIA 1; RHDA1;;...
# 4680   OMIM       125250  OPTIC ATROPHY WITH OR WITHOUT DEAFNESS, OPHTHA...
# 70020  OMIM       612961              MULTIPLE SYNOSTOSES SYNDROME 3; SYNS3
# 5844   OMIM       132400                  EPIPHYSEAL DYSPLASIA, MULTIPLE, 1
# 51207  OMIM       601214                                      NAXOS DISEASE
# 71411  OMIM       613330  SPONDYLO-MEGAEPIPHYSEAL-METAPHYSEAL DYSPLASIA;...
# 63513  OMIM       609622                  #609622 SHORT QT SYNDROME 3; SQT3
# 66191  OMIM       610967  #610967 OSTEOGENESIS IMPERFECTA, TYPE V; OI5;;...
# 92661  OMIM       617396                       ANAUXETIC DYSPLASIA 2; ANXD2
# 54705  OMIM       603554  #603554 OMENN SYNDROME;;RETICULOENDOTHELIOSIS,...
#
#       qualifier       hp_id   db_reference evidence_code onset_modifier  \
# 16258       NaN  HP:0000007    OMIM:191830           TAS            NaN
# 4680        NaN  HP:0000408    OMIM:125250           PCS            NaN
# 70020       NaN  HP:0006064  PMID:19589401           PCS            NaN
# 5844        NaN  HP:0010585    OMIM:132400           TAS            NaN
# 51207       NaN  HP:0011663  PMID:11691526           PCS            NaN
# 71411       NaN  HP:0000007    OMIM:613330           TAS            NaN
# 63513       NaN  HP:0000006  PMID:15761194           PCS            NaN
# 66191       NaN  HP:0000592    OMIM:610967           TAS            NaN
# 92661       NaN  HP:0002812    OMIM:617396           TAS            NaN
# 54705       NaN  HP:0000778    OMIM:603554           TAS            NaN
#
#         frequency  sex modifier aspect   date_created assigned_by  \
# 16258         NaN  NaN        I    NaN   HPO:skoehler         NaN
# 4680          NaN  NaN        P    NaN  HPO:probinson         NaN
# 70020         NaN  NaN        P    NaN  HPO:probinson         NaN
# 5844          NaN  NaN        P    NaN  HPO:probinson         NaN
# 51207         NaN  NaN        P    NaN  HPO:probinson         NaN
# 71411         NaN  NaN        I    NaN  HPO:probinson         NaN
# 63513         NaN  NaN        I    NaN  HPO:probinson         NaN
# 66191  HP:0040283  NaN        P    NaN   HPO:skoehler  HP:0040283
# 92661         NaN  NaN        P    NaN   HPO:skoehler         NaN
# 54705         NaN  NaN        P    NaN  HPO:probinson         NaN
#
#                                             hp_name   disease_id
# 16258               Autosomal recessive inheritance  OMIM:191830
# 4680   Progressive sensorineural hearing impairment  OMIM:125250
# 70020              Limited interphalangeal movement  OMIM:612961
# 5844                                Small epiphyses  OMIM:132400
# 51207              Right ventricular cardiomyopathy  OMIM:601214
# 71411               Autosomal recessive inheritance  OMIM:613330
# 63513                Autosomal dominant inheritance  OMIM:609622
# 66191                                  Blue sclerae  OMIM:610967
# 92661                                     Coxa vara  OMIM:617396
# 54705                      Hypoplasia of the thymus  OMIM:603554

# %%
hp_to_keep = hp_to_dis['hp_id'].unique()

# %% [markdown]
# So these are the HPO ids that we'll keep for our network...
# Not all the Gene to HP ids will be contained in this set so we need to filter a bit

# %%
hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids')['gene_id'].nunique()
# Out:
# 3950

# %%
hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids')['hp_id'].nunique()
# Out:
# 2781

# %%
len(hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids'))
# Out:
# 67031

# %% [markdown]
# ## Aggregate the new edges and save to disk

# %%
hp_to_dis_edges = hp_to_dis.rename(columns={'disease_id': 'start_id', 'hp_id': 'end_id'})
hp_to_dis_edges['start_id'] = hp_to_dis_edges['start_id'].map({v:k for k, v in mesh_to_omim.items()})
hp_to_dis_edges['type'] = 'presents_DpPH'
hp_to_dis_edges['evidence'] = 'curated' # we filtered out all the IEA edges

hp_to_dis_edges[['start_id', 'end_id', 'type']].head(2)
# Out:
#          start_id      end_id           type
# 443  MESH:D016518  HP:0007935  presents_DpPH
# 445  MESH:D016518  HP:0009590  presents_DpPH

# %%
hp_to_gene_edges = hp_gene.query('hp_id in @hp_to_keep and gene_id in @node_ids').copy()
hp_to_gene_edges = hp_to_gene_edges.rename(columns={'hp_id': 'start_id', 'gene_id': 'end_id'})
hp_to_gene_edges['type'] = 'associated_with_PHawG'
hp_to_gene_edges['evidence'] = 'computed'

hp_to_gene_edges[['start_id', 'end_id', 'type']].head(2)
# Out:
#      start_id end_id                   type
# 1  HP:0004322   8192  associated_with_PHawG
# 2  HP:0000786   8192  associated_with_PHawG

# %%
all_edges = pd.concat([hp_to_dis_edges[['start_id', 'end_id', 'type', 'evidence']], 
                       hp_to_gene_edges[['start_id', 'end_id', 'type', 'evidence']]], ignore_index=True)
all_edges.head(2)
# Out:
#        start_id      end_id           type evidence
# 0  MESH:D016518  HP:0007935  presents_DpPH  curated
# 1  MESH:D016518  HP:0009590  presents_DpPH  curated

# %%
all_edges['source'] = 'Human Phenotype Ontology'

# %%
edge_ids = set(all_edges['start_id']).union(set(all_edges['end_id']))
hp_nodes_filt = hp_nodes.query('id in @edge_ids')[['id', 'name']]
hp_nodes_filt['label'] = 'Phenotype'

# %%
all_edges.to_csv(out_dir.joinpath('edges.csv'), index=False)
hp_nodes_filt.to_csv(out_dir.joinpath('nodes.csv'), index=False)
