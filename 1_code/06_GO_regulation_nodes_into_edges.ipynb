# %% [markdown]
# # GO Nodes into Edges
#
# GO Biological Process nodes sometimes have to do with regulation...
#
# E.G. GO:0045861	negative regulation of proteolysis
#
# Any Term that links to this go term essentially has an edge:
#     negatively_regulates -> GO:0006508	proteolysis
#
# Therefore we will determine these regulation nodes and convert them to edges.

# %%
import pandas as pd
from pathlib import Path
from metapaths.tools.hetnet_file_processing import read_reactome
from metapaths.tools.processing import regularize_colnames, head, expand_col_on_char, combine_group_rows_on_char
from hetnet_ml.src import graph_tools as gt

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

load_dir = Path('../2_pipeline/00_download_data/out/').resolve()
network_dir = load_dir.parent.parent.joinpath('05_GO_Genes_and_protein_families/out')

# %%
all_nodes = gt.remove_colons(pd.read_csv(network_dir.joinpath('nodes_all.csv'), dtype=str))
edges = gt.remove_colons(pd.read_csv(network_dir.joinpath('edges.csv'), dtype=str))

# %%
all_node_ids = all_nodes['id'].values
new_nodes = []
new_edges = []

# %%
all_nodes.head(2)
# Out:
#              id                     name     label  \
# 0  MESH:C089250  (0.017ferrocene)amylose  Compound
# 1  MESH:C114385               001-C8-NBD  Compound
#
#                                         tree_numbers drug_bank_ids  \
# 0  D01.490.200/C089250|D02.691.550.200/C089250|D0...           NaN
# 1    D03.383.129.462.580/C114385|D12.644.456/C114385           NaN
#
#   alt_disease_ids gene_symbol alt_gene_ids bio_gridids pharm_gkbids  \
# 0             NaN         NaN          NaN         NaN          NaN
# 1             NaN         NaN          NaN         NaN          NaN
#
#   uni_prot_ids uniprot_id mesh_ids chebi_ids
# 0          NaN        NaN      NaN       NaN
# 1          NaN        NaN      NaN       NaN

# %% [markdown]
# # GO regulation...

# %%
go_terms = all_nodes.query('label in {}'.format(['Molecular Function', 'Cellular Component', 'Biological Process']))
len(go_terms)
# Out:
# 45017

# %%
reg_terms = go_terms['name'].str.contains('regulation of')
reg_terms.sum()
# Out:
# 10748

# %%
reg_ids = go_terms[reg_terms]['id'].values

# %% [markdown]
# ## We'll get the regulation Edges from go.obo
#
# Need some functions to parse the obo file...

# %%
def read_lines(filename):
    with open(filename, 'r') as fin:
        for line in fin.readlines():
            yield line

            
def parse_id(line):
    return line.lstrip('id:').strip()


def parse_name(line):
    return line.lstrip('name:').strip()


def parse_relationship(line, go_id, name):
    value = line.lstrip('relationship:').strip()
    rel_info, tgt_name = value.split(' ! ')
    id_idx = rel_info.index('GO:')
    tgt_id = rel_info[id_idx:]
    rel_type = rel_info[:id_idx].strip()
    
    return {'go_id': go_id, 'go_name': name, 'rel_type': rel_type, 'tgt_id': tgt_id, 'tgt_name': tgt_name}            


def read_obo_relationships(filename):
    relationships = []

    for l in read_lines(filename):
        if l.startswith('id:'):
            go_id = parse_id(l)
        if l.startswith('name:'):
            name = parse_name(l)
        if l.startswith('relationship:'):
            relationship = parse_relationship(l, go_id, name)
            relationships.append(relationship)

    return pd.DataFrame(relationships)

# %%
go_rels = read_obo_relationships(load_dir.joinpath('go.obo'))

# %%
go_rels.head(10)
# Out:
#         go_id                              go_name   rel_type      tgt_id  \
# 0  GO:0000018      regulation of DNA recombination  regulates  GO:0006310
# 1  GO:0000019  regulation of mitotic recombination  regulates  GO:0006312
# 2  GO:0000022           mitotic spindle elongation    part_of  GO:0000070
# 3  GO:0000022           mitotic spindle elongation    part_of  GO:0007052
# 4  GO:0000027     ribosomal large subunit assembly    part_of  GO:0042255
# 5  GO:0000027     ribosomal large subunit assembly    part_of  GO:0042273
# 6  GO:0000028     ribosomal small subunit assembly    part_of  GO:0042255
# 7  GO:0000028     ribosomal small subunit assembly    part_of  GO:0042274
# 8  GO:0000030         mannosyltransferase activity    part_of  GO:0097502
# 9  GO:0000036                acyl carrier activity    part_of  GO:0006633
#
#                                tgt_name
# 0                     DNA recombination
# 1                 mitotic recombination
# 2  mitotic sister chromatid segregation
# 3          mitotic spindle organization
# 4                     ribosome assembly
# 5    ribosomal large subunit biogenesis
# 6                     ribosome assembly
# 7    ribosomal small subunit biogenesis
# 8                         mannosylation
# 9       fatty acid biosynthetic process

# %%
go_rels['rel_type'].value_counts()
# Out:
# part_of                 7933
# regulates               3579
# negatively_regulates    3131
# positively_regulates    3105
# has_part                 733
# occurs_in                193
# happens_during             7
# ends_during                1
# Name: rel_type, dtype: int64

# %%
print(len(go_rels.query('rel_type == "part_of"')))
go_rels.query('rel_type == "part_of"').sample(5)
# Out:
# 7933
#             go_id                                            go_name rel_type  \
# 6203   GO:0035857                      eosinophil fate specification  part_of
# 3355   GO:0015247  aminophospholipid transmembrane transporter ac...  part_of
# 6121   GO:0035599       aspartic acid methylthiotransferase activity  part_of
# 11669  GO:0072326                     vulval cell fate determination  part_of
# 9989   GO:0060681  branch elongation involved in ureteric bud bra...  part_of
#
#            tgt_id                                           tgt_name
# 6203   GO:0035854                         eosinophil fate commitment
# 3355   GO:0015917                        aminophospholipid transport
# 6121   GO:0018339  peptidyl-L-beta-methylthioaspartic acid biosyn...
# 11669  GO:0072325                        vulval cell fate commitment
# 9989   GO:0001658   branching involved in ureteric bud morphogenesis

# %%
reg_rels = ['regulates', 'negatively_regulates', 'positively_regulates']
reg_res = go_rels.query('rel_type in @reg_rels')

# %%
reg_ids = reg_res['go_id'].values

# %%
combo = gt.combine_nodes_and_edges(all_nodes, edges)
combo_cols = ['start_id', 'start_name', 'start_label', 'type', 'end_id', 'end_name', 'end_label']

# %%
no_map_terms = go_terms[reg_terms].query('id not in @reg_ids')['id'].values
print(len(combo.query('start_id in @no_map_terms and end_label == "Disease"')))
combo.query('start_id in @no_map_terms and end_label == "Disease"')[combo_cols].sample(5)
# Out:
# 62099
#            start_id                                         start_name  \
# 4794880  GO:0061418  regulation of transcription from RNA polymeras...
# 4471937  GO:0051092  positive regulation of NF-kappaB transcription...
# 4115201  GO:0043116       negative regulation of vascular permeability
# 4911051  GO:0023019  signal transduction involved in regulation of ...
# 4578923  GO:1901522  positive regulation of transcription from RNA ...
#
#                 start_label                   type        end_id  \
# 4794880  Biological Process  associated_with_BPawD  MESH:D002114
# 4471937  Biological Process  associated_with_BPawD  MESH:D003537
# 4115201  Biological Process  associated_with_BPawD  MESH:D007247
# 4911051  Biological Process  associated_with_BPawD  MESH:D009362
# 4578923  Biological Process  associated_with_BPawD  MESH:D008654
#
#                     end_name end_label
# 4794880           Calcinosis   Disease
# 4471937          Cystadenoma   Disease
# 4115201  Infertility, Female   Disease
# 4911051  Neoplasm Metastasis   Disease
# 4578923         Mesothelioma   Disease

# %%
map_terms = go_terms.query('id in @reg_ids')['id'].values
print(len(combo.query('start_id in @map_terms and end_label == "Disease"')))
combo.query('start_id in @map_terms and end_label == "Disease"')[combo_cols].sample(5)
# Out:
# 656949
#            start_id                                         start_name  \
# 4281435  GO:1900039  positive regulation of cellular response to hy...
# 4028952  GO:2000483     negative regulation of interleukin-8 secretion
# 4792913  GO:0006357   regulation of transcription by RNA polymerase II
# 4234354  GO:2001171    positive regulation of ATP biosynthetic process
# 4271968  GO:0030335              positive regulation of cell migration
#
#                 start_label                   type        end_id  \
# 4281435  Biological Process  associated_with_BPawD  MESH:D012770
# 4028952  Biological Process  associated_with_BPawD  MESH:D007249
# 4792913  Biological Process  associated_with_BPawD  MESH:D018335
# 4234354  Biological Process  associated_with_BPawD  MESH:D009421
# 4271968  Biological Process  associated_with_BPawD  MESH:D020325
#
#                              end_name end_label
# 4281435            Shock, Cardiogenic   Disease
# 4028952                  Inflammation   Disease
# 4792913                Rhabdoid Tumor   Disease
# 4234354  Nervous System Malformations   Disease
# 4271968            Migraine with Aura   Disease

# %%
tgt_ids = reg_res['tgt_id'].values
map_terms1 = go_terms.query('id in @tgt_ids')['id'].values
print(len(combo.query('start_id in @map_terms1 and end_label == "Disease"')))
combo.query('start_id in @map_terms1 and end_label == "Disease"')[combo_cols].sample(5)
# Out:
# 532791
#            start_id                          start_name         start_label  \
# 3418930  GO:0044267  cellular protein metabolic process  Biological Process
# 3723884  GO:0043967              histone H4 acetylation  Biological Process
# 4618984  GO:0016579            protein deubiquitination  Biological Process
# 3326623  GO:0008150                  biological_process  Biological Process
# 3555883  GO:0006310                   DNA recombination  Biological Process
#
#                           type        end_id  \
# 3418930  associated_with_BPawD  MESH:D001480
# 3723884  associated_with_BPawD  MESH:D015417
# 4618984  associated_with_BPawD  MESH:D009422
# 3326623  associated_with_BPawD  MESH:C566593
# 3555883  associated_with_BPawD  MESH:D001855
#
#                                         end_name end_label
# 3418930                   Basal Ganglia Diseases   Disease
# 3723884  Hereditary Sensory and Motor Neuropathy   Disease
# 4618984                  Nervous System Diseases   Disease
# 3326623             Hypomagnesemia 1, Intestinal   Disease
# 3555883                     Bone Marrow Diseases   Disease

# %%
# Regulations of regulation.... not sure what to do here but just drop
print(len(reg_res[reg_res['tgt_name'].str.contains('regulation of')]))
reg_res[reg_res['tgt_name'].str.contains('regulation of')].sample(5)
# Out:
# 34
#             go_id                                            go_name  \
# 13862  GO:1900545  regulation of phenotypic switching by regulati...
# 13809  GO:1900465  negative regulation of arginine catabolic proc...
# 13768  GO:1900415  regulation of fungal-type cell wall biogenesis...
# 13863  GO:1900547  negative regulation of phenotypic switching by...
# 11339  GO:0071809  regulation of fever generation by regulation o...
#
#                    rel_type      tgt_id  \
# 13862             regulates  GO:0100057
# 13809  negatively_regulates  GO:0100045
# 13768             regulates  GO:0100033
# 13863             regulates  GO:0100059
# 11339             regulates  GO:0100008
#
#                                                 tgt_name
# 13862  regulation of phenotypic switching by transcri...
# 13809  negative regulation of arginine catabolic proc...
# 13768  regulation of fungal-type cell wall biogenesis...
# 13863  negative regulation of phenotypic switching by...
# 11339  regulation of fever generation by prostaglandi...

# %%
# Things without 'regulation of' that appearantly regulate...
print(len(reg_res[~reg_res['go_name'].str.contains('regulation of')]))
reg_res[~reg_res['go_name'].str.contains('regulation of')].sample(5)
# Out:
# 166
#             go_id                                            go_name  \
# 6514   GO:0042030                          ATPase inhibitor activity
# 181    GO:0000765  response to pheromone regulating pheromone-ind...
# 3676   GO:0019834                phospholipase A2 inhibitor activity
# 16846  GO:1905318              meiosis I spindle assembly checkpoint
# 9618   GO:0060228  phosphatidylcholine-sterol O-acyltransferase a...
#
#                    rel_type      tgt_id  \
# 6514   negatively_regulates  GO:0016887
# 181               regulates  GO:0000762
# 3676   negatively_regulates  GO:0004623
# 16846  negatively_regulates  GO:0051755
# 9618   positively_regulates  GO:0004607
#
#                                                 tgt_name
# 6514                                     ATPase activity
# 181         pheromone-induced unidirectional conjugation
# 3676                           phospholipase A2 activity
# 16846            meiotic sister chromatid arm separation
# 9618   phosphatidylcholine-sterol O-acyltransferase a...

# %%
edges.columns
# Out:
# Index(['start_id', 'end_id', 'type', 'parent_ixn', 'pub_med_ids',
#        'organism_id', 'abbv', 'direct_evidence', 'corrected_pvalue',
#        'inference_gene_symbol', 'qualifier', 'db_reference', 'evidence_code',
#        'with_or_from', 'date', 'assigned_by', 'experiments', 'support_type'],
#       dtype='object')

# %%
combo_cols += ['abbv', 'parent_ixn', 'db_reference', 'evidence_code']
mrg = pd.merge(combo[combo_cols], reg_res, how='left', left_on='end_id', right_on='go_id')

# %%
len(mrg)
# Out:
# 6333568

# %%
# don't wnat to touch the curated edges... they already have direction to them
reg_edges = mrg[mrg['parent_ixn'].isnull()]
reg_edges = reg_edges.dropna(subset=['tgt_id'])

reg_edges.head(2)
# Out:
#         start_id           start_name start_label               type  \
# 5354839      100  adenosine deaminase        Gene  involved_in_GinBP
# 5354840      100  adenosine deaminase        Gene  involved_in_GinBP
#
#              end_id                                          end_name  \
# 5354839  GO:0002636  positive regulation of germinal center formation
# 5354840  GO:0002686        negative regulation of leukocyte migration
#
#                   end_label   abbv parent_ixn    db_reference evidence_code  \
# 5354839  Biological Process  GinBP        NaN  GO_REF:0000107           IEA
# 5354840  Biological Process  GinBP        NaN  GO_REF:0000107           IEA
#
#               go_id                                           go_name  \
# 5354839  GO:0002636  positive regulation of germinal center formation
# 5354840  GO:0002686        negative regulation of leukocyte migration
#
#                      rel_type      tgt_id                   tgt_name
# 5354839  positively_regulates  GO:0002467  germinal center formation
# 5354840  negatively_regulates  GO:0050900        leukocyte migration

# %%
id_to_label = all_nodes.set_index('id')['label'].to_dict()

# %%
abbv, et = gt.get_abbrev_dict_and_edge_tuples(all_nodes, edges.drop_duplicates(subset=['type']))

# %%
reg_edges = reg_edges.drop(['end_id', 'end_label', 'end_name'], axis=1)
reg_edges['end_label'] = reg_edges['tgt_id'].map(id_to_label)
reg_edges['abbv'] = reg_edges['start_label'].map(abbv) + \
                        reg_edges['rel_type'].apply(lambda s: ''.join([z[0] for z in s.split('_')])) + \
                        reg_edges['end_label'].map(abbv)
reg_edges['type'] = reg_edges['rel_type'] + '_' + reg_edges['abbv']
reg_edges = reg_edges.rename(columns={'tgt_id':'end_id', 'tgt_name': 'end_name'})
reg_edges.head(2)
# Out:
#         start_id           start_name start_label                        type  \
# 5354839      100  adenosine deaminase        Gene  positively_regulates_GprBP
# 5354840      100  adenosine deaminase        Gene  negatively_regulates_GnrBP
#
#           abbv parent_ixn    db_reference evidence_code       go_id  \
# 5354839  GprBP        NaN  GO_REF:0000107           IEA  GO:0002636
# 5354840  GnrBP        NaN  GO_REF:0000107           IEA  GO:0002686
#
#                                                   go_name  \
# 5354839  positive regulation of germinal center formation
# 5354840        negative regulation of leukocyte migration
#
#                      rel_type      end_id                   end_name  \
# 5354839  positively_regulates  GO:0002467  germinal center formation
# 5354840  negatively_regulates  GO:0050900        leukocyte migration
#
#                   end_label
# 5354839  Biological Process
# 5354840  Biological Process

# %%
reg_edges = reg_edges[combo_cols].drop(['start_name', 'start_label', 'end_name', 'end_label'], axis=1).reset_index(drop=True)
reg_edges.head(2)
# Out:
#   start_id                        type      end_id   abbv parent_ixn  \
# 0      100  positively_regulates_GprBP  GO:0002467  GprBP        NaN
# 1      100  negatively_regulates_GnrBP  GO:0050900  GnrBP        NaN
#
#      db_reference evidence_code
# 0  GO_REF:0000107           IEA
# 1  GO_REF:0000107           IEA

# %% [markdown]
# # Putting it all together

# %%
reg_edges.head(2)
# Out:
#   start_id                        type      end_id   abbv parent_ixn  \
# 0      100  positively_regulates_GprBP  GO:0002467  GprBP        NaN
# 1      100  negatively_regulates_GnrBP  GO:0050900  GnrBP        NaN
#
#      db_reference evidence_code
# 0  GO_REF:0000107           IEA
# 1  GO_REF:0000107           IEA

# %%
reg_edges['type'].value_counts()
# Out:
# positively_regulates_GprBP     15578
# negatively_regulates_GnrBP     10464
# regulates_GrBP                 10036
# positively_regulates_GprMF      2144
# negatively_regulates_GnrMF      1593
# regulates_PFrBP                  898
# regulates_GrMF                   851
# negatively_regulates_NnrBP       737
# positively_regulates_NprBP       464
# negatively_regulates_PFnrBP      267
# positively_regulates_XprBP       197
# positively_regulates_PFprBP      196
# negatively_regulates_PFnrMF      111
# regulates_XrBP                   109
# positively_regulates_PFprMF       90
# negatively_regulates_XnrBP        63
# regulates_PFrMF                   58
# negatively_regulates_NnrMF        50
# regulates_NrBP                    48
# regulates_PWrBP                   46
# negatively_regulates_RXnrBP       36
# positively_regulates_PWprBP       30
# positively_regulates_XprMF        17
# positively_regulates_RXprBP       16
# regulates_RXrBP                   13
# regulates_XrMF                    12
# positively_regulates_NprMF        12
# negatively_regulates_PWnrBP       11
# negatively_regulates_XnrMF        10
# regulates_PWrMF                    7
# positively_regulates_RXprMF        6
# positively_regulates_PWprMF        3
# negatively_regulates_RXnrMF        2
# regulates_RXrMF                    1
# Name: type, dtype: int64

# %%
print('Total number of new edges: {:,}'.format(len(reg_edges)))
print('Number of unique new edges: {:,}'.format(len(reg_edges.drop_duplicates(subset=['start_id', 'end_id', 'type']))))
# Out:
# Total number of new edges: 44,176
# Number of unique new edges: 43,704

# %% [markdown]
# Why are so many edges duplicated? what kind are they?

# %%
ix = reg_edges.duplicated(keep=False)
reg_edges[ix].sort_values(['start_id', 'end_id', 'type']).head(10)
# Out:
#      start_id                        type      end_id   abbv parent_ixn  \
# 780     10221  negatively_regulates_GnrMF  GO:0004672  GnrMF        NaN
# 781     10221  negatively_regulates_GnrMF  GO:0004672  GnrMF        NaN
# 1940    10681  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 1941    10681  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2322    10928  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2324    10928  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2626    11142  negatively_regulates_GnrMF  GO:0004691  GnrMF        NaN
# 2628    11142  negatively_regulates_GnrMF  GO:0004691  GnrMF        NaN
# 2805     1124  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2807     1124  positively_regulates_GprMF  GO:0003924  GprMF        NaN
#
#         db_reference evidence_code
# 780    PMID:15299019           IMP
# 781    PMID:15299019           IMP
# 1940   PMID:10521509           IDA
# 1941   PMID:10521509           IDA
# 2322    PMID:7673236       IBA|IDA
# 2324    PMID:7673236       IBA|IDA
# 2626   PMID:21873635           IBA
# 2628   PMID:21873635           IBA
# 2805  GO_REF:0000002           IEA
# 2807  GO_REF:0000002           IEA

# %%
reg_edges[ix]['type'].value_counts()
# Out:
# positively_regulates_GprMF     92
# negatively_regulates_GnrMF     60
# positively_regulates_PFprMF    24
# regulates_GrMF                 10
# negatively_regulates_PFnrMF    10
# negatively_regulates_XnrMF      2
# Name: type, dtype: int64

# %%
dup_types = reg_edges[ix]['type'].unique()

dup_dfs = []

for dt in dup_types:
    dup_dfs.append(reg_edges[ix].query('type == @dt').sort_values(['start_id', 'end_id', 'type']).head(6))
    
pd.concat(dup_dfs)
# Out:
#                  start_id                         type      end_id    abbv  \
# 780                 10221   negatively_regulates_GnrMF  GO:0004672   GnrMF
# 781                 10221   negatively_regulates_GnrMF  GO:0004672   GnrMF
# 2626                11142   negatively_regulates_GnrMF  GO:0004691   GnrMF
# 2628                11142   negatively_regulates_GnrMF  GO:0004691   GnrMF
# 4045               132864   negatively_regulates_GnrMF  GO:0003924   GnrMF
# 4046               132864   negatively_regulates_GnrMF  GO:0003924   GnrMF
# 1940                10681   positively_regulates_GprMF  GO:0003924   GprMF
# 1941                10681   positively_regulates_GprMF  GO:0003924   GprMF
# 2322                10928   positively_regulates_GprMF  GO:0003924   GprMF
# 2324                10928   positively_regulates_GprMF  GO:0003924   GprMF
# 2805                 1124   positively_regulates_GprMF  GO:0003924   GprMF
# 2807                 1124   positively_regulates_GprMF  GO:0003924   GprMF
# 3732               124997               regulates_GrMF  GO:0035004    GrMF
# 3733               124997               regulates_GrMF  GO:0035004    GrMF
# 3933               129138               regulates_GrMF  GO:0004672    GrMF
# 3935               129138               regulates_GrMF  GO:0004672    GrMF
# 6831                 1956               regulates_GrMF  GO:0004517    GrMF
# 6856                 1956               regulates_GrMF  GO:0004517    GrMF
# 41065              CPX-98   negatively_regulates_XnrMF  GO:0008233   XnrMF
# 41066              CPX-98   negatively_regulates_XnrMF  GO:0008233   XnrMF
# 42701  InterPro:IPR003913  positively_regulates_PFprMF  GO:0003924  PFprMF
# 42703  InterPro:IPR003913  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43236  InterPro:IPR026817  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43237  InterPro:IPR026817  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43254  InterPro:IPR027107  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43255  InterPro:IPR027107  positively_regulates_PFprMF  GO:0003924  PFprMF
# 42782  InterPro:IPR007648  negatively_regulates_PFnrMF  GO:0016887  PFnrMF
# 42783  InterPro:IPR007648  negatively_regulates_PFnrMF  GO:0016887  PFnrMF
# 42806  InterPro:IPR008296  negatively_regulates_PFnrMF  GO:0008233  PFnrMF
# 42807  InterPro:IPR008296  negatively_regulates_PFnrMF  GO:0008233  PFnrMF
# 42885  InterPro:IPR010832  negatively_regulates_PFnrMF  GO:0004175  PFnrMF
# 42886  InterPro:IPR010832  negatively_regulates_PFnrMF  GO:0004175  PFnrMF
#
#       parent_ixn    db_reference evidence_code
# 780          NaN   PMID:15299019           IMP
# 781          NaN   PMID:15299019           IMP
# 2626         NaN   PMID:21873635           IBA
# 2628         NaN   PMID:21873635           IBA
# 4045         NaN  GO_REF:0000024           ISS
# 4046         NaN  GO_REF:0000024           ISS
# 1940         NaN   PMID:10521509           IDA
# 1941         NaN   PMID:10521509           IDA
# 2322         NaN    PMID:7673236       IBA|IDA
# 2324         NaN    PMID:7673236       IBA|IDA
# 2805         NaN  GO_REF:0000002           IEA
# 2807         NaN  GO_REF:0000002           IEA
# 3732         NaN   PMID:26783301           IMP
# 3733         NaN   PMID:26783301           IMP
# 3933         NaN   PMID:21873635           IBA
# 3935         NaN   PMID:21873635           IBA
# 6831         NaN   PMID:12828935           IDA
# 6856         NaN   PMID:12828935           IDA
# 41065        NaN   PMID:20860624           IDA
# 41066        NaN   PMID:20860624           IDA
# 42701        NaN             NaN           NaN
# 42703        NaN             NaN           NaN
# 43236        NaN             NaN           NaN
# 43237        NaN             NaN           NaN
# 43254        NaN             NaN           NaN
# 43255        NaN             NaN           NaN
# 42782        NaN             NaN           NaN
# 42783        NaN             NaN           NaN
# 42806        NaN             NaN           NaN
# 42807        NaN             NaN           NaN
# 42885        NaN             NaN           NaN
# 42886        NaN             NaN           NaN

# %% [markdown]
# I see no reason for any of these duplications.... We'll just do a simple 'drop_duplicates' rather than merging any columns

# %%
reg_edges = reg_edges.drop_duplicates(subset=['start_id', 'end_id', 'type']).copy()

# %%
len(reg_edges)
# Out:
# 43704

# %%
all_node_ids = set(all_nodes['id']) 

print(len(reg_edges))
reg_edges_filt = reg_edges.query('start_id in @all_node_ids and end_id in @all_node_ids')
print(len(reg_edges_filt))
# Out:
# 43704
# 43704

# %%
all_edges = pd.concat([edges, reg_edges_filt], sort=False)
all_edges.head(2)
# Out:
#        start_id end_id                       type            parent_ixn  \
# 0  MESH:C000121   4313    decreases_activity_CdaG    decreases^activity
# 1  MESH:C000121   4313  decreases_expression_CdeG  decreases^expression
#
#   pub_med_ids organism_id  abbv direct_evidence corrected_pvalue  \
# 0    25899827        9606  CdaG             NaN              NaN
# 1    25899827        9606  CdeG             NaN              NaN
#
#   inference_gene_symbol qualifier db_reference evidence_code with_or_from  \
# 0                   NaN       NaN          NaN           NaN          NaN
# 1                   NaN       NaN          NaN           NaN          NaN
#
#   date assigned_by experiments support_type
# 0  NaN         NaN         NaN          NaN
# 1  NaN         NaN         NaN          NaN

# %%
all_edge_ids = all_edges[['start_id', 'end_id']].stack()
filt_nodes = all_nodes.query('id in @all_edge_ids')
len(filt_nodes)
# Out:
# 126348

# %% [markdown]
# # Save to Disk

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')
# // hack to get the filename for this notebook

# %%
out_dir = Path('../2_pipeline/').joinpath(nb_name.split('.')[0]).joinpath('out').resolve()
out_dir.mkdir(parents=True, exist_ok=True)

# %%
#gt.add_colons(new_nodes_df, id_name='identifier').to_csv(out_dir.joinpath('new_nodes.csv'), index=False)
gt.add_colons(reg_edges).to_csv(out_dir.joinpath('new_edges.csv'), index=False)

# %%
gt.add_colons(all_nodes, id_name='identifier').to_csv(out_dir.joinpath('nodes_all.csv'), index=False)
gt.add_colons(filt_nodes, id_name='identifier').to_csv(out_dir.joinpath('nodes_filt.csv'), index=False)

gt.add_colons(all_edges).to_csv(out_dir.joinpath('edges.csv'), index=False)
