# %% [markdown]
# # GO Nodes into Edges
#
# GO Biological Process nodes sometimes have to do with regulation...
#
# E.G. GO:0045861	negative regulation of proteolysis
#
# Any Term that links to this go term essentially has an edge:
#     negatively_regulates -> GO:0006508	proteolysis
#
# Therefore we will determine these regulation nodes and convert them to edges.

# %%
import pandas as pd
from pathlib import Path
from metapaths.tools.hetnet_file_processing import read_reactome
from metapaths.tools.processing import regularize_colnames, head, expand_col_on_char, combine_group_rows_on_char
from hetnet_ml.src import graph_tools as gt
import tools.obo_tools as ot

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

load_dir = Path('../2_pipeline/00_download_data/out/').resolve()
network_dir = load_dir.parent.parent.joinpath('05_GO_Genes_and_protein_families/out')

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')
# // hack to get the filename for this notebook

# %%
out_dir = Path('../2_pipeline/').joinpath(nb_name.split('.')[0]).joinpath('out').resolve()
out_dir.mkdir(parents=True, exist_ok=True)

# %%
all_nodes = gt.remove_colons(pd.read_csv(network_dir.joinpath('nodes_all.csv'), dtype=str))
edges = gt.remove_colons(pd.read_csv(network_dir.joinpath('edges.csv'), dtype=str))

# %%
all_node_ids = all_nodes['id'].values
new_nodes = []
new_edges = []

# %%
all_nodes.head(2)
# Out:
#              id                     name     label  \
# 0  MESH:C089250  (0.017ferrocene)amylose  Compound
# 1  MESH:C114385               001-C8-NBD  Compound
#
#                                         tree_numbers drug_bank_ids  \
# 0  D01.490.200/C089250|D02.691.550.200/C089250|D0...           NaN
# 1    D03.383.129.462.580/C114385|D12.644.456/C114385           NaN
#
#   alt_disease_ids gene_symbol alt_gene_ids bio_gridids pharm_gkbids  \
# 0             NaN         NaN          NaN         NaN          NaN
# 1             NaN         NaN          NaN         NaN          NaN
#
#   uni_prot_ids uniprot_id mesh_ids chebi_ids
# 0          NaN        NaN      NaN       NaN
# 1          NaN        NaN      NaN       NaN

# %% [markdown]
# # GO regulation...

# %%
go_terms = all_nodes.query('label in {}'.format(['Molecular Function', 'Cellular Component', 'Biological Process']))
len(go_terms)
# Out:
# 45017

# %%
reg_terms = go_terms['name'].str.contains('regulation of')
reg_terms.sum()
# Out:
# 10748

# %%
reg_ids = go_terms[reg_terms]['id'].values

# %% [markdown]
# ## We'll get the regulation Edges from go.obo
#
# Need some functions to parse the obo file...

# %%
go_rels = ot.get_ontology_edges(load_dir.joinpath('go.obo'))

# %%
go_rels.head(10)
# Out:
#        src_id                                           src_name rel_type  \
# 0  GO:0000001                          mitochondrion inheritance     is_a
# 1  GO:0000001                          mitochondrion inheritance     is_a
# 2  GO:0000002                   mitochondrial genome maintenance     is_a
# 3  GO:0000003                                       reproduction     is_a
# 4  GO:0000006  high-affinity zinc transmembrane transporter a...     is_a
# 5  GO:0000007  low-affinity zinc ion transmembrane transporte...     is_a
# 6  GO:0000009             alpha-1,6-mannosyltransferase activity     is_a
# 7  GO:0000010          trans-hexaprenyltranstransferase activity     is_a
# 8  GO:0000011                                vacuole inheritance     is_a
# 9  GO:0000011                                vacuole inheritance     is_a
#
#        tgt_id                                           tgt_name src_src  \
# 0  GO:0048308                              organelle inheritance      GO
# 1  GO:0048311                         mitochondrion distribution      GO
# 2  GO:0007005                         mitochondrion organization      GO
# 3  GO:0008150                                 biological_process      GO
# 4  GO:0005385        zinc ion transmembrane transporter activity      GO
# 5  GO:0005385        zinc ion transmembrane transporter activity      GO
# 6  GO:0000030                       mannosyltransferase activity      GO
# 7  GO:0016765  transferase activity, transferring alkyl or ar...      GO
# 8  GO:0007033                               vacuole organization      GO
# 9  GO:0048308                              organelle inheritance      GO
#
#   tgt_src
# 0      GO
# 1      GO
# 2      GO
# 3      GO
# 4      GO
# 5      GO
# 6      GO
# 7      GO
# 8      GO
# 9      GO

# %%
go_rels['rel_type'].value_counts()
# Out:
# is_a                    77058
# part_of                  7933
# regulates                3579
# negatively_regulates     3131
# positively_regulates     3105
# has_part                  733
# occurs_in                 193
# happens_during              7
# ends_during                 1
# Name: rel_type, dtype: int64

# %%
go_rels.query('rel_type == "part_of"').sample(5)
# Out:
#            src_id                                           src_name rel_type  \
# 134    GO:0000100  S-methylmethionine transmembrane transporter a...  part_of
# 48808  GO:0048905  anterior lateral line neuromast mantle cell di...  part_of
# 22613  GO:0021628                          olfactory nerve formation  part_of
# 60188  GO:0070743                             interleukin-23 complex  part_of
# 77249  GO:1901260  peptidyl-lysine hydroxylation involved in bact...  part_of
#
#            tgt_id                                     tgt_name src_src tgt_src
# 134    GO:0015806                 S-methylmethionine transport      GO      GO
# 48808  GO:0048901  anterior lateral line neuromast development      GO      GO
# 22613  GO:0021627                olfactory nerve morphogenesis      GO      GO
# 60188  GO:0005615                          extracellular space      GO      GO
# 77249  GO:0072580      bacterial-type EF-P lysine modification      GO      GO

# %%
reg_rels = ['regulates', 'negatively_regulates', 'positively_regulates']
reg_res = go_rels.query('rel_type in @reg_rels')

# %%
reg_ids = reg_res['src_id'].values

# %%
combo = gt.combine_nodes_and_edges(all_nodes, edges)
combo_cols = ['start_id', 'start_name', 'start_label', 'type', 'end_id', 'end_name', 'end_label']

# %%
no_map_terms = go_terms[reg_terms].query('id not in @reg_ids')['id'].values
print('Number of edges containing Regulation terms that cannot be converted to an edge: {:,}'.format(
            len(combo.query('start_id in @no_map_terms and end_label == "Disease"'))))
combo.query('start_id in @no_map_terms and end_label == "Disease"')[combo_cols].sample(5)
# Out:
# Number of edges containing Regulation terms that cannot be converted to an edge: 62,099
#            start_id                                         start_name  \
# 4589622  GO:0035810                positive regulation of urine volume
# 4763535  GO:0099509  regulation of presynaptic cytosolic calcium io...
# 4666560  GO:0008217                       regulation of blood pressure
# 3967266  GO:0045792                   negative regulation of cell size
# 4361165  GO:0010460                  positive regulation of heart rate
#
#                 start_label                   type        end_id  \
# 4589622  Biological Process  associated_with_BPawD  MESH:D009140
# 4763535  Biological Process  associated_with_BPawD  MESH:C563134
# 4666560  Biological Process  associated_with_BPawD  MESH:C536056
# 3967266  Biological Process  associated_with_BPawD  MESH:D009358
# 4361165  Biological Process  associated_with_BPawD  MESH:D052456
#
#                                                   end_name end_label
# 4589622                           Musculoskeletal Diseases   Disease
# 4763535                 Spinocerebellar Ataxia, X-Linked 1   Disease
# 4666560            Osteopetrosis autosomal dominant type 1   Disease
# 3967266  Congenital, Hereditary, and Neonatal Diseases ...   Disease
# 4361165                          Hypoalphalipoproteinemias   Disease

# %%
map_terms = go_terms.query('id in @reg_ids')['id'].values
print('Number of edges containing Regulation terms that can become an edge: {:,}'.format(
    len(combo.query('start_id in @map_terms and end_label == "Disease"'))))
combo.query('start_id in @map_terms and end_label == "Disease"')[combo_cols].sample(5)
# Out:
# Number of edges containing Regulation terms that can become an edge: 656,949
#            start_id                                         start_name  \
# 4350018  GO:0045722             positive regulation of gluconeogenesis
# 4262322  GO:0060355  positive regulation of cell adhesion molecule ...
# 4483534  GO:0045778                positive regulation of ossification
# 4346262  GO:0010628             positive regulation of gene expression
# 4050183  GO:0071638  negative regulation of monocyte chemotactic pr...
#
#                 start_label                   type        end_id  \
# 4350018  Biological Process  associated_with_BPawD  MESH:D011628
# 4262322  Biological Process  associated_with_BPawD  MESH:D001172
# 4483534  Biological Process  associated_with_BPawD  MESH:D013119
# 4346262  Biological Process  associated_with_BPawD  MESH:D012174
# 4050183  Biological Process  associated_with_BPawD  MESH:D010003
#
#                       end_name end_label
# 4350018       Puberty, Delayed   Disease
# 4262322  Arthritis, Rheumatoid   Disease
# 4483534   Spinal Cord Injuries   Disease
# 4346262   Retinitis Pigmentosa   Disease
# 4050183         Osteoarthritis   Disease

# %%
tgt_ids = reg_res['tgt_id'].values
map_terms1 = go_terms.query('id in @tgt_ids')['id'].values
print(len(combo.query('start_id in @map_terms1 and end_label == "Disease"')))
combo.query('start_id in @map_terms1 and end_label == "Disease"')[combo_cols].sample(5)
# Out:
# 532791
#            start_id                               start_name  \
# 3516631  GO:0019221      cytokine-mediated signaling pathway
# 4147031  GO:0006809        nitric oxide biosynthetic process
# 4949394  GO:0036466  synaptic vesicle recycling via endosome
# 4814280  GO:0003016               respiratory system process
# 5011555  GO:0016192               vesicle-mediated transport
#
#                 start_label                   type        end_id  \
# 3516631  Biological Process  associated_with_BPawD  MESH:D011018
# 4147031  Biological Process  associated_with_BPawD  MESH:D009325
# 4949394  Biological Process  associated_with_BPawD  MESH:D000236
# 4814280  Biological Process  associated_with_BPawD  MESH:D005512
# 5011555  Biological Process  associated_with_BPawD  MESH:D002779
#
#                         end_name end_label
# 3516631  Pneumonia, Pneumococcal   Disease
# 4147031                   Nausea   Disease
# 4949394                  Adenoma   Disease
# 4814280    Food Hypersensitivity   Disease
# 5011555              Cholestasis   Disease

# %%
# Regulations of regulation.... not sure what to do here but just drop
print(len(reg_res[reg_res['tgt_name'].str.contains('regulation of')]))
reg_res[reg_res['tgt_name'].str.contains('regulation of')].sample(5)
# Out:
# 34
#            src_id                                           src_name  \
# 74831  GO:1900545  regulation of phenotypic switching by regulati...
# 74370  GO:1900382  regulation of thiamine biosynthetic process by...
# 74384  GO:1900389  regulation of glucose import by regulation of ...
# 54755  GO:0060239  positive regulation of signal transduction inv...
# 84747  GO:1904001  positive regulation of pyrimidine-containing c...
#
#                    rel_type      tgt_id  \
# 74831             regulates  GO:0100057
# 74370             regulates  GO:0100016
# 74384             regulates  GO:0100018
# 54755  positively_regulates  GO:0032005
# 84747  positively_regulates  GO:0100068
#
#                                                 tgt_name src_src tgt_src
# 74831  regulation of phenotypic switching by transcri...      GO      GO
# 74370  regulation of thiamine biosynthetic process by...      GO      GO
# 74384  regulation of glucose import by transcription ...      GO      GO
# 54755  signal transduction involved in positive regul...      GO      GO
# 84747  positive regulation of pyrimidine-containing c...      GO      GO

# %%
# Things without 'regulation of' that appearantly regulate...
print(len(reg_res[~reg_res['src_name'].str.contains('regulation of')]))
reg_res[~reg_res['src_name'].str.contains('regulation of')].sample(5)
# Out:
# 166
#            src_id                                           src_name  \
# 6400   GO:0004860                  protein kinase inhibitor activity
# 10716  GO:0008073         ornithine decarboxylase inhibitor activity
# 53312  GO:0052371  regulation by organism of entry into other org...
# 64057  GO:0072587  DNA topoisomerase (ATP-hydrolyzing) activator ...
# 64951  GO:0075235    modulation of zoospore movement on or near host
#
#                    rel_type      tgt_id  \
# 6400   negatively_regulates  GO:0004672
# 10716  negatively_regulates  GO:0004586
# 53312             regulates  GO:0051828
# 64057  positively_regulates  GO:0003918
# 64951             regulates  GO:0075234
#
#                                                 tgt_name src_src tgt_src
# 6400                             protein kinase activity      GO      GO
# 10716                   ornithine decarboxylase activity      GO      GO
# 53312  entry into other organism involved in symbioti...      GO      GO
# 64057  DNA topoisomerase type II (ATP-hydrolyzing) ac...      GO      GO
# 64951                  zoospore movement on or near host      GO      GO

# %%
edges.columns
# Out:
# Index(['start_id', 'end_id', 'type', 'parent_ixn', 'pub_med_ids',
#        'organism_id', 'abbv', 'source', 'evidence', 'direct_evidence',
#        'corrected_pvalue', 'inference_gene_symbol', 'qualifier',
#        'db_reference', 'evidence_code', 'with_or_from', 'date', 'assigned_by',
#        'experiments', 'support_type'],
#       dtype='object')

# %%
combo_cols += ['abbv', 'parent_ixn', 'db_reference', 'evidence_code', 'source', 'evidence']
mrg = pd.merge(combo[combo_cols], reg_res, how='left', left_on='end_id', right_on='src_id')

# %%
'{:,}'.format(len(mrg))
# Out:
# '6,478,252'

# %%
# don't wnat to touch the curated edges... they already have direction to them
reg_edges = mrg[mrg['parent_ixn'].isnull()]
reg_edges = reg_edges.dropna(subset=['tgt_id'])

reg_edges.head(2)
# Out:
#         start_id           start_name start_label               type  \
# 5354839      100  adenosine deaminase        Gene  involved_in_GinBP
# 5354840      100  adenosine deaminase        Gene  involved_in_GinBP
#
#              end_id                                          end_name  \
# 5354839  GO:0002636  positive regulation of germinal center formation
# 5354840  GO:0002686        negative regulation of leukocyte migration
#
#                   end_label   abbv parent_ixn    db_reference evidence_code  \
# 5354839  Biological Process  GinBP        NaN  GO_REF:0000107           IEA
# 5354840  Biological Process  GinBP        NaN  GO_REF:0000107           IEA
#
#         source  evidence      src_id  \
# 5354839     GO  computed  GO:0002636
# 5354840     GO  computed  GO:0002686
#
#                                                  src_name  \
# 5354839  positive regulation of germinal center formation
# 5354840        negative regulation of leukocyte migration
#
#                      rel_type      tgt_id                   tgt_name src_src  \
# 5354839  positively_regulates  GO:0002467  germinal center formation      GO
# 5354840  negatively_regulates  GO:0050900        leukocyte migration      GO
#
#         tgt_src
# 5354839      GO
# 5354840      GO

# %%
id_to_label = all_nodes.set_index('id')['label'].to_dict()

# %%
abbv, et = gt.get_abbrev_dict_and_edge_tuples(all_nodes, edges.drop_duplicates(subset=['type']))

# %%
reg_edges = reg_edges.drop(['end_id', 'end_label', 'end_name'], axis=1)
reg_edges['end_label'] = reg_edges['tgt_id'].map(id_to_label)
reg_edges['abbv'] = reg_edges['start_label'].map(abbv) + \
                        reg_edges['rel_type'].apply(lambda s: ''.join([z[0] for z in s.split('_')])) + \
                        reg_edges['end_label'].map(abbv)
reg_edges['type'] = reg_edges['rel_type'] + '_' + reg_edges['abbv']
reg_edges = reg_edges.rename(columns={'tgt_id':'end_id', 'tgt_name': 'end_name'})
reg_edges.head(2)
# Out:
#         start_id           start_name start_label                        type  \
# 5354839      100  adenosine deaminase        Gene  positively_regulates_GprBP
# 5354840      100  adenosine deaminase        Gene  negatively_regulates_GnrBP
#
#           abbv parent_ixn    db_reference evidence_code source  evidence  \
# 5354839  GprBP        NaN  GO_REF:0000107           IEA     GO  computed
# 5354840  GnrBP        NaN  GO_REF:0000107           IEA     GO  computed
#
#              src_id                                          src_name  \
# 5354839  GO:0002636  positive regulation of germinal center formation
# 5354840  GO:0002686        negative regulation of leukocyte migration
#
#                      rel_type      end_id                   end_name src_src  \
# 5354839  positively_regulates  GO:0002467  germinal center formation      GO
# 5354840  negatively_regulates  GO:0050900        leukocyte migration      GO
#
#         tgt_src           end_label
# 5354839      GO  Biological Process
# 5354840      GO  Biological Process

# %%
reg_edges = reg_edges[combo_cols].drop(['start_name', 'start_label', 'end_name', 'end_label'], axis=1).reset_index(drop=True)
reg_edges.head(2)
# Out:
#   start_id                        type      end_id   abbv parent_ixn  \
# 0      100  positively_regulates_GprBP  GO:0002467  GprBP        NaN
# 1      100  negatively_regulates_GnrBP  GO:0050900  GnrBP        NaN
#
#      db_reference evidence_code source  evidence
# 0  GO_REF:0000107           IEA     GO  computed
# 1  GO_REF:0000107           IEA     GO  computed

# %% [markdown]
# # Putting it all together

# %%
reg_edges.head(2)
# Out:
#   start_id                        type      end_id   abbv parent_ixn  \
# 0      100  positively_regulates_GprBP  GO:0002467  GprBP        NaN
# 1      100  negatively_regulates_GnrBP  GO:0050900  GnrBP        NaN
#
#      db_reference evidence_code source  evidence
# 0  GO_REF:0000107           IEA     GO  computed
# 1  GO_REF:0000107           IEA     GO  computed

# %%
reg_edges['type'].value_counts()
# Out:
# positively_regulates_GprBP     15578
# negatively_regulates_GnrBP     10464
# regulates_GrBP                 10036
# positively_regulates_GprMF      2144
# negatively_regulates_GnrMF      1593
# regulates_PFrBP                  898
# regulates_GrMF                   851
# negatively_regulates_NnrBP       737
# positively_regulates_NprBP       464
# negatively_regulates_PFnrBP      267
# positively_regulates_XprBP       197
# positively_regulates_PFprBP      196
# negatively_regulates_PFnrMF      111
# regulates_XrBP                   109
# positively_regulates_PFprMF       90
# negatively_regulates_XnrBP        63
# regulates_PFrMF                   58
# negatively_regulates_NnrMF        50
# regulates_NrBP                    48
# regulates_PWrBP                   46
# negatively_regulates_RXnrBP       36
# positively_regulates_PWprBP       30
# positively_regulates_XprMF        17
# positively_regulates_RXprBP       16
# regulates_RXrBP                   13
# regulates_XrMF                    12
# positively_regulates_NprMF        12
# negatively_regulates_PWnrBP       11
# negatively_regulates_XnrMF        10
# regulates_PWrMF                    7
# positively_regulates_RXprMF        6
# positively_regulates_PWprMF        3
# negatively_regulates_RXnrMF        2
# regulates_RXrMF                    1
# Name: type, dtype: int64

# %%
print('Total number of new edges: {:,}'.format(len(reg_edges)))
print('Number of unique new edges: {:,}'.format(len(reg_edges.drop_duplicates(subset=['start_id', 'end_id', 'type']))))
# Out:
# Total number of new edges: 44,176
# Number of unique new edges: 43,704

# %% [markdown]
# Why are so many edges duplicated? what kind are they?

# %%
ix = reg_edges.duplicated(keep=False)
reg_edges[ix].sort_values(['start_id', 'end_id', 'type']).head(10)
# Out:
#      start_id                        type      end_id   abbv parent_ixn  \
# 780     10221  negatively_regulates_GnrMF  GO:0004672  GnrMF        NaN
# 781     10221  negatively_regulates_GnrMF  GO:0004672  GnrMF        NaN
# 1940    10681  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 1941    10681  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2322    10928  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2324    10928  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2626    11142  negatively_regulates_GnrMF  GO:0004691  GnrMF        NaN
# 2628    11142  negatively_regulates_GnrMF  GO:0004691  GnrMF        NaN
# 2805     1124  positively_regulates_GprMF  GO:0003924  GprMF        NaN
# 2807     1124  positively_regulates_GprMF  GO:0003924  GprMF        NaN
#
#         db_reference evidence_code source  evidence
# 780    PMID:15299019           IMP     GO   curated
# 781    PMID:15299019           IMP     GO   curated
# 1940   PMID:10521509           IDA     GO   curated
# 1941   PMID:10521509           IDA     GO   curated
# 2322    PMID:7673236       IDA|IBA     GO   curated
# 2324    PMID:7673236       IDA|IBA     GO   curated
# 2626   PMID:21873635           IBA     GO   curated
# 2628   PMID:21873635           IBA     GO   curated
# 2805  GO_REF:0000002           IEA     GO  computed
# 2807  GO_REF:0000002           IEA     GO  computed

# %%
reg_edges[ix]['type'].value_counts()
# Out:
# positively_regulates_GprMF     92
# negatively_regulates_GnrMF     60
# positively_regulates_PFprMF    24
# regulates_GrMF                 10
# negatively_regulates_PFnrMF    10
# negatively_regulates_XnrMF      2
# Name: type, dtype: int64

# %%
dup_types = reg_edges[ix]['type'].unique()

dup_dfs = []

for dt in dup_types:
    dup_dfs.append(reg_edges[ix].query('type == @dt').sort_values(['start_id', 'end_id', 'type']).head(6))
    
pd.concat(dup_dfs)
# Out:
#                  start_id                         type      end_id    abbv  \
# 780                 10221   negatively_regulates_GnrMF  GO:0004672   GnrMF
# 781                 10221   negatively_regulates_GnrMF  GO:0004672   GnrMF
# 2626                11142   negatively_regulates_GnrMF  GO:0004691   GnrMF
# 2628                11142   negatively_regulates_GnrMF  GO:0004691   GnrMF
# 4045               132864   negatively_regulates_GnrMF  GO:0003924   GnrMF
# 4046               132864   negatively_regulates_GnrMF  GO:0003924   GnrMF
# 1940                10681   positively_regulates_GprMF  GO:0003924   GprMF
# 1941                10681   positively_regulates_GprMF  GO:0003924   GprMF
# 2322                10928   positively_regulates_GprMF  GO:0003924   GprMF
# 2324                10928   positively_regulates_GprMF  GO:0003924   GprMF
# 2805                 1124   positively_regulates_GprMF  GO:0003924   GprMF
# 2807                 1124   positively_regulates_GprMF  GO:0003924   GprMF
# 3732               124997               regulates_GrMF  GO:0035004    GrMF
# 3733               124997               regulates_GrMF  GO:0035004    GrMF
# 3933               129138               regulates_GrMF  GO:0004672    GrMF
# 3935               129138               regulates_GrMF  GO:0004672    GrMF
# 6831                 1956               regulates_GrMF  GO:0004517    GrMF
# 6856                 1956               regulates_GrMF  GO:0004517    GrMF
# 41065              CPX-98   negatively_regulates_XnrMF  GO:0008233   XnrMF
# 41066              CPX-98   negatively_regulates_XnrMF  GO:0008233   XnrMF
# 42701  InterPro:IPR003913  positively_regulates_PFprMF  GO:0003924  PFprMF
# 42703  InterPro:IPR003913  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43236  InterPro:IPR026817  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43237  InterPro:IPR026817  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43254  InterPro:IPR027107  positively_regulates_PFprMF  GO:0003924  PFprMF
# 43255  InterPro:IPR027107  positively_regulates_PFprMF  GO:0003924  PFprMF
# 42782  InterPro:IPR007648  negatively_regulates_PFnrMF  GO:0016887  PFnrMF
# 42783  InterPro:IPR007648  negatively_regulates_PFnrMF  GO:0016887  PFnrMF
# 42806  InterPro:IPR008296  negatively_regulates_PFnrMF  GO:0008233  PFnrMF
# 42807  InterPro:IPR008296  negatively_regulates_PFnrMF  GO:0008233  PFnrMF
# 42885  InterPro:IPR010832  negatively_regulates_PFnrMF  GO:0004175  PFnrMF
# 42886  InterPro:IPR010832  negatively_regulates_PFnrMF  GO:0004175  PFnrMF
#
#       parent_ixn    db_reference evidence_code    source  evidence
# 780          NaN   PMID:15299019           IMP        GO   curated
# 781          NaN   PMID:15299019           IMP        GO   curated
# 2626         NaN   PMID:21873635           IBA        GO   curated
# 2628         NaN   PMID:21873635           IBA        GO   curated
# 4045         NaN  GO_REF:0000024           ISS        GO  computed
# 4046         NaN  GO_REF:0000024           ISS        GO  computed
# 1940         NaN   PMID:10521509           IDA        GO   curated
# 1941         NaN   PMID:10521509           IDA        GO   curated
# 2322         NaN    PMID:7673236       IDA|IBA        GO   curated
# 2324         NaN    PMID:7673236       IDA|IBA        GO   curated
# 2805         NaN  GO_REF:0000002           IEA        GO  computed
# 2807         NaN  GO_REF:0000002           IEA        GO  computed
# 3732         NaN   PMID:26783301           IMP        GO   curated
# 3733         NaN   PMID:26783301           IMP        GO   curated
# 3933         NaN   PMID:21873635           IBA        GO   curated
# 3935         NaN   PMID:21873635           IBA        GO   curated
# 6831         NaN   PMID:12828935           IDA        GO   curated
# 6856         NaN   PMID:12828935           IDA        GO   curated
# 41065        NaN   PMID:20860624           IDA        GO   curated
# 41066        NaN   PMID:20860624           IDA        GO   curated
# 42701        NaN             NaN           NaN  InterPro   curated
# 42703        NaN             NaN           NaN  InterPro   curated
# 43236        NaN             NaN           NaN  InterPro   curated
# 43237        NaN             NaN           NaN  InterPro   curated
# 43254        NaN             NaN           NaN  InterPro   curated
# 43255        NaN             NaN           NaN  InterPro   curated
# 42782        NaN             NaN           NaN  InterPro   curated
# 42783        NaN             NaN           NaN  InterPro   curated
# 42806        NaN             NaN           NaN  InterPro   curated
# 42807        NaN             NaN           NaN  InterPro   curated
# 42885        NaN             NaN           NaN  InterPro   curated
# 42886        NaN             NaN           NaN  InterPro   curated

# %% [markdown]
# I see no reason for any of these duplications.... We'll just do a simple 'drop_duplicates' rather than merging any columns

# %%
reg_edges = reg_edges.drop_duplicates(subset=['start_id', 'end_id', 'type']).copy()

# %%
len(reg_edges)
# Out:
# 43704

# %%
all_node_ids = set(all_nodes['id']) 

print(len(reg_edges))
reg_edges_filt = reg_edges.query('start_id in @all_node_ids and end_id in @all_node_ids')
print(len(reg_edges_filt))
# Out:
# 43704
# 43704

# %%
all_edges = pd.concat([edges, reg_edges_filt], sort=False)
all_edges.head(2)
# Out:
#        start_id end_id                       type            parent_ixn  \
# 0  MESH:C000121   4313    decreases_activity_CdaG    decreases^activity
# 1  MESH:C000121   4313  decreases_expression_CdeG  decreases^expression
#
#   pub_med_ids organism_id  abbv source evidence direct_evidence  \
# 0    25899827        9606  CdaG    CTD  curated             NaN
# 1    25899827        9606  CdeG    CTD  curated             NaN
#
#   corrected_pvalue inference_gene_symbol qualifier db_reference evidence_code  \
# 0              NaN                   NaN       NaN          NaN           NaN
# 1              NaN                   NaN       NaN          NaN           NaN
#
#   with_or_from date assigned_by experiments support_type
# 0          NaN  NaN         NaN         NaN          NaN
# 1          NaN  NaN         NaN         NaN          NaN

# %%
all_edge_ids = all_edges[['start_id', 'end_id']].stack()
filt_nodes = all_nodes.query('id in @all_edge_ids')
len(filt_nodes)
# Out:
# 126691

# %% [markdown]
# # Save to Disk

# %%
gt.add_colons(reg_edges).to_csv(out_dir.joinpath('new_edges.csv'), index=False)

# %%
gt.add_colons(all_nodes, id_name='identifier').to_csv(out_dir.joinpath('nodes_all.csv'), index=False)
gt.add_colons(filt_nodes, id_name='identifier').to_csv(out_dir.joinpath('nodes_filt.csv'), index=False)

gt.add_colons(all_edges).to_csv(out_dir.joinpath('edges.csv'), index=False)
